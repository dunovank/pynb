# %%
from __future__ import division
from scipy import stats
from scipy.stats.stats import pearsonr, spearmanr
import scikits.bootstrap as boot
import itertools
os.chdir('/Users/kyle/Dropbox/PFH/iPFH/')
colors=["#0000B8",'#005CE6',"#89a0ff","#990000" ,'#FF1919', "#ea8989"]
clist=[blues[-4], blues[-3], reds[-4], reds[-2]]

# %%
ewma = pd.read_csv("HDDM/Final/allsx_ewma.csv")
allsx = pd.read_csv("fMRI/behav/all_sx.csv")
allcor = pd.read_csv("fMRI/behav/all_sx_cor.csv")

# %%
b=colors[:3]
r=colors[3:]

# %%
sxdf.to_csv("/Users/kyle/Dropbox/PFH/iPFH/idxPARAM/MSM_AllSx_Parameters")
sxdf.to_csv("/Users/kyle/Dropbox/PFH/iPFH/MODELS/MSM_AllSx_Parameters")

# %% [markdown]
# ## Speed Models: Params and Norm Functions

# %%
msm = rhodf.copy()

# %%
os.chdir('/Users/kyle/Dropbox/PFH/iPFH/idxPARAM')

#MSM Model RhoDF (named rho_df in previous notebooks)
msm=pd.read_csv("msm_rho_df.csv", index_col='idx')

#SpeedSimple, Speed, and MSMS models RhoDF
spds=pd.read_csv("speed_simple_rho_df.csv")
spd=pd.read_csv("speed_model_rho_df.csv")
msms=pd.read_csv("msms_rho_df.csv")

# %%
#Normalizing functions for all speed models
spds_norma=lambda x: x/(spds.a-(spds.a * spds.z))
spds_normb=lambda x: x/(spds.a * spds.z)

spd_norma=lambda x: x/(spd.a-(spd.a * spd.avgz))
spd_normb=lambda x: x/(spd.a * spd.avgz)

msms_norma=lambda x: x/(msms.a-(msms.a * msms.zF))
msms_normb=lambda x: x/(msms.a * msms.zH)

# %% [markdown]
# ## WIN, BW, & WSS Peaks for FFA and PPA Regions

# %%
os.chdir('/Users/kyle/Dropbox/PFH/iPFH/idxPK')
#WIN Peaks
wpk_ppa=pd.read_csv("ppa_rho_df.csv", index_col='idx')
wpk_ffa=pd.read_csv("ffa_rho_df.csv", index_col='idx')

#BW Peaks
bpk_ppa=pd.read_csv("ppa_bw_rhodf.csv", index_col='idx')
bpk_ffa=pd.read_csv("ffa_bw_rhodf.csv", index_col='idx')

#WSS Peaks
spk_ppa=pd.read_csv("ppa_wss_rhodf.csv")
spk_ffa=pd.read_csv("ffa_wss_rhodf.csv")

# %% [markdown]
# ## WIN, BW, & WSS timecourses for FFA and PPA Regions

# %%
os.chdir('/Users/kyle/Dropbox/PFH/iPFH/idxTC')

#WIN Timecourses
wtc_ffa = pd.read_csv('WIN_AllSx_FaceClusters.csv')
wtc_ppa = pd.read_csv('WIN_AllSx_HouseClusters.csv')

#BW Timecourses
btc_ffa = pd.read_csv('BW_AllSx_FaceClusters.csv')
btc_ppa = pd.read_csv('BW_AllSx_HouseClusters.csv')

#WSS Timecourses
stc_ffa = pd.read_csv('WSS_AllSx_FaceClusters.csv')
stc_ppa = pd.read_csv('WSS_AllSx_HouseClusters.csv')

# %% [markdown]
# ## Calculate Slope and Regression Functions

# %%
from matplotlib import rc
rc('text', usetex=False)

# %%
def get_slopes(df, start, direction='pos'):
    
    slopes=[]
    
    if 'idx' in df.columns:
        sub_id_string = 'idx'
    elif 'sx' in df.columns:
        sub_id_string = 'sx'
        
    for i, (sx, sxvec) in enumerate(df.groupby(sub_id_string)):
        
        xhigh=np.where(sxvec.values==sxvec[start].values)[1][0]
        yhigh=sxvec[start].values[0]
        
        if direction=='pos':
            xlow=np.where(sxvec.values==sxvec[start].values)[1][0]
            ylow=sxvec[start].values[0]
            xhigh=np.where(sxvec.values==np.max(sxvec.ix[:,start:].values[0][1:]))[1][0]
            yhigh=np.max(sxvec.ix[:,start:].values)

        elif direction=='neg':
            xlow=np.where(sxvec.values==np.min(sxvec.ix[:,start:].values[0][1:]))[1][0]
            ylow=np.min(sxvec.ix[:,start:].values)
            xhigh=np.where(sxvec.values==sxvec[start].values)[1][0]
            yhigh=sxvec[start].values[0]
        
        else: 
            print "direction must be string, 'pos' or 'neg'"
            return []
        
        slopes.append((yhigh-ylow)/(xhigh-xlow))
    return np.array(slopes)    

def corrplots(x, y, brain, param, stim, cond, test='pearson', start='1', direct='pos', normalize=False, calc_slope=True):
    
    conditions = [' '.join(stimcond) for stimcond in itertools.product(stim, cond)]
    clist=[blues[-4], blues[-3], reds[-4], reds[-2]]
    f, (ax1, ax2) = plt.subplots(1,2, figsize=(9,6), sharey=True, sharex=True)

    for i, (xi, yi) in enumerate(zip(x, y)):

        if i <= 1:
            ax=ax1
        else: 
            ax=ax2

        if calc_slope:
            yi = get_slopes(yi, start, direction=direct)
        
        if normalize:
            xi = (xi - xi.mean())/xi.std()
            yi = (yi - yi.mean())/yi.std()
            
        plot_regression(xi, yi, robust=False, color=clist[::-1][i], ax=ax, cond=conditions[i], test=test)

    for i, ax in enumerate([ax1, ax2]):
        ax.legend(loc=2, fontsize=13)
        ax.set_xlabel(param, fontsize=18)
        #ax.set_title(stim[i])
    ax1.set_ylabel(brain, fontsize=18)
    plt.tight_layout()
    
    return f
    
def plot_regression(x, y, robust=True, color='Navy', cond=None, title=None, test='pearson', ax=None):
    
    if ax is None:
        f, ax = plt.subplots(1)

    if test == 'ci':
        cis = boot.ci((x, y), statfunction=stats.linregress, alpha=.05, method='bca')[:,2]
        legend = '$\/CI_{95%s}[%.2f, %.2f]$' % ('\%', cis[0], cis[1])
    elif test in ['pearson', 'spearman']:
        if test=='pearson':       
            rho, pval = pearsonr(x, y)
            rho_id =';\/r_{p}='
        elif test=='spearman':  
            rho, pval = spearmanr(x, y) 
            rho_id =';\/r_{s}='
        if pval<=.05: sym = '\star'   
        #elif pval<=.1: sym = '\dagger'
        else: sym = 'n.s.'
        legend =r'$%s%.2f%s$' % (rho_id, rho, sym)
    else:
        raise ValueError('test must be ci, pearson, or spearman')
        
    if cond:
        legend = cond + legend

    sns.regplot(x, y, robust=robust, fit_reg=True, line_kws={"color":color, 'lw':2, 'label':legend}, 
                scatter_kws={'color':color, 'alpha':.6}, ax=ax)
    sns.despine()
    plt.tight_layout()

# %%
brain = ['PPA Slope', 'FFA Slope']
param = 'Drift-Rate'
stim = ['House','Face']
cond = ['Valid', 'Invalid']

x=[msm.vHH_n_zH2b.values, msm.vFH_n_zF2b.values, 
   msm.vFF_n_zH2b.values, msm.vHF_n_zF2b.values]

ppay=[wtc_ppa.query('cond=="hchouse"'), wtc_ppa.query('cond=="fchouse"'), 
   wtc_ppa.query('cond=="fcface"'), wtc_ppa.query('cond=="hcface"')]

ffay=[wtc_ffa.query('cond=="hchouse"'), wtc_ffa.query('cond=="fchouse"'), 
   wtc_ffa.query('cond=="fcface"'), wtc_ffa.query('cond=="hcface"')]

for i, data in enumerate([ppay, ffay]):
    region=brain[i]
    f = corrplots(x, data, region, param, stim, cond, direct='pos', start='1', 
                  normalize=True, test='pearson', calc_slope=True)
    
    txt = f.suptitle('$WIN\/GLM:\/%s\/Slope\/and\/Valid/Invalid\/Drift-Rates$' % brain[i][:3], y=.92, fontsize=18)
    plt.subplots_adjust(top=.86)
    f.savefig('/Users/kyle/Desktop/WIN_SlopeDrift_%s.png' % brain[i], dpi=300)
# Out:
# <img src='...
# <img src='...

# %%
brain = ['PPA Slope', 'FFA Slope']
param = 'Drift-Rate'
stim = ['House','Face']
cond = ['Fast', 'Slow']

x=[spds_normb(spds.vHFast.values), spds_normb(spds.vHSlow.values), 
   spds_norma(spds.vFFast.values), spds_norma(spds.vFSlow.values)]

ppay=[stc_ppa.query('cond=="HFast"'), stc_ppa.query('cond=="HSlow"'), 
   stc_ppa.query('cond=="FFast"'), stc_ppa.query('cond=="FSlow"')]
ffay=[stc_ffa.query('cond=="HFast"'), stc_ffa.query('cond=="HSlow"'), 
   stc_ffa.query('cond=="FFast"'), stc_ffa.query('cond=="FSlow"')]

for i, data in enumerate([ppay, ffay]):
    region=brain[i]
    f = corrplots(x, data, region, param, stim, cond, start='1', 
                  test='pearson', normalize=True, calc_slope=True)
    
    txt = f.suptitle('$WSS/GLM:\/%s\/Slope\/and\/Fast/Slow\/Drift-Rates$' % brain[i][:3], y=.92, fontsize=18)
    plt.subplots_adjust(top=.86)
    #f.savefig('/Users/kyle/Desktop/WSS_SlopeDrift_%s.png' % brain[i], dpi=300)
# Out:
# <img src='...
# <img src='...

# %%
brain = ['PPA Slope', 'FFA Slope']
param = 'Drift-Rate'
stim = ['House','Face']
cond = ['Fast', 'Slow']

x=[spd_normb(spd.vHFast.values), spd_normb(spd.vHSlow.values), 
   spd_norma(spd.vFFast.values), spd_norma(spd.vFSlow.values)]

ppay=[stc_ppa.query('cond=="HFast"'), stc_ppa.query('cond=="HSlow"'), 
   stc_ppa.query('cond=="FFast"'), stc_ppa.query('cond=="FSlow"')]
ffay=[stc_ffa.query('cond=="HFast"'), stc_ffa.query('cond=="HSlow"'), 
   stc_ffa.query('cond=="FFast"'), stc_ffa.query('cond=="FSlow"')]

for i, data in enumerate([ppay, ffay]):
    region=brain[i]
    f = corrplots(x, data, region, param, stim, cond, start='1', 
                  test='pearson', normalize=True, calc_slope=True)
    
    txt = f.suptitle('$WSS/GLM:\/%s\/Slope\/and\/Fast/Slow\/Drift-Rates$' % brain[i][:3], y=.92, fontsize=18)
    plt.subplots_adjust(top=.86)
    #f.savefig('/Users/kyle/Desktop/WSS_SlopeDrift_%s.png' % brain[i], dpi=300)
# Out:
# <img src='...
# <img src='...

# %%
brain = 'FFA: Stim - Cue'
param = 'Distance to Threshold'
stim = ['House','Face']
cond = ['Valid', 'Invalid']

x=[msm.zH2b.values, msm.zF2b.values, 
   msm.zF2a.values, msm.zH2a.values]

data=[wpk_ffa["hc-hcH"], wpk_ffa["fc-fcH"], 
    wpk_ffa["fc-fcF"],wpk_ffa["hc-hcF"]]

#for data in ffay:
f = corrplots(x, data, brain, param, stim, cond, 
              normalize=True, test='pearson', calc_slope=False)

f.suptitle('$WIN\/GLM:\/\Delta_{CueStim}\/\/and\/\/\Delta_{Bound}$', y=.92, fontsize=18)
plt.subplots_adjust(top=.86)
f.savefig('/Users/kyle/Desktop/WIN_FFA_DeltaCueStim_DeltaThreshold.png', dpi=300)
# Out:
# <img src='...

# %%
brain = 'FFA: Stim - Cue'
param = 'Distance to Threshold'
stim = ['House','Face']
cond = ['Valid', 'Invalid']

x=[msm.zH2b.values, msm.zF2b.values, 
   msm.zF2a.values, msm.zH2a.values]

data=[bpk_ffa["hc-hcH"], bpk_ffa["fc-fcH"], 
    bpk_ffa["fc-fcF"],bpk_ffa["hc-hcF"]]

#for data in ffay:
f = corrplots(x, data, brain, param, stim, cond, 
              normalize=True, test='pearson', calc_slope=False)

f.suptitle('$BW\/GLM:\/\Delta_{CueStim}\/\/and\/\/\Delta_{Bound}$', y=.92, fontsize=18)
plt.subplots_adjust(top=.86)
f.savefig('/Users/kyle/Desktop/BW_FFA_DeltaCueStim_DeltaThreshold.png', dpi=300)
# Out:
# <img src='...

# %%
cdf = stc_ppa[stc_ppa.cond.isin(['hc','fc','nc'])]
sdf = stc_ppa[~stc_ppa.cond.isin(['hc','fc','nc'])]
sxcue = cdf.groupby('sx').mean().reset_index()
#cdf.rename(columns={'sx':'cond'}, inplace=True)
sxcue['cond'] = 'cue'

#stc_ppa.append(sxcue, ignore_index=True)
#stc_ppa[stc_ppa.cond.isin(['hc','fc','nc'])]

# %%
for spk in [spk_ffa, spk_ppa]:
    spk['cue']=[spk['hc'], spk['nc'], spk['fc']], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-7da3b2a9a490> in <module>()
#       1 for spk in [spk_ffa, spk_ppa]:
# ----> 2     spk['cue']=np.mean([[spk['hc'], spk['nc'], spk['fc']]], axis=1)
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2108         else:
#    2109             # set column
# -> 2110             self._set_item(key, value)
#    2111
#    2112     def _setitem_slice(self, key, value):
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2185
#    2186         self._ensure_valid_index(value)
# -> 2187         value = self._sanitize_column(key, value)
#    2188         NDFrame._set_item(self, key, value)
#    2189
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value)
#    2258         elif (isinstance(value, Index) or is_sequence(value)):
#    2259             from pandas.core.series import _sanitize_index
# -> 2260             value = _sanitize_index(value, self.index, copy=False)
#    2261             if not isinstance(value, (np.ndarray, Index)):
#    2262                 if isinstance(value, list) and len(value) > 0:
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_index(data, index, copy)
#    2543
#    2544     if len(data) != len(index):
# -> 2545         raise ValueError('Length of values does not match length of '
#    2546                          'index')
#    2547
#
# ValueError: Length of values does not match length of index

# %%
spk_ppa
# Out:
#     idx      hc      nc      fc   fFast   hFast   fSlow   hSlow     cue
# 0     8  0.0553  0.0658  0.0598  0.0567  0.2241  0.1012  0.3114  0.0692
# 1    10  0.0134  0.0060 -0.0093  0.0498  0.0648  0.0525  0.1228  0.0692
# 2    11  0.0636  0.0692  0.0616  0.0750  0.2423  0.0528  0.2031  0.0692
# 3    13  0.1136  0.1114  0.1014 -0.0216  0.2395  0.1157  0.1354  0.0692
# 4    15  0.1382  0.0806  0.1636  0.0223  0.2646  0.0674  0.3161  0.0692
# 5    16  0.0523  0.0610  0.0864  0.0292  0.2242  0.1079  0.3641  0.0692
# 6    17  0.0548  0.0546  0.0611  0.1204  0.0767  0.0520  0.1748  0.0692
# 7    18  0.0677  0.0679  0.0761  0.0640  0.2094 -0.0031  0.2106  0.0692
# 8    19  0.0360  0.0648  0.0845  0.1058  0.2297  0.1390  0.2208  0.0692
# 9    20  0.0344  0.0203  0.0485  0.0925  0.1576  0.1076  0.1410  0.0692
# 10   21  0.1224  0.0951  0.1139  0.1467  0.3400  0.1237  0.4231  0.0692
# 11   22  0.0491  0.0219  0.0059  0.1353  0.3102  0.1190  0.1445  0.0692
# 12   23  0.1035  0.1590  0.0850  0.0588  0.2634  0.0738  0.1841  0.0692
# 13   24  0.0866  0.1214  0.0846  0.0796  0.1441  0.1516  0.1075  0.0692
# 14   26  0.0346  0.0638  0.0322  0.0960  0.1761  0.0698  0.1327  0.0692
# 15   27  0.1119  0.1129  0.0714  0.1004  0.3678  0.1016  0.1564  0.0692
# 16   29  0.0877  0.0731  0.0779  0.0743  0.0440  0.1067  0.0685  0.0692
# 17   30  0.0442  0.0418  0.0615  0.0649  0.2760  0.0407  0.2460  0.0692
# 18   31  0.0896  0.0026  0.0268  0.0892  0.1527  0.0305  0.1447  0.0692

# %%
ppanew = pd.concat([sdf, sxcue])
ppanew.sort('sx')
# Out:
#           1      10      11      12       2       3       4       5       6  \
# 3    0.0259  0.0120 -0.0038 -0.0056 -0.0056  0.0567 -0.0352 -0.0165 -0.0435
# 0   -0.0069 -0.0042 -0.0056 -0.0056  0.0224 -0.0086  0.0603 -0.0071  0.0151
# 6    0.0265  0.0445  0.0202  0.0377 -0.0328  0.1974  0.3114  0.2817  0.1984
# 5    0.0616 -0.0254  0.0142  0.0456 -0.0050  0.0964  0.1012  0.0841 -0.0130
# 4   -0.0231 -0.0221  0.0179  0.0050 -0.0469  0.2241  0.2129  0.1710  0.0796
# 11   0.0251 -0.0197  0.0112 -0.0312 -0.0462 -0.0434  0.0340  0.0648  0.0242
# 12  -0.0270  0.0236  0.0356  0.0515  0.0525  0.0399  0.0112 -0.0201 -0.0242
# 13  -0.0281  0.0068 -0.0054 -0.0399 -0.0467 -0.0390  0.0569  0.0983  0.1228
# 1   -0.0046 -0.0326 -0.0546 -0.0244 -0.0108 -0.0425 -0.0354 -0.0399 -0.0412
# 10   0.0149  0.0300  0.0143 -0.0038  0.0498 -0.0111 -0.0105 -0.0972 -0.0952
# 19   0.0528  0.0370  0.0126  0.0105 -0.0151  0.0492 -0.0711 -0.0473 -0.0852
# 20  -0.0393  0.0024  0.0651 -0.0193  0.0392 -0.0081 -0.0004  0.1340  0.2031
# 2    0.0321  0.0635  0.0284  0.0227  0.0319 -0.0100 -0.0254 -0.0252  0.0255
# 17   0.0060  0.0750 -0.0381  0.0015  0.0425 -0.0377 -0.0550 -0.0208 -0.0144
# 18   0.0856 -0.0001  0.0012 -0.0209 -0.0104  0.0545  0.2423  0.2288  0.1366
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 115 -0.0183  0.0432  0.0649  0.0010 -0.0320  0.0297 -0.1142 -0.2483 -0.3126
# 118  0.0197 -0.0712  0.0026  0.0198  0.0442  0.0685  0.0376  0.0511  0.0301
# 16   0.0436  0.0064  0.0416  0.0634  0.0606  0.0519 -0.0291 -0.0802 -0.0380
# 117  0.0897 -0.0275  0.0877  0.1061  0.1067  0.0689  0.0342 -0.0991 -0.2118
# 116 -0.0734  0.0218  0.0345  0.0440 -0.0554 -0.0402 -0.0006 -0.0391 -0.0520
# 124 -0.0040  0.0025 -0.0100  0.0161  0.0169  0.0407 -0.0174 -0.0072 -0.1145
# 122  0.0023  0.0396 -0.0313 -0.0099  0.0168  0.0280  0.0649 -0.0679 -0.2066
# 125 -0.0182  0.0200  0.0206  0.0113  0.0242  0.0424  0.0075  0.1548  0.2460
# 17   0.0009 -0.0171 -0.0329 -0.0331 -0.0063 -0.0076 -0.0255 -0.0756 -0.0772
# 123  0.0003  0.0626  0.0212  0.0103 -0.0034  0.0405  0.1284  0.2760  0.1218
# 131 -0.0006 -0.0091  0.0113  0.0305 -0.0257 -0.0782 -0.0621 -0.1362 -0.0436
# 18   0.0152 -0.0298 -0.0676 -0.0285 -0.0333 -0.0429 -0.0175 -0.0421 -0.0450
# 129  0.0346  0.0833  0.0665  0.0258 -0.0320  0.0017 -0.0481 -0.0688  0.0229
# 130  0.0232 -0.0223  0.0446  0.0188 -0.0276 -0.0774  0.0426  0.1527  0.1359
# 132  0.0146 -0.0434 -0.0245 -0.0306 -0.0196 -0.0229 -0.0558 -0.0109  0.1447
#
#           7       8       9   cond   sx
# 3    0.0033 -0.0207  0.0106  FFast  s08
# 0   -0.0084 -0.0127  0.0267    cue  s08
# 6    0.0346  0.0281  0.0156  HSlow  s08
# 5   -0.0232 -0.0200  0.0040  FSlow  s08
# 4   -0.0079 -0.0175 -0.0093  HFast  s08
# 11   0.0400  0.0468  0.0250  HFast  s10
# 12  -0.0576 -0.0499 -0.0029  FSlow  s10
# 13   0.0153  0.0051  0.0491  HSlow  s10
# 1   -0.0582 -0.0788 -0.0410    cue  s10
# 10  -0.0561  0.0067  0.0426  FFast  s10
# 19  -0.0575 -0.0328 -0.0578  FSlow  s11
# 20   0.1026 -0.0005  0.0491  HSlow  s11
# 2    0.0451  0.0193  0.0028    cue  s11
# 17  -0.0796 -0.0297  0.0230  FFast  s11
# 18   0.0307  0.0096 -0.0034  HFast  s11
# ..      ...     ...     ...    ...  ...
# 115 -0.1770 -0.0560  0.0743  FFast  s29
# 118 -0.0090 -0.0367 -0.1010  HSlow  s29
# 16  -0.0364 -0.0333 -0.0250    cue  s29
# 117 -0.2678 -0.1637 -0.1205  FSlow  s29
# 116 -0.0506 -0.0986 -0.0045  HFast  s29
# 124 -0.0964 -0.0729 -0.0313  FSlow  s30
# 122 -0.1356  0.0195  0.0627  FFast  s30
# 125  0.1634  0.0173 -0.0077  HSlow  s30
# 17  -0.0020  0.0492  0.0063    cue  s30
# 123  0.0213 -0.0030  0.0462  HFast  s30
# 131 -0.1391 -0.0163  0.0296  FSlow  s31
# 18   0.0028 -0.0291  0.0174    cue  s31
# 129 -0.0005  0.0704  0.0892  FFast  s31
# 130  0.0432  0.0031  0.0636  HFast  s31
# 132  0.1192  0.0538  0.0881  HSlow  s31
#
# [95 rows x 14 columns]

# %%
for df in [stc_ppa, stc_ffa]:
    df['cue'] = np.mean()
# Out:
#       cond   sx       1       2       3       4       5       6       7  \
# 0       hc  s08 -0.0210 -0.0063 -0.0081  0.0553 -0.0069  0.0055  0.0073
# 1       nc  s08  0.0009  0.0447  0.0001  0.0658 -0.0157  0.0111 -0.0270
# 2       fc  s08 -0.0005  0.0288 -0.0178  0.0598  0.0015  0.0288 -0.0055
# 3    FFast  s08  0.0259 -0.0056  0.0567 -0.0352 -0.0165 -0.0435  0.0033
# 4    HFast  s08 -0.0231 -0.0469  0.2241  0.2129  0.1710  0.0796 -0.0079
# 5    FSlow  s08  0.0616 -0.0050  0.0964  0.1012  0.0841 -0.0130 -0.0232
# 6    HSlow  s08  0.0265 -0.0328  0.1974  0.3114  0.2817  0.1984  0.0346
# 7       hc  s10  0.0134 -0.0002 -0.0145 -0.0264 -0.0266 -0.0305 -0.0774
# 8       nc  s10  0.0007  0.0060 -0.0647 -0.0225 -0.0048 -0.0383 -0.0367
# 9       fc  s10 -0.0278 -0.0381 -0.0483 -0.0573 -0.0884 -0.0549 -0.0604
# 10   FFast  s10  0.0149  0.0498 -0.0111 -0.0105 -0.0972 -0.0952 -0.0561
# 11   HFast  s10  0.0251 -0.0462 -0.0434  0.0340  0.0648  0.0242  0.0400
# 12   FSlow  s10 -0.0270  0.0525  0.0399  0.0112 -0.0201 -0.0242 -0.0576
# 13   HSlow  s10 -0.0281 -0.0467 -0.0390  0.0569  0.0983  0.1228  0.0153
# 14      hc  s11  0.0389  0.0285 -0.0069 -0.0477 -0.0155 -0.0030  0.0224
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 118  HSlow  s29  0.0197  0.0442  0.0685  0.0376  0.0511  0.0301 -0.0090
# 119     hc  s30  0.0064 -0.0150  0.0010 -0.0173 -0.0786 -0.0724  0.0009
# 120     nc  s30 -0.0096 -0.0041 -0.0229 -0.0276 -0.0815 -0.0782 -0.0019
# 121     fc  s30  0.0058  0.0002 -0.0010 -0.0317 -0.0668 -0.0809 -0.0050
# 122  FFast  s30  0.0023  0.0168  0.0280  0.0649 -0.0679 -0.2066 -0.1356
# 123  HFast  s30  0.0003 -0.0034  0.0405  0.1284  0.2760  0.1218  0.0213
# 124  FSlow  s30 -0.0040  0.0169  0.0407 -0.0174 -0.0072 -0.1145 -0.0964
# 125  HSlow  s30 -0.0182  0.0242  0.0424  0.0075  0.1548  0.2460  0.1634
# 126     hc  s31  0.0896 -0.0388 -0.0270 -0.0575 -0.0124 -0.0141  0.0224
# 127     nc  s31 -0.0255 -0.0423 -0.0421 -0.0151 -0.0862 -0.0188 -0.0102
# 128     fc  s31 -0.0186 -0.0187 -0.0595  0.0201 -0.0277 -0.1022 -0.0039
# 129  FFast  s31  0.0346 -0.0320  0.0017 -0.0481 -0.0688  0.0229 -0.0005
# 130  HFast  s31  0.0232 -0.0276 -0.0774  0.0426  0.1527  0.1359  0.0432
# 131  FSlow  s31 -0.0006 -0.0257 -0.0782 -0.0621 -0.1362 -0.0436 -0.1391
# 132  HSlow  s31  0.0146 -0.0196 -0.0229 -0.0558 -0.0109  0.1447  0.1192
#
#           8       9      10      11      12
# 0   -0.0363  0.0348 -0.0152 -0.0139 -0.0144
# 1   -0.0042  0.0140 -0.0004  0.0020 -0.0047
# 2    0.0026  0.0311  0.0031 -0.0049  0.0024
# 3   -0.0207  0.0106  0.0120 -0.0038 -0.0056
# 4   -0.0175 -0.0093 -0.0221  0.0179  0.0050
# 5   -0.0200  0.0040 -0.0254  0.0142  0.0456
# 6    0.0281  0.0156  0.0445  0.0202  0.0377
# 7   -0.0650 -0.0604 -0.0498 -0.0875 -0.0627
# 8   -0.0715 -0.0267 -0.0387 -0.0396  0.0026
# 9   -0.0999 -0.0359 -0.0093 -0.0366 -0.0130
# 10   0.0067  0.0426  0.0300  0.0143 -0.0038
# 11   0.0468  0.0250 -0.0197  0.0112 -0.0312
# 12  -0.0499 -0.0029  0.0236  0.0356  0.0515
# 13   0.0051  0.0491  0.0068 -0.0054 -0.0399
# 14   0.0101 -0.0358  0.0636  0.0216  0.0252
# ..      ...     ...     ...     ...     ...
# 118 -0.0367 -0.1010 -0.0712  0.0026  0.0198
# 119  0.0442 -0.0084 -0.0129 -0.0365 -0.0406
# 120  0.0418  0.0117 -0.0161 -0.0424 -0.0343
# 121  0.0615  0.0156 -0.0222 -0.0196 -0.0244
# 122  0.0195  0.0627  0.0396 -0.0313 -0.0099
# 123 -0.0030  0.0462  0.0626  0.0212  0.0103
# 124 -0.0729 -0.0313  0.0025 -0.0100  0.0161
# 125  0.0173 -0.0077  0.0200  0.0206  0.0113
# 126  0.0143  0.0405 -0.0224 -0.0353  0.0038
# 127 -0.0547 -0.0152  0.0026 -0.0983 -0.0363
# 128 -0.0469  0.0268 -0.0694 -0.0693 -0.0528
# 129  0.0704  0.0892  0.0833  0.0665  0.0258
# 130  0.0031  0.0636 -0.0223  0.0446  0.0188
# 131 -0.0163  0.0296 -0.0091  0.0113  0.0305
# 132  0.0538  0.0881 -0.0434 -0.0245 -0.0306
#
# [133 rows x 14 columns]

# %%
brain = ['PPA Peak - Cue', 'FFA Peak - Cue']
param = 'Drift-Rate'
stim = ['House','Face']
cond = ['Fast', 'Slow']

x=[spd_normb(spd.vHFast.values), spd_normb(spd.vHSlow.values), 
   spd_norma(spd.vFFast.values), spd_norma(spd.vFSlow.values)]

ppay=[stc_ppa.query('cond=="HFast"'), stc_ppa.query('cond=="HSlow"'), 
   stc_ppa.query('cond=="FFast"'), stc_ppa.query('cond=="FSlow"')]
ffay=[stc_ffa.query('cond=="HFast"'), stc_ffa.query('cond=="HSlow"'), 
   stc_ffa.query('cond=="FFast"'), stc_ffa.query('cond=="FSlow"')]

for i, data in enumerate([ppay, ffay]):
    region=brain[i]
    f = corrplots(x, data, region, param, stim, cond, start='1', 
                  test='pearson', normalize=True, calc_slope=True)
    
    txt = f.suptitle('$WSS/GLM:\/%s\/Slope\/and\/Fast/Slow\/Drift-Rates$' % brain[i][:3], y=.92, fontsize=18)
    plt.subplots_adjust(top=.86)
    #f.savefig('/Users/kyle/Desktop/WSS_SlopeDrift_%s.png' % brain[i], dpi=300)

# %%
spds['z2a']=spd['a']-(spd['z']*spd['a'])
spds['z2b']=spd['z']*spd['a']
spds['vFFast_n_z2a']=spd['vFFast']/spd['z2a']
spds['vHFast_n_z2b']=spd['vHFast']/spd['z2b']
spds['vFSlow_n_z2a']=spd['vFSlow']/spd['z2a']
spds['vHSlow_n_z2b']=spd['vHSlow']/spd['z2b']

# %%
spd['avgz']=np.array([ 0.58806424,  0.58886978,  0.59901976,  0.65960359,  0.69008232,
        0.6407637 ,  0.64188813,  0.66934457,  0.65173494,  0.62666071,
        0.54893321,  0.45613744,  0.67907129,  0.63864626,  0.58237093,
        0.70798236,  0.67800684,  0.66896503,  0.71004195])
