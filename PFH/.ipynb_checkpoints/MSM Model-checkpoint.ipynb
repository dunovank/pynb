# %%
import hddm
import pandas as pd
import kabuki

# %%
#MSM
# %cd /home/kyle/Dropbox/PFH/iPFH/HDDM/Final/msm
# Out:
# /home/kyle/Dropbox/PFH/iPFH/HDDM/Final/msm

# %%
#start commands
data=pd.read_csv("/home/kyle/Dropbox/PFH/iPFH/HDDM/Final/allsx_ewma.csv")
models = []
for i in range(1,3):
    msm = hddm.HDDM(data, depends_on={'v':['stim', 'cue'], 'z':'cue'},  bias=True, informative=False, include=['v', 'z', 't', 'a', 'sv', 'sz', 'st'])
    msm.sample(5000, burn=1000, dbname="msm_traces"+str(i)+".db", db='pickle')
    msm.print_stats("stats"+str(i)+".txt")
    models.append(msm)
allmodels = kabuki.utils.concat_models(models)
allmodels.plot_posteriors(save=True)
allmodels.print_stats("combined_model_stats.txt")
# Out:
#  [                  0%                  ] 2 of 5000 complete in 8.4 sec
#  [                  0%                  ] 3 of 5000 complete in 15.6 sec
#  [                  0%                  ] 4 of 5000 complete in 21.6 sec
#  [                  0%                  ] 5 of 5000 complete in 26.0 sec
#  [                  0%                  ] 6 of 5000 complete in 30.8 sec
#  [                  0%                  ] 7 of 5000 complete in 35.3 sec
#  [                  0%                  ] 8 of 5000 complete in 40.4 sec
#  [                  0%                  ] 9 of 5000 complete in 45.2 sec
#  [                  0%                  ] 10 of 5000 complete in 49.8 sec
#  [                  0%                  ] 11 of 5000 complete in 54.6 sec
#  [                  0%                  ] 12 of 5000 complete in 58.7 sec
#  [                  0%                  ] 13 of 5000 complete in 64.9 sec
#  [                  0%                  ] 14 of 5000 complete in 70.5 sec
# ...

# %%
allmodels.dic
# Out:
# 26656.236740652803

# %%
kabuki.analyze.gelman_rubin(models)
# Out:
# {'a': 0.99990224525961491,
#  'a_std': 0.99975088236260135,
#  'a_subj.10': 0.99999702076663588,
#  'a_subj.11': 1.0013701734589679,
#  'a_subj.13': 1.0023164301238512,
#  'a_subj.15': 1.0005092119511056,
#  'a_subj.16': 1.0064944880179438,
#  'a_subj.17': 1.0009274194504563,
#  'a_subj.18': 0.99976940860807983,
#  'a_subj.19': 0.99977813495450518,
#  'a_subj.20': 1.0001470209416712,
#  'a_subj.21': 1.0003260666803613,
#  'a_subj.22': 1.0008594338603121,
#  'a_subj.23': 1.0035089438365326,
#  'a_subj.24': 0.99993281388605659,
#  'a_subj.25': 1.0016809920147092,
#  'a_subj.26': 1.0002437199968384,
#  'a_subj.27': 0.99986974848945198,
#  'a_subj.28': 1.0081040538149462,
#  'a_subj.29': 0.99978459929612751,
#  'a_subj.30': 1.0048692355249333,
#  'a_subj.31': 0.99975537257511471,
#  'a_subj.8': 1.0004692916833018,
#  'st': 1.0169818111359514,
#  'sv': 1.0061654363234918,
#  'sz': 0.99983238972428679,
#  't': 0.99984314783746453,
#  't_std': 0.99978244462506105,
# ...
