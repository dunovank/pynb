# %%
import hddm
import pandas as pd
import kabuki

# %%
#DBMz
# %cd /home/kyle/Dropbox/PFH/iPFH/HDDM/Final/dbmz_info
# Out:
# /home/kyle/Dropbox/PFH/iPFH/HDDM/Final/dbmz_info

# %%
#start commands
data=pd.read_csv("/home/kyle/Dropbox/PFH/iPFH/HDDM/Final/allsx_ewma.csv")
params=['v', 'z', 't', 'a', 'sv', 'sz', 'st']
models = []
for i in range(3):
    
    dbmz = hddm.HDDM(data, depends_on={'v':['stim', 'cue']},  bias=True, include=params)
    dbmz.sample(5000, burn=1000, dbname="dbmz_traces"+str(i)+".db", db='pickle')
    dbmz.print_stats("stats"+str(i)+".txt")
    models.append(dbmz)
    
allmodels = kabuki.utils.concat_models(models)
allmodels.plot_posteriors(save=True)
allmodels.print_stats("combined_model_stats.txt")
# Out:
#  [                  0%                  ] 2 of 5000 complete in 5.6 sec
#  [                  0%                  ] 3 of 5000 complete in 11.7 sec
#  [                  0%                  ] 4 of 5000 complete in 18.5 sec
#  [                  0%                  ] 5 of 5000 complete in 24.3 sec
#  [                  0%                  ] 6 of 5000 complete in 29.4 sec
#  [                  0%                  ] 7 of 5000 complete in 35.1 sec
#  [                  0%                  ] 8 of 5000 complete in 41.0 sec
#  [                  0%                  ] 9 of 5000 complete in 46.6 sec
#  [                  0%                  ] 10 of 5000 complete in 52.8 sec
#  [                  0%                  ] 11 of 5000 complete in 60.0 sec
#  [                  0%                  ] 12 of 5000 complete in 66.8 sec
#  [                  0%                  ] 13 of 5000 complete in 74.2 sec
#  [                  0%                  ] 14 of 5000 complete in 79.7 sec
# ...

# %%
allmodels.dic
# Out:
# 26655.273470007178

# %%
gr=kabuki.analyze.gelman_rubin(models)

# %%
grdf=pd.DataFrame.from_dict(gr, orient='index')
grdf.rename(columns={0:'GelmanRubin'}, inplace=True)
grdf.to_csv('gelman_rubin.csv')

# %%
allmodels.save('dbmz_info')
