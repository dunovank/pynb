# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from radd import build, fit, vis

# %% [markdown]
# ## Prepare Data/Params

# %%
data = redf_store['redata']
binits = { k: v for k, v in redf_store['rebsl_boot_popt'].items() }
binits['ssv'] = -abs(binits['ssv'])
pinits = { k: v for k, v in redf_store['repnl_boot_popt'].items() }

avg_inits = { k: np.mean([binits[k], pinits[k]]) for k in binits.keys() }
if 'ssd' in avg_inits.keys(): del avg_inits['ssd']

# %% [markdown]
# ##Reactive

# %%
dirpath = pth+'ELife/Fits/ReTR_New'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = redf_store['redata']
inits = dict(deepcopy(avg_inits))

# %%
m = build.Model(data=data, inits=inits, kind='radd', fit_on='average', depends_on={'tr':'Cond'})
# Out:
#       Model is prepared to fit on average radd data, allowing
#       Onset Time to vary across levels of Cond (bsl, pnl)
#
#       See, it's not that simplex...

# %%
m.fitinfo
# Out:
# {'AIC': -241.1755658444948,
#  'BIC': -238.24409403889535,
#  'CNVRG': True,
#  'a': 0.44421009923694654,
#  'chi': 0.014114691820665963,
#  'nfev': 79,
#  'rchi': 0.00047048972735553207,
#  'ssv': -0.95191097195006291,
#  'tr_bsl': 0.30277831216809059,
#  'tr_pnl': 0.31042024589202266,
#  'v': 1.0959327627627728,
#  'z': 0.15413634124041575}

# %%
m.optimize(ntrials=10000, ftol=1.e-6, xtol=1.e-6, maxfev=5000)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.005940
#          Iterations: 63
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 0.013792
#          Iterations: 32
#          Function evaluations: 79

# %%
fits = m.fits.reshape(2, 16)
for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], fits[i], plot_acc=True, save=True, savestr ='fits_'+m.labels[i])
# Out:
# <img src='...
