# %%
from radd import CORE, models, fit, vis, build

# %%
# %mkdir /home/kyle/Dropbox/pro_idx_a_fits
# %cd ~/Dropbox/pro_idx_a_fits
# Out:
# /home/kyle/Dropbox/pro_idx_a_fits

# %%
data = prodf_store.prodata
m=build.Model(data=data, kind='xpro', fit_on='subjects', dynamic='exp', depends_on={'a':'pGo'})
# Out:
#       Model is prepared to fit xpro model (w/ exp dynamic bias) to subjects data,
#       allowing Boundary Height to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       It'll probably work this time

# %%
df = pd.read_csv('fits.csv', index_col=0)

# %%
m.optimize()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000073
#          Iterations: 401
#          Function evaluations: 1048
# ...
# Optimization terminated successfully.
#          Current function value: 0.000132
#          Iterations: 188
#          Function evaluations: 476
# ...
# Optimization terminated successfully.
#          Current function value: 10.578190
#          Iterations: 1182
#          Function evaluations: 3255
# Optimization terminated successfully.
#          Current function value: 0.000085
#          Iterations: 170
#          Function evaluations: 446
# ...
# Optimization terminated successfully.
#          Current function value: 0.800476
#          Iterations: 209
#          Function evaluations: 557
# Optimization terminated successfully.
#          Current function value: 11.193076
#          Iterations: 235
#          Function evaluations: 654
# Optimization terminated successfully.
#          Current function value: 0.000106
# ...
