# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %% [markdown]
# ## Prepare Data/Params

# %% [markdown]
# ##Reactive

# %%
inits
# Out:
# {'a': 0.39267407430266699,
#  'ssv': 1.1243079023153335,
#  'tr': 0.3350242252393334,
#  'v': 1.0379202050853333,
#  'z': 0.15001755257066671}

# %%
dirpath = pth+'ELife/IRM_V_Avg/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = redf_store.redata
inits = dict(deepcopy(redf_store.rebsl_ipa_popt))

# %%
m = build.Model(data=data, inits=inits, kind='irace', fit_on='average', depends_on={'v': 'Cond'})
# Out:
#       Model is prepared to fit on average irace data, allowing
#       Drift-Rate to vary across levels of Cond (bsl, pnl)
#
#       It'll probably work this time

# %%
#m.optimize(ntrials=20000, ftol=1.e-4, xtol=1.e-4, maxfev=100000)
m.optimize(ntrials=2000, ftol=1.e-2, xtol=1.e-2, maxfev=100)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.012993
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.035481
#          Iterations: 7
#          Function evaluations: 16

# %%
for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], plot_acc=True, save=True, savestr=m.labels[i]+'_fits')
# Out:
# <img src='...
# <img src='...
