# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %% [markdown]
# ## Prepare Data/Params

# %% [markdown]
# ##Proactive

# %%
dirpath = '/home/kyle/Dropbox/ELife/ProVTr_Avg/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = prodf_store['prodata']
inits = dict(deepcopy(vtheta))
inits['v'] = np.mean(vopt.values())

# %%
m = build.Model(data=data, inits=inits, kind='proactive', fit_on='average', depends_on={'v': 'pGo', 'tr':'pGo'}, weight_presp=1)
# Out:
#       Model is prepared to fit on average proactive data, allowing
#       Onset Time and Drift-Rate to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       Optimize On, Wayne

# %%
m.optimize(ntrials=20000, ftol=1.e-4, xtol=1.e-4, maxfev=10000)

# %% [markdown]
# ##visualize fits

# %%
yhat = m.simulate()
vis.plot_fits(m.avg_y, yhat, plot_acc=True, kind='pro', save=True, savestr='simulated')
vis.plot_fits(m.avg_y, m.fits, plot_acc=True, kind='pro', save=True, savestr='mfits')
