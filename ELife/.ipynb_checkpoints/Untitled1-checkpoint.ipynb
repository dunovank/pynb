# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %%
rr=dict(deepcopy(redf_store.rebsl_boot_popt))

# %%
dirpath = pth+'ELife/XTESTS/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)
reinits = dict(deepcopy(redf_store.rebsl_boot_popt))
#inits['ssv']=-abs(reinits['ssv'])
data = prodf_store['prodata']
inits = dict(deepcopy(ttheta))
#vinits = dict(deepcopy(vtheta))
#inits['a']=np.mean([tinits['a'], vinits['a']])
#inits['z']=np.mean([tinits['z'], vinits['z']])
inits['v'] = np.mean(vopt.values())
inits['tr'] = np.mean(topt.values())
#inits['ssv']=-abs(reinits['ssv'])
#inits['tr'] = np.mean(topt.values())
inits['xb']=2
if 'ssv' in inits.keys():
      del inits['ssv']
inits['a'] = inits['a'] - inits['z']
del inits['z']

# %%
m = build.Model( data=data, inits=inits, kind='xpro', fit_on='average', depends_on={'v':'pGo'}, weighted=False)
# Out:
#       Model is prepared to fit on average xpro data, allowing
#       Drift-Rate to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       I wish you a steep gradient, and a happy Nature paper

# %%
m.optimize(ntrials=10000, ftol=1.e-10, xtol=1.e-10, maxfev=10000)
m.fitinfo
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000173
#          Iterations: 109
#          Function evaluations: 282
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-c9a14a2e451a> in <module>()
# ----> 1 m.optimize(ntrials=10000, ftol=1.e-10, xtol=1.e-10, maxfev=10000)
#       2 m.fitinfo
#
# /home/kyle/Dropbox/Git/radd/build.py in optimize(self, save, savepth, ntrials, ftol, xtol, maxfev, niter, log_fits, disp, prob)
#      65             self.opt = Optimizer(dframes=self.dframes, fitparams=fp, kind=self.kind, inits=inits, depends_on=self.depends_on, fit_on=self.fit_on, wts=self.wts, pc_map=self.pc_map)
#      66
# ---> 67             self.fits, self.fitinfo, self.popt = self.opt.optimize_model(save=save, savepth=savepth)
#      68             self.residual = self.opt.residual
#      69             self.simulator = self.opt.simulator
#
# /home/kyle/Dropbox/Git/radd/build.py in optimize_model(self, save, savepth)
#     169
#     170             if self.fit_on=='average':
# --> 171                   yhat, fitinfo, popt = self.__opt_routine__(self.avg_y)
#     172                   return yhat, fitinfo, popt
#     173             else:
#
# /home/kyle/Dropbox/Git/radd/build.py in __opt_routine__(self, y)
#     301                         self.simulator.ncond = ncond[i]
#     302                         self.simulator.wts = wts[i]
# --> 303                         yhat, finfo, popt = self.optimize_theta(y=yi, inits=p, flat=flat[i])
#     304                         p = deepcopy(popt)
#     305
#
# /home/kyle/Dropbox/Git/radd/build.py in optimize_theta(self, y, inits, flat)
#     209             opt_kws = {'disp':fp['disp'], 'xtol':fp['xtol'], 'ftol':['ftol'], 'maxfev':fp['maxfev']}
#     210
# --> 211             optmod = minimize(self.simulator.costfx, theta, method=self.method, options=opt_kws)
#     212
#     213             optp = optmod.params
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in minimize(fcn, params, method, args, kws, scale_covar, iter_cb, **fit_kws)
#     758     fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#     759                        iter_cb=iter_cb, scale_covar=scale_covar, **fit_kws)
# --> 760     return fitter.minimize(method=method)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in minimize(self, method, params, **kws)
#     690         elif user_method.startswith('lbfgsb'):
#     691             function = self.lbfgsb
# --> 692         return function(**kwargs)
#     693
#     694 def minimize(fcn, params, method='leastsq', args=None, kws=None,
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in scalar_minimize(self, method, params, **kws)
#     471             ret = _differential_evolution(self.penalty, vars, **fmin_kws)
#     472         else:
# --> 473             ret = scipy_minimize(self.penalty, vars, **fmin_kws)
#     474
#     475         for attr in dir(ret):
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     430                       callback=callback, **options)
#     431     elif meth == 'nelder-mead':
# --> 432         return _minimize_neldermead(fun, x0, args, callback, **options)
#     433     elif meth == 'powell':
#     434         return _minimize_powell(fun, x0, args, callback, **options)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     461         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     462         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 463         fxr = func(xr)
#     464         doshrink = 0
#     465
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     283     def function_wrapper(*wrapper_args):
#     284         ncalls[0] += 1
# --> 285         return function(*(wrapper_args + args))
#     286
#     287     return ncalls, function_wrapper
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in penalty(self, fvars)
#     298             objective function is an array, return the array sum-of-squares
#     299         """
# --> 300         r = self.__residual(fvars)
#     301         if isinstance(r, ndarray):
#     302             r = (r*r).sum()
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in __residual(self, fvars)
#     252         self.result.nfev = self.result.nfev + 1
#     253
# --> 254         out = self.userfcn(params, *self.userargs, **self.userkws)
#     255         if callable(self.iter_cb):
#     256             self.iter_cb(params, self.result.nfev, out,
#
# /home/kyle/Dropbox/Git/radd/fit.py in pro_costfx(self, theta)
#     156             else:
#     157                   p = theta.valuesdict()
# --> 158             dvg = self.simulate_pro(p)
#     159             yhat = self.analyze_pro(dvg, p)
#     160
#
# /home/kyle/Dropbox/Git/radd/fit.py in simulate_pro(self, p)
#     206             a, tr, v, ssv, z, xb, Pg, Tg, Ps, Ts = self.vectorize_params(p)
#     207             # a/tr/v Bias: ALL CONDITIONS
# --> 208             DVg = z + xb *  np.cumsum(np.where((rs((self.ncond, self.ntot, Tg.max())).T < Pg), self.dx, -self.dx).T, axis=2)
#     209             return DVg
#     210
#
# /home/kyle/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in cumsum(a, axis, dtype, out)
#    1991     except AttributeError:
#    1992         return _wrapit(a, 'cumsum', axis, dtype, out)
# -> 1993     return cumsum(axis, dtype, out)
#    1994
#    1995
#
# KeyboardInterrupt:

# %%
m.fits
# Out:
# array([ 1.03395748,  0.73709484,  0.47058824,  0.23289316, -0.03545082,
#         0.02632321,  0.50260741,  0.51921179,  0.5200051 ,  0.51249271,
#         0.54424477,  0.53329747,  0.54308002,  0.54509927,  0.54791601,
#         0.55483294])

# %%
yhat = m.simulate()
vis.plot_fits(m.avg_y, yhat, plot_acc=True, kind='pro', bw=.02, save=False, savestr='simulated_xpro_v5')

# %%
m.wts
# Out:
# array([ 1.5       ,  1.        ,  1.        ,  1.        ,  2.        ,
#         2.        ,  0.27620745,  0.52553195,  0.91749432,  2.14560796,
#         1.41000998,  0.04186772,  0.15626717,  0.27937158,  0.35727406,
#         0.1821659 ])

# %%
def analyze_pro(DVg, DVs, p):

      a, tr, v, z = m.opt.simulator.vectorize_params(p, sim_info=False)
      dt=.0005; ncond=m.ncond; tb=m.tb; prob=m.opt.simulator.prob

      rt = (tr+(np.where((DVg.max(axis=2).T>=a).T, np.argmax((DVg.T>=a).T,axis=2)*dt, 999).T)).T
      ertx = (tr+(np.where((DVg[:, :nss, :].max(axis=2).T>=a).T, np.argmax((DVg[:, :nss, :].T>=a).T,axis=2)*dt, np.nan).T)).T
      ssrt = np.where(np.any(DVs<=0, axis=3), ssd[:, None]+np.argmax(DVs<=0, axis=3)*dt,np.nan)

      # compute RT quantiles for correct and error resp.
      ert = np.array([ertx[i] * np.ones_like(ssrt[i]) for i in range(ncond)])
      if len(m.avg_y)<=(len(prob)+1):
            qrt = mq(rt[rt<tb], prob=prob)*10
      else:
            hi = np.hstack(rt[ncond/2:])
            lo = np.hstack(rt[:ncond/2])
            hilo = [hi[hi<tb], lo[lo<tb]]
            
            # compute RT quantiles for correct and error resp.
            qrt = np.hstack([mq(rti[rti<tb], prob=prob)*10 for rti in hilo])
      
      # Get response and stop accuracy information
      pgo = 1-np.mean(np.where(grt<tb, 1, 0), axis=1)
      np.append(np.where(grt<tb, 1, 0), np.where(ert<ssrt, 0, 1)) 
      return np.hstack([pgo, qrt])
