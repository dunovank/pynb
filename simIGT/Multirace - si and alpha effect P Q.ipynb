# %%
#!/usr/local/bin/env python
from __future__ import division
import numpy as np
from numpy import array
from numpy.random import sample as rs
from numpy import newaxis as na
import pandas as pd 
from scipy.stats import distributions
import seaborn as sns
from radd import multirace
temporal_dynamics = lambda p, t: np.cosh(p['xb'][:, na] * t)

def rew_func(rprob):
    if rs()<rprob:
        return 1
    else:
        return 0

# %%
cards = pd.read_csv("/Users/kyle/Dropbox/CoAx/Projects/IGTob/IGTCards.csv")
cards_scaled=cards*.001
cards_normed = (cards - cards.mean())/cards.std().T

# %%
dt=.001
nc=3
si=.1
tb=.8
ntot=1000
pc_map={'vd': ['vd_a', 'vd_b', 'vd_c', 'vd_d'], 'vi': ['vi_a', 'vi_b', 'vi_c', 'vi_d']}
dx=np.sqrt(si*dt)

p={'vd':1.2, 'vi':1.3}
p['a']=.6
p['tr']=.2
p['xb']=1.5

# %%
from scipy.stats.distributions import norm, uniform
from scipy.misc import factorial

# %%
likelihood = lambda fact, prior, n, k: (fact*prior**k)*(1-prior)**(n-k)
prop = lambda n, k: factorial(n)/(factorial(k)*factorial(n-k))
# estimate posterior uncertainty in action value (from prior)

posterior = lambda n, s, x, ru, choice: (likelihood(prop(n, s), x, n, s)*ru[choice])#/((likelihood(prop(n+1, s), x, n, s)*ru[choice_id])+(likelihood(prop(xn+1, xs), x, xn, xs)*ru[xchoice_id]))


x = np.sort(uniform.rvs(0,1,1000))
prior = uniform.pdf(x)
ru = {sid: deepcopy(prior) for sid in stim_ids}     
ru[choice_id] = posterior(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-642c94a7efd1> in <module>()
#       6
#       7
# ----> 8 x = np.sort(uniform.rvs(0,1,1000))
#       9 prior = uniform.pdf(x)
#      10 ru = {sid: deepcopy(prior) for sid in stim_ids}
#
# NameError: name 'uniform' is not defined

# %%
Beta=15
Alpha=.5

# %%
# standard q learning
q_update = lambda qdict, winner, rew: qdict[winner][-1] + lr*(rew - qdict[winner][-1])
# choice probability boltzmann equation (logistic)
p_update = lambda qdict, winner, alts: np.exp(Beta*qdict[winner][-1])/np.sum([np.exp(Beta*qdict[alt][-1]) for alt in alts])

# %%
np.histogram(choices)
# Out:
# (array([ 29,   0,   0,  43,   0,   0,  18,   0,   0, 410]),
#  array([ 0. ,  0.3,  0.6,  0.9,  1.2,  1.5,  1.8,  2.1,  2.4,  2.7,  3. ]))

# %%
qdict['b'][-1]
# Out:
# -0.049830497492099807

# %%
x=qdict.keys()
x.remove(k)

# %%
#qdict.keys()!=k

pvals=[]

# %%
for k in qdict.keys():
    alts = [kk for kk in qdict.keys() if kk!=k]
    pvals.append(p_update(qdict, k, alts))#)['c', 'd', 'a'])

# %%
pvals
# Out:
# [0.27656583271756768,
#  0.36022377335973377,
#  0.28785638212399778,
#  0.4184576994230767,
#  0.32735761799073676,
#  0.33622993035705706,
#  0.32871714473632213,
#  0.34112310525467604,
#  0.32735761799073676,
#  0.33622993035705706,
#  0.32871714473632213,
#  0.34112310525467604,
#  0.18350242465929464,
#  0.39508866159533523,
#  0.20520784594585773,
#  0.64333785921895381]

# %%
qvals = [0] 
pvals = [.25]
for c in choices:
    cname = np.sort(qdict.keys())[c]
    qup =
# Out:
# a
# a
# a
# c
# c
# b
# c
# a
# b
# a
# b
# a
# d
# c
# d
# a
# b
# c
# d
# c
# d
# a
# a
# c
# d
# b
# b
# d
# d
# d
# d
# d
# d
# a
# c
# a
# d
# d
# c
# a
# d
# a
# b
# d
# c
# b
# b
# b
# a
# d
# d
# b
# c
# b
# b
# b
# a
# a
# b
# a
# a
# a
# b
# d
# d
# d
# a
# d
# c
# d
# d
# a
# b
# d
# b
# d
# d
# c
# d
# b
# a
# b
# b
# d
# d
# b
# d
# b
# a
# d
# c
# b
# b
# a
# c
# d
# d
# d
# d
# d
# d
# d
# a
# d
# d
# b
# a
# b
# d
# d
# d
# d
# b
# d
# c
# b
# d
# b
# c
# d
# b
# d
# d
# a
# b
# a
# d
# d
# b
# d
# d
# d
# d
# b
# d
# c
# d
# d
# b
# d
# b
# d
# b
# d
# d
# d
# b
# b
# b
# a
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# b
# d
# d
# b
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# b
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# ...

# %%
p={'vd':.8, 'vi':.3}
p['a']=.4
p['tr']=.2
p['xb']=1.5
si=.01
alpha_pos=alpha_neg=.01
output = multirace.run_trials(p, cards_normed, nblocks=10, si=si, alpha_pos=alpha_pos, alpha_neg=alpha_neg)

choices, rts, all_traces, qdict = output
choices = np.asarray(choices)

allchoices.append(choices)
allrts.append(rts)
P, Q = multirace.igt_scores(choices)

# %%
p
# Out:
# {'a': array([ 0.4,  0.4,  0.4,  0.4]),
#  'tr': array([ 0.2,  0.2,  0.2,  0.2]),
#  'vd': array([  0.91047,   1.15606,   0.85771,  30.83431]),
#  'vi': array([ 0.35177,  0.31846,  0.3347 ,  0.46019]),
#  'xb': array([ 1.5,  1.5,  1.5,  1.5])}

# %%
nchoice_alt = np.histogram(choices, bins=len(qdict.keys()))[0]
nchoice_alt
# Out:
# array([ 29,  43,  18, 410])

# %%
si_range=np.linspace(.01, .3, 10)
alpha_pos_range=np.linspace(.001, .5, 10)
alpha_neg_range=np.linspace(.001, .5, 10)
#alpha_neg_range=np.linspace(.001, .9, 50)
#alpha_neg_range=np.linspace(.5, 1.5, 100)

allchoices, allrts, allP, allQ = [], [], [], []
for si in si_range:
    for alpha_neg, alpha_pos in zip(alpha_neg_range, alpha_pos_range):
        
        p={'vd':1.8, 'vi':1.}
        p['a']=.4
        p['tr']=.2
        p['xb']=1.5
        output = multirace.run_trials(p, cards_scaled, nblocks=20, si=si, alpha_pos=alpha_pos, alpha_neg=alpha_neg)
        
        choices, rts, all_traces, qdict = output
        choices = np.asarray(choices)
        
        allchoices.append(choices)
        allrts.append(rts)
        
        P, Q = multirace.igt_scores(choices)
        
        allP.append(P)
        allQ.append(Q)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b41ba6bf8c37> in <module>()
#      13         p['tr']=.2
#      14         p['xb']=1.5
# ---> 15         output = multirace.run_trials(p, cards_scaled, nblocks=20, si=si, alpha_pos=alpha_pos, alpha_neg=alpha_neg)
#      16
#      17         choices, rts, all_traces, qdict = output
#
# /home/kyle/Dropbox/Git/radd/multirace.py in run_trials(p, cards, nblocks, si, alpha_pos, alpha_neg)
#      54         winner=np.nan
#      55         while np.isnan(winner):
# ---> 56             execution = simulate_race(p, si=si)
#      57             winner, rt, traces, p, qdict = analyze_multiresponse(execution, p, qdict=qdict, vals=vals, names=names, alpha_pos=alpha_pos, alpha_neg=alpha_neg)
#      58         choice_name = names[winner]
#
# /home/kyle/Dropbox/Git/radd/multirace.py in simulate_race(p, pc_map, dt, si, tb)
# ...

# %%
nchoice_alt = np.histogram(choices, bins=len(qdict.keys()))[0]
# Out:
# (array([137,  76, 173, 114]), array([ 0.  ,  0.75,  1.5 ,  2.25,  3.  ]))

# %%
#grab 
nchoice[nchoice>0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-294-359ccf453e75> in <module>()
# ----> 1 nchoice = np.histogram(choices, range=np.arange(4))[0]
#       2 #grab
#       3 nchoice[nchoice>0]
#
# /home/kyle/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     171
#     172     if (range is not None):
# --> 173         mn, mx = range
#     174         if (mn > mx):
#     175             raise AttributeError(
#
# ValueError: too many values to unpack

# %%
z
# Out:
# (array([137,   0,   0,  76,   0,   0, 173,   0,   0, 114]),
#  array([ 0. ,  0.3,  0.6,  0.9,  1.2,  1.5,  1.8,  2.1,  2.4,  2.7,  3. ]))

# %%
y = z[0]
y[y>0]
# Out:
# array([ 137.,   76.,  173.,  114.])

# %%
aQ = np.asarray(allQ).reshape(100,100)
sns.heatmap(aQ)
#plt.savefig('/home/kyle/Dropbox/sensitivity_noise_alpha.png')

# %%
aP = np.asarray(allP).reshape(100,100)
sns.heatmap(aP)
#plt.savefig('/home/kyle/Dropbox/payoff_noise_alpha.png')

# %%
#dfP1 = pd.DataFrame(data=np.asarray(allP).reshape(100,100))
#dfQ2 = pd.DataFrame(data=np.asarray(allQ).reshape(100,100))

# %%
dfP2 = pd.DataFrame(data=np.asarray(allP).reshape(10,10))
dfQ2 = pd.DataFrame(data=np.asarray(allQ).reshape(10,10))

# %%
dfP2.columns=si_range
dfP2.index=alpha_pos_range
dfP2.index.name='alpha'
dfP2.columns.name='noise'

dfQ2.columns=si_range
dfQ2.index=alpha_pos_range
dfQ2.index.name='alpha'
dfQ2.columns.name='noise'

# %%
Possible values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spectral, spectral_r, spring, spring_r, summer, summer_r, terrain, terrain_r, viridis, viridis_r, winter, winter_r

# %%
sns.set(font_scale=2)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(25,10), sharey=False)
sns.heatmap(dfP, ax=ax1, cmap='inferno', xticklabels=[], yticklabels=[])
sns.heatmap(dfQ, ax=ax2, cmap='inferno', xticklabels=[], yticklabels=[])
ax1.set_title('Payoff (P)')
ax2.set_title('Sensitivity (Q)')

f.savefig('/home/kyle/Dropbox/IGT_Scores_alpha_noise.png', dpi=300)

# %%
sns.set(font_scale=2)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(25,10), sharey=True)
sns.heatmap(dfP2, ax=ax1, cmap='inferno', xticklabels=[], yticklabels=[], vmin=dfP2.min().min(), vmax=dfP2.max().max(), cbar=False)
sns.heatmap(dfQ2, ax=ax2, cmap='inferno', xticklabels=[], yticklabels=[], vmin=dfQ2.min().min(), vmax=dfQ2.max().max(), )
ax1.set_title('Payoff (P)')
ax2.set_title('Sensitivity (Q)')
plt.subplots_adjust(wspace=.04)
f.savefig('/home/kyle/Dropbox/IGT_Scores_alpha_noise2.png', dpi=300)

# %%
dfP.min().min()
# Out:
# -54
