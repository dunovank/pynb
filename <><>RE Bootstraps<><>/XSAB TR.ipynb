# %%
from radd import build, vis
from radd.toolbox import analyze
#os.mkdir('xsab_tr')
os.chdir('xsab_tr')

# %%
popt={'a': array([ 0.53625]), 'xb': array([ 0.87761]), 'ssv': -0.98396462152356978, 'tr': array([ 0.17801]), 'v': array([ 1.26793])}

#popt={'a': array([ 0.48227]), 'sso': 0.01804612312742325, 'v': array([ 1.18368, 1.10]), 'xb': array([ 1.43943]), 'ssv': -0.93274357892086091, 'tr': array([ 0.21019])}

m=build.Model(data=redata, kind='xsab', depends_on={'tr':'Cond'}, inits=popt)
yhat=m.simulate(popt)

# %%
m.optimize(stage='conditional', inits=popt, multiopt=False)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000027
#          Iterations: 28
#          Function evaluations: 68

# %%
m.fitinfo.to_csv('fitinfo.csv')

# %%
m.fitinfo
# Out:
# a            0.53625
# chi        0.0061481
# cnvrg           True
# ndata             32
# nfev              68
# nvary              2
# ssv         -0.98396
# tr_bsl       0.17394
# tr_pnl       0.18334
# v             1.2679
# xb           0.87761
# df                30
# rchi      0.00020494
# logp         -271.77
# AIC          -267.77
# BIC          -267.61
# dtype: object

# %%
m.opt.basinhopping_full(popt, is_flat=False)
# Out:
# basinhopping step 0: f 0.00699003
# basinhopping step 1: f 0.00699003 trial_f 0.112635 accepted 0  lowest_f 0.00699003
# basinhopping step 2: f 0.33634 trial_f 0.33634 accepted 1  lowest_f 0.00699003
# basinhopping step 3: f 0.14144 trial_f 0.14144 accepted 1  lowest_f 0.00699003
# basinhopping step 4: f 0.115339 trial_f 0.115339 accepted 1  lowest_f 0.00699003
# basinhopping step 5: f 0.476535 trial_f 0.476535 accepted 1  lowest_f 0.00699003
# basinhopping step 6: f 0.893184 trial_f 0.893184 accepted 1  lowest_f 0.00699003
# basinhopping step 7: f 1.25294 trial_f 1.25294 accepted 1  lowest_f 0.00699003
# basinhopping step 8: f 0.948504 trial_f 0.948504 accepted 1  lowest_f 0.00699003
# basinhopping step 9: f 1.17215 trial_f 1.17215 accepted 1  lowest_f 0.00699003
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 1.30657 trial_f 1.30657 accepted 1  lowest_f 0.00699003
# basinhopping step 11: f 1.60217 trial_f 1.60217 accepted 1  lowest_f 0.00699003
# basinhopping step 12: f 1.05576 trial_f 1.05576 accepted 1  lowest_f 0.00699003
# basinhopping step 13: f 0.555697 trial_f 0.555697 accepted 1  lowest_f 0.00699003
# basinhopping step 14: f 0.69499 trial_f 0.69499 accepted 1  lowest_f 0.00699003
# basinhopping step 15: f 2.17731 trial_f 2.17731 accepted 1  lowest_f 0.00699003
# basinhopping step 16: f 2.67419 trial_f 2.67419 accepted 1  lowest_f 0.00699003
# basinhopping step 17: f 1.8958 trial_f 1.8958 accepted 1  lowest_f 0.00699003
# basinhopping step 18: f 2.71682 trial_f 2.71682 accepted 1  lowest_f 0.00699003
# basinhopping step 19: f 2.20307 trial_f 2.20307 accepted 1  lowest_f 0.00699003
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 1.215 trial_f 1.215 accepted 1  lowest_f 0.00699003
# basinhopping step 21: f 1.30937 trial_f 1.30937 accepted 1  lowest_f 0.00699003
# basinhopping finished
# ({'a': 0.53625,
#   'ssv': -0.9839646215235698,
#   'tr': array([ 0.17445,  0.18157]),
#   'v': 1.26793,
#   'xb': 0.87761},
#  0.0069900326006924664)

# %%
yhat=m.fits
vis.plot_fits(m.avg_y[0], yhat.reshape(2,16)[0], cdf=False)
vis.plot_fits(m.avg_y[1], yhat.reshape(2,16)[1], cdf=False)
# Out:
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
vis.react_fit_plots(m, save=True)

# %%
m.fits
# Out:
# array([ 0.967  ,  1.     ,  0.9988 ,  0.9206 ,  0.4612 ,  0.1226 ,
#         0.52094,  0.54794,  0.56694,  0.58794,  0.61694,  0.51394,
#         0.53694,  0.55594,  0.57494,  0.60194,  0.9424 ,  1.     ,
#         1.     ,  0.9576 ,  0.5806 ,  0.1596 ,  0.53034,  0.55534,
#         0.57634,  0.59734,  0.62434,  0.52134,  0.54634,  0.56334,
#         0.58234,  0.60934])
