# %% [markdown]
# # Reactive Viii

# %%
from radd import build, vis
from radd.toolbox import analyze

# %%
os.mkdir('xradd_v')
os.chdir('xradd_v')

# %%
xi1={'a': array([ 0.67453]), 'z': 0.0010132587773621401, 'v': array([ 1.21102]), 'xb': array([ 1.20662]), 'ssv': -1.5640145715127098, 'tr': array([ 0.09438])}
xi2={'a': array([ 0.3964]), 'z': 0.11776271765753309, 'v': array([ 0.90978]), 'xb': array([ 1.66779]), 'ssv': -0.78812139050158159, 'tr': array([ 0.29153])}
xi3={'a': array([ 0.54262]), 'z': 0.043672738124915685, 'v': array([ 1.20861]), 'xb': array([ 0.8175]), 'ssv': -1.1048747883708683, 'tr': array([ 0.18567])}
xi4={'a': array([ 0.44534]), 'z': 0.15913361713683202, 'v': array([ 0.96577]), 'xb': array([ 1.52569]), 'ssv': -0.90737967491616311, 'tr': array([ 0.30453])}

# %%
cols = ['cnvrg', 'logp', 'chi', 'rchi', 'AIC', 'BIC', 'a', 'v_bsl', 'v_pnl', 'ssv', 'xb', 'tr', 'z']

# %%
fidf=pd.DataFrame(columns=cols, index=np.arange(20))

# %%
popt={'a':0.54125, 'z': 0.0436727, 'v': 1.208608, 'xb': 0.8175, 'ssv': -1.104875, 'tr': 0.18567}

# %%
m.inits
# Out:
# {'a': 0.44470913,
#  'ssv': -0.9415135,
#  'tr': 0.30481227,
#  'v': 1.07049551,
#  'xb': 1.5,
#  'z': 0.15049553}

# %%
fidf.to_csv("finfo_xradd_v.csv")

# %%
for c in cols:
      fidf.loc[i, c]=m.fitinfo[c]

# %%
m=build.Model(data=redata, kind='xradd', depends_on={'v':'Cond'})
m.inits=popt
for i in range(20):
      m.optimize(stage='full', multiopt=True)      
      #finfo_list.append(m.fitinfo.T) 
      #x = pd.DataFrame(m.fitinfo.T)#.to_csv('finfo.csv')
      for c in cols:
            fidf.loc[i, c]=m.fitinfo[c]
      fidf.to_csv("finfo_xradd_v.csv")
# Out:
# basinhopping step 0: f 0.00203394
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 0.00252403 trial_f 0.00252403 accepted 1  lowest_f 0.00203394
# basinhopping step 2: f 0.16389 trial_f 0.16389 accepted 1  lowest_f 0.00203394
# basinhopping step 3: f 0.0142903 trial_f 0.0142903 accepted 1  lowest_f 0.00203394
# basinhopping step 4: f 0.381964 trial_f 0.381964 accepted 1  lowest_f 0.00203394
# basinhopping step 5: f 0.381964 trial_f 0.788421 accepted 0  lowest_f 0.00203394
# basinhopping step 6: f 0.381964 trial_f 0.900022 accepted 0  lowest_f 0.00203394
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 0.381964 trial_f 0.88539 accepted 0  lowest_f 0.00203394
# basinhopping step 8: f 0.311593 trial_f 0.311593 accepted 1  lowest_f 0.00203394
# basinhopping step 9: f 0.311593 trial_f 1.22287 accepted 0  lowest_f 0.00203394
# adaptive stepsize: acceptance rate 0.500000 target 0.500000 new stepsize 0.045 old stepsize 0.05
# basinhopping step 10: f 1.22639 trial_f 1.22639 accepted 1  lowest_f 0.00203394
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 1.49507 trial_f 1.49507 accepted 1  lowest_f 0.00203394
# basinhopping step 12: f 1.08462 trial_f 1.08462 accepted 1  lowest_f 0.00203394
# basinhopping step 13: f 1.38924 trial_f 1.38924 accepted 1  lowest_f 0.00203394
# basinhopping step 14: f 1.58546 trial_f 1.58546 accepted 1  lowest_f 0.00203394
# basinhopping step 15: f 0.240298 trial_f 0.240298 accepted 1  lowest_f 0.00203394
# basinhopping step 16: f 0.115704 trial_f 0.115704 accepted 1  lowest_f 0.00203394
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 1.4458 trial_f 1.4458 accepted 1  lowest_f 0.00203394
# basinhopping step 18: f 1.4458 trial_f 1.59314 accepted 0  lowest_f 0.00203394
# basinhopping step 19: f 1.24494 trial_f 1.24494 accepted 1  lowest_f 0.00203394
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.05 old stepsize 0.045
# basinhopping step 20: f 1.24411 trial_f 1.24411 accepted 1  lowest_f 0.00203394
# basinhopping step 21: f 0.0625822 trial_f 0.0625822 accepted 1  lowest_f 0.00203394
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 72
#          Function evaluations: 185
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 2.87663
# basinhopping step 1: f 3.03185 trial_f 3.03185 accepted 1  lowest_f 2.87663
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 3.25188 trial_f 3.25188 accepted 1  lowest_f 2.87663
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 3.02464 trial_f 3.02464 accepted 1  lowest_f 2.87663
# basinhopping step 4: f 3.12842 trial_f 3.12842 accepted 1  lowest_f 2.87663
# basinhopping step 5: f 3.18854 trial_f 3.18854 accepted 1  lowest_f 2.87663
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 3.20706 trial_f 3.20706 accepted 1  lowest_f 2.87663
# basinhopping step 7: f 2.98207 trial_f 2.98207 accepted 1  lowest_f 2.87663
# basinhopping step 8: f 2.69903 trial_f 2.69903 accepted 1  lowest_f 2.69903
# found new global minimum on step 8 with function value 2.69903
# basinhopping step 9: f 2.42899 trial_f 2.42899 accepted 1  lowest_f 2.42899
# found new global minimum on step 9 with function value 2.42899
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 2.59047 trial_f 2.59047 accepted 1  lowest_f 2.42899
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 2.33914 trial_f 2.33914 accepted 1  lowest_f 2.33914
# found new global minimum on step 11 with function value 2.33914
# basinhopping step 12: f 2.25649 trial_f 2.25649 accepted 1  lowest_f 2.25649
# found new global minimum on step 12 with function value 2.25649
# basinhopping step 13: f 2.12756 trial_f 2.12756 accepted 1  lowest_f 2.12756
# found new global minimum on step 13 with function value 2.12756
# basinhopping step 14: f 2.10394 trial_f 2.10394 accepted 1  lowest_f 2.10394
# found new global minimum on step 14 with function value 2.10394
# basinhopping step 15: f 1.9665 trial_f 1.9665 accepted 1  lowest_f 1.9665
# found new global minimum on step 15 with function value 1.9665
# basinhopping step 16: f 2.12764 trial_f 2.12764 accepted 1  lowest_f 1.9665
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 2.04138 trial_f 2.04138 accepted 1  lowest_f 1.9665
# basinhopping step 18: f 2.01687 trial_f 2.01687 accepted 1  lowest_f 1.9665
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 2.24466 trial_f 2.24466 accepted 1  lowest_f 1.9665
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# warning: basinhopping: local minimization failure
# basinhopping step 20: f 2.25477 trial_f 2.25477 accepted 1  lowest_f 1.9665
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 1.97159 trial_f 1.97159 accepted 1  lowest_f 1.9665
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 1.89225 trial_f 1.89225 accepted 1  lowest_f 1.89225
# found new global minimum on step 22 with function value 1.89225
# basinhopping step 23: f 2.07519 trial_f 2.07519 accepted 1  lowest_f 1.89225
# basinhopping step 24: f 1.9247 trial_f 1.9247 accepted 1  lowest_f 1.89225
# basinhopping step 25: f 2.11861 trial_f 2.11861 accepted 1  lowest_f 1.89225
# basinhopping step 26: f 2.3898 trial_f 2.3898 accepted 1  lowest_f 1.89225
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 2.53395 trial_f 2.53395 accepted 1  lowest_f 1.89225
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 2.54557 trial_f 2.54557 accepted 1  lowest_f 1.89225
# basinhopping step 29: f 2.34341 trial_f 2.34341 accepted 1  lowest_f 1.89225
# adaptive stepsize: acceptance rate 0.966667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 2.47769 trial_f 2.47769 accepted 1  lowest_f 1.89225
# basinhopping step 31: f 2.34011 trial_f 2.34011 accepted 1  lowest_f 1.89225
# basinhopping step 32: f 2.37411 trial_f 2.37411 accepted 1  lowest_f 1.89225
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 2.50216 trial_f 2.50216 accepted 1  lowest_f 1.89225
# basinhopping step 34: f 2.22064 trial_f 2.22064 accepted 1  lowest_f 1.89225
# basinhopping step 35: f 2.31008 trial_f 2.31008 accepted 1  lowest_f 1.89225
# basinhopping step 36: f 1.95627 trial_f 1.95627 accepted 1  lowest_f 1.89225
# warning: basinhopping: local minimization failure
# basinhopping step 37: f 1.80002 trial_f 1.80002 accepted 1  lowest_f 1.80002
# found new global minimum on step 37 with function value 1.80002
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 1.79119 trial_f 1.79119 accepted 1  lowest_f 1.79119
# found new global minimum on step 38 with function value 1.79119
# basinhopping step 39: f 1.89575 trial_f 1.89575 accepted 1  lowest_f 1.79119
# adaptive stepsize: acceptance rate 0.975000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 1.86767 trial_f 1.86767 accepted 1  lowest_f 1.79119
# basinhopping step 41: f 1.80072 trial_f 1.80072 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 42: f 1.86093 trial_f 1.86093 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 43: f 1.84862 trial_f 1.84862 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 1.93104 trial_f 1.93104 accepted 1  lowest_f 1.79119
# basinhopping step 45: f 1.99955 trial_f 1.99955 accepted 1  lowest_f 1.79119
# basinhopping step 46: f 2.1588 trial_f 2.1588 accepted 1  lowest_f 1.79119
# basinhopping step 47: f 2.28159 trial_f 2.28159 accepted 1  lowest_f 1.79119
# basinhopping step 48: f 2.28159 trial_f 2.74186 accepted 0  lowest_f 1.79119
# basinhopping step 49: f 2.51131 trial_f 2.51131 accepted 1  lowest_f 1.79119
# adaptive stepsize: acceptance rate 0.960000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 2.40731 trial_f 2.40731 accepted 1  lowest_f 1.79119
# basinhopping step 51: f 2.0845 trial_f 2.0845 accepted 1  lowest_f 1.79119
# basinhopping step 52: f 1.97558 trial_f 1.97558 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 53: f 1.79875 trial_f 1.79875 accepted 1  lowest_f 1.79119
# basinhopping step 54: f 1.79695 trial_f 1.79695 accepted 1  lowest_f 1.79119
# basinhopping step 55: f 1.80997 trial_f 1.80997 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 2.00552 trial_f 2.00552 accepted 1  lowest_f 1.79119
# basinhopping step 57: f 1.83352 trial_f 1.83352 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 58: f 2.02244 trial_f 2.02244 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 59: f 2.11394 trial_f 2.11394 accepted 1  lowest_f 1.79119
# adaptive stepsize: acceptance rate 0.966667 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 2.41661 trial_f 2.41661 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 61: f 2.77417 trial_f 2.77417 accepted 1  lowest_f 1.79119
# basinhopping step 62: f 3.19231 trial_f 3.19231 accepted 1  lowest_f 1.79119
# basinhopping step 63: f 2.61865 trial_f 2.61865 accepted 1  lowest_f 1.79119
# basinhopping step 64: f 2.91689 trial_f 2.91689 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 2.91689 trial_f 3.22083 accepted 0  lowest_f 1.79119
# basinhopping step 66: f 2.91586 trial_f 2.91586 accepted 1  lowest_f 1.79119
# basinhopping step 67: f 3.23727 trial_f 3.23727 accepted 1  lowest_f 1.79119
# basinhopping step 68: f 3.56429 trial_f 3.56429 accepted 1  lowest_f 1.79119
# basinhopping step 69: f 3.98454 trial_f 3.98454 accepted 1  lowest_f 1.79119
# adaptive stepsize: acceptance rate 0.957143 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# basinhopping step 70: f 3.99331 trial_f 3.99331 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 3.43021 trial_f 3.43021 accepted 1  lowest_f 1.79119
# basinhopping step 72: f 3.08161 trial_f 3.08161 accepted 1  lowest_f 1.79119
# warning: basinhopping: local minimization failure
# basinhopping step 73: f 2.47841 trial_f 2.47841 accepted 1  lowest_f 1.79119
# basinhopping step 74: f 1.91355 trial_f 1.91355 accepted 1  lowest_f 1.79119
# basinhopping step 75: f 2.07378 trial_f 2.07378 accepted 1  lowest_f 1.79119
# basinhopping step 76: f 1.79447 trial_f 1.79447 accepted 1  lowest_f 1.79119
# basinhopping step 77: f 1.92602 trial_f 1.92602 accepted 1  lowest_f 1.79119
# basinhopping step 78: f 1.78066 trial_f 1.78066 accepted 1  lowest_f 1.78066
# found new global minimum on step 78 with function value 1.78066
# basinhopping step 79: f 1.87093 trial_f 1.87093 accepted 1  lowest_f 1.78066
# adaptive stepsize: acceptance rate 0.962500 target 0.500000 new stepsize 0.116153 old stepsize 0.104538
# basinhopping step 80: f 1.7964 trial_f 1.7964 accepted 1  lowest_f 1.78066
# basinhopping step 0: f 14.0161
# basinhopping step 1: f 12.6573 trial_f 12.6573 accepted 1  lowest_f 12.6573
# found new global minimum on step 1 with function value 12.6573
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 12.6506 trial_f 12.6506 accepted 1  lowest_f 12.6506
# found new global minimum on step 2 with function value 12.6506
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 12.5705 trial_f 12.5705 accepted 1  lowest_f 12.5705
# found new global minimum on step 3 with function value 12.5705
# basinhopping step 4: f 12.4115 trial_f 12.4115 accepted 1  lowest_f 12.4115
# found new global minimum on step 4 with function value 12.4115
# basinhopping step 5: f 11.8311 trial_f 11.8311 accepted 1  lowest_f 11.8311
# found new global minimum on step 5 with function value 11.8311
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 11.8311 trial_f 12.5028 accepted 0  lowest_f 11.8311
# basinhopping step 7: f 11.5068 trial_f 11.5068 accepted 1  lowest_f 11.5068
# found new global minimum on step 7 with function value 11.5068
# basinhopping step 8: f 10.9792 trial_f 10.9792 accepted 1  lowest_f 10.9792
# found new global minimum on step 8 with function value 10.9792
# basinhopping step 9: f 11.5649 trial_f 11.5649 accepted 1  lowest_f 10.9792
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 11.2507 trial_f 11.2507 accepted 1  lowest_f 10.9792
# basinhopping step 11: f 10.4687 trial_f 10.4687 accepted 1  lowest_f 10.4687
# found new global minimum on step 11 with function value 10.4687
# basinhopping step 12: f 10.4687 trial_f 10.7944 accepted 0  lowest_f 10.4687
# basinhopping step 13: f 10.4798 trial_f 10.4798 accepted 1  lowest_f 10.4687
# basinhopping step 14: f 10.4798 trial_f 10.5463 accepted 0  lowest_f 10.4687
# basinhopping step 15: f 10.2792 trial_f 10.2792 accepted 1  lowest_f 10.2792
# found new global minimum on step 15 with function value 10.2792
# basinhopping step 16: f 10.2792 trial_f 10.6779 accepted 0  lowest_f 10.2792
# basinhopping step 17: f 10.476 trial_f 10.476 accepted 1  lowest_f 10.2792
# basinhopping step 18: f 10.476 trial_f 10.7593 accepted 0  lowest_f 10.2792
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 10.8225 trial_f 10.8225 accepted 1  lowest_f 10.2792
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 10.7847 trial_f 10.7847 accepted 1  lowest_f 10.2792
# basinhopping step 21: f 11.1973 trial_f 11.1973 accepted 1  lowest_f 10.2792
# basinhopping step 22: f 10.7355 trial_f 10.7355 accepted 1  lowest_f 10.2792
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 10.4227 trial_f 10.4227 accepted 1  lowest_f 10.2792
# basinhopping step 24: f 10.2774 trial_f 10.2774 accepted 1  lowest_f 10.2774
# found new global minimum on step 24 with function value 10.2774
# basinhopping step 25: f 10.3249 trial_f 10.3249 accepted 1  lowest_f 10.2774
# basinhopping step 26: f 10.3049 trial_f 10.3049 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 10.3686 trial_f 10.3686 accepted 1  lowest_f 10.2774
# basinhopping step 28: f 10.2778 trial_f 10.2778 accepted 1  lowest_f 10.2774
# basinhopping step 29: f 10.3785 trial_f 10.3785 accepted 1  lowest_f 10.2774
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 10.4519 trial_f 10.4519 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 10.9932 trial_f 10.9932 accepted 1  lowest_f 10.2774
# basinhopping step 32: f 10.9932 trial_f 12.256 accepted 0  lowest_f 10.2774
# basinhopping step 33: f 10.392 trial_f 10.392 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 10.3887 trial_f 10.3887 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 10.6156 trial_f 10.6156 accepted 1  lowest_f 10.2774
# basinhopping step 36: f 10.9761 trial_f 10.9761 accepted 1  lowest_f 10.2774
# basinhopping step 37: f 10.9761 trial_f 12.2089 accepted 0  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 10.2858 trial_f 10.2858 accepted 1  lowest_f 10.2774
# basinhopping step 39: f 10.5333 trial_f 10.5333 accepted 1  lowest_f 10.2774
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 10.4016 trial_f 10.4016 accepted 1  lowest_f 10.2774
# basinhopping step 41: f 10.6128 trial_f 10.6128 accepted 1  lowest_f 10.2774
# basinhopping step 42: f 10.6128 trial_f 11.3825 accepted 0  lowest_f 10.2774
# basinhopping step 43: f 10.3046 trial_f 10.3046 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 10.6222 trial_f 10.6222 accepted 1  lowest_f 10.2774
# basinhopping step 45: f 10.4398 trial_f 10.4398 accepted 1  lowest_f 10.2774
# basinhopping step 46: f 10.5206 trial_f 10.5206 accepted 1  lowest_f 10.2774
# basinhopping step 47: f 10.617 trial_f 10.617 accepted 1  lowest_f 10.2774
# basinhopping step 48: f 10.4567 trial_f 10.4567 accepted 1  lowest_f 10.2774
# basinhopping step 49: f 11.0644 trial_f 11.0644 accepted 1  lowest_f 10.2774
# adaptive stepsize: acceptance rate 0.820000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 11.2884 trial_f 11.2884 accepted 1  lowest_f 10.2774
# basinhopping step 51: f 10.6203 trial_f 10.6203 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 52: f 10.653 trial_f 10.653 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 53: f 10.653 trial_f 11.2581 accepted 0  lowest_f 10.2774
# basinhopping step 54: f 10.3801 trial_f 10.3801 accepted 1  lowest_f 10.2774
# basinhopping step 55: f 10.7934 trial_f 10.7934 accepted 1  lowest_f 10.2774
# basinhopping step 56: f 10.7934 trial_f 11.1816 accepted 0  lowest_f 10.2774
# basinhopping step 57: f 10.7895 trial_f 10.7895 accepted 1  lowest_f 10.2774
# basinhopping step 58: f 10.2981 trial_f 10.2981 accepted 1  lowest_f 10.2774
# basinhopping step 59: f 10.9789 trial_f 10.9789 accepted 1  lowest_f 10.2774
# adaptive stepsize: acceptance rate 0.816667 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 10.3761 trial_f 10.3761 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 61: f 10.5277 trial_f 10.5277 accepted 1  lowest_f 10.2774
# basinhopping step 62: f 10.869 trial_f 10.869 accepted 1  lowest_f 10.2774
# warning: basinhopping: local minimization failure
# basinhopping step 63: f 10.869 trial_f 11.296 accepted 0  lowest_f 10.2774
# basinhopping step 64: f 10.578 trial_f 10.578 accepted 1  lowest_f 10.2774
# basinhopping step 65: f 10.4232 trial_f 10.4232 accepted 1  lowest_f 10.2774
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000013
#          Iterations: 35
#          Function evaluations: 85
# basinhopping step 0: f 0.00193524
# basinhopping step 1: f 0.0225079 trial_f 0.0225079 accepted 1  lowest_f 0.00193524
# basinhopping step 2: f 0.0590317 trial_f 0.0590317 accepted 1  lowest_f 0.00193524
# basinhopping step 3: f 0.124408 trial_f 0.124408 accepted 1  lowest_f 0.00193524
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 0.220003 trial_f 0.220003 accepted 1  lowest_f 0.00193524
# basinhopping step 5: f 0.0159106 trial_f 0.0159106 accepted 1  lowest_f 0.00193524
# basinhopping step 6: f 0.00627576 trial_f 0.00627576 accepted 1  lowest_f 0.00193524
# basinhopping step 7: f 0.00959094 trial_f 0.00959094 accepted 1  lowest_f 0.00193524
# basinhopping step 8: f 0.00959094 trial_f 0.487369 accepted 0  lowest_f 0.00193524
# basinhopping step 9: f 0.0375763 trial_f 0.0375763 accepted 1  lowest_f 0.00193524
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.982991 trial_f 0.982991 accepted 1  lowest_f 0.00193524
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 1.04192 trial_f 1.04192 accepted 1  lowest_f 0.00193524
# basinhopping step 12: f 1.39604 trial_f 1.39604 accepted 1  lowest_f 0.00193524
# basinhopping step 13: f 1.64124 trial_f 1.64124 accepted 1  lowest_f 0.00193524
# basinhopping step 14: f 1.64124 trial_f 3.03669 accepted 0  lowest_f 0.00193524
# basinhopping step 15: f 1.64124 trial_f 2.99546 accepted 0  lowest_f 0.00193524
# basinhopping step 16: f 1.35838 trial_f 1.35838 accepted 1  lowest_f 0.00193524
# basinhopping step 17: f 1.35838 trial_f 2.35554 accepted 0  lowest_f 0.00193524
# basinhopping step 18: f 1.35838 trial_f 3.61544 accepted 0  lowest_f 0.00193524
# basinhopping step 19: f 0.977036 trial_f 0.977036 accepted 1  lowest_f 0.00193524
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 0.825305 trial_f 0.825305 accepted 1  lowest_f 0.00193524
# basinhopping step 21: f 0.958675 trial_f 0.958675 accepted 1  lowest_f 0.00193524
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000003
#          Iterations: 55
#          Function evaluations: 157
# basinhopping step 0: f 2.86656
# basinhopping step 1: f 2.74876 trial_f 2.74876 accepted 1  lowest_f 2.74876
# found new global minimum on step 1 with function value 2.74876
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 2.42243 trial_f 2.42243 accepted 1  lowest_f 2.42243
# found new global minimum on step 2 with function value 2.42243
# basinhopping step 3: f 2.42243 trial_f 2.5603 accepted 0  lowest_f 2.42243
# basinhopping step 4: f 2.32689 trial_f 2.32689 accepted 1  lowest_f 2.32689
# found new global minimum on step 4 with function value 2.32689
# basinhopping step 5: f 2.32934 trial_f 2.32934 accepted 1  lowest_f 2.32689
# basinhopping step 6: f 2.09089 trial_f 2.09089 accepted 1  lowest_f 2.09089
# found new global minimum on step 6 with function value 2.09089
# basinhopping step 7: f 2.09089 trial_f 2.29471 accepted 0  lowest_f 2.09089
# basinhopping step 8: f 2.30544 trial_f 2.30544 accepted 1  lowest_f 2.09089
# basinhopping step 9: f 2.07831 trial_f 2.07831 accepted 1  lowest_f 2.07831
# found new global minimum on step 9 with function value 2.07831
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 2.07831 trial_f 2.30437 accepted 0  lowest_f 2.07831
# basinhopping step 11: f 2.19561 trial_f 2.19561 accepted 1  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 12: f 2.16534 trial_f 2.16534 accepted 1  lowest_f 2.07831
# basinhopping step 13: f 2.32511 trial_f 2.32511 accepted 1  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 14: f 2.45995 trial_f 2.45995 accepted 1  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 2.7716 trial_f 2.7716 accepted 1  lowest_f 2.07831
# basinhopping step 16: f 2.43791 trial_f 2.43791 accepted 1  lowest_f 2.07831
# basinhopping step 17: f 2.78331 trial_f 2.78331 accepted 1  lowest_f 2.07831
# basinhopping step 18: f 2.60506 trial_f 2.60506 accepted 1  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 2.35594 trial_f 2.35594 accepted 1  lowest_f 2.07831
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 2.35594 trial_f 2.54339 accepted 0  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 2.21366 trial_f 2.21366 accepted 1  lowest_f 2.07831
# basinhopping step 22: f 2.32385 trial_f 2.32385 accepted 1  lowest_f 2.07831
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 2.43557 trial_f 2.43557 accepted 1  lowest_f 2.07831
# basinhopping step 24: f 2.26696 trial_f 2.26696 accepted 1  lowest_f 2.07831
# basinhopping step 25: f 2.00823 trial_f 2.00823 accepted 1  lowest_f 2.00823
# found new global minimum on step 25 with function value 2.00823
# basinhopping step 26: f 2.24052 trial_f 2.24052 accepted 1  lowest_f 2.00823
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 2.13675 trial_f 2.13675 accepted 1  lowest_f 2.00823
# basinhopping step 28: f 2.02349 trial_f 2.02349 accepted 1  lowest_f 2.00823
# basinhopping step 29: f 2.24432 trial_f 2.24432 accepted 1  lowest_f 2.00823
# adaptive stepsize: acceptance rate 0.833333 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 2.30313 trial_f 2.30313 accepted 1  lowest_f 2.00823
# basinhopping step 31: f 2.30313 trial_f 2.59895 accepted 0  lowest_f 2.00823
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 2.21857 trial_f 2.21857 accepted 1  lowest_f 2.00823
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 2.13315 trial_f 2.13315 accepted 1  lowest_f 2.00823
# basinhopping step 34: f 2.31 trial_f 2.31 accepted 1  lowest_f 2.00823
# basinhopping step 35: f 2.31 trial_f 2.52362 accepted 0  lowest_f 2.00823
# basinhopping step 36: f 2.21913 trial_f 2.21913 accepted 1  lowest_f 2.00823
# basinhopping step 37: f 2.38601 trial_f 2.38601 accepted 1  lowest_f 2.00823
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 2.35086 trial_f 2.35086 accepted 1  lowest_f 2.00823
# basinhopping step 39: f 2.34796 trial_f 2.34796 accepted 1  lowest_f 2.00823
# adaptive stepsize: acceptance rate 0.825000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 2.04884 trial_f 2.04884 accepted 1  lowest_f 2.00823
# basinhopping step 41: f 1.80625 trial_f 1.80625 accepted 1  lowest_f 1.80625
# found new global minimum on step 41 with function value 1.80625
# basinhopping step 42: f 1.77304 trial_f 1.77304 accepted 1  lowest_f 1.77304
# found new global minimum on step 42 with function value 1.77304
# basinhopping step 43: f 1.89013 trial_f 1.89013 accepted 1  lowest_f 1.77304
# basinhopping step 44: f 1.78884 trial_f 1.78884 accepted 1  lowest_f 1.77304
# basinhopping step 45: f 1.81044 trial_f 1.81044 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 46: f 1.89891 trial_f 1.89891 accepted 1  lowest_f 1.77304
# basinhopping step 47: f 2.07505 trial_f 2.07505 accepted 1  lowest_f 1.77304
# basinhopping step 48: f 1.88521 trial_f 1.88521 accepted 1  lowest_f 1.77304
# basinhopping step 49: f 1.79696 trial_f 1.79696 accepted 1  lowest_f 1.77304
# adaptive stepsize: acceptance rate 0.860000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 1.81481 trial_f 1.81481 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 51: f 1.88339 trial_f 1.88339 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 52: f 2.08196 trial_f 2.08196 accepted 1  lowest_f 1.77304
# basinhopping step 53: f 1.86843 trial_f 1.86843 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 54: f 1.93443 trial_f 1.93443 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 55: f 2.19244 trial_f 2.19244 accepted 1  lowest_f 1.77304
# basinhopping step 56: f 2.06253 trial_f 2.06253 accepted 1  lowest_f 1.77304
# basinhopping step 57: f 2.13436 trial_f 2.13436 accepted 1  lowest_f 1.77304
# basinhopping step 58: f 2.38351 trial_f 2.38351 accepted 1  lowest_f 1.77304
# basinhopping step 59: f 2.18926 trial_f 2.18926 accepted 1  lowest_f 1.77304
# adaptive stepsize: acceptance rate 0.883333 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 2.41222 trial_f 2.41222 accepted 1  lowest_f 1.77304
# basinhopping step 61: f 2.09691 trial_f 2.09691 accepted 1  lowest_f 1.77304
# basinhopping step 62: f 1.92036 trial_f 1.92036 accepted 1  lowest_f 1.77304
# basinhopping step 63: f 2.08625 trial_f 2.08625 accepted 1  lowest_f 1.77304
# basinhopping step 64: f 2.08625 trial_f 2.41261 accepted 0  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 2.08625 trial_f 2.29088 accepted 0  lowest_f 1.77304
# basinhopping step 66: f 2.49166 trial_f 2.49166 accepted 1  lowest_f 1.77304
# basinhopping step 67: f 2.23224 trial_f 2.23224 accepted 1  lowest_f 1.77304
# basinhopping step 68: f 2.72078 trial_f 2.72078 accepted 1  lowest_f 1.77304
# basinhopping step 69: f 2.42642 trial_f 2.42642 accepted 1  lowest_f 1.77304
# adaptive stepsize: acceptance rate 0.871429 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# warning: basinhopping: local minimization failure
# basinhopping step 70: f 2.02075 trial_f 2.02075 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 2.45579 trial_f 2.45579 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 72: f 2.45579 trial_f 3.10547 accepted 0  lowest_f 1.77304
# basinhopping step 73: f 2.19766 trial_f 2.19766 accepted 1  lowest_f 1.77304
# basinhopping step 74: f 1.83973 trial_f 1.83973 accepted 1  lowest_f 1.77304
# warning: basinhopping: local minimization failure
# basinhopping step 75: f 2.24352 trial_f 2.24352 accepted 1  lowest_f 1.77304
# basinhopping step 76: f 2.7426 trial_f 2.7426 accepted 1  lowest_f 1.77304
# basinhopping step 77: f 3.01552 trial_f 3.01552 accepted 1  lowest_f 1.77304
# basinhopping step 78: f 3.54636 trial_f 3.54636 accepted 1  lowest_f 1.77304
# basinhopping step 79: f 3.48811 trial_f 3.48811 accepted 1  lowest_f 1.77304
# adaptive stepsize: acceptance rate 0.875000 target 0.500000 new stepsize 0.116153 old stepsize 0.104538
# basinhopping step 80: f 2.92147 trial_f 2.92147 accepted 1  lowest_f 1.77304
# basinhopping step 0: f 14.034
# basinhopping step 1: f 14.034 trial_f 15.3842 accepted 0  lowest_f 14.034
# basinhopping step 2: f 12.8291 trial_f 12.8291 accepted 1  lowest_f 12.8291
# found new global minimum on step 2 with function value 12.8291
# basinhopping step 3: f 12.7619 trial_f 12.7619 accepted 1  lowest_f 12.7619
# found new global minimum on step 3 with function value 12.7619
# basinhopping step 4: f 11.7619 trial_f 11.7619 accepted 1  lowest_f 11.7619
# found new global minimum on step 4 with function value 11.7619
# basinhopping step 5: f 11.7619 trial_f 12.9409 accepted 0  lowest_f 11.7619
# basinhopping step 6: f 11.0136 trial_f 11.0136 accepted 1  lowest_f 11.0136
# found new global minimum on step 6 with function value 11.0136
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 10.9078 trial_f 10.9078 accepted 1  lowest_f 10.9078
# found new global minimum on step 7 with function value 10.9078
# basinhopping step 8: f 11.5362 trial_f 11.5362 accepted 1  lowest_f 10.9078
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 10.8825 trial_f 10.8825 accepted 1  lowest_f 10.8825
# found new global minimum on step 9 with function value 10.8825
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 10.4666 trial_f 10.4666 accepted 1  lowest_f 10.4666
# found new global minimum on step 10 with function value 10.4666
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 10.4196 trial_f 10.4196 accepted 1  lowest_f 10.4196
# found new global minimum on step 11 with function value 10.4196
# basinhopping step 12: f 10.2687 trial_f 10.2687 accepted 1  lowest_f 10.2687
# found new global minimum on step 12 with function value 10.2687
# warning: basinhopping: local minimization failure
# basinhopping step 13: f 10.479 trial_f 10.479 accepted 1  lowest_f 10.2687
# basinhopping step 14: f 10.5645 trial_f 10.5645 accepted 1  lowest_f 10.2687
# basinhopping step 15: f 10.2505 trial_f 10.2505 accepted 1  lowest_f 10.2505
# found new global minimum on step 15 with function value 10.2505
# basinhopping step 16: f 10.4435 trial_f 10.4435 accepted 1  lowest_f 10.2505
# basinhopping step 17: f 10.5972 trial_f 10.5972 accepted 1  lowest_f 10.2505
# basinhopping step 18: f 10.5972 trial_f 11.1723 accepted 0  lowest_f 10.2505
# basinhopping step 19: f 10.6166 trial_f 10.6166 accepted 1  lowest_f 10.2505
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 10.7716 trial_f 10.7716 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 10.4591 trial_f 10.4591 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 10.327 trial_f 10.327 accepted 1  lowest_f 10.2505
# basinhopping step 23: f 10.3289 trial_f 10.3289 accepted 1  lowest_f 10.2505
# basinhopping step 24: f 10.394 trial_f 10.394 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 10.5822 trial_f 10.5822 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 26: f 10.5822 trial_f 11.4251 accepted 0  lowest_f 10.2505
# basinhopping step 27: f 10.5505 trial_f 10.5505 accepted 1  lowest_f 10.2505
# basinhopping step 28: f 11.108 trial_f 11.108 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 29: f 10.4639 trial_f 10.4639 accepted 1  lowest_f 10.2505
# adaptive stepsize: acceptance rate 0.833333 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# warning: basinhopping: local minimization failure
# basinhopping step 30: f 10.5103 trial_f 10.5103 accepted 1  lowest_f 10.2505
# basinhopping step 31: f 10.2887 trial_f 10.2887 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 10.9225 trial_f 10.9225 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 11.4052 trial_f 11.4052 accepted 1  lowest_f 10.2505
# basinhopping step 34: f 11.4052 trial_f 11.7132 accepted 0  lowest_f 10.2505
# basinhopping step 35: f 12.0183 trial_f 12.0183 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 36: f 12.0183 trial_f 12.2484 accepted 0  lowest_f 10.2505
# basinhopping step 37: f 12.2553 trial_f 12.2553 accepted 1  lowest_f 10.2505
# basinhopping step 38: f 12.2553 trial_f 12.4543 accepted 0  lowest_f 10.2505
# basinhopping step 39: f 11.8899 trial_f 11.8899 accepted 1  lowest_f 10.2505
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 11.5691 trial_f 11.5691 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 11.2008 trial_f 11.2008 accepted 1  lowest_f 10.2505
# basinhopping step 42: f 10.3898 trial_f 10.3898 accepted 1  lowest_f 10.2505
# basinhopping step 43: f 10.2708 trial_f 10.2708 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 10.3558 trial_f 10.3558 accepted 1  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 45: f 10.3299 trial_f 10.3299 accepted 1  lowest_f 10.2505
# basinhopping step 46: f 10.3392 trial_f 10.3392 accepted 1  lowest_f 10.2505
# basinhopping step 47: f 10.6558 trial_f 10.6558 accepted 1  lowest_f 10.2505
# basinhopping step 48: f 10.4173 trial_f 10.4173 accepted 1  lowest_f 10.2505
# basinhopping step 49: f 10.8128 trial_f 10.8128 accepted 1  lowest_f 10.2505
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 10.7859 trial_f 10.7859 accepted 1  lowest_f 10.2505
# basinhopping step 51: f 10.7859 trial_f 11.4907 accepted 0  lowest_f 10.2505
# basinhopping step 52: f 10.3727 trial_f 10.3727 accepted 1  lowest_f 10.2505
# basinhopping step 53: f 10.3727 trial_f 10.4358 accepted 0  lowest_f 10.2505
# basinhopping step 54: f 10.2881 trial_f 10.2881 accepted 1  lowest_f 10.2505
# basinhopping step 55: f 10.2881 trial_f 10.7767 accepted 0  lowest_f 10.2505
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 10.9657 trial_f 10.9657 accepted 1  lowest_f 10.2505
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 35
#          Function evaluations: 80
# basinhopping step 0: f 0.00216976
# basinhopping step 1: f 0.0291999 trial_f 0.0291999 accepted 1  lowest_f 0.00216976
# basinhopping step 2: f 0.461337 trial_f 0.461337 accepted 1  lowest_f 0.00216976
# basinhopping step 3: f 0.461337 trial_f 1.04467 accepted 0  lowest_f 0.00216976
# basinhopping step 4: f 0.0248554 trial_f 0.0248554 accepted 1  lowest_f 0.00216976
# basinhopping step 5: f 0.131815 trial_f 0.131815 accepted 1  lowest_f 0.00216976
# basinhopping step 6: f 0.131815 trial_f 1.42053 accepted 0  lowest_f 0.00216976
# basinhopping step 7: f 0.131815 trial_f 0.714014 accepted 0  lowest_f 0.00216976
# basinhopping step 8: f 0.163031 trial_f 0.163031 accepted 1  lowest_f 0.00216976
# basinhopping step 9: f 0.409981 trial_f 0.409981 accepted 1  lowest_f 0.00216976
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.105121 trial_f 0.105121 accepted 1  lowest_f 0.00216976
# basinhopping step 11: f 0.286204 trial_f 0.286204 accepted 1  lowest_f 0.00216976
# basinhopping step 12: f 0.286204 trial_f 1.13631 accepted 0  lowest_f 0.00216976
# basinhopping step 13: f 1.80092 trial_f 1.80092 accepted 1  lowest_f 0.00216976
# basinhopping step 14: f 2.46971 trial_f 2.46971 accepted 1  lowest_f 0.00216976
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 2.46971 trial_f 4.73533 accepted 0  lowest_f 0.00216976
# basinhopping step 16: f 0.544372 trial_f 0.544372 accepted 1  lowest_f 0.00216976
# basinhopping step 17: f 0.337579 trial_f 0.337579 accepted 1  lowest_f 0.00216976
# basinhopping step 18: f 1.98818 trial_f 1.98818 accepted 1  lowest_f 0.00216976
# basinhopping step 19: f 1.15259 trial_f 1.15259 accepted 1  lowest_f 0.00216976
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 1.05421 trial_f 1.05421 accepted 1  lowest_f 0.00216976
# basinhopping step 21: f 1.05421 trial_f 2.33169 accepted 0  lowest_f 0.00216976
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000003
#          Iterations: 49
#          Function evaluations: 144
# basinhopping step 0: f 2.89265
# basinhopping step 1: f 2.53163 trial_f 2.53163 accepted 1  lowest_f 2.53163
# found new global minimum on step 1 with function value 2.53163
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 2.7218 trial_f 2.7218 accepted 1  lowest_f 2.53163
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 2.48556 trial_f 2.48556 accepted 1  lowest_f 2.48556
# found new global minimum on step 3 with function value 2.48556
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 2.16485 trial_f 2.16485 accepted 1  lowest_f 2.16485
# found new global minimum on step 4 with function value 2.16485
# basinhopping step 5: f 2.17785 trial_f 2.17785 accepted 1  lowest_f 2.16485
# basinhopping step 6: f 2.04466 trial_f 2.04466 accepted 1  lowest_f 2.04466
# found new global minimum on step 6 with function value 2.04466
# basinhopping step 7: f 1.94647 trial_f 1.94647 accepted 1  lowest_f 1.94647
# found new global minimum on step 7 with function value 1.94647
# basinhopping step 8: f 1.82207 trial_f 1.82207 accepted 1  lowest_f 1.82207
# found new global minimum on step 8 with function value 1.82207
# basinhopping step 9: f 1.79449 trial_f 1.79449 accepted 1  lowest_f 1.79449
# found new global minimum on step 9 with function value 1.79449
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 1.935 trial_f 1.935 accepted 1  lowest_f 1.79449
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 1.935 trial_f 2.06987 accepted 0  lowest_f 1.79449
# warning: basinhopping: local minimization failure
# basinhopping step 12: f 1.935 trial_f 2.18461 accepted 0  lowest_f 1.79449
# basinhopping step 13: f 1.85316 trial_f 1.85316 accepted 1  lowest_f 1.79449
# basinhopping step 14: f 1.7864 trial_f 1.7864 accepted 1  lowest_f 1.7864
# found new global minimum on step 14 with function value 1.7864
# basinhopping step 15: f 1.91082 trial_f 1.91082 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 1.88022 trial_f 1.88022 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 1.90163 trial_f 1.90163 accepted 1  lowest_f 1.7864
# basinhopping step 18: f 1.91937 trial_f 1.91937 accepted 1  lowest_f 1.7864
# basinhopping step 19: f 1.82599 trial_f 1.82599 accepted 1  lowest_f 1.7864
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 1.79083 trial_f 1.79083 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 1.90987 trial_f 1.90987 accepted 1  lowest_f 1.7864
# basinhopping step 22: f 1.8088 trial_f 1.8088 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 1.98919 trial_f 1.98919 accepted 1  lowest_f 1.7864
# basinhopping step 24: f 1.91764 trial_f 1.91764 accepted 1  lowest_f 1.7864
# basinhopping step 25: f 1.8008 trial_f 1.8008 accepted 1  lowest_f 1.7864
# basinhopping step 26: f 1.93809 trial_f 1.93809 accepted 1  lowest_f 1.7864
# basinhopping step 27: f 2.16676 trial_f 2.16676 accepted 1  lowest_f 1.7864
# basinhopping step 28: f 2.41357 trial_f 2.41357 accepted 1  lowest_f 1.7864
# basinhopping step 29: f 2.7116 trial_f 2.7116 accepted 1  lowest_f 1.7864
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 2.83621 trial_f 2.83621 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 2.52268 trial_f 2.52268 accepted 1  lowest_f 1.7864
# basinhopping step 32: f 2.29502 trial_f 2.29502 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 2.60247 trial_f 2.60247 accepted 1  lowest_f 1.7864
# basinhopping step 34: f 2.77266 trial_f 2.77266 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 2.37705 trial_f 2.37705 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 36: f 2.27253 trial_f 2.27253 accepted 1  lowest_f 1.7864
# basinhopping step 37: f 1.94183 trial_f 1.94183 accepted 1  lowest_f 1.7864
# basinhopping step 38: f 2.00302 trial_f 2.00302 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 2.13203 trial_f 2.13203 accepted 1  lowest_f 1.7864
# adaptive stepsize: acceptance rate 0.925000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 2.01312 trial_f 2.01312 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 2.22938 trial_f 2.22938 accepted 1  lowest_f 1.7864
# basinhopping step 42: f 2.48377 trial_f 2.48377 accepted 1  lowest_f 1.7864
# basinhopping step 43: f 2.15798 trial_f 2.15798 accepted 1  lowest_f 1.7864
# basinhopping step 44: f 2.1912 trial_f 2.1912 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 45: f 2.1912 trial_f 2.47967 accepted 0  lowest_f 1.7864
# basinhopping step 46: f 1.89838 trial_f 1.89838 accepted 1  lowest_f 1.7864
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 1.76578 trial_f 1.76578 accepted 1  lowest_f 1.76578
# found new global minimum on step 47 with function value 1.76578
# basinhopping step 48: f 1.80711 trial_f 1.80711 accepted 1  lowest_f 1.76578
# basinhopping step 49: f 1.76736 trial_f 1.76736 accepted 1  lowest_f 1.76578
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 1.78462 trial_f 1.78462 accepted 1  lowest_f 1.76578
# basinhopping step 51: f 1.78681 trial_f 1.78681 accepted 1  lowest_f 1.76578
# basinhopping step 52: f 1.81693 trial_f 1.81693 accepted 1  lowest_f 1.76578
# basinhopping step 53: f 2.08893 trial_f 2.08893 accepted 1  lowest_f 1.76578
# basinhopping step 54: f 2.30096 trial_f 2.30096 accepted 1  lowest_f 1.76578
# basinhopping step 55: f 1.93201 trial_f 1.93201 accepted 1  lowest_f 1.76578
# basinhopping step 56: f 1.87956 trial_f 1.87956 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 57: f 1.91917 trial_f 1.91917 accepted 1  lowest_f 1.76578
# basinhopping step 58: f 2.31052 trial_f 2.31052 accepted 1  lowest_f 1.76578
# basinhopping step 59: f 2.68801 trial_f 2.68801 accepted 1  lowest_f 1.76578
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 2.72085 trial_f 2.72085 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 61: f 2.43143 trial_f 2.43143 accepted 1  lowest_f 1.76578
# basinhopping step 62: f 2.58667 trial_f 2.58667 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 63: f 2.18844 trial_f 2.18844 accepted 1  lowest_f 1.76578
# basinhopping step 64: f 2.61975 trial_f 2.61975 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 2.77099 trial_f 2.77099 accepted 1  lowest_f 1.76578
# basinhopping step 66: f 2.67683 trial_f 2.67683 accepted 1  lowest_f 1.76578
# basinhopping step 67: f 2.70946 trial_f 2.70946 accepted 1  lowest_f 1.76578
# basinhopping step 68: f 2.87113 trial_f 2.87113 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 69: f 2.60519 trial_f 2.60519 accepted 1  lowest_f 1.76578
# adaptive stepsize: acceptance rate 0.942857 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# warning: basinhopping: local minimization failure
# basinhopping step 70: f 2.60519 trial_f 3.14023 accepted 0  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 3.16816 trial_f 3.16816 accepted 1  lowest_f 1.76578
# basinhopping step 72: f 3.42067 trial_f 3.42067 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 73: f 3.40176 trial_f 3.40176 accepted 1  lowest_f 1.76578
# basinhopping step 74: f 3.60488 trial_f 3.60488 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 75: f 3.53567 trial_f 3.53567 accepted 1  lowest_f 1.76578
# basinhopping step 76: f 3.02236 trial_f 3.02236 accepted 1  lowest_f 1.76578
# basinhopping step 77: f 2.31979 trial_f 2.31979 accepted 1  lowest_f 1.76578
# warning: basinhopping: local minimization failure
# basinhopping step 78: f 1.92444 trial_f 1.92444 accepted 1  lowest_f 1.76578
# basinhopping step 79: f 1.94769 trial_f 1.94769 accepted 1  lowest_f 1.76578
# adaptive stepsize: acceptance rate 0.937500 target 0.500000 new stepsize 0.116153 old stepsize 0.104538
# basinhopping step 80: f 2.09628 trial_f 2.09628 accepted 1  lowest_f 1.76578
# basinhopping step 0: f 14.0283
# basinhopping step 1: f 14.731 trial_f 14.731 accepted 1  lowest_f 14.0283
# basinhopping step 2: f 16.2755 trial_f 16.2755 accepted 1  lowest_f 14.0283
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 14.9576 trial_f 14.9576 accepted 1  lowest_f 14.0283
# basinhopping step 4: f 14.2454 trial_f 14.2454 accepted 1  lowest_f 14.0283
# basinhopping step 5: f 13.9557 trial_f 13.9557 accepted 1  lowest_f 13.9557
# found new global minimum on step 5 with function value 13.9557
# basinhopping step 6: f 13.9557 trial_f 14.1914 accepted 0  lowest_f 13.9557
# basinhopping step 7: f 15.3818 trial_f 15.3818 accepted 1  lowest_f 13.9557
# warning: basinhopping: local minimization failure
# basinhopping step 8: f 14.6605 trial_f 14.6605 accepted 1  lowest_f 13.9557
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 14.6605 trial_f 15.388 accepted 0  lowest_f 13.9557
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 14.6605 trial_f 16.3845 accepted 0  lowest_f 13.9557
# ...
# basinhopping step 69: f 10.4093 trial_f 10.4093 accepted 1  lowest_f 10.1797
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# basinhopping step 70: f 11.0693 trial_f 11.0693 accepted 1  lowest_f 10.1797
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 11.0693 trial_f 13.4716 accepted 0  lowest_f 10.1797
# basinhopping step 72: f 11.0693 trial_f 13.1625 accepted 0  lowest_f 10.1797
# basinhopping step 73: f 12.4 trial_f 12.4 accepted 1  lowest_f 10.1797
# basinhopping step 74: f 13.2214 trial_f 13.2214 accepted 1  lowest_f 10.1797
# basinhopping step 75: f 10.7546 trial_f 10.7546 accepted 1  lowest_f 10.1797
# warning: basinhopping: local minimization failure
# basinhopping step 76: f 12.5227 trial_f 12.5227 accepted 1  lowest_f 10.1797
# basinhopping step 77: f 12.5227 trial_f 15.1717 accepted 0  lowest_f 10.1797
# basinhopping step 78: f 11.5728 trial_f 11.5728 accepted 1  lowest_f 10.1797
# basinhopping step 79: f 12.1666 trial_f 12.1666 accepted 1  lowest_f 10.1797
# adaptive stepsize: acceptance rate 0.787500 target 0.500000 new stepsize 0.116153 old stepsize 0.104538
# basinhopping step 80: f 10.9694 trial_f 10.9694 accepted 1  lowest_f 10.1797
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 36
#          Function evaluations: 81
# basinhopping step 0: f 0.0017392
# basinhopping step 1: f 0.166564 trial_f 0.166564 accepted 1  lowest_f 0.0017392
# basinhopping step 2: f 0.0260416 trial_f 0.0260416 accepted 1  lowest_f 0.0017392
# basinhopping step 3: f 0.0481881 trial_f 0.0481881 accepted 1  lowest_f 0.0017392
# basinhopping step 4: f 0.00748608 trial_f 0.00748608 accepted 1  lowest_f 0.0017392
# basinhopping step 5: f 0.00980425 trial_f 0.00980425 accepted 1  lowest_f 0.0017392
# basinhopping step 6: f 0.67785 trial_f 0.67785 accepted 1  lowest_f 0.0017392
# basinhopping step 7: f 0.67785 trial_f 1.48077 accepted 0  lowest_f 0.0017392
# basinhopping step 8: f 0.594064 trial_f 0.594064 accepted 1  lowest_f 0.0017392
# basinhopping step 9: f 0.0359012 trial_f 0.0359012 accepted 1  lowest_f 0.0017392
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.363826 trial_f 0.363826 accepted 1  lowest_f 0.0017392
# basinhopping step 11: f 0.109939 trial_f 0.109939 accepted 1  lowest_f 0.0017392
# basinhopping step 12: f 1.48439 trial_f 1.48439 accepted 1  lowest_f 0.0017392
# warning: basinhopping: local minimization failure
# basinhopping step 13: f 1.55373 trial_f 1.55373 accepted 1  lowest_f 0.0017392
# basinhopping step 14: f 0.327847 trial_f 0.327847 accepted 1  lowest_f 0.0017392
# basinhopping step 15: f 0.172772 trial_f 0.172772 accepted 1  lowest_f 0.0017392
# basinhopping step 16: f 0.324269 trial_f 0.324269 accepted 1  lowest_f 0.0017392
# basinhopping step 17: f 0.326069 trial_f 0.326069 accepted 1  lowest_f 0.0017392
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 0.326069 trial_f 0.827579 accepted 0  lowest_f 0.0017392
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 0.0108363 trial_f 0.0108363 accepted 1  lowest_f 0.0017392
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 0.0108363 trial_f 0.301155 accepted 0  lowest_f 0.0017392
# basinhopping step 21: f 0.164425 trial_f 0.164425 accepted 1  lowest_f 0.0017392
# basinhopping finished
# Optimization terminated successfully.
#          Current function value: 0.000003
#          Iterations: 57
#          Function evaluations: 168
# basinhopping step 0: f 2.8408
# basinhopping step 1: f 3.16982 trial_f 3.16982 accepted 1  lowest_f 2.8408
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 3.03879 trial_f 3.03879 accepted 1  lowest_f 2.8408
# basinhopping step 3: f 2.78851 trial_f 2.78851 accepted 1  lowest_f 2.78851
# found new global minimum on step 3 with function value 2.78851
# basinhopping step 4: f 2.96862 trial_f 2.96862 accepted 1  lowest_f 2.78851
# basinhopping step 5: f 2.95748 trial_f 2.95748 accepted 1  lowest_f 2.78851
# basinhopping step 6: f 3.2116 trial_f 3.2116 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 3.28424 trial_f 3.28424 accepted 1  lowest_f 2.78851
# basinhopping step 8: f 3.26694 trial_f 3.26694 accepted 1  lowest_f 2.78851
# basinhopping step 9: f 3.03893 trial_f 3.03893 accepted 1  lowest_f 2.78851
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 3.03795 trial_f 3.03795 accepted 1  lowest_f 2.78851
# basinhopping step 11: f 2.95458 trial_f 2.95458 accepted 1  lowest_f 2.78851
# basinhopping step 12: f 3.22321 trial_f 3.22321 accepted 1  lowest_f 2.78851
# basinhopping step 13: f 3.0873 trial_f 3.0873 accepted 1  lowest_f 2.78851
# basinhopping step 14: f 3.23399 trial_f 3.23399 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 3.36762 trial_f 3.36762 accepted 1  lowest_f 2.78851
# basinhopping step 16: f 3.02762 trial_f 3.02762 accepted 1  lowest_f 2.78851
# basinhopping step 17: f 2.93777 trial_f 2.93777 accepted 1  lowest_f 2.78851
# basinhopping step 18: f 3.27205 trial_f 3.27205 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 3.20465 trial_f 3.20465 accepted 1  lowest_f 2.78851
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 3.26187 trial_f 3.26187 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 3.26909 trial_f 3.26909 accepted 1  lowest_f 2.78851
# basinhopping step 22: f 3.51898 trial_f 3.51898 accepted 1  lowest_f 2.78851
# basinhopping step 23: f 3.48097 trial_f 3.48097 accepted 1  lowest_f 2.78851
# basinhopping step 24: f 3.82967 trial_f 3.82967 accepted 1  lowest_f 2.78851
# basinhopping step 25: f 3.74243 trial_f 3.74243 accepted 1  lowest_f 2.78851
# basinhopping step 26: f 3.49008 trial_f 3.49008 accepted 1  lowest_f 2.78851
# basinhopping step 27: f 3.54847 trial_f 3.54847 accepted 1  lowest_f 2.78851
# basinhopping step 28: f 3.65132 trial_f 3.65132 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 29: f 3.90032 trial_f 3.90032 accepted 1  lowest_f 2.78851
# adaptive stepsize: acceptance rate 0.966667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# warning: basinhopping: local minimization failure
# basinhopping step 30: f 3.59662 trial_f 3.59662 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 3.33759 trial_f 3.33759 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 3.51167 trial_f 3.51167 accepted 1  lowest_f 2.78851
# basinhopping step 33: f 3.75919 trial_f 3.75919 accepted 1  lowest_f 2.78851
# basinhopping step 34: f 3.30851 trial_f 3.30851 accepted 1  lowest_f 2.78851
# basinhopping step 35: f 3.30851 trial_f 3.67736 accepted 0  lowest_f 2.78851
# basinhopping step 36: f 3.46554 trial_f 3.46554 accepted 1  lowest_f 2.78851
# basinhopping step 37: f 3.50732 trial_f 3.50732 accepted 1  lowest_f 2.78851
# basinhopping step 38: f 3.22967 trial_f 3.22967 accepted 1  lowest_f 2.78851
# basinhopping step 39: f 2.9585 trial_f 2.9585 accepted 1  lowest_f 2.78851
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 2.9585 trial_f 3.36793 accepted 0  lowest_f 2.78851
# basinhopping step 41: f 3.24224 trial_f 3.24224 accepted 1  lowest_f 2.78851
# basinhopping step 42: f 3.44192 trial_f 3.44192 accepted 1  lowest_f 2.78851
# basinhopping step 43: f 3.46631 trial_f 3.46631 accepted 1  lowest_f 2.78851
# basinhopping step 44: f 3.86336 trial_f 3.86336 accepted 1  lowest_f 2.78851
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 13.9505
# basinhopping step 1: f 13.9505 trial_f 15.4105 accepted 0  lowest_f 13.9505
# basinhopping step 2: f 13.5549 trial_f 13.5549 accepted 1  lowest_f 13.5549
# found new global minimum on step 2 with function value 13.5549
# basinhopping step 3: f 13.5549 trial_f 14.9725 accepted 0  lowest_f 13.5549
# basinhopping step 4: f 14.8547 trial_f 14.8547 accepted 1  lowest_f 13.5549
# basinhopping step 5: f 14.0336 trial_f 14.0336 accepted 1  lowest_f 13.5549
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 14.0336 trial_f 15.1925 accepted 0  lowest_f 13.5549
# basinhopping step 7: f 14.7722 trial_f 14.7722 accepted 1  lowest_f 13.5549
# warning: basinhopping: local minimization failure
# basinhopping step 8: f 14.7722 trial_f 15.2458 accepted 0  lowest_f 13.5549
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 13.7874 trial_f 13.7874 accepted 1  lowest_f 13.5549
# adaptive stepsize: acceptance rate 0.500000 target 0.500000 new stepsize 0.045 old stepsize 0.05
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 13.7874 trial_f 14.5719 accepted 0  lowest_f 13.5549
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 12.453 trial_f 12.453 accepted 1  lowest_f 12.453
# found new global minimum on step 11 with function value 12.453
# basinhopping step 12: f 12.453 trial_f 12.5558 accepted 0  lowest_f 12.453
# basinhopping step 13: f 11.6313 trial_f 11.6313 accepted 1  lowest_f 11.6313
# found new global minimum on step 13 with function value 11.6313
# basinhopping step 14: f 11.1132 trial_f 11.1132 accepted 1  lowest_f 11.1132
# found new global minimum on step 14 with function value 11.1132
# basinhopping step 15: f 10.727 trial_f 10.727 accepted 1  lowest_f 10.727
# found new global minimum on step 15 with function value 10.727
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0e857a3d46ac> in <module>()
#       2 m.inits=popt
#       3 for i in range(20):
# ----> 4       m.optimize(stage='full', multiopt=True)
#       5       #finfo_list.append(m.fitinfo.T)
#       6       #x = pd.DataFrame(m.fitinfo.T)#.to_csv('finfo.csv')
#
# /home/kyle/Dropbox/Git/radd/build.py in optimize(self, save, savepth, ntrials, tol, maxfev, niter, disp, prob, multiopt, stage, inits, y)
#      74                   self.fits, self.fitinfo, self.popt = y, fi, p
#      75             else:
# ---> 76                   y, fi, p = self.opt.optimize_model(save=save, savepth=savepth)
#      77                   self.fits, self.fitinfo, self.popt = y, fi, p
#      78
#
# /home/kyle/Dropbox/Git/radd/fit.py in optimize_model(self, save, savepth)
#      71
#      72             if self.fit_on=='average':
# ---> 73                   self.yhat, self.fitinfo, self.popt = self.__opt_routine__()
#      74             elif self.fit_on in ['subjects', 'bootstrap']:
#      75                   self.__indx_optimize__(save=save, savepth=savepth)
#
# /home/kyle/Dropbox/Git/radd/fit.py in __opt_routine__(self)
#     151             flat_yh, flat_fi, flat_p = self.optimize_flat()
#     152             # STAGE 2 (Nudge/BasinHopping) & STAGE 3 (Final Simplex)
# --> 153             yhat, finfo, popt = self.optimize_conditional(p=flat_p)
#     154
#     155             return yhat, finfo, popt
#
# /home/kyle/Dropbox/Git/radd/fit.py in optimize_conditional(self, p, y, precond)
#     135             if precond and self.multiopt:
#     136                   # pretune conditional parameters (1/time)
# --> 137                   p2 = self.single_basin(p2)
#     138
#     139             # STAGE 3: (Final Simplex)
#
# /home/kyle/Dropbox/Git/radd/fit.py in single_basin(self, p, disp, interval, niter, stepsize, nsuccess)
#     253             for i, x in enumerate(vals):
#     254                   self.simulator.__update__(is_flat=True, y=self.bdata[i], wts=self.bwts[i])
# --> 255                   out = basinhopping(self.simulator.basinhopping_minimizer, x, stepsize=stepsize, minimizer_kwargs=mkwargs, interval=interval, niter=niter, niter_success=nsuccess, disp=disp)
#     256                   xbasin.append(out.x)
#     257             for i, pk in enumerate(pkeys):
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success)
#     612                " successfully"]
#     613     for i in range(niter):
# --> 614         new_global_min = bh.one_cycle()
#     615
#     616         if isinstance(callback, collections.Callable):
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in one_cycle(self)
#     154         new_global_min = False
#     155
# --> 156         xtrial, energy_trial, accept = self._monte_carlo_step()
#     157
#     158         if accept:
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in _monte_carlo_step(self)
#     102
#     103         # do a local minimization
# --> 104         minres = self.minimizer(x_after_step)
#     105         x_after_quench = minres.x
#     106         energy_after_quench = minres.fun
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_basinhopping.pyc in __call__(self, x0)
#     277             return self.minimizer(x0, **self.kwargs)
#     278         else:
# --> 279             return self.minimizer(self.func, x0, **self.kwargs)
#     280
#     281
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     445     elif meth == 'tnc':
#     446         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
# --> 447                              **options)
#     448     elif meth == 'cobyla':
#     449         return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/tnc.pyc in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, **unknown_options)
#     407                                         offset, messages, maxCGit, maxfun,
#     408                                         eta, stepmx, accuracy, fmin, ftol,
# --> 409                                         xtol, pgtol, rescale, callback)
#     410
#     411     funv, jacv = func_and_grad(x)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/tnc.pyc in func_and_grad(x)
#     365         def func_and_grad(x):
#     366             f = fun(x, *args)
# --> 367             g = approx_fprime(x, fun, epsilon, *args)
#     368             return f, g
#     369     else:
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in approx_fprime(xk, f, epsilon, *args)
#     616
#     617     """
# --> 618     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     619
#     620
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     556         ei[k] = 1.0
#     557         d = epsilon * ei
# --> 558         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     559         ei[k] = 0.0
#     560     return grad
#
# /home/kyle/Dropbox/Git/radd/models.pyc in basinhopping_minimizer(self, x)
#     105                   return 1.e5
#     106
# --> 107             yhat = self.sim_fx(p)
#     108             cost = np.sum((self.wts*(yhat-self.y)**2))
#     109             if hasattr(cost, '__iter__'):
#
# /home/kyle/Dropbox/Git/radd/models.pyc in simulate_radd(self, p, analyze)
#     251             nssd = self.nssd; nss= self.nss;
#     252             nc = self.ncond; dx=self.dx; ntot=self.ntot
# --> 253             DVg = self.xtb[:,na]*np.cumsum(np.where((rs((nc, ntot, Tg.max())).T<Pg),dx,-dx).T, axis=2)
#     254             if 'radd' in self.kind:
#     255                   DVg+=p['z']
#
# KeyboardInterrupt:

# %%
x1 = {'a_bsl':   0.529353,
'a_pnl': 0.553150,
'xb': 0.817502,
'ssv': -1.104875,
'tr': 0.185667,
'v': 1.208608,
'z': 0.0436727}

x2 = {'a': 0.3964024,
 'ssv': -0.7881214,
 'tr': 0.2915253,
 'v_bsl': 0.93931011,
 'v_pnl': 0.88324705,
 'xb': 1.667787,
 'z': 0.1177627}

x3={'a': 0.44534253,
 'ssv':  -.9073797,
 'tr_bsl':   0.29969275,
 'tr_pnl':   0.31056620,
 'v': 0.965766,
 'xb': 1.52569355,
 'z': 0.1591336}

x4={'a': 0.44534253,
 'ssv':  -1.564015,
 'tr_bsl': 0.19521031,
 'tr_pnl': 0.19703793,
 'v_bsl': 1.80694264,
 'v_pnl': 1.75763984,
 'xb': 1.206618,
 'z': 0.001013259}

x4['tr'] = np.mean([x4['tr_bsl'], x4['tr_pnl']])
x4['v'] = np.mean([x4['v_bsl'], x4['v_pnl']])
x2['v'] = np.mean([x2['v_bsl'], x2['v_pnl']])
x3['tr'] = np.mean([x3['tr_bsl'], x3['tr_pnl']])
x1['a'] = np.mean([x1['a_bsl'], x1['a_pnl']])

# %%
finfo_list, yhat_list = [], []

# %%
for i in range(20):
      
      xinits_list = [deepcopy(xdct) for xdct in [x1,x2,x3,x4]]
      parameter = 'v'
      depends_on = {parameter:'Cond'}

      d = '/'.join(['FinalRe', parameter+'iii'])
      if not os.path.isdir(pth+d):
            os.mkdir(pth+d)
      os.chdir(pth+d)

      for xi in xinits_list:
            model = build.Model(data=redata, kind='xradd', inits=xi, depends_on=depends_on)
            model.make_optimizer(tol=1.e-5, multiopt=True, maxfev=500)
            opt=model.opt
            opt.make_simulator()

            ydata, ywts = model.avg_y, model.avg_wts
            # STAGE 3 (Final Simplex)
            yhat, finfo, xiv = opt.gradient_descent(y=ydata, wts=ywts, inits=xi, is_flat=False)

            finfo_list.append(finfo)
            yhat_list.append(yhat)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 26
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: 0.000052
#          Iterations: 87
#          Function evaluations: 240
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 26
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.000059
#          Iterations: 36
#          Function evaluations: 84
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 22
#          Function evaluations: 60
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 21
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: 0.000057
#          Iterations: 23
#          Function evaluations: 65
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 23
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.000051
#          Iterations: 141
#          Function evaluations: 370
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 23
#          Function evaluations: 59
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000166
#          Iterations: 71
#          Function evaluations: 173
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 24
#          Function evaluations: 58
# Optimization terminated successfully.
#          Current function value: 0.000058
#          Iterations: 28
#          Function evaluations: 71
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000013
#          Iterations: 21
#          Function evaluations: 58
# Optimization terminated successfully.
#          Current function value: 0.000073
#          Iterations: 99
#          Function evaluations: 268
# Optimization terminated successfully.
#          Current function value: 0.000167
#          Iterations: 70
#          Function evaluations: 183
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 23
#          Function evaluations: 57
# Optimization terminated successfully.
#          Current function value: 0.000048
#          Iterations: 79
#          Function evaluations: 212
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 25
#          Function evaluations: 60
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000166
#          Iterations: 55
#          Function evaluations: 134
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 25
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: 0.000058
#          Iterations: 26
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.000170
#          Iterations: 39
#          Function evaluations: 105
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 20
#          Function evaluations: 56
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 28
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: 0.000063
#          Iterations: 29
#          Function evaluations: 72
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 21
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 0.000060
#          Iterations: 28
#          Function evaluations: 74
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 27
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: 0.000059
#          Iterations: 24
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: 0.000173
#          Iterations: 82
#          Function evaluations: 216
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 29
#          Function evaluations: 68
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 23
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: 0.000058
#          Iterations: 42
#          Function evaluations: 114
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 28
#          Function evaluations: 61
# Optimization terminated successfully.
#          Current function value: 0.000050
#          Iterations: 79
#          Function evaluations: 213
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000015
#          Iterations: 28
#          Function evaluations: 60
# Optimization terminated successfully.
#          Current function value: 0.000061
#          Iterations: 31
#          Function evaluations: 82
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 23
#          Function evaluations: 53
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 0.000172
#          Iterations: 41
#          Function evaluations: 95
# Warning: Maximum number of function evaluations has been exceeded.

# %%
dfx = pd.DataFrame([fi.T for fi in finfo_list])
dff = dfx[['cnvrg', 'logp', 'chi', 'rchi', 'AIC', 'BIC', 'a', 'v_bsl', 'v_pnl', 'ssv', 'xb', 'tr', 'z']]
dff.to_csv('xradd_v_bootinfo.csv', index=False)

yfits = np.vstack([np.vstack(yh.reshape(2,16)) for yh in yhat_list])
cond = ['bsl', 'pnl']*int(len(yfits)/2)
yhatdf = pd.DataFrame(yfits)
yhatdf.insert(0, 'Cond', cond)
yhatdf.to_csv('xradd_v_bootfits.csv')

# %%
f, axes = plt.subplots(2,3,figsize=(12, 7))
sns.set_context('notebook', font_scale=1.6)
fits=m.fits.reshape(2,16)
y=m.avg_y
labels=['Baseline', 'Caution']
datas=[redata.query('Cond=="bsl"'), redata.query('Cond=="pnl"')]
colors=["#e74c3c"]*2
for i in range(m.ncond):
      vis.plot_fits(y[i], fits[i], kind='radd', colors=["#e74c3c"]*2, data=datas[i], axes=axes[i])

for ax in axes.flatten():
      if ax.is_last_col():
            continue
      ax.set_ylim(0,11)

plt.savefig('re_drift_fitsII.png', dpi=500)
plt.savefig('re_drift_fitsII.svg', rasterized=True)
