# %%
# %%capture
import radd
from radd import build
from radd.tools import vis
# %matplotlib inline

# %%
from os import path
import pandas as pd
_homedir = path.expanduser('~')
coxon_data_dir = path.join(_homedir, "Dropbox/Projects/Coxon/coxon_behav_data.csv")
coxon_data = pd.read_csv(coxon_data_dir)

# initiate dependent process model with dynamic gain (kind = 'xdpm')
# (change kind='dpm' for model with no dynamic gain signal)
# drift-rate (v) depends on Baseline and Caution levels of 'Cond' variable
dpm = build.Model(kind='xdpm', data=coxon_data, depends_on={'v':'Cond'}, fit_on='average')

# initiate independent race model with dynamic gain (kind = 'xirace')
# irm = build.Model(kind='xirace', data=coxon_data, depends_on={'v':'Cond'}, fit_on='average')

# %% [markdown]
# ## Animation of Dependent Process Model

# %%
# Initial state of Stop process (red) depends on current strength of Go activation (green)
# Assumes Stop signal efficacy at later SSDs diminishes as the state of the Go process 
# approaches the execution threshold (upper bound). pink lines denote t=SSD, blue is trial deadline
radd.load_dpm_animation()
# Out:
# <video width="50%" alt="test" loop=1 controls> <source src="data:video/mp4; base64,..." type="video/mp4" /> </video>

# %% [markdown]
# ### columns in model's observed dataframe (model.observedDF)
# * **idx**: subject ID
# * **Cond**: Baseline(bsl)/Caution(pnl) (could be any experimental condition of interest)
# * **Acc**: Accuracy on "go" trials
# * **sacc**: Mean accuracy on "stop" trials (mean condition SSD used during simulations)
# * **c10 - c90**: 10th - 90th RT quantiles for correct responses
# * **e10 - e90**: 10th - 90th RT quantiles for error responses

# %%
dpm.observedDF.head()
# Out:
#    idx  Cond  acc     sacc      c10      c30     c50      c70      c90  \
# 0    1   pro  1.0  0.52500  0.76784  0.79500  0.8095  0.82400  0.84916
# 1    1  reac  1.0  0.51613  0.76300  0.78300  0.7960  0.81634  0.84000
# 2    2   pro  1.0  0.48750  0.78442  0.80200  0.8150  0.83500  0.85158
# 3    2  reac  1.0  0.46774  0.78200  0.79800  0.8070  0.81914  0.83600
# 4    3   pro  1.0  0.50000  0.77282  0.79366  0.8130  0.83500  0.86200
#
#        e10      e30     e50      e70      e90
# 0  0.76066  0.77700  0.7895  0.80356  0.82402
# 1  0.75642  0.76746  0.7850  0.79854  0.81216
# 2  0.76300  0.78600  0.7970  0.81100  0.82200
# 3  0.76500  0.77900  0.7890  0.80722  0.82800
# 4  0.75310  0.78300  0.7945  0.81754  0.84812

# %% [markdown]
# ### Optimize DPM to the average data (drift-rate free across levels of "Cond")

# %%
# Set basinhopping step-size to .1 (see HopStep class in radd.fit 
# and get_stepsize_scalars function in radd.tools.theta). 
# Sample 5000 possible parameters sets, perform global opt on best 3. 
# Set disp=False to perform optimization quietly. 
dpm.set_basinparams(stepsize=.1, nrand_samples=5000, nrand_inits=3)#, disp=False)

# fit DPM using combination of global (basinhopping + TNC)
# and local gradient optimization (Nelder-Mead Simplex)
dpm.optimize(plot_fits=True)
# Out:
# default inits: fmin = 2.290466785
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 0.00250815
# basinhopping step 1: f 0.00125874 trial_f 0.00125874 accepted 1  lowest_f 0.00125874
# found new global minimum on step 1 with function value 0.00125874
# basinhopping step 2: f 0.0087772 trial_f 0.0087772 accepted 1  lowest_f 0.00125874
# basinhopping step 3: f 0.0189011 trial_f 0.0189011 accepted 1  lowest_f 0.00125874
# basinhopping step 4: f 0.0286927 trial_f 0.0286927 accepted 1  lowest_f 0.00125874
# basinhopping step 5: f 0.0286927 trial_f 0.136054 accepted 0  lowest_f 0.00125874
# basinhopping step 6: f 0.0656454 trial_f 0.0656454 accepted 1  lowest_f 0.00125874
# basinhopping step 7: f 0.0226379 trial_f 0.0226379 accepted 1  lowest_f 0.00125874
# basinhopping step 8: f 0.0530794 trial_f 0.0530794 accepted 1  lowest_f 0.00125874
# basinhopping step 9: f 0.0205069 trial_f 0.0205069 accepted 1  lowest_f 0.00125874
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.111111 old stepsize 0.1
# basinhopping step 10: f 0.0284953 trial_f 0.0284953 accepted 1  lowest_f 0.00125874
# basinhopping step 11: f 0.0593528 trial_f 0.0593528 accepted 1  lowest_f 0.00125874
# basinhopping step 12: f 0.0639794 trial_f 0.0639794 accepted 1  lowest_f 0.00125874
# basinhopping step 13: f 0.0995462 trial_f 0.0995462 accepted 1  lowest_f 0.00125874
# basinhopping step 14: f 0.0858256 trial_f 0.0858256 accepted 1  lowest_f 0.00125874
# basinhopping step 15: f 0.0627728 trial_f 0.0627728 accepted 1  lowest_f 0.00125874
# basinhopping step 16: f 0.0613269 trial_f 0.0613269 accepted 1  lowest_f 0.00125874
# basinhopping step 17: f 0.106651 trial_f 0.106651 accepted 1  lowest_f 0.00125874
# basinhopping step 18: f 0.0746315 trial_f 0.0746315 accepted 1  lowest_f 0.00125874
# basinhopping step 19: f 0.0607111 trial_f 0.0607111 accepted 1  lowest_f 0.00125874
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.123457 old stepsize 0.111111
# basinhopping step 20: f 0.00900684 trial_f 0.00900684 accepted 1  lowest_f 0.00125874
# basinhopping step 21: f 0.0476263 trial_f 0.0476263 accepted 1  lowest_f 0.00125874
# basinhopping step 22: f 0.0408334 trial_f 0.0408334 accepted 1  lowest_f 0.00125874
# basinhopping step 23: f 0.0385793 trial_f 0.0385793 accepted 1  lowest_f 0.00125874
# basinhopping step 24: f 0.0547497 trial_f 0.0547497 accepted 1  lowest_f 0.00125874
# basinhopping step 25: f 0.140992 trial_f 0.140992 accepted 1  lowest_f 0.00125874
# basinhopping step 26: f 0.170279 trial_f 0.170279 accepted 1  lowest_f 0.00125874
# basinhopping step 27: f 0.0982706 trial_f 0.0982706 accepted 1  lowest_f 0.00125874
# basinhopping step 28: f 0.0292112 trial_f 0.0292112 accepted 1  lowest_f 0.00125874
# basinhopping step 29: f 0.0873101 trial_f 0.0873101 accepted 1  lowest_f 0.00125874
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.137174 old stepsize 0.123457
# basinhopping step 30: f 0.0556571 trial_f 0.0556571 accepted 1  lowest_f 0.00125874
# basinhopping step 31: f 0.0620585 trial_f 0.0620585 accepted 1  lowest_f 0.00125874
# basinhopping step 32: f 0.0620585 trial_f 0.0941005 accepted 0  lowest_f 0.00125874
# basinhopping step 0: f 0.00293319
# basinhopping step 1: f 0.127221 trial_f 0.127221 accepted 1  lowest_f 0.00293319
# basinhopping step 2: f 0.127221 trial_f 0.154276 accepted 0  lowest_f 0.00293319
# basinhopping step 3: f 0.163227 trial_f 0.163227 accepted 1  lowest_f 0.00293319
# basinhopping step 4: f 0.103992 trial_f 0.103992 accepted 1  lowest_f 0.00293319
# basinhopping step 5: f 1.51539 trial_f 1.51539 accepted 1  lowest_f 0.00293319
# basinhopping step 6: f 1.50868 trial_f 1.50868 accepted 1  lowest_f 0.00293319
# basinhopping step 7: f 1.50964 trial_f 1.50964 accepted 1  lowest_f 0.00293319
# basinhopping step 8: f 0.108912 trial_f 0.108912 accepted 1  lowest_f 0.00293319
# basinhopping step 9: f 0.108912 trial_f 1.50997 accepted 0  lowest_f 0.00293319
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.111111 old stepsize 0.1
# basinhopping step 10: f 0.108912 trial_f 1.50911 accepted 0  lowest_f 0.00293319
# basinhopping step 11: f 0.052946 trial_f 0.052946 accepted 1  lowest_f 0.00293319
# basinhopping step 12: f 1.51947 trial_f 1.51947 accepted 1  lowest_f 0.00293319
# basinhopping step 13: f 0.0805047 trial_f 0.0805047 accepted 1  lowest_f 0.00293319
# basinhopping step 14: f 0.109411 trial_f 0.109411 accepted 1  lowest_f 0.00293319
# basinhopping step 15: f 0.0879822 trial_f 0.0879822 accepted 1  lowest_f 0.00293319
# basinhopping step 16: f 0.0879822 trial_f 1.50961 accepted 0  lowest_f 0.00293319
# basinhopping step 17: f 0.111394 trial_f 0.111394 accepted 1  lowest_f 0.00293319
# basinhopping step 18: f 0.0527947 trial_f 0.0527947 accepted 1  lowest_f 0.00293319
# basinhopping step 19: f 0.0338438 trial_f 0.0338438 accepted 1  lowest_f 0.00293319
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.123457 old stepsize 0.111111
# basinhopping step 20: f 0.0435643 trial_f 0.0435643 accepted 1  lowest_f 0.00293319
# basinhopping step 21: f 0.0484045 trial_f 0.0484045 accepted 1  lowest_f 0.00293319
# basinhopping step 22: f 0.0484045 trial_f 0.208668 accepted 0  lowest_f 0.00293319
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 0.112484 trial_f 0.112484 accepted 1  lowest_f 0.00293319
# basinhopping step 24: f 0.112484 trial_f 1.72137 accepted 0  lowest_f 0.00293319
# basinhopping step 25: f 0.150239 trial_f 0.150239 accepted 1  lowest_f 0.00293319
# basinhopping step 26: f 0.0656211 trial_f 0.0656211 accepted 1  lowest_f 0.00293319
# basinhopping step 27: f 0.116143 trial_f 0.116143 accepted 1  lowest_f 0.00293319
# basinhopping step 28: f 0.0860548 trial_f 0.0860548 accepted 1  lowest_f 0.00293319
# basinhopping step 29: f 0.0904389 trial_f 0.0904389 accepted 1  lowest_f 0.00293319
# adaptive stepsize: acceptance rate 0.766667 target 0.500000 new stepsize 0.137174 old stepsize 0.123457
# basinhopping step 30: f 0.0904389 trial_f 0.27656 accepted 0  lowest_f 0.00293319
# basinhopping step 31: f 0.0303293 trial_f 0.0303293 accepted 1  lowest_f 0.00293319
# basinhopping step 0: f 0.00296377
# basinhopping step 1: f 0.0268297 trial_f 0.0268297 accepted 1  lowest_f 0.00296377
# basinhopping step 2: f 0.00371402 trial_f 0.00371402 accepted 1  lowest_f 0.00296377
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 0.0012217 trial_f 0.0012217 accepted 1  lowest_f 0.0012217
# found new global minimum on step 3 with function value 0.0012217
# basinhopping step 4: f 0.00217604 trial_f 0.00217604 accepted 1  lowest_f 0.0012217
# basinhopping step 5: f 0.0823615 trial_f 0.0823615 accepted 1  lowest_f 0.0012217
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 0.0243136 trial_f 0.0243136 accepted 1  lowest_f 0.0012217
# basinhopping step 7: f 0.0346045 trial_f 0.0346045 accepted 1  lowest_f 0.0012217
# basinhopping step 8: f 0.0535515 trial_f 0.0535515 accepted 1  lowest_f 0.0012217
# basinhopping step 9: f 0.155347 trial_f 0.155347 accepted 1  lowest_f 0.0012217
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.111111 old stepsize 0.1
# basinhopping step 10: f 0.151972 trial_f 0.151972 accepted 1  lowest_f 0.0012217
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 0.135628 trial_f 0.135628 accepted 1  lowest_f 0.0012217
# basinhopping step 12: f 0.168643 trial_f 0.168643 accepted 1  lowest_f 0.0012217
# basinhopping step 13: f 0.180995 trial_f 0.180995 accepted 1  lowest_f 0.0012217
# basinhopping step 14: f 0.0739137 trial_f 0.0739137 accepted 1  lowest_f 0.0012217
# basinhopping step 15: f 0.0636366 trial_f 0.0636366 accepted 1  lowest_f 0.0012217
# basinhopping step 16: f 0.0649643 trial_f 0.0649643 accepted 1  lowest_f 0.0012217
# basinhopping step 17: f 0.0489103 trial_f 0.0489103 accepted 1  lowest_f 0.0012217
# basinhopping step 18: f 0.0594633 trial_f 0.0594633 accepted 1  lowest_f 0.0012217
# basinhopping step 19: f 0.0877978 trial_f 0.0877978 accepted 1  lowest_f 0.0012217
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.123457 old stepsize 0.111111
# basinhopping step 20: f 0.0446225 trial_f 0.0446225 accepted 1  lowest_f 0.0012217
# basinhopping step 21: f 0.0319953 trial_f 0.0319953 accepted 1  lowest_f 0.0012217
# basinhopping step 22: f 0.0437747 trial_f 0.0437747 accepted 1  lowest_f 0.0012217
# basinhopping step 23: f 0.0437747 trial_f 0.154133 accepted 0  lowest_f 0.0012217
# basinhopping step 24: f 0.0457382 trial_f 0.0457382 accepted 1  lowest_f 0.0012217
# basinhopping step 25: f 0.0987594 trial_f 0.0987594 accepted 1  lowest_f 0.0012217
# basinhopping step 26: f 0.123978 trial_f 0.123978 accepted 1  lowest_f 0.0012217
# basinhopping step 27: f 0.0980928 trial_f 0.0980928 accepted 1  lowest_f 0.0012217
# basinhopping step 28: f 0.0657919 trial_f 0.0657919 accepted 1  lowest_f 0.0012217
# basinhopping step 29: f 0.125686 trial_f 0.125686 accepted 1  lowest_f 0.0012217
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.137174 old stepsize 0.123457
# basinhopping step 30: f 0.10088 trial_f 0.10088 accepted 1  lowest_f 0.0012217
# basinhopping step 31: f 0.201771 trial_f 0.201771 accepted 1  lowest_f 0.0012217
# basinhopping step 32: f 0.201771 trial_f 1.66116 accepted 0  lowest_f 0.0012217
# basinhopping step 33: f 0.177257 trial_f 0.177257 accepted 1  lowest_f 0.0012217
# basinhopping step 34: f 0.058811 trial_f 0.058811 accepted 1  lowest_f 0.0012217
# NEW GLOBAL MINIMUM: fmin_new=0.001221704; fmin_inits= 2.290467)
# Finished Hopping Around
# Warning: Maximum number of function evaluations has been exceeded.
# basinhopping step 0: f 0.00216959
# basinhopping step 1: f 0.0440337 trial_f 0.0440337 accepted 1  lowest_f 0.00216959
# basinhopping step 2: f 0.110372 trial_f 0.110372 accepted 1  lowest_f 0.00216959
# basinhopping step 3: f 0.00937757 trial_f 0.00937757 accepted 1  lowest_f 0.00216959
# basinhopping step 4: f 0.0253161 trial_f 0.0253161 accepted 1  lowest_f 0.00216959
# basinhopping step 5: f 0.00479596 trial_f 0.00479596 accepted 1  lowest_f 0.00216959
# basinhopping step 6: f 0.0277329 trial_f 0.0277329 accepted 1  lowest_f 0.00216959
# basinhopping step 7: f 0.102345 trial_f 0.102345 accepted 1  lowest_f 0.00216959
# basinhopping step 8: f 0.309706 trial_f 0.309706 accepted 1  lowest_f 0.00216959
# basinhopping step 9: f 0.111372 trial_f 0.111372 accepted 1  lowest_f 0.00216959
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.111111 old stepsize 0.1
# basinhopping step 10: f 0.0440634 trial_f 0.0440634 accepted 1  lowest_f 0.00216959
# basinhopping step 11: f 0.191703 trial_f 0.191703 accepted 1  lowest_f 0.00216959
# basinhopping step 12: f 0.677129 trial_f 0.677129 accepted 1  lowest_f 0.00216959
# basinhopping step 13: f 1.2859 trial_f 1.2859 accepted 1  lowest_f 0.00216959
# basinhopping step 14: f 0.650806 trial_f 0.650806 accepted 1  lowest_f 0.00216959
# basinhopping step 15: f 0.54404 trial_f 0.54404 accepted 1  lowest_f 0.00216959
# basinhopping step 16: f 0.189188 trial_f 0.189188 accepted 1  lowest_f 0.00216959
# basinhopping step 17: f 0.0306279 trial_f 0.0306279 accepted 1  lowest_f 0.00216959
# basinhopping step 18: f 0.138065 trial_f 0.138065 accepted 1  lowest_f 0.00216959
# basinhopping step 19: f 0.124317 trial_f 0.124317 accepted 1  lowest_f 0.00216959
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.123457 old stepsize 0.111111
# basinhopping step 20: f 0.138413 trial_f 0.138413 accepted 1  lowest_f 0.00216959
# basinhopping step 21: f 0.249355 trial_f 0.249355 accepted 1  lowest_f 0.00216959
# basinhopping step 22: f 0.249355 trial_f 1.1678 accepted 0  lowest_f 0.00216959
# basinhopping step 23: f 0.286651 trial_f 0.286651 accepted 1  lowest_f 0.00216959
# basinhopping step 24: f 0.270381 trial_f 0.270381 accepted 1  lowest_f 0.00216959
# basinhopping step 25: f 0.652422 trial_f 0.652422 accepted 1  lowest_f 0.00216959
# basinhopping step 26: f 0.652422 trial_f 2.13905 accepted 0  lowest_f 0.00216959
# basinhopping step 27: f 1.33365 trial_f 1.33365 accepted 1  lowest_f 0.00216959
# basinhopping step 28: f 1.33365 trial_f 2.63497 accepted 0  lowest_f 0.00216959
# basinhopping step 29: f 1.33365 trial_f 2.6837 accepted 0  lowest_f 0.00216959
# adaptive stepsize: acceptance rate 0.833333 target 0.500000 new stepsize 0.137174 old stepsize 0.123457
# basinhopping step 30: f 1.33365 trial_f 2.60755 accepted 0  lowest_f 0.00216959
# basinhopping step 31: f 1.33365 trial_f 2.60196 accepted 0  lowest_f 0.00216959
# Warning: Maximum number of iterations has been exceeded.
# /Users/kyle/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ## if fits don't look great you can try a few different things

# %% [markdown]
# * increasing size of the parameters search and setting more conservative convergence criteria
#      * model.set_basinparams(niter_success=50, tol=1e6, nrand_inits=10, nrand_samples=10000)
#      * model.set_fitparams(maxfev=5000, tol=1e-6)

# %% [markdown]
# * Fits can also get thrown off if the cost_fx weights are unreasonable the following methods show vectors of weights applied to each value in the cost function or in other words, each column in the model.observerdDF.
#     * all models are initially fit to a flat data vector, weighted by an equal length array of weights estimated as the inverse of the measured uncertainty in each observed data point (flat meaning single-dimensional vector, collapsing across conditions)
#     * if the user supplies a **depends_on** dictionary when instantiating the model (see above), then all parameters from the initial (flat) fit are held constant except for the parameter in **depends_on.keys()** which is free to vary across levels of the condition in **depends_on.values()**.
#     * For instance, to fit a model with drift-rate free to vary across levels of 'Cond' (column in the data)
#         * depends_on = {'v': 'Cond'}
#
#
# * for **model** with **fit_on** = 'average' and **depends_on** = {**param** : **condition**}
#
# |model information | method used to calculate | how to access|
# |--|--|--|
# | flat data | **model**.observedDF.mean() | **model**.observed_flat |
# | flat weights | **model**.wtsDF.mean() | **model**.flat_wts |
# | conditional data | **model**.observedDF.groupby(**condition**).mean()| **model**.observed |
# | conditional weights | **model**.wtsDF.groupby(**condition**).mean() |  **model**.cond_wts |
#
# * if fits are wonky, check out the wts vectors to see if any contain extreme values
# * try re-running the fits with an unweighted model (all wts = 1)
#     * m = build.Model(data=data, ... weighted=False)

# %%
dpm.yhatDF
# Out:
#        idx  Cond      acc    sacc      c10      c30      c50      c70  \
# 0  average   pro  0.99995  0.4853  0.77746  0.80246  0.82246  0.84246
# 1  average  reac  0.99990  0.4908  0.77246  0.79746  0.81246  0.83746
#
#        c90      e10      e30      e50      e70      e90
# 0  0.86746  0.76246  0.77746  0.79746  0.80246  0.82246
# 1  0.86746  0.76246  0.77746  0.79746  0.80246  0.82246

# %% [markdown]
# ## Examine fits
# * txt summary of the fit results are saved to the working dir

# %%
# the fit summary (goodness of fit measures, etc.) 
dpm.fitDF
# Out:
# idx        average
# a          0.49908
# ssv        -1.2777
# tr         0.39246
# xb          1.5052
# v_pro      0.94778
# v_reac     0.96441
# nfev          1075
# nvary            2
# df              22
# chi       0.001633
# rchi    7.4229e-05
# logp        -228.2
# AIC         -224.2
# BIC        -224.33
# cnvrg            0

# %%
# model predictions
# to save as csv file: dpm.yhatDF.to_csv("path_where_you_want_to_save_to", index=False)
# to extract values as numpy ndarray: dpm.yhatDF.loc[:, 'acc':].values
dpm.yhatDF
# Out:
#        idx  Cond  acc    sacc      c10      c30      c50      c70      c90  \
# 0  average   pro  1.0  0.4790  0.78137  0.80637  0.81637  0.83637  0.86137
# 1  average  reac  1.0  0.5186  0.78137  0.80137  0.81637  0.83637  0.86137
#
#        e10      e30      e50      e70      e90
# 0  0.77137  0.79137  0.80137  0.80637  0.83637
# 1  0.77137  0.79137  0.80137  0.80637  0.82637

# %%
# best-fit parameter estimates also stored in popt dictionary
dpm.popt
# Out:
# {'a': 0.49908413581994382,
#  'ssv': -1.2777324504102632,
#  'tr': 0.39245545758723105,
#  'v': array([ 0.94778,  0.96441]),
#  'v_pro': 0.94777748486210922,
#  'v_reac': 0.96440778554936757,
#  'xb': 1.5052117872193238}

# %%
def css_styling():
    import radd
    from IPython.core.display import HTML
    css_path = os.path.join(radd._examples_dir, 'custom.css')
    styles = open(css_path, "r").read()
    return HTML(styles)
css_styling()
# Out:
# /*
#     Name:       grade3
#     Author:     Kyle Dunovan (http://github.com/dunovank)
# */
# <style>
#     body {background-color: #ffffff;}
#
#     a {color: #303030; font-family: 'Helvetica', sans-serif; }
#     div#notebook, div.CodeMirror, div.output_area pre, div.output_wrapper, div.prompt, div.CodeMirror pre {font-family:'Hack', monospace; font-size: 11pt;}
#
#     /* Hiding the ipython log */
#     div#ipython_notebook { display: none; }
#
#     /* INTRO PAGE */
#     .toolbar_info { color: #2c2c2c; font-size: 12pt; border: 0; font-family: 'Helvetica', sans-serif; text-shadow: none !important; }
#     .list_container {color: #2c2c2c; font-size: 12pt; border: 0; font-family: 'Helvetica', sans-serif;text-shadow: none !important; }
#     .breadcrumb>li {text-shadow:0 0px 0; color:#2c2c2c; font-family: 'Helvetica', sans-serif; font-size: 12pt}
#     .list_container a {color: #2c2c2c; font-family: 'Helvetica', sans-serif; font-size: 12pt; border: 0; text-shadow: none !important; }
#     .item_icon {color: #3572C6;}
#     .item_buttons .kernel-name {
#         color: #3572C6;
#     }
#     .running_notebook_icon:before {
#         color: #ff8132 !important;
#     }
#     .item_buttons .running-indicator {
#         padding-top: 4px;
#         color: #ff8132;
#     }
#     .nav-tabs > li > a:hover {
#         color: #222222;
#         background: #ffffff;
#         background-color: #ffffff;
#         background-image: none;
#         border: 1px solid #ff8132;
#         border-bottom-color: #ffffff;
#     }
#     .nav-tabs > li.active > a, .nav-tabs > li.active > a:hover, .nav-tabs > li.active > a:focus {
#         color: #222222;
#         background: #ffffff;
#         background-color: #ffffff;
#         border: 1px solid #ff8132;
#         border-bottom-color: #ffffff;
#     }
#     .nav-tabs {
#         border-bottom: 1px solid #ff8132;
#     }
#
#     /*<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>
#     *****************************************
#     COMMENT THIS LINE OUT TO RESTORE TOOLBAR
#     *****************************************
#     <<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>> */
#     div#maintoolbar {display: none !important;}
#     .list_header {
#         font-weight: normal;
#         background-color: transparent;
#         color: #4c4c4c;
#     }
#     div.list_container a:hover {color: #222222;}
#     div.list_item:hover {
#         background-color: rgba(184, 184, 184, 0.10);
#     }
#     ul#selector-menu.dropdown-menu > li > a {
#         background: #efefef;
#         background-color: #efefef;
#     }
#     ul#selector-menu.dropdown-menu > li > a:hover {
#         background: #efefef;
#         background-color: rgba(184, 184, 184, 0.10);
#     }
#
#     /* PANELS // LISTS // DROPDOWN MENUS*/
#     .dropdown-menu {
#         background-color: #efefef;
#         background: #efefef;
#         border: 2px solid #dddddd;
#         box-shadow: none;
#         padding: 0px 0;
#         font-size: 12pt;
#         text-align: left;
#         vertical-align: middle;
#     }
#     .dropdown-menu:hover {
#         background-color: #efefef;
#         border: 2px solid #dddddd;
#         box-shadow: none;
#         vertical-align: middle;
#     }
#     .dropdown-header {
#         font-size: 13pt;
#         display: block;
#         line-height: 1.25;
#         color: #333333;
#         text-decoration: underline;
#         text-decoration-color: rgba(184, 184, 184, 0.40);
#         white-space: nowrap;
#     }
#     .dropdown-menu > li > a {
#         font-size: 12pt;
#         display: block;
#         clear: both;
#         padding: 8px 20px;
#         font-weight: normal;
#         line-height: 1.25;
#         color: #333333;
#         white-space: nowrap;
#         background-color: #efefef;
#         background: #efefef;
#     }
#     .dropdown-menu > li > a:hover {
#         font-size: 12pt;
#         color: #111111;
#         display: block;
#         clear: both;
#         padding: 8px 20px;
#         font-weight: normal;
#         line-height: 1.25;
#         white-space: nowrap;
#         background: #efefef;
#         background-color: rgba(184, 184, 184, 0.30);
#     }
#     .dropdown-menu .divider {
#         height: 2px;
#         margin: 0px 0px;
#         overflow: hidden;
#         background-color: #dddddd;
#     }
#     .dropdown-submenu > .dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-top: -2px;
#         margin-left: 0px;
#         padding-top: 0px;
#     }
#     .dropdown-menu > .disabled > a, .dropdown-menu > .disabled > a:hover, .dropdown-menu > .disabled > a:focus {
#         color: #aaaaaa;
#     }
#     .modal-header {
#         padding: 15px;
#         border-bottom: 1px solid #ffffff;
#         min-height: 16.4286px;
#     }
#     .modal-content {
#         position: relative;
#         background-color: #ffffff;
#         border: 1px solid #808080;
#         border-radius: 3px;
#         box-shadow: 0px 3px 9px #808080;
#         background-clip: padding-box;
#         outline: 0px none;
#     }
#     .panel {
#         line-height: 22px;
#         fontsize: 12px;
#         margin-bottom: 18px;
#         background-color: #ffffff;
#         color: #2c2c2c;
#         box-shadow: none;
#     }
#     #running .panel-group .panel .panel-heading {
#         background-color: #ffffff;
#         padding: 4px 7px;
#         line-height: 22px;
#     }
#     #running .panel-group .panel .panel-heading a:hover {
#         color: #ff8132;
#     }
#     #running .panel-group .panel .panel-body .list_container .list_item {
#         border-bottom: 1px solid rgba(224, 224, 224, 0.55);
#     }
#     #project_name > .breadcrumb {
#         font-weight: normal;
#         color: #ff8132;
#     }
#     .rendered_html pre, .rendered_html code {
#         font-size: 12pt;
#         color: #2c2c2c;
#         line-height: 100%;
#         background: #dfdfdf;
#     }
#     body {
#         font-family: "Helvetica", Helvetica, Arial, sans-serif;
#         font-size: 12pt;
#         line-height: 1.42857;
#         color: #2c2c2c;
#     }
#     #kernel_indicator {
#         float: right !important;
#         color: #ff8132;
#     }
#     #kernel_indicator .kernel_indicator_name {
#         padding-left: 5px;
#         padding-right: 5px;
#         font-size: 13pt;
#     }
#     #modal_indicator {
#         float: right !important;
#         color: #ff8132;
#
#     }
#     .notebook_app {
#         background-color: #ffffff;
#     }
#     .notebook_app #header {
#         box-shadow: none !important;
#         background-color: #ffffff;
#     }
#     #notebook-container {
#         padding: 15px;
#         background-color: #ffffff;
#         min-height: 0px;
#         box-shadow: none;
#     }
#     #header {
#         box-shadow: none;
#         background-color: #ffffff;
#         position: relative;
#         z-index: 100;
#     }
#     #header-container {
#         padding-bottom: 5px;
#         display: none !important;
#         box-shadow: none;
#     }
#     #header .header-bar {
#         background: #ffffff;
#     }
#     /* text in output area (i.e. print some_list) */
#     div.output_html {color: #1e2429;}
#
#     /* Formatting code in text, code*/
#     .rendered_html table, .rendered_html th, .rendered_html tr, .rendered_html td {
#       border: 1px #4c4c4c; solid;
#       color: #4c4c4c;
#       background-color: #ffffff !important;
#       align-content: left !important;
#     }
#     .navbar-default {
#         background-color: #ffffff;
#         border-color: #ffffff;
#     }
#     #menubar .navbar {
#         border-top: 1px;
#         border-radius: 0 0 2px 2px;
#         margin-bottom: 0;
#         margin-top: 8px;
#     }
#     .navbar-default .navbar-nav > li > a {
#         color: #333333;
#         font-size: 14pt;
#     }
#     .navbar-default .navbar-nav > li > a:hover, .navbar-default .navbar-nav > li > a:focus {
#         color: #222222;
#         background-color: #efefef;
#     }
#     .navbar-default .navbar-nav > .open > a, .navbar-default .navbar-nav > .open > a:hover, .navbar-default .navbar-nav > .open > a:focus {
#         color: #222222;
#         background-color: #efefef;
#     }
#     .btn {
#         color: #4c4c4c;
#         background: transparent;
#         background-color: transparent;
#         font-size: 12pt;
#         font-weight: normal;
#         border: 0 none !important;
#         box-shadow: none !important;
#         text-shadow: none;
#         vertical-align: 0px;
