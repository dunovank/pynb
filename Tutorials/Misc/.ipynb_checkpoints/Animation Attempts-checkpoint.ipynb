# %%
# %matplotlib inline
from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt
import sys, time
from scipy.special import jn

x = np.linspace(0,5)
f, ax = plt.subplots()
ax.set_title("Bessel functions")

for n in range(1,10):
    time.sleep(1)
    ax.plot(x, jn(x,n))
    clear_output(wait=True)
    display(f)

# close the figure at the end, so we don't get a duplicate
# of the last plot
plt.close()

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %%
# Scatter points
#import seaborn as sns
#sns.set_style('dark')
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el27891397280206220327238318890"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el27891397280206220327238318890", {"axes": [{"xlim": [-3.0, 3.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-3.0, 3.0], "ylim": [-4.0, 3.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#D3D3D3", "alpha": 0.7, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#D3D3D3", "alpha": 0.7, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [], "markers": [], "id": "el2789139727992294800", "ydomain": [-4.0, 3.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [1.0], "offsets": "data01", "yindex": 1, "id": "el2789139727991207376", "pathtransforms": [[16.348522912120725, 0.0, 0.0, 16.348522912120725, 0.0, 0.0], [18.057420231551603, 0.0, 0.0, 18.057420231551603, 0.0, 0.0], [14.686860930116316, 0.0, 0.0, 14.686860930116316, 0.0, 0.0], [21.963488223860693, 0.0, 0.0, 21.963488223860693, 0.0, 0.0], [21.53122408051117, 0.0, 0.0, 21.53122408051117, 0.0, 0.0], [23.923899504768666, 0.0, 0.0, 23.923899504768666, 0.0, 0.0], [4.2275221872632205, 0.0, 0.0, 4.2275221872632205, 0.0, 0.0], [23.513737660604505, 0.0, 0.0, 23.513737660604505, 0.0, 0.0], [15.566836950098674, 0.0, 0.0, 15.566836950098674, 0.0, 0.0], [23.285301030086014, 0.0, 0.0, 23.285301030086014, 0.0, 0.0], [20.649705945900994, 0.0, 0.0, 20.649705945900994, 0.0, 0.0], [24.687538180298255, 0.0, 0.0, 24.687538180298255, 0.0, 0.0], [21.649315726600737, 0.0, 0.0, 21.649315726600737, 0.0, 0.0], [15.000918202283376, 0.0, 0.0, 15.000918202283376, 0.0, 0.0], [17.58687734750734, 0.0, 0.0, 17.58687734750734, 0.0, 0.0], [15.242669867443535, 0.0, 0.0, 15.242669867443535, 0.0, 0.0], [15.008471599939693, 0.0, 0.0, 15.008471599939693, 0.0, 0.0], [12.690632770345427, 0.0, 0.0, 12.690632770345427, 0.0, 0.0], [17.49727131060602, 0.0, 0.0, 17.49727131060602, 0.0, 0.0], [20.514071428802847, 0.0, 0.0, 20.514071428802847, 0.0, 0.0], [13.08425383186103, 0.0, 0.0, 13.08425383186103, 0.0, 0.0], [17.991421328113333, 0.0, 0.0, 17.991421328113333, 0.0, 0.0], [8.512166099778627, 0.0, 0.0, 8.512166099778627, 0.0, 0.0], [9.933273889151966, 0.0, 0.0, 9.933273889151966, 0.0, 0.0], [5.375203396219885, 0.0, 0.0, 5.375203396219885, 0.0, 0.0], [24.478908063511984, 0.0, 0.0, 24.478908063511984, 0.0, 0.0], [1.543675170178418, 0.0, 0.0, 1.543675170178418, 0.0, 0.0], [10.499264173442748, 0.0, 0.0, 10.499264173442748, 0.0, 0.0], [19.45026505130572, 0.0, 0.0, 19.45026505130572, 0.0, 0.0], [7.0871819110498295, 0.0, 0.0, 7.0871819110498295, 0.0, 0.0], [23.331964286514335, 0.0, 0.0, 23.331964286514335, 0.0, 0.0], [21.076289378747887, 0.0, 0.0, 21.076289378747887, 0.0, 0.0], [24.424107341029007, 0.0, 0.0, 24.424107341029007, 0.0, 0.0], [17.701843860867893, 0.0, 0.0, 17.701843860867893, 0.0, 0.0], [13.617428990821058, 0.0, 0.0, 13.617428990821058, 0.0, 0.0], [18.417325659322138, 0.0, 0.0, 18.417325659322138, 0.0, 0.0], [23.970387045732192, 0.0, 0.0, 23.9703870457321 ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
animation.Animation._repr_html_ = anim_to_html

# %%
animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
# Out:
# <video controls>
#  <source src="...

# %%
import mpld3
from mpld3 import plugins
from mpld3.utils import get_id
import collections

N_paths = 5
N_steps = 100

x = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y = y.cumsum(1)

fig, ax = plt.subplots()
labels = ["a", "b", "c", "d", "e"]
line_collections = ax.plot(x, y.T, lw=4, alpha=0.2)
#interactive_legend = plugins.InteractiveLegendPlugin(line_collections, labels)
#plugins.connect(fig, interactive_legend)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el27891397280221833767254542519"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el27891397280221833767254542519", {"axes": [{"xlim": [0.0, 10.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 10.0], "ylim": [-0.80000000000000004, 0.40000000000000013], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728022182992"}, {"color": "#007F00", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728023168400"}, {"color": "#FF0000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728023169040"}, {"color": "#00BFBF", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728023169488"}, {"color": "#BF00BF", "yindex": 5, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728023169936"}], "markers": [], "id": "el2789139728022182544", "ydomain": [-0.80000000000000004, 0.40000000000000013], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 320.0, "width": 480.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data01": [[0.0, -0.02544694890062861, 0.03649552100585897, -0.03827969284865762, 0.044454574946608164, 0.018535007007690785], [0.10101010101010101, -0.05699505375308092, 0.06280745978939119, 0.006163156193670187, 0.0734333071958338, 0.030808910152478042], [0.20202020202020202, -0.07520260559504699, 0.08861276993348008, -0.035242019625143006, 0.10386211284847016, 0.05002702557254349], [0.30303030303030304, -0.09707796348893155, 0.054035621402132576, -0.07993055016929608, 0.08987151902464022, 0.023105950359319175], [0.40404040404040403, -0.10846981649804097, 0.035755757072938814, -0.06243331455306303, 0.08188625568019336, 0.02777122308438205], [0.5050505050505051, -0.11199337976424606, 0.011206740999018475, -0.1061651464864326, 0.057798198640515, 0.06202131485880452], [0.6060606060606061, -0.07831060429665732, 0.053507315298284494, -0.11737844331075437, 0.0874593408622866, 0.07671027672524043], [0.7070707070707071, -0.08225316494696538, 0.06476452537371905, -0.16671003710890114, 0.11161260243363526, 0.09106609001028351], [0.8080808080808081, -0.13017788711733078, 0.09443027647309105, -0.13238811542562914, 0.15807404190485302, 0.12595586993040153], [0.9090909090909091, -0.11969977719933605, 0.09892867277385042, -0.16714775835572593, 0.11587104037971462, 0.13349926831563314], [1.0101010101010102, -0.07558115418963232, 0.057284134442512465, -0.16821576426223292, 0.07567454386466094, 0.14960605136254068], [1.1111111111111112, -0.07081991107295657, 0.02247754498231847, -0.19466582708458308, 0.046760644400843, 0.19949691593114394], [1.2121212121212122, -0.09771230684669907, 0.02732166062173675, -0.1874962193910779, 0.09219992852862079, 0.18442608427258675], [1.3131313131313131, -0.050947028315384224, 0.014979242580445813, -0.14426064736887606, 0.12475935036331796, 0.14298604759272313], [1.4141414141414141, -0.07652722424411039, 0.022027194532718283, -0.1064166424955294, 0.08952875871414998, 0.11335604217445294], [1.5151515151515151, -0.11005060859850874, -0.025354942835468904, -0.12376544610054131, 0.07117479873964519, 0.09254962854247153] ...

# %%
import jinja2
import json
import numpy as np
import matplotlib.pyplot as plt

import mpld3
from mpld3 import plugins, utils

class HighlightLines(plugins.PluginBase):
    """A plugin to highlight lines on hover"""

    JAVASCRIPT = """
    mpld3.register_plugin("linehighlight", LineHighlightPlugin);
    LineHighlightPlugin.prototype = Object.create(mpld3.Plugin.prototype);
    LineHighlightPlugin.prototype.constructor = LineHighlightPlugin;
    LineHighlightPlugin.prototype.requiredProps = ["line_ids"];
    LineHighlightPlugin.prototype.defaultProps = {alpha_bg:0.3, alpha_fg:1.0}
    function LineHighlightPlugin(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    LineHighlightPlugin.prototype.draw = function(){
      for(var i=0; i<this.props.line_ids.length; i++){
         var obj = mpld3.get_element(this.props.line_ids[i], this.fig),
             alpha_fg = this.props.alpha_fg;
             alpha_bg = this.props.alpha_bg;
         obj.elements()
             .on("mouseover", function(d, i){
                            d3.select(this).transition().duration(50)
                              .style("stroke-opacity", alpha_fg); })
             .on("mouseout", function(d, i){
                            d3.select(this).transition().duration(200)
                              .style("stroke-opacity", alpha_bg); });
      }
    };
    """

    def __init__(self, lines):
        self.lines = lines
        self.dict_ = {"type": "linehighlight",
                      "line_ids": [utils.get_id(line) for line in lines],
                      "alpha_bg": lines[0].get_alpha(),
                      "alpha_fg": 1.0}

# %%
N_paths = 50
N_steps = 100

x = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y = y.cumsum(1)

fig, ax = plt.subplots(subplot_kw={'xticks': [], 'yticks': []})
lines = ax.plot(x, y.T, color='blue', lw=4, alpha=0.1)
plugins.connect(fig, HighlightLines(lines))

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el2789139728019731856203805268"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("linehighlight", LineHighlightPlugin);
#     LineHighlightPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     LineHighlightPlugin.prototype.constructor = LineHighlightPlugin;
#     LineHighlightPlugin.prototype.requiredProps = ["line_ids"];
#     LineHighlightPlugin.prototype.defaultProps = {alpha_bg:0.3, alpha_fg:1.0}
#     function LineHighlightPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     LineHighlightPlugin.prototype.draw = function(){
#       for(var i=0; i<this.props.line_ids.length; i++){
#          var obj = mpld3.get_element(this.props.line_ids[i], this.fig),
#              alpha_fg = this.props.alpha_fg;
#              alpha_bg = this.props.alpha_bg;
#          obj.elements()
#              .on("mouseover", function(d, i){
#                             d3.select(this).transition().duration(50)
#                               .style("stroke-opacity", alpha_fg); })
#              .on("mouseout", function(d, i){
#                             d3.select(this).transition().duration(200)
#                               .style("stroke-opacity", alpha_bg); });
#       }
#     };
#
#        mpld3.draw_figure("fig_el2789139728019731856203805268", {"axes": [{"xlim": [0.0, 10.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 10.0], "ylim": [-0.57859277541059118, 0.96760198802440356], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728019732048"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020865808"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020866704"}, {"color": "#0000FF", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020867408"}, {"color": "#0000FF", "yindex": 5, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020868048"}, {"color": "#0000FF", "yindex": 6, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020865680"}, {"color": "#0000FF", "yindex": 7, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020868560"}, {"color": "#0000FF", "yindex": 8, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021149904"}, {"color": "#0000FF", "yindex": 9, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021150224"}, {"color": "#0000FF", "yindex": 10, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021150032"}, {"color": "#0000FF", "yindex": 11, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021150096"}, {"color": "#0000FF", "yindex": 12, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021148816"}, {"color": "#0000FF", "yindex": 13, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021151632"}, {"color": "#0000FF", "yindex": 14, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728021150672"}, {"color": "#0000FF", "yindex": 15, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020929616"}, {"color": "#0000FF", "yindex": 16, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020928976"}, {"color": "#0000FF", "yindex": 17, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020929424"}, {"color": "#0000FF", "yindex": 18, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2789139728020930448"}, {"color": "#0000FF", "yindex": 19, "coordinates": "data", "dasharra ...
