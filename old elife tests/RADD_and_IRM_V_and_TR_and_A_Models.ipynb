# %%
from copy import deepcopy
from radd import fit, models, build, vis

# %% [markdown]
# #X-RADD (hyp)

# %%
labels = ['bsl', 'pnl']

# %%
# %cd ~/Dropbox/RADD_FITS
#s.mkdir('V_HYP')
os.chdir('V_HYP')

data=redf_store.redata
depends_on = {'v':'Cond'}
kind = 'xradd'



m=build.Model(data=data, depends_on=depends_on, kind=kind, multiopt=False)

m.optimize(tol=1e-05, ntrials=5000, maxfev=500)
# Out:
# /Users/kyle/Dropbox/RADD_FITS
# ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-ff5da2029a11> in <module>()
#      11 m=build.Model(data=data, depends_on=depends_on, kind=kind, multiopt=False)
#      12
# ---> 13 m.optimize(tol=1e-05, ntrials=5000, maxfev=500)
#
# /Users/kyle/Dropbox/Git/radd/build.pyc in optimize(self, save, savepth, ntrials, tol, maxfev, niter, disp, prob)
#      74             self.opt = fit.Optimizer(dframes=self.dframes, fitparams=fp, kind=self.kind, inits=inits, depends_on=self.depends_on, fit_on=self.fit_on, wts=self.wts, pc_map=self.pc_map, multiopt=self.multiopt)
#      75
# ---> 76             self.fits, self.fitinfo, self.popt = self.opt.optimize_model(save=save, savepth=savepth)
#      77             # get residuals
#      78             self.residual = self.opt.residual
#
# ...

# %%
for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='drift_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='drift_hyp_sims'+labels[i])
# Out:
# /Users/kyle/Dropbox/RADD_FITS
# ...
# /Users/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.py:358: RuntimeWarning: Method Nelder-Mead does not use gradient information (jac).
#   RuntimeWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3aaaac7b4a48> in <module>()
#      10
#      11 m=build.Model(data=data, depends_on=depends_on, kind=kind)
# ---> 12 m.optimize(tol=1e-05, ntrials=5000, maxfev=500)
#      13 for i in range(m.ncond):
#      14       vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='drift_hyp_fits'+labels[i])
#
# /Users/kyle/Dropbox/Git/radd/build.pyc in optimize(self, save, savepth, ntrials, tol, maxfev, niter, disp, prob)
# ...

# %%
# %cd ~/Dropbox/RADD_FITS
#os.mkdir('TR_HYP')
os.chdir('TR_HYP')

data=redf_store.redata
depends_on = {'tr':'Cond'}
kind = 'xradd'
m=build.Model(data=data, depends_on=depends_on, kind=kind)
m.optimize(tol=1e-10, ntrials=10000, maxfev=5000)

for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='onset_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='onset_hyp_sims'+labels[i])
# Out:
# /Users/kyle/Dropbox/RADD_FITS
#
#       Model is prepared to fit xradd model (w/ hyp dynamic bias) to average data,
#       allowing Onset Time to vary across levels of Cond (bsl, pnl)
#
#       See, it's not that simplex...
#
# ...
# <img src='...
# <img src='...
# <img src='...
# <img src='...

# %%
# %cd ~/Dropbox/RADD_FITS
os.mkdir('A_HYP')
os.chdir('A_HYP')

data=redf_store.redata
depends_on = {'a':'Cond'}
kind = 'xradd'
m=build.Model(data=data, depends_on=depends_on, kind=kind)
m.optimize(tol=1e-10, ntrials=10000, maxfev=5000)

for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='bound_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='bound_hyp_sims'+labels[i])

# %% [markdown]
# #X-IRace (hyp)

# %%
# %cd ~/Dropbox/IRM_FITS
os.mkdir('V_HYP')
os.chdir('V_HYP')

data=redf_store.redata
depends_on = {'v':'Cond'}
kind = 'xirace'
m=build.Model(data=data, depends_on=depends_on, kind=kind)
m.optimize(tol=1e-10, ntrials=10000, maxfev=5000)

for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='drift_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='drift_hyp_sims'+labels[i])

# %%
# %cd ~/Dropbox/IRM_FITS
os.mkdir('TR_HYP')
os.chdir('TR_HYP')

data=redf_store.redata
depends_on = {'tr':'Cond'}
kind = 'xirace'
m=build.Model(data=data, depends_on=depends_on, kind=kind)
m.optimize(tol=1e-10, ntrials=10000, maxfev=5000)

for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='onset_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='onset_hyp_sims'+labels[i])

# %%
# %cd ~/Dropbox/IRM_FITS
os.mkdir('A_HYP')
os.chdir('A_HYP')

data=redf_store.redata
depends_on = {'a':'Cond'}
kind = 'xirace'
m=build.Model(data=data, depends_on=depends_on, kind=kind)
m.optimize(tol=1e-10, ntrials=10000, maxfev=5000)

for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], m.fits.reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='bound_hyp_fits'+labels[i])
      vis.plot_fits(m.avg_y[i], m.simulate().reshape(2,16)[i], kind='radd', bw=.01, save=True, savestr='bound_hyp_sims'+labels[i])
