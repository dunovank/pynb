# %%
y = lambda c,k,x,x0,y0: a / (1 + np.exp(-k*b)) + y0

# %%
r= lambda a, b, c, x: a / (1 + b*c**-x)

# %%
k=-.0001

x=np.arange(250,400)
x0=500
plt.plot(np.exp(k*(x-x0)))
# Out:
# <img src='...

# %%
plt.plot(r(1, .3,.990,np.arange(100)))
# Out:
# <img src='...
