# %%
from __future__ import division
from radd import xopt, psy, simfx, ss, utils
import pandas as pd
import seaborn as sns

pth=utils.find_path()

prodf=pd.read_csv(pth+"DataFiles/Pro_AllData.csv", index_col=0)

# %%
pth=utils.find_path()
pro=pd.read_csv(pth+"Proactive/SS_v2p3_fullsummary.dat", sep="\t")
pro['RT_sec']=pro['RT'].copy()*.001
pro=pro.rename(columns={'RT':'rtmsec', 'RT_sec':'rt', 'Keypress':'response'}, axis=1)
stops=pro[(pro['response']==0)&(pro['rt']<=.545)]
gos=pro[(pro['response']==1)&(pro['rt']<=.545)]
sns.set_style("ticks", {"axes.grid":False, 'grid.color': 'white', "axes.facecolor": "white"})


fg,axx=plt.subplots(1,figsize=(6,4))

i=0

cp=sns.color_palette(n_colors=6)

for sx, sxdf in gos.groupby('SubID'):
    
    sxgo=gos[gos['SubID']==sx]
    
    sxgo.rt.hist(bins=20, histtype='stepfilled', ax=axx, alpha=.4, color=cp[1], edgecolor=cp[1])
    #sxdf.rt.hist(bins=5, histtype='stepfilled', ax=axx, alpha=.6, color=cp[2], edgecolor=cp[2])
    
axx.vlines(.545, 0, 60, 'k', linestyle='--',  label='545 ms', alpha=.3)
axx.set_title("Only Go RTs Recorded <=.545 (no boundary rts) \nGo RTs Less Skewed", 
              fontsize=14, loc='center', fontdict={'fontweight' : 'bold'})    
plt.setp(axx, xlim=(.4, .56))
plt.setp(axx.get_yticklabels(), fontsize=14)
axx.set_ylabel("Count", fontsize=17)
axx.legend(loc=2, fontsize=16)
plt.setp(axx, xticks = ([.405, .555]))
axx.set_xticklabels(["400", "560"], fontsize=14)
axx.set_xlabel("RT (sec)", fontsize=17)

plt.tight_layout()
sns.despine()
fg.savefig("Go RTs <= 545ms.png", dpi=600)

# %%
pth=utils.find_path()
pro=pd.read_csv(pth+"Proactive/SS_v2p3_fullsummary.dat", sep="\t")
pro['RT_sec']=pro['RT'].copy()*.001
pro=pro.rename(columns={'RT':'rtmsec', 'RT_sec':'rt', 'Keypress':'response'}, axis=1)
stops=pro[(pro['response']==0)&(pro['rt']<=.546)]
gos=pro[(pro['response']==1)&(pro['rt']<=.546)]
sns.set_style("ticks", {"axes.grid":False, 'grid.color': 'white', "axes.facecolor": "white"})


fg,axx=plt.subplots(1,figsize=(6,4))

i=0

cp=sns.color_palette(n_colors=6)

for sx, sxdf in stops.groupby('SubID'):
    
    sxgo=gos[gos['SubID']==sx]
    
    sxgo.rt.hist(bins=20, histtype='stepfilled', ax=axx, alpha=.4, color=cp[1], edgecolor=cp[1])
    sxdf.rt.hist(bins=1, histtype='stepfilled', ax=axx, alpha=1, color=cp[2], edgecolor=cp[2])
    

axx.vlines(.546, 0, 300, 'k', linestyle='--', label='546 ms', alpha=.3)
axx.set_title("Go & Boundary RTs Recorded <= 546 ms \nGo RTs Heavily Skewed", fontsize=14, loc='center', 
              fontdict={'fontweight' : 'bold'})    
plt.setp(axx, xlim=(.4, .56))
plt.setp(axx.get_yticklabels(), fontsize=14)
axx.set_ylabel("Count", fontsize=17)
axx.legend(loc=2, fontsize=16)
plt.setp(axx, xticks = ([.405, .555]))
axx.set_xticklabels(["400", "560"], fontsize=14)
axx.set_xlabel("RT (sec)", fontsize=17)


plt.tight_layout()
sns.despine()
fg.savefig("Go & Boundary RTs <= 546 ms.png", dpi=600)

# %%
pth=utils.find_path()
pro=pd.read_csv(pth+"Proactive/SS_v2p3_fullsummary.dat", sep="\t")
pro['RT_sec']=pro['RT'].copy()*.001
pro=pro.rename(columns={'RT':'rtmsec', 'RT_sec':'rt', 'Keypress':'response'}, axis=1)
stops=pro[pro['response']==0]
gos=pro[pro['response']==1]
sns.set_style("ticks", {"axes.grid":False, 'grid.color': 'white', "axes.facecolor": "white"})

f,axes=plt.subplots(8,8,figsize=(25,18), sharex=True, sharey=True)
i=0
cp=sns.color_palette(n_colors=6)
for sx, sxdf in stops.groupby('SubID'):
    
    ax=f.axes[i]
    sxgo=gos[gos['SubID']==sx]
    
    sxgo.rt.hist(bins=12, histtype='stepfilled', ax=ax, color=cp[1], label='go', edgecolor=cp[1])
    sxdf.rt.hist(bins=3, histtype='stepfilled', ax=ax, color=cp[2], label='bound', edgecolor=cp[2])
       
    ax.set_title("Sx "+str(sx), fontsize=13, loc='center', fontdict={'fontweight' : 'bold'})
    
    plt.setp(ax, xlim=(.4, .56))
    plt.setp(ax, xticks = ([.405, .555]))
    ax.set_xticklabels(["400", "560"], fontsize=14)
    
    if ax.is_first_col():
        plt.setp(ax.get_yticklabels(), fontsize=14)
        ax.set_ylabel("Count", fontsize=17)
        ax.legend(loc=2, fontsize=12)
    
    if ax.is_last_row():
        ax.set_xlabel("RT (sec)", fontsize=17)
    
        
    sns.despine()
    i+=1   

plt.tight_layout()
f.subplots_adjust(top=.95, wspace=.14, hspace=.24)
f.suptitle("Sx Go & Boundary Times", fontsize=22)
f.savefig("SingleSx Go and Boundary RTs (All Data).png", dpi=300)

# %%
pth=utils.find_path()
pro=pd.read_csv(pth+"Proactive/SS_v2p3_fullsummary.dat", sep="\t")
pro['RT_sec']=pro['RT'].copy()*.001
pro=pro.rename(columns={'RT':'rtmsec', 'RT_sec':'rt', 'Keypress':'response'}, axis=1)
stops=pro[pro['response']==0]
gos=pro[pro['response']==1]
sns.set_style('ticks')

f,axes=plt.subplots(8,8,figsize=(20,14), sharex=True, sharey=True)
i=0
cp=sns.color_palette(n_colors=6)
for sx, sxdf in stops.groupby('SubID'):
    sxgo=gos[gos['SubID']==sx]
    ax=f.axes[i]
    sxdf.rt.hist(bins=10, ax=f.axes[i], color=cp[2], label=str(sx))
    sxgos.rt.hist(bins=25 ax=f.axes[i], color=cp[4])
    ax.legend(loc=0, fontsize=12)
    
    plt.setp(ax, xlim=(.54, .56))
    if ax.is_first_col():
        plt.setp(ax.get_yticklabels(), fontsize=14)
        ax.set_ylabel("Count", fontsize=17)
    if ax.is_last_row():
        plt.setp(ax, xticks = ([.541,.559]))
        ax.set_xticklabels(["540", "560"], fontsize=14)
        ax.set_xlabel("RT (sec)", fontsize=17)
    sns.despine()
    i+=1   

    
plt.tight_layout()
f.subplots_adjust(top=.95, wspace=.14, hspace=.12)
f.suptitle("Sx Time Boundaries", fontsize=22)
f.savefig("SxTimeBoundPlots.png", dpi=300)
