# %%
import time
import numpy as np
import matplotlib.pyplot as plt

plt.axis([0, 1000, 0, 1])
plt.ion()
plt.show()

for i in range(1000):
    y = np.random.random()
    plt.scatter(i, y)
    plt.draw()
    time.sleep(0.05)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e23566b423fa> in <module>()
#      10     y = np.random.random()
#      11     plt.scatter(i, y)
# ---> 12     plt.draw()
#      13     time.sleep(0.05)
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in draw()
#     569
#     570     """
# --> 571     get_current_fig_manager().canvas.draw()
#     572
#     573
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
# ...

# %%
# %matplotlib inline
import sys, time
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import display, clear_output

for i in range(10):
    time.sleep(0.25)
    clear_output(wait=True)
    print(i)
    sys.stdout.flush()
# Out:
# 9

# %%
from scipy.special import jn
x = np.linspace(0,5)
f, ax = plt.subplots()
ax.set_title("Bessel functions")

for n in range(1,10):
    time.sleep(.2)
    ax.plot(x, jn(x,n))
    clear_output(wait=True)
    display(f)

# close the figure at the end, so we don't get a duplicate
# of the last plot
plt.close()

# %%
from radd import lcfit, utils, fitre, fitpro, npsim
import pandas as pd
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
#parampath=utils.find_path()+"ParamFiles/"
rtheta=pd.read_csv("/Users/kyle/Dropbox/SS_Backups/SS/Proactive/Boot/ProBootDriftF/flat_opt_theta.csv", names=['mean'], index_col=0)

theta=rtheta['mean'].to_dict()

# %%
theta['pGo']=.5
theta['ssd']=.40

df=fitpro.simulate(theta, model='radd', ntrials=20, return_all=True)
dvg, dvs = npsim.radd(theta)

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    y=dvg[i]
    x=np.arange(dvg[i])
    #x = np.linspace(0, 10, 1000)
    #y = np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi)
    line.set_data(x, y)
    
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=30)
# Out:
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in text/html formatter: only length-1 arrays can be converted to Python scalars
#   FormatterWarning,

# %%
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
display_animation(anim)

# %%
np.shape(dvg)
# Out:
# (2000, 575)

# %%
dvg[0]
# Out:
# array([ 0.17380648,  0.17157042,  0.16933435,  0.17157042,  0.17380648,
#         0.17604255,  0.17827862,  0.18051469,  0.18275076,  0.18498682,
#         0.18722289,  0.18945896,  0.19169503,  0.18945896,  0.18722289,
#         0.18945896,  0.19169503,  0.1939311 ,  0.19616716,  0.19840323,
#         0.19616716,  0.19840323,  0.19616716,  0.19840323,  0.19616716,
#         0.1939311 ,  0.19169503,  0.1939311 ,  0.19169503,  0.1939311 ,
#         0.19616716,  0.1939311 ,  0.19169503,  0.18945896,  0.19169503,
#         0.18945896,  0.19169503,  0.1939311 ,  0.19169503,  0.1939311 ,
#         0.19616716,  0.19840323,  0.2006393 ,  0.20287537,  0.2006393 ,
#         0.19840323,  0.2006393 ,  0.20287537,  0.20511144,  0.2073475 ,
#         0.20511144,  0.2073475 ,  0.20511144,  0.20287537,  0.20511144,
#         0.20287537,  0.2006393 ,  0.20287537,  0.20511144,  0.2073475 ,
#         0.20511144,  0.2073475 ,  0.20958357,  0.21181964,  0.21405571,
# ...

# %%
y=dvg[6]

# %%
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, 200), ylim=(0, .3))
line, = ax.plot([],[], lw=2)

x=np.arange(len(y))

def init():
    line.set_data([], [])
    return line,

def animate(i):
    x2=i+1
    line.set_data([x[:i],x[:x2]], [y[:i],y[:i+1]])
    return line, 

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=500, interval=20, blit=True)

# %%
np.shape(dvg[:3])
# Out:
# (3, 575)

# %%
# Output a set of images using plot3dsine()
nframes = 10 # Use 100 to produce bigger animation
print('Frame number:')
for i in xrange(0,nframes,1):
    # 3D plot parameters as function of iterator i
    theta = 45 - 0.3*i
    phi = 290 + 0.4*i
    time = i/25.0
    # Call plotting function and save figure into file
    plot3dsine(theta,phi,time);
    plt.savefig('animation_frames/frame{0:07d}.png'.format(i+1));
    plt.close()
    print i,

# %% [markdown]
# # USE THIS CELL... NOT WORKING BUT ALMOST!!!!

# %%
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation
# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, len(y)), ylim=(0, .5))
line, = ax.plot([], [], lw=2, )
colors=['b', 'k', 'g']
x = np.arange(len(y))
nline=0

def init():
    line.set_data([], [])
    return line,

def animate(i):
    
    x2=i+1
    if y[i]==theta['z']:
        xx=0
        x = np.arange(len(y))
        line.set_color(colors[nline])
        nline+=1
    x+=1
    line.set_data(x[:xx], y[nline-1, :i+1])
        
    return line, 

#for y in dvg[:2]:
animation.FuncAnimation(fig, animate, init_func=init, frames=len(y), interval=3, blit=True)
# Out:
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in text/html formatter: local variable 'x' referenced before assignment
#   FormatterWarning,

# %%
from scipy.special import jn
x = np.linspace(0,5)
f, ax = plt.subplots()
for l in dvg:
    x = np.arange(len(l))
    for i, dv1 in enumerate(l):

        if i==0:
            x0=0
            dv0=theta['z']
            
        ax.plot([x0,x[i]], [dv0,dv1], linewidth=1, color='b')
        
        clear_output(wait=True)
        display(f)
        dv0 = dv1
        x0=x[i]
# close the figure at the end, so we don't get a duplicate
# of the last plot
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2ff18bdb05a9> in <module>()
#      12         ax.plot([x0,x[i]], [dv0,dv1], linewidth=1, color='b')
#      13
# ---> 14         clear_output(wait=True)
#      15         display(f)
#      16         dv0 = dv1
#
# NameError: name 'clear_output' is not defined

# %%
ssd=.330 
timebound=0.653
task='ssRe'
normp=False

sns.set(style='white', font="Helvetica")
a=theta['a']
z=theta['z']
t=theta['t']
lb=0

if normp:
    a_orig=a; a=a-z; z=0; lb=z-.08*a

df_sorted=df.sort(['len_go_tsteps'], ascending=True)
df_sortGO=df.sort(['len_go_tsteps'], ascending=True)
df_sortSS=df.sort(['len_ss_tsteps'], ascending=True)
ss_tsteps=list(pd.Series(df_sortSS['ss_tsteps']))
ss_paths=list(pd.Series(df_sortSS['ss_paths']))
go_tsteps=list(pd.Series(df_sortGO['go_tsteps']))
go_paths=list(pd.Series(df_sortGO['go_paths']))
choices=list(pd.Series(df_sorted['choice']))

ssfilled=df.ix[(df['len_ss_tsteps']>0)&(df['trial_type']=='stop'), 'ss_tsteps']
gofilled=pd.Series(df.ix[(df['len_go_tsteps']>0)&(df['choice']=='go'), 'go_tsteps'])
ssfilledPath=df.ix[(df['len_ss_tsteps']>0)&(df['trial_type']=='stop'), 'ss_paths']
gofilledPath=pd.Series(df.ix[(df['len_go_tsteps']>0)&(df['choice']=='go'), 'go_paths'])

f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
tr=t
xmax=timebound+.05
xmin=0
xlim=ax.set_xlim([xmin, xmax])
ylim=ax.set_ylim([lb, a])

plt.hlines(y=a, xmin=xlim[0], xmax=xlim[1], lw=4, color='k')
plt.hlines(y=lb, xmin=xlim[0], xmax=xlim[1], lw=4, color='k')
plt.hlines(y=z, xmin=xlim[0], xmax=xlim[1], alpha=0.5, color='k', lw=4, linestyle='--')
plt.hlines(y=z, xmin=xlim[0], xmax=t, lw=6, color='k', alpha=.5)
plt.vlines(x=xlim[0], ymin=lb, ymax=a, lw=4, color='k')
plt.vlines(x=timebound, ymin=lb, ymax=a, lw=2, color='#3F51B5', alpha=.7)

sns.despine(fig=f, ax=ax, top=True, bottom=True, left=False, right=False)

divider = make_axes_locatable(ax)
lo = divider.append_axes("bottom", size=1, pad=0, xlim=[xmin, xmax]) #xlim=[0, xmax],
hi = divider.append_axes("top", size=1, pad=0, xlim=[xmin, xmax])  #xlim=[0, xmax],

hi.set_xticklabels([]); hi.set_yticklabels([]); lo.set_yticklabels([]); lo.set_xticklabels([]), lo.invert_yaxis();
ax.set_xticklabels([]); ax.set_yticklabels([]); f.subplots_adjust(hspace=0)

sns.despine(fig=f, ax=lo, top=True, bottom=True, left=True, right=True)
sns.despine(fig=f, ax=hi, top=True, bottom=True, left=True, right=True)

nstops=len(ss_tsteps)

ngos=len(go_tsteps)

# %%
for i, (sst, ssp) in enumerate(zip(ss_tsteps, ss_paths)):
    if i<len(go_tsteps):
        gx0, gy0 = z, z
        
        for ii, (gx, gy) in enumerate(zip(go_tsteps[i], go_paths[i])):
            #time.sleep(.00001)
            ax.plot(np.array([gx0, gx]), np.array([gy0, gy]), color="#717cb8", alpha=1, lw=.8)
            gx0, gy0 = gx, gy
            clear_output(wait=True)
            display(f)
            sys.stdout.flush()
            if len(sst)<=1:
                continue
                sx0, sy0 = sst[0], ssp[0]
                
                if len(go_tsteps[i][ii:])<=len(sst):
                    ax.plot(np.array([sx0, sst[ii]]), np.array([sy0, ssp[ii]]), color="#E26A6A", alpha=.12, lw=.75)
                    sx0, sy0 = sst[ii], ssp[ii]
                    clear_output(wait=True)
                    display(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-787aa6135d6f> in <module>()
#       8             gx0, gy0 = gx, gy
#       9             clear_output(wait=True)
# ---> 10             display(f)
#      11             sys.stdout.flush()
#      12             if len(sst)<=1:
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     129             publish_display_data('display', obj, metadata)
#     130         else:
# --> 131             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     132             if metadata:
#     133                 # kwarg-specified metadata gets precedence
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     198             md = None
#     199             try:
# ...

# %%
            
    if len(sst)<=1:
        continue
    for ii in range(len(sst)):
        time.sleep(.001)
        ax.plot(sst[ii], ssp[ii], color="#E26A6A", alpha=.12, lw=.75)
        clear_output(wait=True)
        display(f)
        
if i<len(go_tsteps):
    for t,p in zip(go_tsteps[i:], go_paths[i:]):
        for ii in t:
            time.sleep(.001)
            c="#717cb8"
            ax.plot(t[ii], p[ii], color=c, alpha=.2, lw=1)
            clear_output(wait=True)
            display(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-f0fb4d8dc74b> in <module>()
#       6             ax.plot(go_tsteps[i][ii], go_paths[i][ii], color=c, alpha=.2, lw=1)
#       7             clear_output(wait=True)
# ----> 8             display(f)
#       9
#      10     if len(sst)<=1:
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     129             publish_display_data('display', obj, metadata)
#     130         else:
# --> 131             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     132             if metadata:
#     133                 # kwarg-specified metadata gets precedence
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     198             md = None
#     199             try:
# ...

# %%
x=go_tsteps[4]; y=go_paths[2]
#plt.plot(x, y)
x
# Out:
# []

# %%
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

x = np.linspace(0, 10, 1000)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
i = pd.date_range('2013-1-1',periods=100,freq='s')
while True:
    plt.plot(pd.Series(data=np.random.randn(100), index=i))
    #pd.Series(data=np.random.randn(100), index=i).plot() also tried this one
    time.sleep(5)

# %%
def animate_radd_func():

    for i, (sst, ssp) in enumerate(zip(ss_tsteps, ss_paths)):

        if i<len(go_tsteps):
            gx0, gy0 = z, z

            for ii, (gx, gy) in enumerate(zip(go_tsteps[i], go_paths[i])):
                #time.sleep(.00001)
                ax.plot(np.array([gx0, gx]), np.array([gy0, gy]), color="#717cb8", alpha=1, lw=.8)
                gx0, gy0 = gx, gy
                clear_output(wait=True)
                display(f)
                sys.stdout.flush()
                if len(sst)<=1:
                    continue
                    sx0, sy0 = sst[0], ssp[0]

                    if len(go_tsteps[i][ii:])<=len(sst):
                        ax.plot(np.array([sx0, sst[ii]]), np.array([sy0, ssp[ii]]), 
                                color="#E26A6A", alpha=.12, lw=.75)
                        sx0, sy0 = sst[ii], ssp[ii]
                        clear_output(wait=True)
                        display(f)
