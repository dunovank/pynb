# %%
from radd import ss, simfx, opt, psy, hd, utils

# %%
ss=reload(ss); simfx=reload(simfx); ss=reload(ss); simfx=reload(simfx); 

theta={'pGo':.5, 'ssv': -1.4, 'ssd':.4,'a':0.3325, 'z':0.063, 'v':1.13,'t':0.35, 'eta':0.03, 'st':0.0, 'sz':0.0, 'si':.1}
df=ss.set_model(theta, ntrials=500, visual=True)

# %%
ss=reload(ss); simfx=reload(simfx); ss=reload(ss); simfx=reload(simfx); 

theta={'pGo':.5, 'ssv': -1.4, 'ssd':.4,'a':0.3325, 'z':0.063, 'v':1.13,'t':0.35, 'eta':0.03, 'st':0.0, 'sz':0.0, 'si':.1}
df=ss.set_model(theta, ntrials=500, visual=True)
