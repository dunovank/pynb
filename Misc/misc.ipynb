# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/kyle/Dropbox/CoAx/ss/Reactive/SSv1p3_BSL.csv")
df.head(5)
# Out:
#    Acc200  Acc250  Acc300  Acc350  Acc400 Cond  CondNum        GoMn  \
# 0       1       1    0.95    0.60    0.00  BSL        1  551.205985
# 1       1       1    1.00    0.90    0.00  BSL        1  562.947747
# 2       1       1    1.00    0.80    0.25  BSL        1  592.891542
# 3       1       1    1.00    0.65    0.00  BSL        1  561.552708
# 4       1       1    1.00    0.75    0.10  BSL        1  587.769930
#
#        GoStd         PSE  Precision  SID  SNum        SSRT     Theta1  \
# 0  33.752583  351.113569  25.556473  S28     1  148.886431  13.738733
# 1  31.726341  354.961974   3.871849  S29     2  145.038026  91.677640
# 2  41.783661  378.169632  30.940600  S30     3  121.830368  12.222440
# 3  32.795491  351.601346   4.155882  S31     4  148.398654  84.603311
# 4  37.638089  367.581511  24.747566  S32     5  132.418489  14.853239
#
#        Theta2
# 0  -19.564515
# 1 -129.137270
# 2  -16.159997
# 3 -120.311415
# 4  -20.204007

# %%
plt.hist(df['PSE'])
# Out:
# (array([  4.,   5.,   5.,  11.,  15.,   6.,   9.,   5.,   0.,   1.]),
#  array([ 302.20884484,  312.85742459,  323.50600434,  334.1545841 ,
#          344.80316385,  355.4517436 ,  366.10032335,  376.7489031 ,
#          387.39748285,  398.0460626 ,  408.69464235]),
#  <a list of 10 Patch objects>)
