# %%
# %pylab inline
# %reload_ext base16_mplrc
# %base16_mplrc dark ocean
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Setting plotting theme to ocean-dark. Palette available in b16_colors
# [autoreload of base16_mplrc failed: Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: No module named base16_mplrc
# ]

# %%
for i in range(3):
    plot(np.arange(10),np.random.random(10),'-o')
text(0,0,'hello')
ylabel('foo')
xlabel('bar')
title('foo vs. bar')
sns.despine()
os.chdir("/Users/kyle/")
plt.savefig("test.png", dpi=600)

# %%
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[b16_colors.jet, b16_colors.gray,b16_colors.blues,b16_colors.greens,
      b16_colors.oranges,b16_colors.reds,b16_colors.flame,b16_colors.brbg]
l=len(maps)+1
for i, m in enumerate(maps):
    subplot(1,l,i+1)
    axis("off")
    imshow(a,aspect='auto',cmap=m,origin="lower")
    title(m.name,rotation=0,fontsize=10)

# %%
N=255
M=N//3
reds = np.concatenate((np.linspace(b16red[0],b16blue[0],M),np.linspace(b16blue[0],b16green[0],M)))
blues = np.concatenate((np.linspace(b16red[1],b16blue[1],M),np.linspace(b16blue[1],b16green[1],M)))
greens = np.concatenate((np.linspace(b16red[2],b16blue[2],M),np.linspace(b16blue[2],b16green[2],M)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0c4898e26393> in <module>()
#       1 N=255
#       2 M=N//3
# ----> 3 reds = np.concatenate((np.linspace(b16red[0],b16blue[0],M),np.linspace(b16blue[0],b16green[0],M)))
#       4 blues = np.concatenate((np.linspace(b16red[1],b16blue[1],M),np.linspace(b16blue[1],b16green[1],M)))
#       5 greens = np.concatenate((np.linspace(b16red[2],b16blue[2],M),np.linspace(b16blue[2],b16green[2],M)))
#
# NameError: name 'b16red' is not defined

# %%
colors = np.array((reds,blues,greens)).transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-335592efbb2c> in <module>()
# ----> 1 colors = np.array((reds,blues,greens)).transpose()
#
# NameError: name 'reds' is not defined

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(colors,name='b16')
from matplotlib import cm
cm.register_cmap('b16_jet',cmap)
rcParams['image.cmap']='b16_jet'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8befe9fe2cc2> in <module>()
#       1 from matplotlib.colors import ListedColormap
# ----> 2 cmap = ListedColormap(colors,name='b16')
#       3 from matplotlib import cm
#       4 cm.register_cmap('b16_jet',cmap)
#       5 rcParams['image.cmap']='b16_jet'
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/colors.pyc in __init__(self, colors, name, N)
#     806                                  # identical; needed for contouring.
#     807         if N is None:
# --> 808             N = len(self.colors)
#     809         else:
#     810             if cbook.is_string_like(self.colors):
#
# TypeError: object of type 'function' has no len()

# %%
xg,yg= np.meshgrid(np.linspace(0,10,100),np.linspace(0,10,100))
xs=xg.ravel()
ys=yg.ravel()
img = np.exp(-(xs*xs+ ys*ys)/(2.0*2*2)).reshape(100,100)
imshow(img)#map='b16_jet')

# %%
dir(b16_colors)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'b',
#  'black',
#  'blue',
#  'blues',
#  'brbg',
#  'brown',
#  'c',
#  'cyan',
#  'flame',
#  'g',
#  'gray',
#  'green',
#  'greens',
#  'jet',
#  'k',
#  'm',
#  'magenta',
#  'n',
#  'o',
#  'orange',
#  'oranges',
#  'r',
#  'red',
#  'reds',
#  'w',
#  'white',
#  'y',
#  'yellow']

# %%
#Make a "jet" colormap
cols =[b16_colors.b,
       b16_colors.c,
       b16_colors.g,
       b16_colors.y,
       b16_colors.o,
       b16_colors.r]
print(make_gradient(cols))
b16_colors.jet = ListedColormap(make_gradient(cols),name='b16_jet')
cm.register_cmap('b16_jet',b16_colors.jet)
# Out:
# [[ 0.4         0.6         0.8       ]
#  [ 0.4         0.605       0.8       ]
#  [ 0.4         0.61        0.8       ]
#  [ 0.4         0.615       0.8       ]
#  [ 0.4         0.62        0.8       ]
#  [ 0.4         0.625       0.8       ]
#  [ 0.4         0.63        0.8       ]
#  [ 0.4         0.635       0.8       ]
#  [ 0.4         0.64        0.8       ]
#  [ 0.4         0.645       0.8       ]
#  [ 0.4         0.65        0.8       ]
#  [ 0.4         0.655       0.8       ]
#  [ 0.4         0.66        0.8       ]
#  [ 0.4         0.665       0.8       ]
#  [ 0.4         0.67        0.8       ]
#  [ 0.4         0.675       0.8       ]
#  [ 0.4         0.68        0.8       ]
#  [ 0.4         0.685       0.8       ]
#  [ 0.4         0.69        0.8       ]
#  [ 0.4         0.695       0.8       ]
#  [ 0.4         0.7         0.8       ]
#  [ 0.4         0.705       0.8       ]
#  [ 0.4         0.71        0.8       ]
#  [ 0.4         0.715       0.8       ]
# ...

# %%
#Make a "grayscale" colormap
cols = [conv.to_rgb(theme_colors['base{:02X}'.format(i)]) for i in range(8)]
b16_colors.gray = ListedColormap(make_gradient(cols),name='b16_gray')
cm.register_cmap('b16_gray',b16_colors.gray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8cda6a0b089e> in <module>()
#       1 #Make a "grayscale" colormap
# ----> 2 cols = [conv.to_rgb(theme_colors['base{:02X}'.format(i)]) for i in range(8)]
#       3 b16_colors.gray = ListedColormap(make_gradient(cols),name='b16_gray')
#       4 cm.register_cmap('b16_gray',b16_colors.gray)
#       5
#
# NameError: name 'conv' is not defined
