# %%
# this is a comment ('cause of #)

# the hash ("#") tells the python interpreter (i.e. the thing that translates 
# python syntax (code) to machine-speak) to ignore everything on that line  

# if we're feeling verbose, we can use a triple quote to mark the start and end of a comment
# so as to avoid having to start each line out with a #

"""see, I could go on and on 
and on and on and on"""

# comments become enormously important as your code becomes more complex. not only
# for others to understand what you've done, but as a future reference for yourself.
# Out:
# 'see, I could go on and on \nand on and on and on'

# %% [markdown]
# # Let's define some variables

# %%
# x is an 'int' (or integer in regular speak)
x = 5
print 'x is', type(x)
# Out:
# x is <type 'int'>

# %% [markdown]
# # What does __type 'int'__ mean?
# ---
# * everything in python is an object
#     * all variables
#     * all functions
#     * all classes
#     * by everything i mean everything
# ---
# * x is an object, and its *type* is __int__
# * we can use the built-in __type()__ function to find this out

# %%
# y is the name of a 'list' object. The list contains two 'int' objects
# we could just as well as named our list "asdfasdfasdf" and it would still be a list of ints

y = [1, 2]
print "y is a %s of %s's" % (type(y), type(y[0]))
# Out:
# y is a <type 'list'> of <type 'int'>'s

# %%
# Now we'll make another list, called z, filled with three 'str' or string objects
z = ['one', 'two', 'three']
print "z is a %s of %s's" % (type(z), type(z[0]))
# Out:
# z is a <type 'list'> of <type 'str'>'s

# %% [markdown]
# # Working with lists

# %%
# acess the first element (python indexes from 0)
print z[0]

# acess the second element
print z[1]

# replace the last element
z[-1]=3000
print z[-1]

# make a new list from the combination of two others
l = y + z
print l
# Out:
# one
# two
# 3000
# [1, 2, 'one', 'two', 3000]

# %% [markdown]
# #Objects have methods
#
# Methods basically describe the functionality of a particular object.
# For instance, you can add an element to an existing list by using its __append__ method.
#
# We can do this (below) by inserting our int object, __x__, at the end of our list object, __y__.
#
# However, we couldn't do this the other way around because __append__ is a special method that only
# list objects can perform. Try __x.append(y)__ and you'll see what I mean.

# %%
print 'before', y
y.append(x)
print 'after', y
# Out:
# before [1, 2]
# after [1, 2, 1]

# %% [markdown]
# Assignment:
#
# Go to this link: http://nbviewer.ipython.org/github/chrisalbon/code_py/tree/master/
#
# find an ipynb file that looks interesting and click on it.
#
# copy and paste some code into your own ipython notebook and execute it.
#
# * Did it work?
# * If so, what did it do?
# * If not, why not?
#
# Below is an example of some code I copied and tweaked from the matplotlib demo page.
# Go find some cool plotting examples online, copy and paste the code into your ipython notebook.
# See if you can figure out how to change the color of the plot.

# %% [markdown]
# # Look at how easy this is!

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

f = plt.figure()
ax = f.gca(projection='3d')
x,y,z = axes3d.get_test_data()
ax.plot_surface(x, y, z, rstride=1, cstride=2, alpha=0.5, cmap=cm.Blues)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)
# Out:
# (-100, 100)
