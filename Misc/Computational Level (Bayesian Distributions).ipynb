# %%
import scipy as scp
import seaborn as sns

# %%
(np.random.lognormal(size=50000)+4)*4.5
# Out:
# array([ 21.29512,  18.85051,  19.14899, ...,  19.91331,  19.6962 ,
#         38.55748])

# %%
sns.set_style('white')
f, ax = plt.subplots(1, figsize=(12,9))
sns.kdeplot((np.random.randn(50000)+6)*12.5, shade=True, bw=1.5, color='k', alpha=.15)
sns.kdeplot((np.random.randn(50000)+5)*7.9, shade=True, bw=1.5, color='k', alpha=.35)
#sns.kdeplot((np.random.lognormal(7, 500000)), shade=True, bw=1, color='k', alpha=.58)
sns.kdeplot(np.random.chisquare(2.5, size=50000)*5, shade=True, bw=1.5, color='k', alpha=.58)

sns.despine(left=True, bottom=True,)
ax=plt.gca()
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.savefig('/Users/kyle/Dropbox/computational_level.png', dpi=600)
