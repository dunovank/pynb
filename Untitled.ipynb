# %%
from sklearn.neighbors import KernelDensity

# %%
x = KernelDensity(kernel='linear')

# %%
x.

# %%
from radd import build
m = build.Model(data=redata, kind='xiact', depends_on={'v':'Cond'})
m.make_optimizer()
m.optimize(stage='flat', multiopt=True)
# Out:
# ...
# basinhopping step 0: f 0.0715008
# basinhopping step 1: f 0.423615 trial_f 0.423615 accepted 1  lowest_f 0.0715008
# ...
# basinhopping step 2: f 0.321284 trial_f 0.321284 accepted 1  lowest_f 0.0715008
# ...
# basinhopping step 3: f 0.978999 trial_f 0.978999 accepted 1  lowest_f 0.0715008
# basinhopping step 4: f 0.677116 trial_f 0.677116 accepted 1  lowest_f 0.0715008
# basinhopping step 5: f 0.880544 trial_f 0.880544 accepted 1  lowest_f 0.0715008
# basinhopping step 6: f 0.0135777 trial_f 0.0135777 accepted 1  lowest_f 0.0135777
# found new global minimum on step 6 with function value 0.0135777
# basinhopping step 7: f 0.0430913 trial_f 0.0430913 accepted 1  lowest_f 0.0135777
# basinhopping step 8: f 0.0321608 trial_f 0.0321608 accepted 1  lowest_f 0.0135777
# basinhopping step 9: f 0.0422728 trial_f 0.0422728 accepted 1  lowest_f 0.0135777
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# ...

# %%
m.optimize(stage='conditional', multiopt=True)
# Out:
# ...
# basinhopping step 0: f 3.88255
# basinhopping step 1: f 4.22174 trial_f 4.22174 accepted 1  lowest_f 3.88255
# basinhopping step 2: f 3.93426 trial_f 3.93426 accepted 1  lowest_f 3.88255
# basinhopping step 3: f 3.93426 trial_f 4.36668 accepted 0  lowest_f 3.88255
# basinhopping step 4: f 4.09834 trial_f 4.09834 accepted 1  lowest_f 3.88255
# basinhopping step 5: f 4.02689 trial_f 4.02689 accepted 1  lowest_f 3.88255
# basinhopping step 6: f 3.76667 trial_f 3.76667 accepted 1  lowest_f 3.76667
# found new global minimum on step 6 with function value 3.76667
# basinhopping step 7: f 3.75112 trial_f 3.75112 accepted 1  lowest_f 3.75112
# found new global minimum on step 7 with function value 3.75112
# basinhopping step 8: f 3.92157 trial_f 3.92157 accepted 1  lowest_f 3.75112
# basinhopping step 9: f 4.01502 trial_f 4.01502 accepted 1  lowest_f 3.75112
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# ...

# %%
m.flat_popt
# Out:
# {'a': array([ 0.44353]),
#  'sso': 0.19903593128012517,
#  'ssv': 3.0023602420101709,
#  'tr': array([ 0.221]),
#  'v': array([ 1.17909]),
#  'xb': array([ 1.45628])}

# %%
m.optimize(stage='conditional', )

# %%
x=np.linspace(-4,4,100)

# %%
x = np.arange(500)*.0005
#plt.plot(x, cosh(x), label='hyp')

#plt.legend()

# %%
x = np.arange(500)
xx= (exp(x) + -exp(-x))

# %%
plt.plot(x, xx)
# Out:
# <img src='...' width=437 height=348/>
