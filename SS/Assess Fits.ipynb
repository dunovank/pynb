# %%
import pandas as pd
from radd import utils, psy, qsim, ss, simfx

# %%
pth=utils.find_path()
simdf=pd.read_csv(pth+"CoAx/SS/ReSSV_Sims/Nested/800trials_50maxfun/SxFitSummary.csv")
data=pd.read_csv(pth+"CoAx/SS/Reactive/Re_AllData.csv")

# %%
df.head()
# Out:
#    subj_idx     chisq    redchi       ssv   err200   err250   err300   err350  \
# 0        28  0.060073  0.015018 -0.765904 -0.01250 -0.03125 -0.07375 -0.00500
# 1        29  0.069023  0.017256 -0.734193 -0.01125 -0.03625 -0.11125 -0.08250
# 2        30  0.873841  0.218460 -0.755959 -0.05375 -0.39500 -0.69250 -0.47625
# 3        31  0.119763  0.029941 -0.625764 -0.02875 -0.06625 -0.16750 -0.09375
# 4        32  0.048067  0.012017 -0.787620 -0.01000 -0.02625 -0.09125 -0.09125
#
#     err400       SSE
# 0  0.23125  0.060073
# 1  0.22000  0.069023
# 2 -0.09250  0.873841
# 3  0.27875  0.119763
# 4  0.17500  0.048067

# %%
data.head()
# Out:
#    subj_idx  GoTrial  StopSignal Cond trial_type choice  response  acc  \
# 0        28        1        1000  bsl         go     go         1    1
# 1        28        1        1000  bsl         go     go         1    1
# 2        28        1        1000  bsl         go     go         1    1
# 3        28        1        1000  bsl         go     go         1    1
# 4        28        1        1000  bsl         go     go         1    1
#
#          rt   ssd
# 0  0.598535  1000
# 1  0.520169  1000
# 2  0.545129  1000
# 3  0.571587  1000
# 4  0.505221  1000

# %%
for sx in df.subj_idx.values:
    
    x=np.arange(.2,.45,.05)
    y=df.ix[df['subj_idx']==sx, ('err200', 'err250', 'err300', 'err350', 'err400')].values[0]
    
    plt.plot(x, y)

# %%
#asdfasdf
