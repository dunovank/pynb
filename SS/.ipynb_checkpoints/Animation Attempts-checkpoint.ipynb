# %%
# %matplotlib inline
from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt
import sys, time
from scipy.special import jn

x = np.linspace(0,5)
f, ax = plt.subplots()
ax.set_title("Bessel functions")

for n in range(1,10):
    time.sleep(1)
    ax.plot(x, jn(x,n))
    clear_output(wait=True)
    display(f)

# close the figure at the end, so we don't get a duplicate
# of the last plot
plt.close()

# %%
from radd import utils

# %%
utils=reload(utils)
p=utils.ProgressBar

# %%
import time, sys
from IPython.display import clear_output
f, ax = plt.subplots()

for i in range(10):
  y = i/10*sin(x) 
  ax.plot(x,y)
  time.sleep(0.5)
  clear_output()
  display(f)
  ax.cla() # turn this off if you'd like to "build up" plots
plt.close()

# %%
prog=p(1000)
for x in range(1001):
    time.sleep(.025)
    prog.animate(x)
# Out:
# [                  0%                  ]
# [                  0%                  ]  1 of 1000 complete
# [                  0%                  ]  2 of 1000 complete
# [                  0%                  ]  3 of 1000 complete
# [                  0%                  ]  4 of 1000 complete
# [                  1%                  ]  5 of 1000 complete
# [                  1%                  ]  6 of 1000 complete
# [                  1%                  ]  7 of 1000 complete
# [                  1%                  ]  8 of 1000 complete
# [                  1%                  ]  9 of 1000 complete
# [                  1%                  ]  10 of 1000 complete
# [                  1%                  ]  11 of 1000 complete
# [                  1%                  ]  12 of 1000 complete
# [                  1%                  ]  13 of 1000 complete
# [                  1%                  ]  14 of 1000 complete
# [*                 2%                  ]  15 of 1000 complete
# [*                 2%                  ]  16 of 1000 complete
# [*                 2%                  ]  17 of 1000 complete
# [*                 2%                  ]  18 of 1000 complete
# [*                 2%                  ]  19 of 1000 complete
# [*                 2%                  ]  20 of 1000 complete
# [*                 2%                  ]  21 of 1000 complete
# [*                 2%                  ]  22 of 1000 complete
# [*                 2%                  ]  23 of 1000 complete
# [*                 2%                  ]  24 of 1000 complete
# [*                 3%                  ]  25 of 1000 complete
# [*                 3%                  ]  26 of 1000 complete
# [*                 3%                  ]  27 of 1000 complete
# [*                 3%                  ]  28 of 1000 complete
# [*                 3%                  ]  29 of 1000 complete
# [*                 3%                  ]  30 of 1000 complete
# [*                 3%                  ]  31 of 1000 complete
# [*                 3%                  ]  32 of 1000 complete
# [*                 3%                  ]  33 of 1000 complete
# [*                 3%                  ]  34 of 1000 complete
# [**                4%                  ]  35 of 1000 complete
# [**                4%                  ]  36 of 1000 complete
# [**                4%                  ]  37 of 1000 complete
# [**                4%                  ]  38 of 1000 complete
# [**                4%                  ]  39 of 1000 complete
# [**                4%                  ]  40 of 1000 complete
# [**                4%                  ]  41 of 1000 complete
# [**                4%                  ]  42 of 1000 complete
# [**                4%                  ]  43 of 1000 complete
# [**                4%                  ]  44 of 1000 complete
# [**                5%                  ]  45 of 1000 complete
# [**                5%                  ]  46 of 1000 complete
# [**                5%                  ]  47 of 1000 complete
# [**                5%                  ]  48 of 1000 complete
# [**                5%                  ]  49 of 1000 complete
# [**                5%                  ]  50 of 1000 complete
# [**                5%                  ]  51 of 1000 complete
# [**                5%                  ]  52 of 1000 complete
# [**                5%                  ]  53 of 1000 complete
# [**                5%                  ]  54 of 1000 complete
# [**                6%                  ]  55 of 1000 complete
# [**                6%                  ]  56 of 1000 complete
# [**                6%                  ]  57 of 1000 complete
# [**                6%                  ]  58 of 1000 complete
# [**                6%                  ]  59 of 1000 complete
# [**                6%                  ]  60 of 1000 complete
# [**                6%                  ]  61 of 1000 complete
# [**                6%                  ]  62 of 1000 complete
# [**                6%                  ]  63 of 1000 complete
# [**                6%                  ]  64 of 1000 complete
# [***               7%                  ]  65 of 1000 complete
# [***               7%                  ]  66 of 1000 complete
# [***               7%                  ]  67 of 1000 complete
# [***               7%                  ]  68 of 1000 complete
# [***               7%                  ]  69 of 1000 complete
# [***               7%                  ]  70 of 1000 complete
# [***               7%                  ]  71 of 1000 complete
# [***               7%                  ]  72 of 1000 complete
# [***               7%                  ]  73 of 1000 complete
# [***               7%                  ]  74 of 1000 complete
# [***               8%                  ]  75 of 1000 complete
# [***               8%                  ]  76 of 1000 complete
# [***               8%                  ]  77 of 1000 complete
# [***               8%                  ]  78 of 1000 complete
# [***               8%                  ]  79 of 1000 complete
# [***               8%                  ]  80 of 1000 complete
# [***               8%                  ]  81 of 1000 complete
# [***               8%                  ]  82 of 1000 complete
# [***               8%                  ]  83 of 1000 complete
# [***               8%                  ]  84 of 1000 complete
# [***               9%                  ]  85 of 1000 complete
# [***               9%                  ]  86 of 1000 complete
# [***               9%                  ]  87 of 1000 complete
# [***               9%                  ]  88 of 1000 complete
# [***               9%                  ]  89 of 1000 complete
# [***               9%                  ]  90 of 1000 complete
# [***               9%                  ]  91 of 1000 complete
# [***               9%                  ]  92 of 1000 complete
# [***               9%                  ]  93 of 1000 complete
# [***               9%                  ]  94 of 1000 complete
# [****             10%                  ]  95 of 1000 complete
# [****             10%                  ]  96 of 1000 complete
# [****             10%                  ]  97 of 1000 complete
# [****             10%                  ]  98 of 1000 complete
# [****             10%                  ]  99 of 1000 complete
# [****             10%                  ]  100 of 1000 complete
# [****             10%                  ]  101 of 1000 complete
# [****             10%                  ]  102 of 1000 complete
# [****             10%                  ]  103 of 1000 complete
# [****             10%                  ]  104 of 1000 complete
# [****             11%                  ]  105 of 1000 complete
# [****             11%                  ]  106 of 1000 complete
# [****             11%                  ]  107 of 1000 complete
# [****             11%                  ]  108 of 1000 complete
# [****             11%                  ]  109 of 1000 complete
# [****             11%                  ]  110 of 1000 complete
# [****             11%                  ]  111 of 1000 complete
# [****             11%                  ]  112 of 1000 complete
# [****             11%                  ]  113 of 1000 complete
# [****             11%                  ]  114 of 1000 complete
# [*****            12%                  ]  115 of 1000 complete
# [*****            12%                  ]  116 of 1000 complete
# [*****            12%                  ]  117 of 1000 complete
# [*****            12%                  ]  118 of 1000 complete
# [*****            12%                  ]  119 of 1000 complete
# [*****            12%                  ]  120 of 1000 complete
# [*****            12%                  ]  121 of 1000 complete
# [*****            12%                  ]  122 of 1000 complete
# [*****            12%                  ]  123 of 1000 complete
# [*****            12%                  ]  124 of 1000 complete
# [*****            13%                  ]  125 of 1000 complete
# [*****            13%                  ]  126 of 1000 complete
# [*****            13%                  ]  127 of 1000 complete
# [*****            13%                  ]  128 of 1000 complete
# [*****            13%                  ]  129 of 1000 complete
# [*****            13%                  ]  130 of 1000 complete
# [*****            13%                  ]  131 of 1000 complete
# [*****            13%                  ]  132 of 1000 complete
# [*****            13%                  ]  133 of 1000 complete
# [*****            13%                  ]  134 of 1000 complete
# [*****            14%                  ]  135 of 1000 complete
# [*****            14%                  ]  136 of 1000 complete
# [*****            14%                  ]  137 of 1000 complete
# [*****            14%                  ]  138 of 1000 complete
# [*****            14%                  ]  139 of 1000 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-abae7813ef44> in <module>()
#       1 prog=p(1000)
#       2 for x in range(1001):
# ----> 3     time.sleep(.025)
#       4     prog.animate(x)
#
# KeyboardInterrupt:

# %%
ssvlist = -1*np.arange(.2, 1.8,.20)
len(ssvlist)
# Out:
# 8

# %%
8*2*500*5
# Out:
# 40000

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
#display_animation(anim)
animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)


from IPython.display import HTML
def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 1000)
lines = ax.plot(x, np.sin(x), lw=2)
for i in range(100):
    lines[0].set_ydata(np.sin(x + 0.1 * i))
    fig.canvas.draw()

# %%
ion()
for i in range(100):
    lines[0].set_ydata(np.sin(x + 0.1 * i))
    fig.canvas.draw()

# %%
import matplotlib.pyplot as plt
import numpy as np

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# %%
# animation function.  This is called sequentially
x = np.linspace(0, 2, 1000)

def animate(i):
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# %%
from matplotlib import animation

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=False)

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %%
# Scatter points
#import seaborn as sns
#sns.set_style('dark')
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

# %%
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_
# %%
f, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-b51bfc0123f6> in <module>()
#      23
#      24 # call our new function to display the animation
# ---> 25 display_animation(anim)
#
# <ipython-input-8-63a8cd04f4be> in display_animation(anim)
#       3 def display_animation(anim):
#       4     plt.close(anim._fig)
# ----> 5     return HTML(anim_to_html(anim))
#
# <ipython-input-7-179e3b43dd45> in anim_to_html(anim)
#       9     if not hasattr(anim, '_encoded_video'):
#      10         with NamedTemporaryFile(suffix='.mp4') as f:
# ---> 11             anim.save(f.name, fps=20, extra_args=['-vcodec'])
#      12             video = open(f.name, "rb").read()
#      13         anim._encoded_video = video.encode("base64")
#
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     716                     #TODO: Need to see if turning off blit is really necessary
#     717                     anim._draw_next_frame(d, blit=False)
# --> 718                 writer.grab_frame(**savefig_kwargs)
#     719
#     720         # Reconnect signal for first draw if necessary
#
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in grab_frame(self, **savefig_kwargs)
#     202             # frame format and dpi.
#     203             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 204                              dpi=self.dpi, **savefig_kwargs)
#     205         except RuntimeError:
#     206             out, err = self._proc.communicate()
#
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1419             self.set_frameon(frameon)
#    1420
# -> 1421         self.canvas.print_figure(*args, **kwargs)
#    1422
#    1423         if frameon:
#
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2218                 orientation=orientation,
#    2219                 bbox_inches_restore=_bbox_inches_restore,
# -> 2220                 **kwargs)
#    2221         finally:
#    2222             if bbox_inches and restore_bbox:
#
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_raw(self, filename_or_obj, *args, **kwargs)
#     495             close = False
#     496         try:
# --> 497             renderer._renderer.write_rgba(filename_or_obj)
#     498         finally:
#     499             if close:
#
# RuntimeError: Error writing to file

# %%
animation.Animation._repr_html_ = anim_to_html

# %%
animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
# Out:
# <video controls>
#  <source src="...
