# %%
from __future__ import division
from radd import ss, ssex, ssex_onsets, psy
import seaborn as sns
import pandas as pd
import os
import collections
from itertools import cycle
#globals
a=.37; z=.5*a; Ter=.347; eta=.14; st=.0001; sz=.0001; s2=.01; xpo=[12, 12.29]
mu_ss=-2.17; ssTer=.099; ssRe_TB=.653; ssPro_TB=.6; nt=3000; sTB=.00001; ssTer_var=.0001

#ssRe
#ssdlist=[.2, .25, .3, .35, .4]
#ssPro
pGo_list=[0, .2, .4, .6, .8, 1]
pSSD=.450
vlist_bsl=[0.073, 0.26, 0.4385, 0.601, 0.93, 1.09]
vlist_pnl=[0.05, 0.23, 0.425, 0.601, 0.93, 1.09]


"""
For the reactive condition, the stop signals occurred at 

75ms (early stop)
250ms (late stop)

For the proactive condition, the stopping probabilities were:

0%   (Go trials)
33% (low prob)
67% (high prob)
100% (All Stop)
"""

ssdlist=[.075, .25]
pGo_list=[0, .33, .67, 1]
vlist_bsl=[0.073, 0.38, 0.71, 1.09]

#ssPro

# %%
ss=reload(ss); ssex=reload(ssex)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-125-559ca22fdd18> in <module>()
# ----> 1 ss=reload(ss); ssex=reload(ssex)
#
# /usr/local/lib/python2.7/site-packages/radd/ss.pyc in <module>()
#       8 from itertools import cycle
#       9 from mpl_toolkits.axes_grid1 import make_axes_locatable
# ---> 10 from ssex import sim_exp
#      11 sns.set(font="Helvetica")
#      12
#
# ImportError: cannot import name sim_exp

# %% [markdown]
# # ssRe BSL Thalamus Predictions

# %%
ss=reload(ss); ssex=reload(ssex)

df_ssd=[]

ssdlist=[.075, .25]

gp={'a':a, 'z':z, 'v':0.611, 'Ter':Ter, 'eta':eta, 'st':st, 'sz':sz, 's2':s2}

for i, ssd in enumerate(ssdlist):

    sp={'mu_ss':mu_ss, 'pGo':.5, 'ssd':ssd, 'ssTer':ssTer, 'ssTer_var':ssTer_var}
    
    dfout=ss.set_model(gParams=gp, sParams=sp, ntrials=nt, timebound=ssRe_TB, stb=sTB, t_exp=True, 
                       analyze=True, exp_scale=xpo, visual=False, task='ssReBSL', 
                       predictBOLD=True)
    
    df_ssd.append(dfout)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-124-4a14ef35a4d8> in <module>()
# ----> 1 ss=reload(ss); ssex=reload(ssex)
#       2 #ssex_onsets=reload(ssex_onsets)
#       3
#       4 df_ssd=[]
#       5
#
# /usr/local/lib/python2.7/site-packages/radd/ss.pyc in <module>()
#       8 from itertools import cycle
#       9 from mpl_toolkits.axes_grid1 import make_axes_locatable
# ---> 10 from ssex import sim_exp
#      11 sns.set(font="Helvetica")
#      12
#
# ImportError: cannot import name sim_exp

# %%
#LATEST BLOCK
conditions=['75', '250']
ssd_dict=dict()

for i, dfout in enumerate(df_ssd):
    
    conds_dict=dict()
    
    for df in dfout.keys():
        dfout[df].dropna(inplace=True)
        dfout[df].index=np.arange(len(dfout[df]))
        
        csumlist=[]

        for trace in dfout[df][:]:
            csum=pd.Series(trace).cumsum().max()
            csumlist.append(csum)
        
        conds_dict[df]=np.mean(csumlist)
        
    ssd_dict[conditions[i]]=conds_dict

# %%
for d in ssd_dict.keys():
    for k in ssd_dict[d].keys():
        print "%s ms; %s: %s\n" % (d, k, str(ssd_dict[d][k]))
# Out:
# 75 ms; IncorrectGo: 658.249851282
#
# 75 ms; CorrectStop: 81.3126675367
#
# 75 ms; CorrectGo: 563.843287442
#
# 250 ms; IncorrectGo: 698.889621142
#
# 250 ms; CorrectStop: 191.8262937
#
# 250 ms; IncorrectStop: 315.15704185
#
# 250 ms; CorrectGo: 569.461316987

# %%
########################################################################################################################

##################################################### SSD = 75 ms ######################################################

########################################################################################################################




dfout=df_ssd[0]

sns.set_style("white")

for df in dfout.keys():
    dfout[df].dropna(inplace=True)
    dfout[df].index=np.arange(len(dfout[df]))
    
    clist=sns.blend_palette(["DeepSkyBlue", "DarkBlue"], len(dfout[df]))
    cyclec=cycle(clist)
    
    f = plt.figure(figsize=(14, 7.5)) 
    f.subplots_adjust(top=0.95, wspace=0.12, left=0.23, right=0.97, bottom=0.10)
    ax = f.add_subplot(111)
    ci=.6
    for i in dfout[df][:]:
        ci=ci-.00001
        iarray=np.array(i)
        c=next(cyclec)
        ax.plot(iarray, color=c, alpha=ci)
        ax.set_title(str(df), fontsize=20)
        plt.setp(ax.get_xticklabels(), fontsize=14)
        plt.setp(ax.get_yticklabels(), fontsize=14)
        ax.set_xlim(0, 4500)

# %%
#######################################################################################################################

###################################################  SSD = 250 ms #####################################################

#######################################################################################################################


dfout=df_ssd[1]

sns.set_style("white")

for df in dfout.keys():
    dfout[df].dropna(inplace=True)
    dfout[df].index=np.arange(len(dfout[df]))
    
    clist=sns.blend_palette(["DeepSkyBlue", "DarkBlue"], len(dfout[df]))
    cyclec=cycle(clist)
    
    f = plt.figure(figsize=(14, 7.5)) 
    f.subplots_adjust(top=0.95, wspace=0.12, left=0.23, right=0.97, bottom=0.10)
    ax = f.add_subplot(111)
    ci=.6
    for i in dfout[df][:]:
        ci=ci-.00001
        iarray=np.array(i)
        c=next(cyclec)
        ax.plot(iarray, color=c, alpha=ci)
        ax.set_title(str(df), fontsize=20)
        plt.setp(ax.get_xticklabels(), fontsize=14)
        plt.setp(ax.get_yticklabels(), fontsize=14)
        ax.set_xlim(0, 4500)

# %%
#dfout=df_ssd[3]

for df in dfout.keys():
    dfout[df].dropna(inplace=True)
    dfout[df].index=np.arange(len(dfout[df]))
    
    csumlist=[]
    for i in dfout[df][:]:
        csum=pd.Series(i).cumsum().max()
        #csum=np.cumsum(i)
        csumlist.append(csum)
        
    #np.average(csumlist)
#csumlist[0]

# %%
#ssRE
#Successful stops for early/late stop signals
#Successful go vs incorrect

#ssPro
#100,80, 40, 0 (Go and NoGo)
#for gomean, ssmean in zip(
auc_list=[]
for gomean, ssmean in zip(gdf_list, sdf_list):
    go_idx = (np.abs(gomean-ssmean.max())).argmin()
    ss_idx = (np.abs(ssmean-.185)).argmin()#(np.abs(ssmean.max()-.185)).argmin()
    
    sum_g=gomean[:go_idx].cumsum().max()
    sum_s=ssmean[:ss_idx].cumsum().max()
    auc=sum_g+sum_s
    auc_list.append(auc)
    #sum_s_full=(ssmean[ss_idx:]).cumsum().max()

# %%
df=pd.read_csv("/home/kyle/Dropbox/CoAx/ss/ssRe/ssRe_all.csv")
bsl=df.ix[df['task']=='ReBSL']
bslg=bsl.groupby('SSD')

bslg.describe()
