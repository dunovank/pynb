# %%
from radd import build, models, fit, vis
from radd.toolbox import theta

# %%
#%mkdir XRADD_v_Final
# %cd XRADD_v_Final
# Out:
# /Users/kyle/Dropbox/XRADD_v_Final

# %%
m = build.Model(data=redf_store.redata, kind='xradd', dynamic='hyp', depends_on={'v':'Cond'})
m.make_optimizer(tol=1.e-10, multiopt=True)

# %%
m.optimize(ntrials=10000, multiopt=True)
#vis.plot_reactive_fits(m, save=True)
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.

# %%
yh = m.fits.reshape(2,16)

# %%
yh = m.fits.reshape(2,16)
yh
# Out:
# array([[ 0.964  ,  0.9974 ,  0.9872 ,  0.9352 ,  0.5084 ,  0.1204 ,
#          0.51894,  0.54494,  0.56594,  0.58694,  0.61694,  0.51094,
#          0.53394,  0.55294,  0.57394,  0.60394],
#        [ 0.9245 ,  0.9988 ,  0.99   ,  0.9558 ,  0.5962 ,  0.1768 ,
#          0.52594,  0.55694,  0.57494,  0.59594,  0.62594,  0.51894,
#          0.54294,  0.56194,  0.58294,  0.61094]])

# %%
vis.plot_reactive_fits(m)
# Out:
# <img src='...
