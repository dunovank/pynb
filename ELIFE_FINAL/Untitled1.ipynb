# %%
from radd import build, models, fit, vis
from radd.toolbox import theta

# %%
#!/usr/local/bin/env python
from __future__ import division
from radd import models
from radd.toolbox import theta
from radd.toolbox.messages import logger, global_logger
from lmfit import Parameters, minimize
from radd.CORE import RADDCore
from scipy.optimize import basinhopping, differential_evolution, brute

p = m.inits
bounds = theta.get_bounds(kind=m.opt.kind, tb=m.opt.fitparams['tb'])
stepsize=1.1
nsuccess=2

# %%
basin_keys=['v', 'tr']
ncond=2
x=np.arange(4)
p=m.opt.simulator.basin_params

# %%
xx = array(deepcopy(x)).reshape(len(basin_keys), m.opt.simulator.ncond)
for i, pk in enumerate(basin_keys):
      p[pk]=xx[i]

# %%
p
# Out:
# {'a': array([ 0.32567]),
#  'sso': 0.10272785210628138,
#  'ssv': -1.2345792119855004,
#  'tr': array([2, 3]),
#  'v': array([0, 1]),
#  'xb': array([ 1.81506])}

# %%
basin_keys
# Out:
# ['v', 'tr']

# %%
for k in basin_keys:
      p[k]=x.reshape(len(basin_keys), ncond)

# %%
p = m.opt.simulator.basin_params

# %%
x.pop
# Out:
# 1

# %%
z = [x.pop(:) for i in range(ncond)]

# %%
z
# Out:
# [0, 2]

# %%
for i, pk in enumerate(basin_keys):
      p[pk]=

# %%
p
# Out:
# {'a': array([ 0.32567]),
#  'sso': 0.10272785210628138,
#  'ssv': -1.2345792119855004,
#  'tr': array([[1], []], dtype=object),
#  'v': array([[0, 1], [1]], dtype=object),
#  'xb': array([ 1.81506])}

# %%
# %cd /home/kyle/Dropbox/FINAL_REACTIVE_TESTS
#%mkdir xradd_test
# %cd xradd_test
# Out:
# /home/kyle/Dropbox/FINAL_REACTIVE_TESTS
# /home/kyle/Dropbox/FINAL_REACTIVE_TESTS/xradd_test

# %%
m = build.Model(data=redf_store.redata, kind='xsab', dynamic='hyp', depends_on={'v':'Cond'})
m.make_optimizer(tol=1.e-5, multiopt=True)

# %%
m.optimize()
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1158-68dbe65363ec> in <module>()
# ----> 1 m.optimize()
#
# /home/kyle/Dropbox/Git/radd/build.py in optimize(self, save, savepth, ntrials, tol, maxfev, niter, disp, prob, multiopt)
#      78                   self.make_optimizer(ntrials=ntrials, tol=tol, maxfev=maxfev, niter=niter, disp=disp, prob=prob)
#      79
# ---> 80             self.fits, self.fitinfo, self.popt = self.opt.optimize_model(save=save, savepth=savepth)
#      81             # get residuals
#      82             self.residual = self.opt.residual
#
# /home/kyle/Dropbox/Git/radd/fit.py in optimize_model(self, save, savepth)
#      76             if self.fit_on=='average':
#      77                   self.fit_id='AVERAGE'
# ---> 78                   self.yhat, self.fitinfo, self.popt = self.__opt_routine__()
# ...

# %%
vis.plot_reactive_fits(m)

# %%
m.optimize()

# %%
for pkey, pclist in m.pc_map.items():
      popt[pkey]=array([popt[pc] for pc in pclist])

# %%
popt
# Out:
# {'a': 0.44618461438724705,
#  'ssv': -0.96895229048544351,
#  'tr': 0.30580779953649029,
#  'v': array([ 1.0897 ,  1.06215]),
#  'v_bsl': 1.08969824308134,
#  'v_pnl': 1.0621450687500782,
#  'xb': 1.5026123139739842,
#  'z': 0.14960870175284674}

# %%
m.opt.__nudge_params__(p)
# Out:
# {'a': array([ 0.44618,  0.44618]),
#  'ssv': -0.9689522904854435,
#  'tr': array([ 0.30581,  0.30581]),
#  'v': array([ 1.06705,  1.08252]),
#  'xb': array([ 1.50261,  1.50261]),
#  'z': 0.14960870175284674}

# %%
pdict=[':'.join(["'"+str(k)+"'",str(v)]) for k,v in popt.items()]
popt = 'popt = {'+', '.join(pdict)+'}'

# %%
popt
# Out:
# "popt = {'a':0.446184614387, 'xb':1.50261231397, 'ssv':-0.968952290485, 'tr':0.305807799536, 'v_bsl':1.08969824308, 'v':[ 1.0897   1.06215], 'v_pnl':1.06214506875, 'z':0.149608701753}"

# %%
yhat = array([0.9826, 0.999, 0.9956, 0.9654, 0.5414, 0.1063, 0.5128, 0.5473, 0.5691, 0.5884, 0.6148, 0.5048, 0.5305, 0.5505, 0.5703, 0.5977, 0.9775, 0.9996, 0.9974, 0.9744, 0.6189, 0.2490, 0.5168, 0.5542, 0.5769, 0.5988, 0.6235, 0.5088, 0.5318, 0.5575, 0.5735, 0.6025])
m.fits = yhat
vis.plot_reactive_fits(m)

# %%
m.fits=simfx(p)

# %%
m.fits
# Out:
# array([ 0.9864 ,  0.9994 ,  0.9946 ,  0.9664 ,  0.523  ,  0.0954 ,
#         0.51281,  0.53781,  0.55481,  0.57581,  0.60581,  0.50681,
#         0.52781,  0.54581,  0.56481,  0.58881,  0.9764 ,  0.9996 ,
#         0.9972 ,  0.971  ,  0.5778 ,  0.1202 ,  0.51881,  0.54181,
#         0.56081,  0.58181,  0.61181,  0.51081,  0.53381,  0.54881,
#         0.56781,  0.59681])
