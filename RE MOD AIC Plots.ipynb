# %%
from radd import build, vis

# %% [markdown]
# # DRIFT

# %%
sns.set(style='white', font_scale=1.5)
y = y.reshape(2,16)
y1=np.zeros(16)
wts=wts.reshape(2,16)
x=np.arange(16)
mlist = [drift, onset, bound]#vonset,
mybsl, mypnl = [[(y[i] - mpred.reshape(2,16)[i])for mpred in mlist] for i in range(2)]

# %%
apopt={'a': array([ 0.52517,  0.55142]), 'v': array([ 1.26793,  1.26793]), 'xb': array([ 0.87761,  0.87761]), 'a_bsl': 0.52516967219637334, 'ssv': -0.9839646215235698, 'tr': array([ 0.17801,  0.17801]), 'a_pnl': 0.55142241293987604}
trpopt={'a': array([ 0.53164,  0.53164]), 'tr_pnl': 0.18034021369229908, 'tr_bsl': 0.17142081674730247, 'v': array([ 1.23557,  1.23557]), 'xb': array([ 0.89315,  0.89315]), 'ssv': -0.96019697539856796, 'tr': array([ 0.17142,  0.18034])}
trvpopt={'a': array([ 0.53808,  0.53808]), 'v_pnl': 1.2473882701264474, 'tr_pnl': 0.17807577357146914, 'tr_bsl': 0.1734367331216069, 'v': array([ 1.26948,  1.24739]), 'xb': array([ 0.85862,  0.85862]), 'ssv': -0.9887336427033713, 'tr': array([ 0.17344,  0.17808]), 'v_bsl': 1.2694752448264996}
vpopt={'a': array([ 0.53625,  0.53625]), 'v_pnl': 1.2435812523041054, 'v': array([ 1.2887 ,  1.24358]), 'xb': array([ 0.87761,  0.87761]), 'ssv': -0.9839646215235698, 'tr': array([ 0.17801,  0.17801]), 'v_bsl': 1.2886965219271527}

# %%
names = ['Drift', 'Boundary', 'Onset']

# %%
f, (ax1, ax2) = plt.subplots(2,1, figsize=(12,9))

for i in range(3):
      
      myb, myp = mybsl[i], mypnl[i]
      
      ax1.plot(x, myb, color=pals[i], lw=3, label=names[i])
      ax2.plot(x, myp, color=pals[i], lw=3, label=names[i])
      ax1.fill_between(x, y1=y1, y2=myb, color=pals[i], alpha=.1, lw=0)
      ax2.fill_between(x, y1=y1, y2=myp, color=pals[i], alpha=.1, lw=0)
      sns.despine()
      ax1.legend()
      ax2.legend()
plt.savefig('remod_err.png', dpi=300)
# Out:
# <img src='...

# %%
for ax in [ax1, ax2]:

      ax.plot(x, (y-drift), color=pals[0], lw=3)
      ax.plot(x, (y-bound), color=pals[1], lw=3)
      ax.plot(x, (y-onset), color=pals[2], lw=3)

      sns.despine()
      ht = ([-.05, .05])
      ax.fill_betweenx(ht, x1=0, x2=5, color='#2c3e50', alpha=.1)
      ax.fill_betweenx(ht, x1=5, x2=10, color='#48647c', alpha=.1)
      ax.fill_betweenx(ht, x1=10, x2=16, color='#2c3e50', alpha=.1)


      ax.text(0.2, .04, 'Stop Curve', fontsize=20)
      ax.text(5.5, .04, 'Correct Q', fontsize=20)
      ax.text(11.4, .04, 'Error Q', fontsize=20)
      plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-27f0267b9b88> in <module>()
# ----> 1 f, (ax1, ax2) = plt.subplots(1, figsize=(12,9))
#       2 x=np.arange(len(ybsl))
#       3 y1=np.zeros(len(y))
#       4 for mpred in [drift, onset, vonset, bound]:
#       5
#
# TypeError: 'AxesSubplot' object is not iterable
# <img src='...' width=655 height=544/>

# %%
ax.text(2., -.02, 'Stop Curve', fontsize=20)
ax.text(6.9, -.02, 'Correct Q', fontsize=20)
ax.text(12.0, -.02, 'Error Q', fontsize=20)
plt.tight_layout()

# %%
plt.plot((y-onset))#*wts)
plt.plot((y-vonset))#*wts)
# Out:
# <img src='...

# %%
plt.plot((y-bound)*wts-(y-avgm))
plt.plot((y-onset)*wts-(y-avgm))
# Out:
# <img src='...

# %%
plt.plot(abs(drift-y), label='drift')
plt.plot(abs(bound-y), label='bound')
plt.plot(abs(onset-y), label='onset')
plt.gca().legend()
# Out:
# <img src='...

# %%
aic = arr([-273.459,-269.994,-271.651,-260.793])

# %%
x = [x.set_fontsize(16) for x in ax.get_yticklabels()]

# %%
x.set_fontsize(18)

# %%
reaic = array([-122.40, -106.652, -104.379])
rebic = ([-128.018, -112.270, -111.815])
rec1 = ["#2F9171","#C53B2B", "#374FB7"]

remod_aic = array([-273.459,-271.651, -260.793, -269.994])
remod_bic = array([-273.301, -271.492, -263.941, -269.835])

# %%
pro_aic = array([-122.65, -99.378, -104.654, -98.654])
pro_bic = array([-130.08, -106.81, -122.77, -106.09])
rec1 = ["#2F9171","#C53B2B", "#374FB7"]
rec2 = ["#236a53","#9b2e22", "#2b3e90"]

# %%
c2 = ["#107360", "#335291", "#c87f0a", "#a92314"]

# %%
#aic=array([-122.40, -106.652, -104.379])
sns.set(style='white', font_scale=2.2)
c1 = ["#16a085", "#4168B7", "#f39c12", "#d62c1a"]
c2 = ["#107360", "#335291", "#c87f0a", "#a92314"]

#aic = array([-273.459,-271.651, -260.793, -269.994])
f, ax = plt.subplots()
#plt.subplots_adjust(hspace=.3)
#x = array([.75,1.5,2.25])
x=array([1,2,3,4])
#c1 = ['#555555']*len(x)
#rec2 = ['#333333']*len(x)
#ax.plot(array([1,2,3,4]), aic, marker='o', ms=10, color='Red')
for i in range(len(x)):
      #ax.bar(x[i], aici, color=pals[i], align='center')
      if i == 0:
            l1, l2=['AIC', 'BIC']
      else:
            l1,l2 = [None,None]
      ax.bar(x[i]-.2, remod_aic[i], width=.4, color=c1[i], label=l1, align='center')
      ax.bar(x[i]+.2, remod_bic[i], width=.4, color=c2[i], label=l2, align='center')

ax.set_xlim(x[0]-.5, x[-1]+.5)
ax.set_ylim(-280, -250)
#ax.set_yli
#ax.set_ylim(-130, -90)
ax.set_xticks(x)
#ax.set_yticklabels(ax.get_yticklabels(), fontsize=16)
[xx.set_fontsize(18) for xx in ax.get_yticklabels()]
ax.set_xticklabels(['Drift', 'Onset', 'Drift &\nOnset', 'Bound'], fontsize=26)
#ax.set_xticklabels(['DPM', 'Ind-RM', 'Int-RM'], fontsize=22)
ax.set_ylabel('IC', fontsize=24)
ax.set
ax.set_xlabel('Model', fontsize=24)
sns.despine(bottom=True, top=False)
ax.set_yticklabels(np.arange(-280, -240, 10), fontsize=20)
ax.set_yticks(np.arange(-280, -240, 10))
#ax.set_yticks([-90, -130])
plt.tight_layout()
#ax.legend(loc=0)
#plt.savefig('react_aicbic_color.png', dpi=900)
plt.savefig('remod_aicbic_color.svg')
# Out:
# <img src='...

# %%
#aic=array([-122.40, -106.652, -104.379])
sns.set(style='white', font_scale=1.8)
c1 = ["#16a085", "#4168B7", "#f39c12", "#d62c1a"]
c2 = ["#107360", "#335291", "#c87f0a", "#a92314"]

#aic = array([-273.459,-271.651, -260.793, -269.994])
f, ax = plt.subplots(1, sharey=True, figsize=(8,4))
#plt.subplots_adjust(hspace=.3)
x = array([.75,1.5,2.25])

#rec1 = ['#555555']*len(x)
#rec2 = ['#333333']*len(x)
#ax.plot(array([1,2,3,4]), aic, marker='o', ms=10, color='Red')
for i in range(len(x)):
      #ax.bar(x[i], aici, color=pals[i], align='center')
      if i == 0:
            l1, l2=['AIC', 'BIC']
      else:
            l1,l2 = [None,None]
      ax.bar(x[i]-.1, reaic[i], width=.2, color=rec1[i], label=l1, align='center')
      ax.bar(x[i]+.1, rebic[i], width=.2, color=rec2[i], label=l2, align='center')

ax.set_xlim(x[0]-.5, x[-1]+.5)
#ax.set_ylim(-280, -250)
#ax.set_yli
ax.set_ylim(-130, -90)
ax.set_xticks(x)
#ax.set_yticklabels(ax.get_yticklabels(), fontsize=16)
[xx.set_fontsize(18) for xx in ax.get_yticklabels()]
#ax.set_xticklabels(['Drift', 'Onset', 'Drift &\nOnset', 'Bound'], fontsize=18)
ax.set_xticklabels(['DPM', 'Ind-RM', 'Int-RM'], fontsize=22)
ax.set_ylabel('IC', fontsize=24)
ax.set
ax.set_xlabel('Model', fontsize=24)
sns.despine(bottom=True, top=False)
ax.set_yticklabels([-90, -130])
ax.set_yticks([-90, -130])
plt.tight_layout()
#ax.legend(loc=0)
#plt.savefig('react_aicbic_color.png', dpi=900)
plt.savefig('react_aicbic_color.svg')
# Out:
# <img src='...' width=569 height=281/>

# %%
reaic[i]
# Out:
# -104.379

# %%
#aic=array([-122.40, -106.652, -104.379])
sns.set(style='white', font_scale=1.5)
c1 = ["#16a085", "#4168B7", "#f39c12", "#d62c1a"]
c2 = ["#107360", "#335291", "#c87f0a", "#a92314"]

#aic = array([-273.459,-271.651, -260.793, -269.994])
f, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4), sharey=True)
plt.subplots_adjust(hspace=.3)
x = array([1,3,5,7])

#c1 = ['#555555']*len(x)
#c2 = ['#333333']*len(x)
#ax.plot(array([1,2,3,4]), aic, marker='o', ms=10, color='Red')
for i in range(len(x)):
      #ax.bar(x[i], aici, color=pals[i], align='center')
      if i == 0:
            l1, l2=['AIC', 'BIC']
      else:
            l1,l2 = [None,None]
      ax1.bar(x[i], remod_aic[i], color=c1[i], align='center', label=l1)
      ax2.bar(x[i], remod_bic[i], color=c2[i], align='center', label=l2)
l=['AIC', 'BIC']
for i, ax in enumerate([ax1, ax2]):      
      ax.set_xlim(0, 8)
      ax.set_ylim(-280, -250)
      ax.set_xticks(x)
      #ax.set_yticklabels(ax.get_yticklabels(), fontsize=16)
      [xx.set_fontsize(18) for xx in ax.get_yticklabels()]
      ax.set_xticklabels(['Drift', 'Onset', 'Drift &\nOnset', 'Bound'])
      ax.set_ylabel(l[i])
      ax.set_xlabel('Model')
      sns.despine()
      ax.legend(loc=0)
#plt.savefig('remod_aicbic_gray.png', dpi=900)
#plt.savefig('remod_aicbic_gray.svg', rasterized=True)
# Out:
# <img src='...

# %%
vis.plot_fits(y.reshape(2,16)[0], vorel.reshape(2,16)[0], cdf=True)
# Out:
# <img src='...

# %%
y
# Out:
# array([ 0.942 ,  0.9942,  0.9827,  0.8967,  0.5049,  0.1032,  0.5126,
#         0.5425,  0.5629,  0.5821,  0.6103,  0.4979,  0.5291,  0.5481,
#         0.5675,  0.5942,  0.9272,  0.9934,  0.9852,  0.9254,  0.5942,
#         0.1811,  0.5165,  0.549 ,  0.5698,  0.5903,  0.6176,  0.4969,
#         0.5293,  0.5531,  0.5716,  0.5996])

# %%
abs(y-drift)
# Out:
# array([ 0.0248,  0.0058,  0.0169,  0.0311,  0.0317,  0.0072,  0.0094,
#         0.0055,  0.0051,  0.0049,  0.0047,  0.0141,  0.0079,  0.0059,
#         0.0055,  0.0058,  0.0068,  0.0066,  0.0144,  0.0268,  0.0214,
#         0.0121,  0.0145,  0.009 ,  0.0072,  0.0057,  0.0074,  0.0271,
#         0.0177,  0.0129,  0.0114,  0.0114])

# %%
vrel = y-np.abs((drift-avgm)*wts)
orel = y-np.abs((onset-avgm)*wts)
arel = y-np.abs((bound-avgm)*wts)
vorel = y-np.abs((vonset-avgm)*wts)

# %%
y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])

# %%
dr=drift.reshape(2,16)

# %%
drift = array([0.9668, 1.0, 0.9996, 0.9278, 0.4732, 0.1104, 0.5220, 0.5480, 0.5680, 0.5870, 0.6150, 0.5120, 0.5370, 0.5540, 0.5730, 0.6000, 0.934, 1.0, 0.9996, 0.9522, 0.5728, 0.169, 0.5310, 0.5580, 0.5770, 0.5960, 0.6250, 0.5240, 0.5470, 0.5660, 0.5830, 0.6110])
onset = array([0.954, 1.0, 0.9982, 0.9096, 0.4756, 0.142, 0.5234, 0.5494, 0.5704, 0.5894, 0.6204, 0.5134, 0.5404, 0.5574, 0.5764, 0.6054, 0.9319, 1.0, 0.9996, 0.9454, 0.5698, 0.1674, 0.5323, 0.5583, 0.5793, 0.5983, 0.6253, 0.5243, 0.5473, 0.5663, 0.5853, 0.6123])
vonset = array([0.9621, 1.0, 0.9996, 0.9332, 0.4894, 0.1268, 0.5234, 0.5504, 0.5694, 0.5904, 0.6194, 0.5164, 0.5414, 0.5604, 0.5774, 0.6044, 0.9341, 1.0, 0.9998, 0.9452, 0.5766, 0.1666, 0.5300, 0.5590, 0.5780, 0.5990, 0.6260, 0.5190, 0.5470, 0.5650, 0.5840, 0.6110])
bound= array([0.9684, 1.0, 0.9988, 0.9254, 0.4804, 0.12, 0.5180, 0.5450, 0.5640, 0.5850, 0.6160, 0.5110, 0.5340, 0.5530, 0.5700, 0.5990, 0.9303, 1.0, 0.9998, 0.951, 0.5758, 0.1738, 0.5340, 0.5600, 0.5810, 0.6010, 0.6250, 0.5240, 0.5510, 0.5680, 0.5870, 0.6140])
wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911, 0.9930, 3.8033, 2.7456, 1.0070, 0.4801, 0.6022, 0.6353, 0.9111, 1.0153, 1.2368, 1.0781, 0.1800, 0.2929, 0.3159, 0.3173, 0.2739])

avgm = np.vstack([drift,onset,vonset,bound]).mean(axis=0)

# %% [raw]
# ============================================================
# average FULL
# MODEL: xsab (hyp)
# Cond DEPENDS ON ('v',)
# wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911, 0.9930, 3.8033, 2.7456, 1.0070, 0.4801, 0.6022, 0.6353, 0.9111, 1.0153, 1.2368, 1.0781, 0.1800, 0.2929, 0.3159, 0.3173, 0.2739])
# yhat = array([0.9668, 1.0, 0.9996, 0.9278, 0.4732, 0.1104, 0.5220, 0.5480, 0.5680, 0.5870, 0.6150, 0.5120, 0.5370, 0.5540, 0.5730, 0.6000, 0.934, 1.0, 0.9996, 0.9522, 0.5728, 0.169, 0.5310, 0.5580, 0.5770, 0.5960, 0.6250, 0.5240, 0.5470, 0.5660, 0.5830, 0.6110])
# y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])
# ------------------------------------------------------------
# FIT REPORT
# ------------------------------------------------------------
# [[Fit Statistics]]
#     # function evals   = 69
#     # data points      = 1
#     # variables        = 2
#     chi-square         = 2.648774e-05
#     reduced chi-square = -0.000
# [[Variables]]
#     v_bsl:   1.28869652 (init= 1.382599)
#     v_pnl:   1.24358125 (init= 1.184162)
#     a:       0.53625 (fixed)
#     xb:      0.87761 (fixed)
#     ssv:    -0.9839646 (fixed)
#     tr:      0.17801 (fixed)
# [[Correlations]] (unreported correlations are <  0.100)
# ------------------------------------------------------------
# popt={'a': array([ 0.53625,  0.53625]), 'v_pnl': 1.2435812523041054, 'v': array([ 1.2887 ,  1.24358], dtype=float32), 'xb': array([ 0.87761,  0.87761]), 'ssv': -0.9839646215235698, 'tr': array([ 0.17801,  0.17801]), 'v_bsl': 1.2886965219271527}
# AIC: -273.45957390
# BIC: -273.30069081
# chi: 0.00514662
# rchi: 0.00017155
# converged: True
# ============================================================

# %% [markdown]
# # Onset

# %% [raw]
# ============================================================
# average FULL
# MODEL: xsab (hyp)
# Cond DEPENDS ON ('tr',)
# wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911, 0.9930, 3.8033, 2.7456, 1.0070, 0.4801, 0.6022, 0.6353, 0.9111, 1.0153, 1.2368, 1.0781, 0.1800, 0.2929, 0.3159, 0.3173, 0.2739])
# yhat = array([0.954, 1.0, 0.9982, 0.9096, 0.4756, 0.142, 0.5234, 0.5494, 0.5704, 0.5894, 0.6204, 0.5134, 0.5404, 0.5574, 0.5764, 0.6054, 0.9319, 1.0, 0.9996, 0.9454, 0.5698, 0.1674, 0.5323, 0.5583, 0.5793, 0.5983, 0.6253, 0.5243, 0.5473, 0.5663, 0.5853, 0.6123])
# y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])
# ------------------------------------------------------------
# FIT REPORT
# ------------------------------------------------------------
# [[Fit Statistics]]
#     # function evals   = 104
#     # data points      = 1
#     # variables        = 2
#     chi-square         = 2.965738e-05
#     reduced chi-square = -0.000
# [[Variables]]
#     tr_bsl:   0.17142081 (init= 0.24254)
#     tr_pnl:   0.18034021 (init= 0.2447828)
#     a:        0.531645 (fixed)
#     xb:       0.8931473 (fixed)
#     ssv:     -0.960197 (fixed)
#     v:        1.235572 (fixed)
# [[Correlations]] (unreported correlations are <  0.100)
# ------------------------------------------------------------
# popt={'a': array([ 0.53164,  0.53164]), 'tr_pnl': 0.18034021369229908, 'tr_bsl': 0.17142081674730247, 'v': array([ 1.23557,  1.23557]), 'xb': array([ 0.89315,  0.89315]), 'ssv': -0.96019697539856796, 'tr': array([ 0.17142,  0.18034], dtype=float32)}
# AIC: -271.65110945
# BIC: -271.49222637
# chi: 0.00544586
# rchi: 0.00018153
# converged: True
# ============================================================

# %% [markdown]
# # BOUND

# %% [raw]
# ============================================================
# average FULL
# MODEL: xsab (hyp)
# Cond DEPENDS ON ('a',)
# wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911, 0.9930, 3.8033, 2.7456, 1.0070, 0.4801, 0.6022, 0.6353, 0.9111, 1.0153, 1.2368, 1.0781, 0.1800, 0.2929, 0.3159, 0.3173, 0.2739])
# yhat = array([0.9684, 1.0, 0.9988, 0.9254, 0.4804, 0.12, 0.5180, 0.5450, 0.5640, 0.5850, 0.6160, 0.5110, 0.5340, 0.5530, 0.5700, 0.5990, 0.9303, 1.0, 0.9998, 0.951, 0.5758, 0.1738, 0.5340, 0.5600, 0.5810, 0.6010, 0.6250, 0.5240, 0.5510, 0.5680, 0.5870, 0.6140])
# y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])
# ------------------------------------------------------------
# FIT REPORT
# ------------------------------------------------------------
# [[Fit Statistics]]
#     # function evals   = 65
#     # data points      = 1
#     # variables        = 2
#     chi-square         = 3.2893131e-05
#     reduced chi-square = -0.000
# [[Variables]]
#     a_bsl:   0.52516967 (init= 0.525525)
#     a_pnl:   0.55142241 (init= 0.546975)
#     xb:      0.87761 (fixed)
#     ssv:    -0.9839646 (fixed)
#     tr:      0.17801 (fixed)
#     v:       1.26793 (fixed)
# [[Correlations]] (unreported correlations are <  0.100)
# ------------------------------------------------------------
# popt={'a': array([ 0.52517,  0.55142], dtype=float32), 'v': array([ 1.26793,  1.26793]), 'xb': array([ 0.87761,  0.87761]), 'a_bsl': 0.52516967219637334, 'ssv': -0.9839646215235698, 'tr': array([ 0.17801,  0.17801]), 'a_pnl': 0.55142241293987604}
# AIC: -269.99426296
# BIC: -269.83537988
# chi: 0.00573525
# rchi: 0.00019118
# converged: True
# ============================================================

# %% [markdown]
# # DRIFT + ONSET

# %% [raw]
# ============================================================
# average FULL
# MODEL: xsab (hyp)
# Cond DEPENDS ON ('tr', 'v')
# wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911, 0.9930, 3.8033, 2.7456, 1.0070, 0.4801, 0.6022, 0.6353, 0.9111, 1.0153, 1.2368, 1.0781, 0.1800, 0.2929, 0.3159, 0.3173, 0.2739])
# yhat = array([0.9621, 1.0, 0.9996, 0.9332, 0.4894, 0.1268, 0.5234, 0.5504, 0.5694, 0.5904, 0.6194, 0.5164, 0.5414, 0.5604, 0.5774, 0.6044, 0.9341, 1.0, 0.9998, 0.9452, 0.5766, 0.1666, 0.5300, 0.5590, 0.5780, 0.5990, 0.6260, 0.5190, 0.5470, 0.5650, 0.5840, 0.6110])
# y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])
# ------------------------------------------------------------
# FIT REPORT
# ------------------------------------------------------------
# [[Fit Statistics]]
#     # function evals   = 119
#     # data points      = 1
#     # variables        = 4
#     chi-square         = 3.9658738e-05
#     reduced chi-square = -0.000
# [[Variables]]
#     tr_bsl:   0.17343673 (init= 0.1702652)
#     tr_pnl:   0.17807577 (init= 0.1844568)
#     v_bsl:    1.26947524 (init= 1.315208)
#     v_pnl:    1.24738827 (init= 1.214083)
#     a:        0.53808 (fixed)
#     xb:       0.85862 (fixed)
#     ssv:     -0.9887336 (fixed)
# [[Correlations]] (unreported correlations are <  0.100)
# ------------------------------------------------------------
# popt={'a': array([ 0.53808,  0.53808]), 'v_pnl': 1.2473882701264474, 'tr_pnl': 0.17807577357146914, 'tr_bsl': 0.1734367331216069, 'v': array([ 1.26948,  1.24739], dtype=float32), 'xb': array([ 0.85862,  0.85862]), 'ssv': -0.9887336427033713, 'tr': array([ 0.17344,  0.17808], dtype=float32), 'v_bsl': 1.2694752448264996}
# AIC: -260.79373192
# BIC: -263.94170165
# chi: 0.00629752
# rchi: 0.00022491
# converged: True
# ============================================================

# %%
yhat = array([0.9684, 1.0, 0.9988, 0.9254, 0.4804, 0.12, 0.5180, 0.5450, 0.5640, 0.5850, 0.6160, 0.5110, 0.5340, 0.5530, 0.5700, 0.5990, 0.9303, 1.0, 0.9998, 0.951, 0.5758, 0.1738, 0.5340, 0.5600, 0.5810, 0.6010, 0.6250, 0.5240, 0.5510, 0.5680, 0.5870, 0.6140])
y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942, 0.9272, 0.9934, 0.9852, 0.9254, 0.5942, 0.1811, 0.5165, 0.5490, 0.5698, 0.5903, 0.6176, 0.4969, 0.5293, 0.5531, 0.5716, 0.5996])
