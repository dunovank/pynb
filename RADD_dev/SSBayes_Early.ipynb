# %%
### import radd
from radd import build
from radd.tools import analyze
from itertools import takewhile
from scipy.stats.mstats_extras import mjci
homedir = os.path.expanduser('~')

ssb = pd.read_csv(os.path.join(homedir, "Dropbox/Projects/SSBayes/alldata_clean.csv"))
udf = ssb[ssb.cond.isin(['uniform'])]
edf = ssb[ssb.cond.isin(['early'])]
ldf = ssb[ssb.cond.isin(['late'])]

re = pd.read_csv(os.path.join(homedir, "Dropbox/Projects/SS/Reactive/Re_Data.csv"), index_col=0)
cox = pd.read_csv(os.path.join(homedir, "Dropbox/Projects/Coxon/coxon_behav_data_binned.csv"))

inits = {'a': 0.45, 'v': 1.26, 'xb': 1.3, 'ssv': -1.3, 'tr': 0.2}

# %%
popt_flat = {'a': 0.5878,  'ssv': -1.1539, 'tr': 0.120, 'v': 0.95904, 'xb': 1.845}

# %%
mearly = build.Model(data=edf, inits=popt_flat, kind='xdpm', fit_on='average')
# mu = build.Model(data=udf, inits=popt_flat, kind='xdpm', fit_on='average')
# ml = build.Model(data=ldf, inits=popt_flat, kind='xdpm', fit_on='average')

# %%
mearly.set_basinparams(nrand_inits=20, nrand_samples=500, interval=5, niter=40, stepsize=.06, niter_success=30, tol=1e-4, disp=True)

mearly.optimize(fit_cond=False)
# Out:
# default inits: fmin0=0.467234433
# basinhopping step 0: f 0.060836
# basinhopping step 1: f 0.0773025 trial_f 0.0773025 accepted 1  lowest_f 0.060836
# basinhopping step 2: f 0.074674 trial_f 0.074674 accepted 1  lowest_f 0.060836
# basinhopping step 3: f 0.114318 trial_f 0.114318 accepted 1  lowest_f 0.060836
# basinhopping step 4: f 0.537236 trial_f 0.537236 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.608646 trial_f 0.608646 accepted 1  lowest_f 0.060836
# basinhopping step 6: f 0.468389 trial_f 0.468389 accepted 1  lowest_f 0.060836
# basinhopping step 7: f 0.143974 trial_f 0.143974 accepted 1  lowest_f 0.060836
# basinhopping step 8: f 0.143974 trial_f 0.624935 accepted 0  lowest_f 0.060836
# basinhopping step 9: f 0.126088 trial_f 0.126088 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.196055 trial_f 0.196055 accepted 1  lowest_f 0.060836
# basinhopping step 11: f 0.121454 trial_f 0.121454 accepted 1  lowest_f 0.060836
# basinhopping step 12: f 0.13486 trial_f 0.13486 accepted 1  lowest_f 0.060836
# basinhopping step 13: f 0.135605 trial_f 0.135605 accepted 1  lowest_f 0.060836
# basinhopping step 14: f 0.233209 trial_f 0.233209 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.14363 trial_f 0.14363 accepted 1  lowest_f 0.060836
# basinhopping step 16: f 0.176796 trial_f 0.176796 accepted 1  lowest_f 0.060836
# basinhopping step 17: f 0.202056 trial_f 0.202056 accepted 1  lowest_f 0.060836
# basinhopping step 18: f 0.202056 trial_f 0.308753 accepted 0  lowest_f 0.060836
# basinhopping step 19: f 0.253094 trial_f 0.253094 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.174012 trial_f 0.174012 accepted 1  lowest_f 0.060836
# basinhopping step 21: f 0.3684 trial_f 0.3684 accepted 1  lowest_f 0.060836
# basinhopping step 22: f 0.639299 trial_f 0.639299 accepted 1  lowest_f 0.060836
# basinhopping step 23: f 0.391225 trial_f 0.391225 accepted 1  lowest_f 0.060836
# basinhopping step 24: f 0.224701 trial_f 0.224701 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.880000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.269457 trial_f 0.269457 accepted 1  lowest_f 0.060836
# basinhopping step 26: f 0.269457 trial_f 0.674385 accepted 0  lowest_f 0.060836
# basinhopping step 27: f 0.269457 trial_f 0.546696 accepted 0  lowest_f 0.060836
# basinhopping step 28: f 0.269457 trial_f 0.754605 accepted 0  lowest_f 0.060836
# basinhopping step 29: f 0.267208 trial_f 0.267208 accepted 1  lowest_f 0.060836
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.246871 trial_f 0.246871 accepted 1  lowest_f 0.060836
# basinhopping step 31: f 1.52603 trial_f 1.52603 accepted 1  lowest_f 0.060836
# basinhopping step 0: f 0.0749162
# basinhopping step 1: f 0.197242 trial_f 0.197242 accepted 1  lowest_f 0.0749162
# basinhopping step 2: f 0.485713 trial_f 0.485713 accepted 1  lowest_f 0.0749162
# basinhopping step 3: f 0.197441 trial_f 0.197441 accepted 1  lowest_f 0.0749162
# basinhopping step 4: f 0.130525 trial_f 0.130525 accepted 1  lowest_f 0.0749162
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.430721 trial_f 0.430721 accepted 1  lowest_f 0.0749162
# basinhopping step 6: f 0.182172 trial_f 0.182172 accepted 1  lowest_f 0.0749162
# basinhopping step 7: f 0.564612 trial_f 0.564612 accepted 1  lowest_f 0.0749162
# basinhopping step 8: f 0.564612 trial_f 0.756265 accepted 0  lowest_f 0.0749162
# basinhopping step 9: f 0.464183 trial_f 0.464183 accepted 1  lowest_f 0.0749162
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.464183 trial_f 0.58715 accepted 0  lowest_f 0.0749162
# basinhopping step 11: f 0.0745578 trial_f 0.0745578 accepted 1  lowest_f 0.0745578
# found new global minimum on step 11 with function value 0.0745578
# basinhopping step 12: f 0.227965 trial_f 0.227965 accepted 1  lowest_f 0.0745578
# warning: basinhopping: local minimization failure
# basinhopping step 13: f 0.119754 trial_f 0.119754 accepted 1  lowest_f 0.0745578
# basinhopping step 14: f 0.123303 trial_f 0.123303 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.218762 trial_f 0.218762 accepted 1  lowest_f 0.0745578
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 0.813637 trial_f 0.813637 accepted 1  lowest_f 0.0745578
# basinhopping step 17: f 0.622818 trial_f 0.622818 accepted 1  lowest_f 0.0745578
# basinhopping step 18: f 0.718403 trial_f 0.718403 accepted 1  lowest_f 0.0745578
# basinhopping step 19: f 1.66055 trial_f 1.66055 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 2.07458 trial_f 2.07458 accepted 1  lowest_f 0.0745578
# basinhopping step 21: f 2.71428 trial_f 2.71428 accepted 1  lowest_f 0.0745578
# basinhopping step 22: f 2.16559 trial_f 2.16559 accepted 1  lowest_f 0.0745578
# basinhopping step 23: f 2.16559 trial_f 2.76025 accepted 0  lowest_f 0.0745578
# basinhopping step 24: f 2.25936 trial_f 2.25936 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 1.14253 trial_f 1.14253 accepted 1  lowest_f 0.0745578
# basinhopping step 26: f 0.487322 trial_f 0.487322 accepted 1  lowest_f 0.0745578
# basinhopping step 27: f 0.500566 trial_f 0.500566 accepted 1  lowest_f 0.0745578
# basinhopping step 28: f 0.421252 trial_f 0.421252 accepted 1  lowest_f 0.0745578
# basinhopping step 29: f 0.229116 trial_f 0.229116 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.157663 trial_f 0.157663 accepted 1  lowest_f 0.0745578
# basinhopping step 31: f 0.122145 trial_f 0.122145 accepted 1  lowest_f 0.0745578
# basinhopping step 32: f 0.177977 trial_f 0.177977 accepted 1  lowest_f 0.0745578
# basinhopping step 33: f 0.177977 trial_f 0.536611 accepted 0  lowest_f 0.0745578
# basinhopping step 34: f 0.111246 trial_f 0.111246 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.857143 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.112241 trial_f 0.112241 accepted 1  lowest_f 0.0745578
# basinhopping step 36: f 0.112241 trial_f 0.58131 accepted 0  lowest_f 0.0745578
# basinhopping step 37: f 0.112241 trial_f 0.988387 accepted 0  lowest_f 0.0745578
# basinhopping step 38: f 0.112241 trial_f 1.06857 accepted 0  lowest_f 0.0745578
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 0.12368 trial_f 0.12368 accepted 1  lowest_f 0.0745578
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.251608 trial_f 0.251608 accepted 1  lowest_f 0.0745578
# basinhopping step 0: f 0.0663374
# basinhopping step 1: f 0.089028 trial_f 0.089028 accepted 1  lowest_f 0.0663374
# basinhopping step 2: f 0.109147 trial_f 0.109147 accepted 1  lowest_f 0.0663374
# basinhopping step 3: f 0.103046 trial_f 0.103046 accepted 1  lowest_f 0.0663374
# basinhopping step 4: f 0.0859877 trial_f 0.0859877 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.425441 trial_f 0.425441 accepted 1  lowest_f 0.0663374
# basinhopping step 6: f 0.779101 trial_f 0.779101 accepted 1  lowest_f 0.0663374
# basinhopping step 7: f 0.589637 trial_f 0.589637 accepted 1  lowest_f 0.0663374
# warning: basinhopping: local minimization failure
# basinhopping step 8: f 0.324631 trial_f 0.324631 accepted 1  lowest_f 0.0663374
# basinhopping step 9: f 0.155378 trial_f 0.155378 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.260008 trial_f 0.260008 accepted 1  lowest_f 0.0663374
# basinhopping step 11: f 0.181699 trial_f 0.181699 accepted 1  lowest_f 0.0663374
# basinhopping step 12: f 0.224585 trial_f 0.224585 accepted 1  lowest_f 0.0663374
# basinhopping step 13: f 0.197642 trial_f 0.197642 accepted 1  lowest_f 0.0663374
# basinhopping step 14: f 0.0674874 trial_f 0.0674874 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.0849719 trial_f 0.0849719 accepted 1  lowest_f 0.0663374
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 0.301022 trial_f 0.301022 accepted 1  lowest_f 0.0663374
# basinhopping step 17: f 0.356736 trial_f 0.356736 accepted 1  lowest_f 0.0663374
# basinhopping step 18: f 0.912949 trial_f 0.912949 accepted 1  lowest_f 0.0663374
# basinhopping step 19: f 0.843798 trial_f 0.843798 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.843798 trial_f 1.20725 accepted 0  lowest_f 0.0663374
# basinhopping step 21: f 0.337539 trial_f 0.337539 accepted 1  lowest_f 0.0663374
# basinhopping step 22: f 0.187681 trial_f 0.187681 accepted 1  lowest_f 0.0663374
# basinhopping step 23: f 0.277548 trial_f 0.277548 accepted 1  lowest_f 0.0663374
# basinhopping step 24: f 0.451985 trial_f 0.451985 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.360009 trial_f 0.360009 accepted 1  lowest_f 0.0663374
# basinhopping step 26: f 0.249766 trial_f 0.249766 accepted 1  lowest_f 0.0663374
# basinhopping step 27: f 0.179008 trial_f 0.179008 accepted 1  lowest_f 0.0663374
# basinhopping step 28: f 0.525083 trial_f 0.525083 accepted 1  lowest_f 0.0663374
# basinhopping step 29: f 0.488954 trial_f 0.488954 accepted 1  lowest_f 0.0663374
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.703508 trial_f 0.703508 accepted 1  lowest_f 0.0663374
# basinhopping step 31: f 0.703508 trial_f 1.15619 accepted 0  lowest_f 0.0663374
# basinhopping step 0: f 0.100683
# basinhopping step 1: f 0.0876706 trial_f 0.0876706 accepted 1  lowest_f 0.0876706
# found new global minimum on step 1 with function value 0.0876706
# basinhopping step 2: f 0.495197 trial_f 0.495197 accepted 1  lowest_f 0.0876706
# basinhopping step 3: f 0.41637 trial_f 0.41637 accepted 1  lowest_f 0.0876706
# basinhopping step 4: f 0.55307 trial_f 0.55307 accepted 1  lowest_f 0.0876706
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.709287 trial_f 0.709287 accepted 1  lowest_f 0.0876706
# basinhopping step 6: f 0.709287 trial_f 1.37489 accepted 0  lowest_f 0.0876706
# basinhopping step 7: f 0.262448 trial_f 0.262448 accepted 1  lowest_f 0.0876706
# basinhopping step 8: f 0.262177 trial_f 0.262177 accepted 1  lowest_f 0.0876706
# basinhopping step 9: f 0.285851 trial_f 0.285851 accepted 1  lowest_f 0.0876706
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.352643 trial_f 0.352643 accepted 1  lowest_f 0.0876706
# basinhopping step 11: f 0.352643 trial_f 1.15624 accepted 0  lowest_f 0.0876706
# basinhopping step 12: f 0.915745 trial_f 0.915745 accepted 1  lowest_f 0.0876706
# basinhopping step 13: f 0.197969 trial_f 0.197969 accepted 1  lowest_f 0.0876706
# basinhopping step 14: f 0.197969 trial_f 0.359517 accepted 0  lowest_f 0.0876706
# adaptive stepsize: acceptance rate 0.733333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.163087 trial_f 0.163087 accepted 1  lowest_f 0.0876706
# basinhopping step 16: f 0.163087 trial_f 0.553738 accepted 0  lowest_f 0.0876706
# basinhopping step 17: f 0.607823 trial_f 0.607823 accepted 1  lowest_f 0.0876706
# basinhopping step 18: f 0.405133 trial_f 0.405133 accepted 1  lowest_f 0.0876706
# basinhopping step 19: f 0.56945 trial_f 0.56945 accepted 1  lowest_f 0.0876706
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.56945 trial_f 0.90411 accepted 0  lowest_f 0.0876706
# basinhopping step 21: f 0.235551 trial_f 0.235551 accepted 1  lowest_f 0.0876706
# basinhopping step 22: f 0.235551 trial_f 0.477123 accepted 0  lowest_f 0.0876706
# basinhopping step 23: f 0.242265 trial_f 0.242265 accepted 1  lowest_f 0.0876706
# basinhopping step 24: f 0.174065 trial_f 0.174065 accepted 1  lowest_f 0.0876706
# adaptive stepsize: acceptance rate 0.720000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.100273 trial_f 0.100273 accepted 1  lowest_f 0.0876706
# basinhopping step 26: f 0.100273 trial_f 0.35392 accepted 0  lowest_f 0.0876706
# basinhopping step 27: f 0.137264 trial_f 0.137264 accepted 1  lowest_f 0.0876706
# basinhopping step 28: f 0.137264 trial_f 1.33758 accepted 0  lowest_f 0.0876706
# basinhopping step 29: f 0.0754566 trial_f 0.0754566 accepted 1  lowest_f 0.0754566
# found new global minimum on step 29 with function value 0.0754566
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.0754566 trial_f 0.435243 accepted 0  lowest_f 0.0754566
# basinhopping step 31: f 0.345718 trial_f 0.345718 accepted 1  lowest_f 0.0754566
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 0.190572 trial_f 0.190572 accepted 1  lowest_f 0.0754566
# basinhopping step 33: f 0.190572 trial_f 0.237114 accepted 0  lowest_f 0.0754566
# basinhopping step 34: f 0.146982 trial_f 0.146982 accepted 1  lowest_f 0.0754566
# adaptive stepsize: acceptance rate 0.685714 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.146982 trial_f 0.325208 accepted 0  lowest_f 0.0754566
# basinhopping step 36: f 0.04409 trial_f 0.04409 accepted 1  lowest_f 0.04409
# found new global minimum on step 36 with function value 0.04409
# basinhopping step 37: f 0.04409 trial_f 0.514686 accepted 0  lowest_f 0.04409
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 0.04409 trial_f 0.483247 accepted 0  lowest_f 0.04409
# basinhopping step 39: f 0.419246 trial_f 0.419246 accepted 1  lowest_f 0.04409
# adaptive stepsize: acceptance rate 0.650000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.702843 trial_f 0.702843 accepted 1  lowest_f 0.04409
# basinhopping step 0: f 0.0997881
# basinhopping step 1: f 0.184555 trial_f 0.184555 accepted 1  lowest_f 0.0997881
# basinhopping step 2: f 0.084865 trial_f 0.084865 accepted 1  lowest_f 0.084865
# found new global minimum on step 2 with function value 0.084865
# basinhopping step 3: f 0.084865 trial_f 0.313282 accepted 0  lowest_f 0.084865
# basinhopping step 4: f 0.0717037 trial_f 0.0717037 accepted 1  lowest_f 0.0717037
# found new global minimum on step 4 with function value 0.0717037
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.0802048 trial_f 0.0802048 accepted 1  lowest_f 0.0717037
# basinhopping step 6: f 0.124884 trial_f 0.124884 accepted 1  lowest_f 0.0717037
# basinhopping step 7: f 0.0858811 trial_f 0.0858811 accepted 1  lowest_f 0.0717037
# basinhopping step 8: f 0.0562931 trial_f 0.0562931 accepted 1  lowest_f 0.0562931
# found new global minimum on step 8 with function value 0.0562931
# basinhopping step 9: f 0.144733 trial_f 0.144733 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.558542 trial_f 0.558542 accepted 1  lowest_f 0.0562931
# basinhopping step 11: f 0.656725 trial_f 0.656725 accepted 1  lowest_f 0.0562931
# basinhopping step 12: f 0.374315 trial_f 0.374315 accepted 1  lowest_f 0.0562931
# basinhopping step 13: f 0.250966 trial_f 0.250966 accepted 1  lowest_f 0.0562931
# basinhopping step 14: f 0.259496 trial_f 0.259496 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.259496 trial_f 1.01981 accepted 0  lowest_f 0.0562931
# basinhopping step 16: f 0.643872 trial_f 0.643872 accepted 1  lowest_f 0.0562931
# basinhopping step 17: f 2.03985 trial_f 2.03985 accepted 1  lowest_f 0.0562931
# basinhopping step 18: f 1.76257 trial_f 1.76257 accepted 1  lowest_f 0.0562931
# basinhopping step 19: f 0.830303 trial_f 0.830303 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.672343 trial_f 0.672343 accepted 1  lowest_f 0.0562931
# basinhopping step 21: f 0.649211 trial_f 0.649211 accepted 1  lowest_f 0.0562931
# basinhopping step 22: f 0.0893834 trial_f 0.0893834 accepted 1  lowest_f 0.0562931
# basinhopping step 23: f 0.136297 trial_f 0.136297 accepted 1  lowest_f 0.0562931
# basinhopping step 24: f 0.801082 trial_f 0.801082 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.880000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.356827 trial_f 0.356827 accepted 1  lowest_f 0.0562931
# basinhopping step 26: f 0.356827 trial_f 2.08298 accepted 0  lowest_f 0.0562931
# basinhopping step 27: f 0.356827 trial_f 1.13137 accepted 0  lowest_f 0.0562931
# basinhopping step 28: f 0.307139 trial_f 0.307139 accepted 1  lowest_f 0.0562931
# basinhopping step 29: f 0.687016 trial_f 0.687016 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.833333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.673503 trial_f 0.673503 accepted 1  lowest_f 0.0562931
# basinhopping step 31: f 0.490457 trial_f 0.490457 accepted 1  lowest_f 0.0562931
# basinhopping step 32: f 0.378918 trial_f 0.378918 accepted 1  lowest_f 0.0562931
# basinhopping step 33: f 0.243854 trial_f 0.243854 accepted 1  lowest_f 0.0562931
# basinhopping step 34: f 0.35484 trial_f 0.35484 accepted 1  lowest_f 0.0562931
# adaptive stepsize: acceptance rate 0.857143 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 2.38064 trial_f 2.38064 accepted 1  lowest_f 0.0562931
# basinhopping step 36: f 2.02042 trial_f 2.02042 accepted 1  lowest_f 0.0562931
# basinhopping step 37: f 1.20606 trial_f 1.20606 accepted 1  lowest_f 0.0562931
# basinhopping step 38: f 1.20606 trial_f 2.27364 accepted 0  lowest_f 0.0562931
# basinhopping step 39: f 1.90623 trial_f 1.90623 accepted 1  lowest_f 0.0562931
# basinhopping step 0: f 0.108123
# basinhopping step 1: f 0.123324 trial_f 0.123324 accepted 1  lowest_f 0.108123
# basinhopping step 2: f 0.16283 trial_f 0.16283 accepted 1  lowest_f 0.108123
# basinhopping step 3: f 0.125716 trial_f 0.125716 accepted 1  lowest_f 0.108123
# basinhopping step 4: f 0.214112 trial_f 0.214112 accepted 1  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.312659 trial_f 0.312659 accepted 1  lowest_f 0.108123
# basinhopping step 6: f 0.151488 trial_f 0.151488 accepted 1  lowest_f 0.108123
# basinhopping step 7: f 0.238447 trial_f 0.238447 accepted 1  lowest_f 0.108123
# basinhopping step 8: f 0.248515 trial_f 0.248515 accepted 1  lowest_f 0.108123
# basinhopping step 9: f 0.15763 trial_f 0.15763 accepted 1  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.139962 trial_f 0.139962 accepted 1  lowest_f 0.108123
# basinhopping step 11: f 0.207486 trial_f 0.207486 accepted 1  lowest_f 0.108123
# basinhopping step 12: f 0.15516 trial_f 0.15516 accepted 1  lowest_f 0.108123
# basinhopping step 13: f 0.231577 trial_f 0.231577 accepted 1  lowest_f 0.108123
# basinhopping step 14: f 0.242106 trial_f 0.242106 accepted 1  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.206488 trial_f 0.206488 accepted 1  lowest_f 0.108123
# basinhopping step 16: f 0.20671 trial_f 0.20671 accepted 1  lowest_f 0.108123
# basinhopping step 17: f 0.20671 trial_f 0.534212 accepted 0  lowest_f 0.108123
# basinhopping step 18: f 0.147419 trial_f 0.147419 accepted 1  lowest_f 0.108123
# basinhopping step 19: f 0.117473 trial_f 0.117473 accepted 1  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.468818 trial_f 0.468818 accepted 1  lowest_f 0.108123
# basinhopping step 21: f 1.216 trial_f 1.216 accepted 1  lowest_f 0.108123
# basinhopping step 22: f 0.569955 trial_f 0.569955 accepted 1  lowest_f 0.108123
# basinhopping step 23: f 1.36735 trial_f 1.36735 accepted 1  lowest_f 0.108123
# basinhopping step 24: f 0.666102 trial_f 0.666102 accepted 1  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.644043 trial_f 0.644043 accepted 1  lowest_f 0.108123
# basinhopping step 26: f 0.432897 trial_f 0.432897 accepted 1  lowest_f 0.108123
# basinhopping step 27: f 0.532291 trial_f 0.532291 accepted 1  lowest_f 0.108123
# basinhopping step 28: f 1.07278 trial_f 1.07278 accepted 1  lowest_f 0.108123
# basinhopping step 29: f 1.07278 trial_f 1.60194 accepted 0  lowest_f 0.108123
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.847707 trial_f 0.847707 accepted 1  lowest_f 0.108123
# basinhopping step 31: f 0.410086 trial_f 0.410086 accepted 1  lowest_f 0.108123
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 0.136448
# basinhopping step 1: f 0.193948 trial_f 0.193948 accepted 1  lowest_f 0.136448
# basinhopping step 2: f 0.321957 trial_f 0.321957 accepted 1  lowest_f 0.136448
# basinhopping step 3: f 0.321957 trial_f 0.36361 accepted 0  lowest_f 0.136448
# basinhopping step 4: f 0.394398 trial_f 0.394398 accepted 1  lowest_f 0.136448
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.313443 trial_f 0.313443 accepted 1  lowest_f 0.136448
# basinhopping step 6: f 0.40317 trial_f 0.40317 accepted 1  lowest_f 0.136448
# basinhopping step 7: f 0.468892 trial_f 0.468892 accepted 1  lowest_f 0.136448
# basinhopping step 8: f 0.340942 trial_f 0.340942 accepted 1  lowest_f 0.136448
# basinhopping step 9: f 0.308767 trial_f 0.308767 accepted 1  lowest_f 0.136448
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.175783 trial_f 0.175783 accepted 1  lowest_f 0.136448
# basinhopping step 11: f 0.175783 trial_f 0.247197 accepted 0  lowest_f 0.136448
# basinhopping step 12: f 0.403728 trial_f 0.403728 accepted 1  lowest_f 0.136448
# basinhopping step 13: f 0.295928 trial_f 0.295928 accepted 1  lowest_f 0.136448
# basinhopping step 14: f 0.185081 trial_f 0.185081 accepted 1  lowest_f 0.136448
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.246597 trial_f 0.246597 accepted 1  lowest_f 0.136448
# basinhopping step 16: f 0.32864 trial_f 0.32864 accepted 1  lowest_f 0.136448
# basinhopping step 17: f 0.163752 trial_f 0.163752 accepted 1  lowest_f 0.136448
# basinhopping step 18: f 0.193871 trial_f 0.193871 accepted 1  lowest_f 0.136448
# basinhopping step 19: f 0.329993 trial_f 0.329993 accepted 1  lowest_f 0.136448
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.216963 trial_f 0.216963 accepted 1  lowest_f 0.136448
# basinhopping step 21: f 0.14737 trial_f 0.14737 accepted 1  lowest_f 0.136448
# basinhopping step 22: f 0.123673 trial_f 0.123673 accepted 1  lowest_f 0.123673
# found new global minimum on step 22 with function value 0.123673
# basinhopping step 23: f 0.123673 trial_f 0.239051 accepted 0  lowest_f 0.123673
# basinhopping step 24: f 0.172219 trial_f 0.172219 accepted 1  lowest_f 0.123673
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.309652 trial_f 0.309652 accepted 1  lowest_f 0.123673
# basinhopping step 26: f 0.221322 trial_f 0.221322 accepted 1  lowest_f 0.123673
# basinhopping step 27: f 0.23103 trial_f 0.23103 accepted 1  lowest_f 0.123673
# basinhopping step 28: f 0.430184 trial_f 0.430184 accepted 1  lowest_f 0.123673
# basinhopping step 29: f 0.335808 trial_f 0.335808 accepted 1  lowest_f 0.123673
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.715293 trial_f 0.715293 accepted 1  lowest_f 0.123673
# basinhopping step 31: f 0.346106 trial_f 0.346106 accepted 1  lowest_f 0.123673
# basinhopping step 32: f 0.189266 trial_f 0.189266 accepted 1  lowest_f 0.123673
# basinhopping step 33: f 0.318606 trial_f 0.318606 accepted 1  lowest_f 0.123673
# basinhopping step 34: f 0.174089 trial_f 0.174089 accepted 1  lowest_f 0.123673
# adaptive stepsize: acceptance rate 0.885714 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.27494 trial_f 0.27494 accepted 1  lowest_f 0.123673
# basinhopping step 36: f 0.486138 trial_f 0.486138 accepted 1  lowest_f 0.123673
# basinhopping step 37: f 0.41688 trial_f 0.41688 accepted 1  lowest_f 0.123673
# basinhopping step 38: f 0.41688 trial_f 0.736201 accepted 0  lowest_f 0.123673
# basinhopping step 39: f 0.523677 trial_f 0.523677 accepted 1  lowest_f 0.123673
# adaptive stepsize: acceptance rate 0.875000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# warning: basinhopping: local minimization failure
# basinhopping step 40: f 0.803579 trial_f 0.803579 accepted 1  lowest_f 0.123673
# basinhopping step 0: f 0.13137
# basinhopping step 1: f 0.197916 trial_f 0.197916 accepted 1  lowest_f 0.13137
# basinhopping step 2: f 0.197916 trial_f 0.515818 accepted 0  lowest_f 0.13137
# basinhopping step 3: f 0.250701 trial_f 0.250701 accepted 1  lowest_f 0.13137
# basinhopping step 4: f 0.237298 trial_f 0.237298 accepted 1  lowest_f 0.13137
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.471542 trial_f 0.471542 accepted 1  lowest_f 0.13137
# basinhopping step 6: f 0.597615 trial_f 0.597615 accepted 1  lowest_f 0.13137
# basinhopping step 7: f 1.19827 trial_f 1.19827 accepted 1  lowest_f 0.13137
# basinhopping step 8: f 1.2417 trial_f 1.2417 accepted 1  lowest_f 0.13137
# basinhopping step 9: f 1.49699 trial_f 1.49699 accepted 1  lowest_f 0.13137
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.379952 trial_f 0.379952 accepted 1  lowest_f 0.13137
# basinhopping step 11: f 0.775288 trial_f 0.775288 accepted 1  lowest_f 0.13137
# basinhopping step 12: f 0.46019 trial_f 0.46019 accepted 1  lowest_f 0.13137
# basinhopping step 13: f 0.46019 trial_f 0.682961 accepted 0  lowest_f 0.13137
# basinhopping step 14: f 0.46019 trial_f 0.819691 accepted 0  lowest_f 0.13137
# adaptive stepsize: acceptance rate 0.733333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.303815 trial_f 0.303815 accepted 1  lowest_f 0.13137
# basinhopping step 16: f 0.738932 trial_f 0.738932 accepted 1  lowest_f 0.13137
# basinhopping step 17: f 0.755536 trial_f 0.755536 accepted 1  lowest_f 0.13137
# basinhopping step 18: f 0.607378 trial_f 0.607378 accepted 1  lowest_f 0.13137
# basinhopping step 19: f 0.258488 trial_f 0.258488 accepted 1  lowest_f 0.13137
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.151147 trial_f 0.151147 accepted 1  lowest_f 0.13137
# basinhopping step 21: f 0.239652 trial_f 0.239652 accepted 1  lowest_f 0.13137
# basinhopping step 22: f 0.592745 trial_f 0.592745 accepted 1  lowest_f 0.13137
# basinhopping step 23: f 0.324571 trial_f 0.324571 accepted 1  lowest_f 0.13137
# basinhopping step 24: f 0.120095 trial_f 0.120095 accepted 1  lowest_f 0.120095
# found new global minimum on step 24 with function value 0.120095
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.144319 trial_f 0.144319 accepted 1  lowest_f 0.120095
# basinhopping step 26: f 0.15862 trial_f 0.15862 accepted 1  lowest_f 0.120095
# basinhopping step 27: f 0.205444 trial_f 0.205444 accepted 1  lowest_f 0.120095
# basinhopping step 28: f 0.140645 trial_f 0.140645 accepted 1  lowest_f 0.120095
# basinhopping step 29: f 0.162636 trial_f 0.162636 accepted 1  lowest_f 0.120095
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.133894 trial_f 0.133894 accepted 1  lowest_f 0.120095
# basinhopping step 31: f 0.220585 trial_f 0.220585 accepted 1  lowest_f 0.120095
# basinhopping step 32: f 0.291974 trial_f 0.291974 accepted 1  lowest_f 0.120095
# basinhopping step 33: f 0.327542 trial_f 0.327542 accepted 1  lowest_f 0.120095
# basinhopping step 34: f 0.251989 trial_f 0.251989 accepted 1  lowest_f 0.120095
# adaptive stepsize: acceptance rate 0.885714 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.165132 trial_f 0.165132 accepted 1  lowest_f 0.120095
# basinhopping step 36: f 0.265029 trial_f 0.265029 accepted 1  lowest_f 0.120095
# basinhopping step 37: f 0.246922 trial_f 0.246922 accepted 1  lowest_f 0.120095
# basinhopping step 38: f 0.180893 trial_f 0.180893 accepted 1  lowest_f 0.120095
# basinhopping step 39: f 0.253734 trial_f 0.253734 accepted 1  lowest_f 0.120095
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.285182 trial_f 0.285182 accepted 1  lowest_f 0.120095
# basinhopping step 0: f 0.151007
# basinhopping step 1: f 0.189708 trial_f 0.189708 accepted 1  lowest_f 0.151007
# basinhopping step 2: f 0.219941 trial_f 0.219941 accepted 1  lowest_f 0.151007
# basinhopping step 3: f 0.218788 trial_f 0.218788 accepted 1  lowest_f 0.151007
# basinhopping step 4: f 0.285191 trial_f 0.285191 accepted 1  lowest_f 0.151007
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.299571 trial_f 0.299571 accepted 1  lowest_f 0.151007
# basinhopping step 6: f 0.454152 trial_f 0.454152 accepted 1  lowest_f 0.151007
# basinhopping step 7: f 0.885783 trial_f 0.885783 accepted 1  lowest_f 0.151007
# basinhopping step 8: f 0.691081 trial_f 0.691081 accepted 1  lowest_f 0.151007
# basinhopping step 9: f 0.567318 trial_f 0.567318 accepted 1  lowest_f 0.151007
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.462105 trial_f 0.462105 accepted 1  lowest_f 0.151007
# basinhopping step 11: f 0.765888 trial_f 0.765888 accepted 1  lowest_f 0.151007
# basinhopping step 12: f 0.821503 trial_f 0.821503 accepted 1  lowest_f 0.151007
# basinhopping step 13: f 0.988144 trial_f 0.988144 accepted 1  lowest_f 0.151007
# basinhopping step 14: f 0.81995 trial_f 0.81995 accepted 1  lowest_f 0.151007
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.538291 trial_f 0.538291 accepted 1  lowest_f 0.151007
# basinhopping step 16: f 0.538291 trial_f 0.891955 accepted 0  lowest_f 0.151007
# basinhopping step 17: f 0.318147 trial_f 0.318147 accepted 1  lowest_f 0.151007
# basinhopping step 18: f 0.335667 trial_f 0.335667 accepted 1  lowest_f 0.151007
# basinhopping step 19: f 0.499521 trial_f 0.499521 accepted 1  lowest_f 0.151007
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.859352 trial_f 0.859352 accepted 1  lowest_f 0.151007
# basinhopping step 21: f 0.413791 trial_f 0.413791 accepted 1  lowest_f 0.151007
# basinhopping step 22: f 0.605011 trial_f 0.605011 accepted 1  lowest_f 0.151007
# basinhopping step 23: f 0.577884 trial_f 0.577884 accepted 1  lowest_f 0.151007
# warning: basinhopping: local minimization failure
# basinhopping step 24: f 0.563115 trial_f 0.563115 accepted 1  lowest_f 0.151007
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.363831 trial_f 0.363831 accepted 1  lowest_f 0.151007
# basinhopping step 26: f 0.132293 trial_f 0.132293 accepted 1  lowest_f 0.132293
# found new global minimum on step 26 with function value 0.132293
# basinhopping step 27: f 0.157778 trial_f 0.157778 accepted 1  lowest_f 0.132293
# basinhopping step 28: f 0.251861 trial_f 0.251861 accepted 1  lowest_f 0.132293
# basinhopping step 29: f 0.213155 trial_f 0.213155 accepted 1  lowest_f 0.132293
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.225278 trial_f 0.225278 accepted 1  lowest_f 0.132293
# basinhopping step 31: f 0.311735 trial_f 0.311735 accepted 1  lowest_f 0.132293
# basinhopping step 32: f 0.317645 trial_f 0.317645 accepted 1  lowest_f 0.132293
# basinhopping step 33: f 0.443314 trial_f 0.443314 accepted 1  lowest_f 0.132293
# basinhopping step 34: f 0.443314 trial_f 0.823512 accepted 0  lowest_f 0.132293
# adaptive stepsize: acceptance rate 0.914286 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.384462 trial_f 0.384462 accepted 1  lowest_f 0.132293
# basinhopping step 36: f 0.653934 trial_f 0.653934 accepted 1  lowest_f 0.132293
# basinhopping step 37: f 0.474862 trial_f 0.474862 accepted 1  lowest_f 0.132293
# basinhopping step 38: f 0.477748 trial_f 0.477748 accepted 1  lowest_f 0.132293
# basinhopping step 39: f 0.448544 trial_f 0.448544 accepted 1  lowest_f 0.132293
# adaptive stepsize: acceptance rate 0.925000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.534229 trial_f 0.534229 accepted 1  lowest_f 0.132293
# basinhopping step 0: f 0.144659
# basinhopping step 1: f 0.284252 trial_f 0.284252 accepted 1  lowest_f 0.144659
# basinhopping step 2: f 0.260235 trial_f 0.260235 accepted 1  lowest_f 0.144659
# basinhopping step 3: f 0.29053 trial_f 0.29053 accepted 1  lowest_f 0.144659
# basinhopping step 4: f 0.407188 trial_f 0.407188 accepted 1  lowest_f 0.144659
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.593748 trial_f 0.593748 accepted 1  lowest_f 0.144659
# basinhopping step 6: f 0.255918 trial_f 0.255918 accepted 1  lowest_f 0.144659
# basinhopping step 7: f 0.261179 trial_f 0.261179 accepted 1  lowest_f 0.144659
# basinhopping step 8: f 0.495948 trial_f 0.495948 accepted 1  lowest_f 0.144659
# basinhopping step 9: f 0.987909 trial_f 0.987909 accepted 1  lowest_f 0.144659
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.543509 trial_f 0.543509 accepted 1  lowest_f 0.144659
# basinhopping step 11: f 0.194398 trial_f 0.194398 accepted 1  lowest_f 0.144659
# basinhopping step 12: f 0.194398 trial_f 0.673534 accepted 0  lowest_f 0.144659
# basinhopping step 13: f 0.111008 trial_f 0.111008 accepted 1  lowest_f 0.111008
# found new global minimum on step 13 with function value 0.111008
# basinhopping step 14: f 0.160536 trial_f 0.160536 accepted 1  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.244179 trial_f 0.244179 accepted 1  lowest_f 0.111008
# basinhopping step 16: f 0.248881 trial_f 0.248881 accepted 1  lowest_f 0.111008
# basinhopping step 17: f 0.179235 trial_f 0.179235 accepted 1  lowest_f 0.111008
# basinhopping step 18: f 0.191909 trial_f 0.191909 accepted 1  lowest_f 0.111008
# basinhopping step 19: f 0.118494 trial_f 0.118494 accepted 1  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.112043 trial_f 0.112043 accepted 1  lowest_f 0.111008
# basinhopping step 21: f 0.1316 trial_f 0.1316 accepted 1  lowest_f 0.111008
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 0.137452 trial_f 0.137452 accepted 1  lowest_f 0.111008
# basinhopping step 23: f 0.230627 trial_f 0.230627 accepted 1  lowest_f 0.111008
# basinhopping step 24: f 0.294041 trial_f 0.294041 accepted 1  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.238049 trial_f 0.238049 accepted 1  lowest_f 0.111008
# basinhopping step 26: f 0.335296 trial_f 0.335296 accepted 1  lowest_f 0.111008
# basinhopping step 27: f 0.316047 trial_f 0.316047 accepted 1  lowest_f 0.111008
# basinhopping step 28: f 0.628576 trial_f 0.628576 accepted 1  lowest_f 0.111008
# basinhopping step 29: f 0.628576 trial_f 2.07306 accepted 0  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.734439 trial_f 0.734439 accepted 1  lowest_f 0.111008
# basinhopping step 31: f 1.13834 trial_f 1.13834 accepted 1  lowest_f 0.111008
# basinhopping step 32: f 0.890895 trial_f 0.890895 accepted 1  lowest_f 0.111008
# basinhopping step 33: f 0.890895 trial_f 1.40547 accepted 0  lowest_f 0.111008
# basinhopping step 34: f 0.89212 trial_f 0.89212 accepted 1  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.885714 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.89212 trial_f 1.1468 accepted 0  lowest_f 0.111008
# basinhopping step 36: f 0.89212 trial_f 1.86394 accepted 0  lowest_f 0.111008
# basinhopping step 37: f 0.89212 trial_f 0.978776 accepted 0  lowest_f 0.111008
# basinhopping step 38: f 1.52868 trial_f 1.52868 accepted 1  lowest_f 0.111008
# basinhopping step 39: f 0.709426 trial_f 0.709426 accepted 1  lowest_f 0.111008
# adaptive stepsize: acceptance rate 0.825000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 1.23365 trial_f 1.23365 accepted 1  lowest_f 0.111008
# basinhopping step 0: f 0.149405
# basinhopping step 1: f 0.230232 trial_f 0.230232 accepted 1  lowest_f 0.149405
# basinhopping step 2: f 0.173798 trial_f 0.173798 accepted 1  lowest_f 0.149405
# basinhopping step 3: f 0.164483 trial_f 0.164483 accepted 1  lowest_f 0.149405
# basinhopping step 4: f 0.14065 trial_f 0.14065 accepted 1  lowest_f 0.14065
# found new global minimum on step 4 with function value 0.14065
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.14065 trial_f 0.352076 accepted 0  lowest_f 0.14065
# basinhopping step 6: f 0.187038 trial_f 0.187038 accepted 1  lowest_f 0.14065
# basinhopping step 7: f 0.187416 trial_f 0.187416 accepted 1  lowest_f 0.14065
# basinhopping step 8: f 0.113623 trial_f 0.113623 accepted 1  lowest_f 0.113623
# found new global minimum on step 8 with function value 0.113623
# basinhopping step 9: f 0.114066 trial_f 0.114066 accepted 1  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.154656 trial_f 0.154656 accepted 1  lowest_f 0.113623
# basinhopping step 11: f 0.154656 trial_f 0.185431 accepted 0  lowest_f 0.113623
# basinhopping step 12: f 0.170603 trial_f 0.170603 accepted 1  lowest_f 0.113623
# basinhopping step 13: f 0.201477 trial_f 0.201477 accepted 1  lowest_f 0.113623
# basinhopping step 14: f 0.154083 trial_f 0.154083 accepted 1  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.163572 trial_f 0.163572 accepted 1  lowest_f 0.113623
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 0.163278 trial_f 0.163278 accepted 1  lowest_f 0.113623
# basinhopping step 17: f 0.15723 trial_f 0.15723 accepted 1  lowest_f 0.113623
# basinhopping step 18: f 0.352636 trial_f 0.352636 accepted 1  lowest_f 0.113623
# basinhopping step 19: f 0.246102 trial_f 0.246102 accepted 1  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.19556 trial_f 0.19556 accepted 1  lowest_f 0.113623
# basinhopping step 21: f 0.2042 trial_f 0.2042 accepted 1  lowest_f 0.113623
# basinhopping step 22: f 0.147427 trial_f 0.147427 accepted 1  lowest_f 0.113623
# basinhopping step 23: f 0.194342 trial_f 0.194342 accepted 1  lowest_f 0.113623
# basinhopping step 24: f 0.140851 trial_f 0.140851 accepted 1  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.880000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 0.204177 trial_f 0.204177 accepted 1  lowest_f 0.113623
# basinhopping step 26: f 0.183304 trial_f 0.183304 accepted 1  lowest_f 0.113623
# basinhopping step 27: f 0.183304 trial_f 0.284011 accepted 0  lowest_f 0.113623
# basinhopping step 28: f 0.243947 trial_f 0.243947 accepted 1  lowest_f 0.113623
# basinhopping step 29: f 0.243947 trial_f 0.313668 accepted 0  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.833333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.138842 trial_f 0.138842 accepted 1  lowest_f 0.113623
# basinhopping step 31: f 0.212285 trial_f 0.212285 accepted 1  lowest_f 0.113623
# basinhopping step 32: f 0.316402 trial_f 0.316402 accepted 1  lowest_f 0.113623
# basinhopping step 33: f 0.301815 trial_f 0.301815 accepted 1  lowest_f 0.113623
# basinhopping step 34: f 0.217186 trial_f 0.217186 accepted 1  lowest_f 0.113623
# adaptive stepsize: acceptance rate 0.857143 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.238658 trial_f 0.238658 accepted 1  lowest_f 0.113623
# basinhopping step 36: f 0.2453 trial_f 0.2453 accepted 1  lowest_f 0.113623
# basinhopping step 37: f 0.130452 trial_f 0.130452 accepted 1  lowest_f 0.113623
# basinhopping step 38: f 0.130452 trial_f 0.213086 accepted 0  lowest_f 0.113623
# basinhopping step 39: f 0.693236 trial_f 0.693236 accepted 1  lowest_f 0.113623
# basinhopping step 0: f 0.170572
# basinhopping step 1: f 0.157331 trial_f 0.157331 accepted 1  lowest_f 0.157331
# found new global minimum on step 1 with function value 0.157331
# basinhopping step 2: f 0.199311 trial_f 0.199311 accepted 1  lowest_f 0.157331
# basinhopping step 3: f 0.251992 trial_f 0.251992 accepted 1  lowest_f 0.157331
# basinhopping step 4: f 0.22795 trial_f 0.22795 accepted 1  lowest_f 0.157331
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.325378 trial_f 0.325378 accepted 1  lowest_f 0.157331
# basinhopping step 6: f 0.409716 trial_f 0.409716 accepted 1  lowest_f 0.157331
# basinhopping step 7: f 0.282401 trial_f 0.282401 accepted 1  lowest_f 0.157331
# basinhopping step 8: f 0.208917 trial_f 0.208917 accepted 1  lowest_f 0.157331
# basinhopping step 9: f 0.548655 trial_f 0.548655 accepted 1  lowest_f 0.157331
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.580003 trial_f 0.580003 accepted 1  lowest_f 0.157331
# basinhopping step 11: f 0.820831 trial_f 0.820831 accepted 1  lowest_f 0.157331
# basinhopping step 12: f 0.66883 trial_f 0.66883 accepted 1  lowest_f 0.157331
# basinhopping step 13: f 0.48632 trial_f 0.48632 accepted 1  lowest_f 0.157331
# basinhopping step 14: f 0.295619 trial_f 0.295619 accepted 1  lowest_f 0.157331
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.320295 trial_f 0.320295 accepted 1  lowest_f 0.157331
# basinhopping step 16: f 0.574167 trial_f 0.574167 accepted 1  lowest_f 0.157331
# basinhopping step 17: f 0.407165 trial_f 0.407165 accepted 1  lowest_f 0.157331
# basinhopping step 18: f 0.132944 trial_f 0.132944 accepted 1  lowest_f 0.132944
# found new global minimum on step 18 with function value 0.132944
# basinhopping step 19: f 0.140332 trial_f 0.140332 accepted 1  lowest_f 0.132944
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.12528 trial_f 0.12528 accepted 1  lowest_f 0.12528
# found new global minimum on step 20 with function value 0.12528
# basinhopping step 21: f 0.328807 trial_f 0.328807 accepted 1  lowest_f 0.12528
# basinhopping step 22: f 0.187986 trial_f 0.187986 accepted 1  lowest_f 0.12528
# basinhopping step 23: f 0.406386 trial_f 0.406386 accepted 1  lowest_f 0.12528
# basinhopping step 24: f 0.65006 trial_f 0.65006 accepted 1  lowest_f 0.12528
# adaptive stepsize: acceptance rate 0.960000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.65006 trial_f 1.55387 accepted 0  lowest_f 0.12528
# basinhopping step 26: f 0.284232 trial_f 0.284232 accepted 1  lowest_f 0.12528
# basinhopping step 27: f 0.149886 trial_f 0.149886 accepted 1  lowest_f 0.12528
# basinhopping step 28: f 0.52985 trial_f 0.52985 accepted 1  lowest_f 0.12528
# basinhopping step 29: f 0.520825 trial_f 0.520825 accepted 1  lowest_f 0.12528
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.637261 trial_f 0.637261 accepted 1  lowest_f 0.12528
# basinhopping step 31: f 0.637261 trial_f 1.07265 accepted 0  lowest_f 0.12528
# basinhopping step 32: f 0.637261 trial_f 1.61924 accepted 0  lowest_f 0.12528
# basinhopping step 33: f 0.913391 trial_f 0.913391 accepted 1  lowest_f 0.12528
# basinhopping step 34: f 0.575477 trial_f 0.575477 accepted 1  lowest_f 0.12528
# adaptive stepsize: acceptance rate 0.885714 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.872868 trial_f 0.872868 accepted 1  lowest_f 0.12528
# basinhopping step 36: f 0.872868 trial_f 2.50914 accepted 0  lowest_f 0.12528
# basinhopping step 37: f 0.0754421 trial_f 0.0754421 accepted 1  lowest_f 0.0754421
# found new global minimum on step 37 with function value 0.0754421
# basinhopping step 38: f 0.417286 trial_f 0.417286 accepted 1  lowest_f 0.0754421
# basinhopping step 39: f 0.455071 trial_f 0.455071 accepted 1  lowest_f 0.0754421
# adaptive stepsize: acceptance rate 0.875000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.752625 trial_f 0.752625 accepted 1  lowest_f 0.0754421
# basinhopping step 0: f 0.202474
# basinhopping step 1: f 0.365559 trial_f 0.365559 accepted 1  lowest_f 0.202474
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 0.187309 trial_f 0.187309 accepted 1  lowest_f 0.187309
# found new global minimum on step 2 with function value 0.187309
# basinhopping step 3: f 0.277336 trial_f 0.277336 accepted 1  lowest_f 0.187309
# basinhopping step 4: f 0.283512 trial_f 0.283512 accepted 1  lowest_f 0.187309
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.147309 trial_f 0.147309 accepted 1  lowest_f 0.147309
# ...
# basinhopping step 17: f 0.502091 trial_f 0.502091 accepted 1  lowest_f 0.198697
# basinhopping step 18: f 0.756046 trial_f 0.756046 accepted 1  lowest_f 0.198697
# basinhopping step 19: f 0.894645 trial_f 0.894645 accepted 1  lowest_f 0.198697
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.751875 trial_f 0.751875 accepted 1  lowest_f 0.198697
# basinhopping step 21: f 0.70979 trial_f 0.70979 accepted 1  lowest_f 0.198697
# basinhopping step 22: f 0.72672 trial_f 0.72672 accepted 1  lowest_f 0.198697
# basinhopping step 23: f 0.703279 trial_f 0.703279 accepted 1  lowest_f 0.198697
# basinhopping step 24: f 0.670308 trial_f 0.670308 accepted 1  lowest_f 0.198697
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.86732 trial_f 0.86732 accepted 1  lowest_f 0.198697
# basinhopping step 26: f 0.772296 trial_f 0.772296 accepted 1  lowest_f 0.198697
# basinhopping step 27: f 0.608425 trial_f 0.608425 accepted 1  lowest_f 0.198697
# basinhopping step 28: f 0.805566 trial_f 0.805566 accepted 1  lowest_f 0.198697
# basinhopping step 29: f 0.662141 trial_f 0.662141 accepted 1  lowest_f 0.198697
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.408512 trial_f 0.408512 accepted 1  lowest_f 0.198697
# basinhopping step 31: f 0.459268 trial_f 0.459268 accepted 1  lowest_f 0.198697
# basinhopping step 32: f 0.783165 trial_f 0.783165 accepted 1  lowest_f 0.198697
# basinhopping step 33: f 0.699435 trial_f 0.699435 accepted 1  lowest_f 0.198697
# basinhopping step 34: f 0.613651 trial_f 0.613651 accepted 1  lowest_f 0.198697
# basinhopping step 0: f 0.258983
# basinhopping step 1: f 0.258983 trial_f 0.460379 accepted 0  lowest_f 0.258983
# basinhopping step 2: f 0.143874 trial_f 0.143874 accepted 1  lowest_f 0.143874
# found new global minimum on step 2 with function value 0.143874
# basinhopping step 3: f 0.177335 trial_f 0.177335 accepted 1  lowest_f 0.143874
# basinhopping step 4: f 0.174432 trial_f 0.174432 accepted 1  lowest_f 0.143874
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.199597 trial_f 0.199597 accepted 1  lowest_f 0.143874
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 0.355132 trial_f 0.355132 accepted 1  lowest_f 0.143874
# basinhopping step 7: f 0.355132 trial_f 0.668526 accepted 0  lowest_f 0.143874
# basinhopping step 8: f 0.242096 trial_f 0.242096 accepted 1  lowest_f 0.143874
# basinhopping step 9: f 0.319839 trial_f 0.319839 accepted 1  lowest_f 0.143874
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.138379 trial_f 0.138379 accepted 1  lowest_f 0.138379
# found new global minimum on step 10 with function value 0.138379
# basinhopping step 11: f 0.137053 trial_f 0.137053 accepted 1  lowest_f 0.137053
# found new global minimum on step 11 with function value 0.137053
# basinhopping step 12: f 0.0865323 trial_f 0.0865323 accepted 1  lowest_f 0.0865323
# found new global minimum on step 12 with function value 0.0865323
# basinhopping step 13: f 0.160754 trial_f 0.160754 accepted 1  lowest_f 0.0865323
# basinhopping step 14: f 0.102469 trial_f 0.102469 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.117342 trial_f 0.117342 accepted 1  lowest_f 0.0865323
# basinhopping step 16: f 0.117342 trial_f 0.309615 accepted 0  lowest_f 0.0865323
# basinhopping step 17: f 0.0942635 trial_f 0.0942635 accepted 1  lowest_f 0.0865323
# basinhopping step 18: f 0.206249 trial_f 0.206249 accepted 1  lowest_f 0.0865323
# basinhopping step 19: f 0.317443 trial_f 0.317443 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.851528 trial_f 0.851528 accepted 1  lowest_f 0.0865323
# basinhopping step 21: f 1.32325 trial_f 1.32325 accepted 1  lowest_f 0.0865323
# basinhopping step 22: f 1.32325 trial_f 2.03802 accepted 0  lowest_f 0.0865323
# basinhopping step 23: f 1.32325 trial_f 1.63972 accepted 0  lowest_f 0.0865323
# basinhopping step 24: f 0.704383 trial_f 0.704383 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.760000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 3.05428 trial_f 3.05428 accepted 1  lowest_f 0.0865323
# basinhopping step 26: f 3.69035 trial_f 3.69035 accepted 1  lowest_f 0.0865323
# basinhopping step 27: f 3.47997 trial_f 3.47997 accepted 1  lowest_f 0.0865323
# basinhopping step 28: f 3.33764 trial_f 3.33764 accepted 1  lowest_f 0.0865323
# basinhopping step 29: f 2.47689 trial_f 2.47689 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 2.47689 trial_f 3.33828 accepted 0  lowest_f 0.0865323
# basinhopping step 31: f 2.46894 trial_f 2.46894 accepted 1  lowest_f 0.0865323
# basinhopping step 32: f 1.51489 trial_f 1.51489 accepted 1  lowest_f 0.0865323
# basinhopping step 33: f 0.785199 trial_f 0.785199 accepted 1  lowest_f 0.0865323
# basinhopping step 34: f 0.64965 trial_f 0.64965 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.260923 trial_f 0.260923 accepted 1  lowest_f 0.0865323
# basinhopping step 36: f 0.260923 trial_f 0.495865 accepted 0  lowest_f 0.0865323
# basinhopping step 37: f 0.343128 trial_f 0.343128 accepted 1  lowest_f 0.0865323
# basinhopping step 38: f 0.343128 trial_f 0.953664 accepted 0  lowest_f 0.0865323
# basinhopping step 39: f 0.844716 trial_f 0.844716 accepted 1  lowest_f 0.0865323
# adaptive stepsize: acceptance rate 0.775000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 0.728278 trial_f 0.728278 accepted 1  lowest_f 0.0865323
# basinhopping step 0: f 0.241327
# basinhopping step 1: f 0.206002 trial_f 0.206002 accepted 1  lowest_f 0.206002
# found new global minimum on step 1 with function value 0.206002
# basinhopping step 2: f 0.212811 trial_f 0.212811 accepted 1  lowest_f 0.206002
# basinhopping step 3: f 0.244268 trial_f 0.244268 accepted 1  lowest_f 0.206002
# basinhopping step 4: f 0.260919 trial_f 0.260919 accepted 1  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.343894 trial_f 0.343894 accepted 1  lowest_f 0.206002
# basinhopping step 6: f 0.271541 trial_f 0.271541 accepted 1  lowest_f 0.206002
# basinhopping step 7: f 0.333219 trial_f 0.333219 accepted 1  lowest_f 0.206002
# basinhopping step 8: f 0.389113 trial_f 0.389113 accepted 1  lowest_f 0.206002
# basinhopping step 9: f 0.332346 trial_f 0.332346 accepted 1  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 0.442804 trial_f 0.442804 accepted 1  lowest_f 0.206002
# basinhopping step 11: f 0.358953 trial_f 0.358953 accepted 1  lowest_f 0.206002
# basinhopping step 12: f 0.561441 trial_f 0.561441 accepted 1  lowest_f 0.206002
# basinhopping step 13: f 0.72396 trial_f 0.72396 accepted 1  lowest_f 0.206002
# basinhopping step 14: f 0.625064 trial_f 0.625064 accepted 1  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 0.957894 trial_f 0.957894 accepted 1  lowest_f 0.206002
# basinhopping step 16: f 0.957894 trial_f 1.24154 accepted 0  lowest_f 0.206002
# basinhopping step 17: f 0.957894 trial_f 1.24014 accepted 0  lowest_f 0.206002
# basinhopping step 18: f 0.899973 trial_f 0.899973 accepted 1  lowest_f 0.206002
# basinhopping step 19: f 0.899973 trial_f 1.57481 accepted 0  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 0.737836 trial_f 0.737836 accepted 1  lowest_f 0.206002
# basinhopping step 21: f 0.556342 trial_f 0.556342 accepted 1  lowest_f 0.206002
# basinhopping step 22: f 0.556342 trial_f 1.34954 accepted 0  lowest_f 0.206002
# basinhopping step 23: f 0.461752 trial_f 0.461752 accepted 1  lowest_f 0.206002
# basinhopping step 24: f 0.906592 trial_f 0.906592 accepted 1  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.882066 trial_f 0.882066 accepted 1  lowest_f 0.206002
# basinhopping step 26: f 1.34551 trial_f 1.34551 accepted 1  lowest_f 0.206002
# basinhopping step 27: f 0.790932 trial_f 0.790932 accepted 1  lowest_f 0.206002
# basinhopping step 28: f 0.790932 trial_f 1.60282 accepted 0  lowest_f 0.206002
# basinhopping step 29: f 0.679004 trial_f 0.679004 accepted 1  lowest_f 0.206002
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.3749 trial_f 0.3749 accepted 1  lowest_f 0.206002
# basinhopping step 31: f 0.519049 trial_f 0.519049 accepted 1  lowest_f 0.206002
# basinhopping step 32: f 0.386386 trial_f 0.386386 accepted 1  lowest_f 0.206002
# basinhopping step 0: f 0.244648
# basinhopping step 1: f 0.244648 trial_f 0.520185 accepted 0  lowest_f 0.244648
# basinhopping step 2: f 0.287524 trial_f 0.287524 accepted 1  lowest_f 0.244648
# basinhopping step 3: f 0.29274 trial_f 0.29274 accepted 1  lowest_f 0.244648
# basinhopping step 4: f 0.401472 trial_f 0.401472 accepted 1  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0666667 old stepsize 0.06
# basinhopping step 5: f 0.401472 trial_f 0.599906 accepted 0  lowest_f 0.244648
# basinhopping step 6: f 0.464634 trial_f 0.464634 accepted 1  lowest_f 0.244648
# basinhopping step 7: f 0.498188 trial_f 0.498188 accepted 1  lowest_f 0.244648
# warning: basinhopping: local minimization failure
# basinhopping step 8: f 0.77949 trial_f 0.77949 accepted 1  lowest_f 0.244648
# basinhopping step 9: f 0.77949 trial_f 1.28468 accepted 0  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.600000 target 0.500000 new stepsize 0.0740741 old stepsize 0.0666667
# basinhopping step 10: f 1.49977 trial_f 1.49977 accepted 1  lowest_f 0.244648
# basinhopping step 11: f 1.74243 trial_f 1.74243 accepted 1  lowest_f 0.244648
# basinhopping step 12: f 1.78357 trial_f 1.78357 accepted 1  lowest_f 0.244648
# basinhopping step 13: f 1.48701 trial_f 1.48701 accepted 1  lowest_f 0.244648
# basinhopping step 14: f 1.48701 trial_f 2.3872 accepted 0  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.666667 target 0.500000 new stepsize 0.0823045 old stepsize 0.0740741
# basinhopping step 15: f 2.06806 trial_f 2.06806 accepted 1  lowest_f 0.244648
# basinhopping step 16: f 2.37407 trial_f 2.37407 accepted 1  lowest_f 0.244648
# basinhopping step 17: f 2.05699 trial_f 2.05699 accepted 1  lowest_f 0.244648
# basinhopping step 18: f 2.03338 trial_f 2.03338 accepted 1  lowest_f 0.244648
# basinhopping step 19: f 2.12713 trial_f 2.12713 accepted 1  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.0914495 old stepsize 0.0823045
# basinhopping step 20: f 1.64347 trial_f 1.64347 accepted 1  lowest_f 0.244648
# basinhopping step 21: f 1.19904 trial_f 1.19904 accepted 1  lowest_f 0.244648
# basinhopping step 22: f 0.723424 trial_f 0.723424 accepted 1  lowest_f 0.244648
# basinhopping step 23: f 1.4849 trial_f 1.4849 accepted 1  lowest_f 0.244648
# basinhopping step 24: f 1.4849 trial_f 2.76973 accepted 0  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.760000 target 0.500000 new stepsize 0.101611 old stepsize 0.0914495
# basinhopping step 25: f 0.814204 trial_f 0.814204 accepted 1  lowest_f 0.244648
# basinhopping step 26: f 0.915044 trial_f 0.915044 accepted 1  lowest_f 0.244648
# basinhopping step 27: f 1.02439 trial_f 1.02439 accepted 1  lowest_f 0.244648
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 1.02439 trial_f 1.52235 accepted 0  lowest_f 0.244648
# basinhopping step 29: f 1.02439 trial_f 1.68171 accepted 0  lowest_f 0.244648
# adaptive stepsize: acceptance rate 0.733333 target 0.500000 new stepsize 0.112901 old stepsize 0.101611
# basinhopping step 30: f 0.222771 trial_f 0.222771 accepted 1  lowest_f 0.222771
# found new global minimum on step 30 with function value 0.222771
# basinhopping step 31: f 0.242425 trial_f 0.242425 accepted 1  lowest_f 0.222771
# basinhopping step 32: f 0.371659 trial_f 0.371659 accepted 1  lowest_f 0.222771
# basinhopping step 33: f 0.368189 trial_f 0.368189 accepted 1  lowest_f 0.222771
# basinhopping step 34: f 0.382295 trial_f 0.382295 accepted 1  lowest_f 0.222771
# adaptive stepsize: acceptance rate 0.771429 target 0.500000 new stepsize 0.125445 old stepsize 0.112901
# basinhopping step 35: f 0.431203 trial_f 0.431203 accepted 1  lowest_f 0.222771
# basinhopping step 36: f 0.525898 trial_f 0.525898 accepted 1  lowest_f 0.222771
# basinhopping step 37: f 0.525898 trial_f 1.45353 accepted 0  lowest_f 0.222771
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 0.765625 trial_f 0.765625 accepted 1  lowest_f 0.222771
# basinhopping step 39: f 0.765625 trial_f 0.936294 accepted 0  lowest_f 0.222771
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.139383 old stepsize 0.125445
# basinhopping step 40: f 1.59336 trial_f 1.59336 accepted 1  lowest_f 0.222771
# NEW GLOBAL MINIMUM: fmin_new=0.044090040; fmin_inits= 0.467234)
# Finished Hopping Around
# Optimization terminated successfully.
#          Current function value: 0.000281
#          Iterations: 58
#          Function evaluations: 131
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-556f631d1d76> in <module>()
#       1 mearly.set_basinparams(nrand_inits=20, nrand_samples=500, interval=5, niter=40, stepsize=.06, niter_success=30, tol=1e-4, disp=True)
#       2
# ----> 3 mearly.optimize(fit_cond=False)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/radd/build.pyc in optimize(self, inits, fit_flat, fit_cond, multiopt)
#      70                 flat_wts = self.flat_cost_wts[idx]
#      71                 self.set_fitparams(idx=idx, y=flat_y, wts=flat_wts)
# ---> 72                 yhat_flat, finfo_flat, popt_flat = self.optimize_flat(p=p_flat)
#      73
#      74                 self.yhat_flat_list.append(yhat_flat)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/radd/build.pyc in optimize_flat(self, p)
#     106
#     107         # Flat Simplex Optimization of Parameters at Global Minimum
# --> 108         yhat_flat, finfo_flat, popt_flat = self.opt.gradient_descent(inits=p, is_flat=True)
#     109         return yhat_flat, finfo_flat, popt_flat
#     110
#
# /home/kyle/anaconda/lib/python2.7/site-packages/radd/fit.pyc in gradient_descent(self, inits, is_flat)
#     227         log_arrays = {'y': y, 'yhat': yhat, 'wts': wts}
#     228         param_report = fit_report(optmod.params)
# --> 229         messages.logger(param_report=param_report, finfo=finfo, pdict=popt, depends_on=fp['depends_on'], log_arrays=log_arrays, is_flat=is_flat, kind=self.kind, fit_on=fp['fit_on'], dynamic=fp['dynamic'], pc_map=self.pc_map)
#     230
#     231         return yhat, finfo, popt
#
# /home/kyle/anaconda/lib/python2.7/site-packages/radd/tools/messages.pyc in logger(param_report, finfo, depends_on, pdict, is_flat, log_arrays, kind, dynamic, fit_on, pc_map)
#     102     pkeys = depends_on.keys()
#     103     pvals = depends_on.values()
# --> 104     fname = '_'.join(['./' + kind, '_'.join(pkeys) + '.txt'])
#     105     model_id = "MODEL: %s" % kind
#     106     if 'x' in kind:
#
# TypeError: sequence item 0: expected string, NoneType found

# %%
m.opt.fitparams
# Out:
# {'depends_on': {None: None},
#  'disp': True,
#  'dynamic': 'hyp',
#  'fit_on': 'average',
#  'idx': 0,
#  'maxfev': 5000,
#  'maxiter': 500,
#  'method': 'nelder',
#  'niter': 500,
#  'nssd': 5,
#  'ntrials': 10000,
#  'percentiles': array([ 0.1,  0.3,  0.5,  0.7,  0.9]),
#  'ssd': array([ 0.2 ,  0.25,  0.3 ,  0.35,  0.4 ]),
#  'tb': 0.68448999999999993,
#  'tol': 0.0001,
#  'wts': array([ 1.38035,  1.38035,  0.50671,  0.56856,  0.87712,  1.16293,
#          3.55126,  4.42539,  4.42799,  3.26663,  1.96042,  0.54994,
#          0.86212,  0.9497 ,  0.78003,  0.49244]),
#  'y': array([ 1.     ,  0.9595 ,  0.81217,  0.2965 ,  0.07121,  0.038  ,
#          0.48216,  0.51211,  0.53217,  0.55622,  0.60192,  0.47295,
#          0.50366,  0.52213,  0.54281,  0.57885])}

# %%
m.opt.simulator.basin_params
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-1e3d78c95eb2> in <module>()
# ----> 1 m.opt.simulator.basin_params
#
# AttributeError: 'Simulator' object has no attribute 'basin_params'
