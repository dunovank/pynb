# %%
dt = .001
v=.9
a=.7
ter=.2
z=.5
eta = .05-np.random.random_sample(1000)*.1
theta=np.zeros(1001)
ddm = lambda theta, dt, eta, i: theta[i] + v*dt + eta[i]
for i in xrange(1000):
    theta[i+1] = ddm(theta, dt, eta, i)

# %%
plt.plot(theta)
