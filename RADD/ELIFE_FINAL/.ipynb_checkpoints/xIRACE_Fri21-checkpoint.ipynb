# %%
from radd import build, models, fit, vis
from radd.toolbox import theta

# %%
m = build.Model(data=redf_store.redata, kind='xradd', dynamic='hyp')
m.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True)

# %%
popt={'a': array([ 0.44462,  0.44462]), 'v_pnl': 0.9689235891638055, 'z': 0.15225778581757374, 'v': array([ 1.04458,  0.96892], dtype=np.float32), 'xb': array([ 1.3909,  1.3909]), 'ssv': -0.92778056287176547, 'tr': array([ 0.30429,  0.30429]), 'v_bsl': 1.0445817952733745}

# %%
m.avg_y
# Out:
# array([[ 0.94125,  0.99668,  0.98653,  0.90386,  0.50872,  0.10362,
#          0.51461,  0.54372,  0.56341,  0.58263,  0.61047,  0.50345,
#          0.53184,  0.54934,  0.56775,  0.59466],
#        [ 0.92624,  0.99918,  0.9908 ,  0.93297,  0.59871,  0.18197,
#          0.52012,  0.55012,  0.57034,  0.59051,  0.61803,  0.51074,
#          0.53919,  0.55427,  0.5731 ,  0.60007]])

# %%
m.simulate()
# Out:
# array([ 0.9741 ,  0.9996 ,  0.9914 ,  0.952  ,  0.4968 ,  0.1112 ,
#         0.51629,  0.54129,  0.56029,  0.58129,  0.61429,  0.50829,
#         0.53129,  0.54929,  0.56829,  0.59929,  0.9252 ,  0.9988 ,
#         0.9954 ,  0.9742 ,  0.6156 ,  0.197  ,  0.52829,  0.55729,
#         0.57629,  0.59929,  0.62729,  0.51829,  0.54329,  0.56229,
#         0.58329,  0.61229])

# %%
#m.opt.flat_y=bsly
m.fitinfo
# Out:
# {'AIC': nan,
#  'BIC': nan,
#  'CNVRG': False,
#  'a': array([ 0.44462,  0.44462]),
#  'chi': 2.215644304680633e-05,
#  'nfev': 1082,
#  'rchi': -2.215644304680633e-05,
#  'ssv': -0.92778056287176547,
#  'tr': array([ 0.30429,  0.30429]),
#  'v_bsl': 1.0445817952733745,
#  'v_pnl': 0.9689235891638055,
#  'xb': array([ 1.3909,  1.3909]),
#  'z': 0.15225778581757374}

# %%
m.optimize()
# Out:
# ...
# basinhopping step 0: f 0.0139277
# ...
# basinhopping step 1: f 0.0139277 trial_f 0.0203085 accepted 0  lowest_f 0.0139277
# basinhopping step 2: f 0.0258473 trial_f 0.0258473 accepted 1  lowest_f 0.0139277
# basinhopping step 3: f 0.0258473 trial_f 0.0602561 accepted 0  lowest_f 0.0139277
# basinhopping step 4: f 0.0204523 trial_f 0.0204523 accepted 1  lowest_f 0.0139277
# ...
# basinhopping step 5: f 0.0588427 trial_f 0.0588427 accepted 1  lowest_f 0.0139277
# basinhopping step 6: f 0.083443 trial_f 0.083443 accepted 1  lowest_f 0.0139277
# basinhopping step 7: f 0.0620173 trial_f 0.0620173 accepted 1  lowest_f 0.0139277
# basinhopping step 8: f 0.0335389 trial_f 0.0335389 accepted 1  lowest_f 0.0139277
# basinhopping step 9: f 0.0248975 trial_f 0.0248975 accepted 1  lowest_f 0.0139277
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0777778 old stepsize 0.07
# basinhopping step 10: f 0.0163612 trial_f 0.0163612 accepted 1  lowest_f 0.0139277
# ...

# %%
yhat = array([0.9848, 1.0, 0.999, 0.931, 0.505, 0.108, 0.5077, 0.5337, 0.5537, 0.5757, 0.6057, 0.4937, 0.5197, 0.5357, 0.5497, 0.5777])
y = array([0.9412, 0.9966, 0.9865, 0.9038, 0.5087, 0.1036, 0.5146, 0.5437, 0.5634, 0.5826, 0.6104, 0.5034, 0.5318, 0.5493, 0.5677, 0.5946])

# %%
xyhat = y-((y-yhat)*m.flat_wts)

# %%
yhat = array([0.9781, 0.998, 0.9884, 0.9474, 0.4764, 0.0962, 0.5138, 0.5408, 0.5608, 0.5818, 0.6118, 0.5068, 0.5318, 0.5488, 0.5678, 0.5948])
y = array([0.9412, 0.9966, 0.9865, 0.9038, 0.5087, 0.1036, 0.5146, 0.5437, 0.5634, 0.5826, 0.6104, 0.5034, 0.5318, 0.5493, 0.5677, 0.5946])

# %%
yhat=y-((y-yhat)*m.flat_wts)

# %%
vis.plot_reactive_fits(m)

# %%
vis.plot_fits(bsly, yh[:len(bsly)], kind='radd')

# %%
vis.scurves([y[1:6], yhat[1:6], xyhat[1:6]], kind='radd', linestyles=['-', '--', '--'])
# Out:
# [0.35078007800780076,
#  0.35078007800780076,
#  0.34836483648364835,
#  0.34836483648364835,
#  0.35039503950395046,
#  0.35039503950395046]
