# %% [markdown]
# # Reactive A

# %%
from radd import build, vis
from radd.toolbox import analyze

# %%
d = 'FinalRe/a'
if not os.path.isdir(pth+d):
      os.mkdir(pth+d)
os.chdir(pth+d)
m = build.Model(data=redata, kind='xradd', dynamic='hyp', tb=.650, depends_on={'a':'Cond'})
m.optimize(tol=1.e-5, multiopt=True, maxfev=5000, ntrials=10000)
# Out:
# basinhopping step 0: f 0.0082467
# basinhopping step 1: f 0.0136504 trial_f 0.0136504 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 0.137153 trial_f 0.137153 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 0.422542 trial_f 0.422542 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 1.28591 trial_f 1.28591 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 5: f 0.761848 trial_f 0.761848 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 0.761848 trial_f 1.65905 accepted 0  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 0.701936 trial_f 0.701936 accepted 1  lowest_f 0.0082467
# basinhopping step 8: f 0.701936 trial_f 1.8547 accepted 0  lowest_f 0.0082467
# basinhopping step 9: f 0.245481 trial_f 0.245481 accepted 1  lowest_f 0.0082467
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 0.0924007 trial_f 0.0924007 accepted 1  lowest_f 0.0082467
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 0.00738182 trial_f 0.00738182 accepted 1  lowest_f 0.00738182
# found new global minimum on step 11 with function value 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 12: f 0.0178071 trial_f 0.0178071 accepted 1  lowest_f 0.00738182
# basinhopping step 13: f 0.0293316 trial_f 0.0293316 accepted 1  lowest_f 0.00738182
# basinhopping step 14: f 0.0293316 trial_f 0.310701 accepted 0  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 0.0535587 trial_f 0.0535587 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 0.316261 trial_f 0.316261 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 0.0626083 trial_f 0.0626083 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 0.0212671 trial_f 0.0212671 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 0.191067 trial_f 0.191067 accepted 1  lowest_f 0.00738182
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 0.0283191 trial_f 0.0283191 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 0.0283191 trial_f 0.536062 accepted 0  lowest_f 0.00738182
# basinhopping step 22: f 0.0865987 trial_f 0.0865987 accepted 1  lowest_f 0.00738182
# basinhopping step 23: f 0.0865987 trial_f 0.416127 accepted 0  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 24: f 0.074873 trial_f 0.074873 accepted 1  lowest_f 0.00738182
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 0.00715521 trial_f 0.00715521 accepted 1  lowest_f 0.00715521
# found new global minimum on step 25 with function value 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 26: f 0.0855572 trial_f 0.0855572 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 0.00947981 trial_f 0.00947981 accepted 1  lowest_f 0.00715521
# basinhopping step 28: f 0.117206 trial_f 0.117206 accepted 1  lowest_f 0.00715521
# basinhopping step 29: f 1.28542 trial_f 1.28542 accepted 1  lowest_f 0.00715521
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# warning: basinhopping: local minimization failure
# basinhopping step 30: f 0.764202 trial_f 0.764202 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 0.955814 trial_f 0.955814 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 0.955814 trial_f 1.89692 accepted 0  lowest_f 0.00715521
# basinhopping step 33: f 1.31663 trial_f 1.31663 accepted 1  lowest_f 0.00715521
# basinhopping step 34: f 0.838873 trial_f 0.838873 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 0.838873 trial_f 1.16603 accepted 0  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 36: f 0.0775747 trial_f 0.0775747 accepted 1  lowest_f 0.00715521
# basinhopping step 37: f 0.0775747 trial_f 1.18517 accepted 0  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 0.0416612 trial_f 0.0416612 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 0.0416612 trial_f 5.97406 accepted 0  lowest_f 0.00715521
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# warning: basinhopping: local minimization failure
# basinhopping step 40: f 0.152247 trial_f 0.152247 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 0.282122 trial_f 0.282122 accepted 1  lowest_f 0.00715521
# basinhopping step 42: f 0.243028 trial_f 0.243028 accepted 1  lowest_f 0.00715521
# basinhopping step 43: f 0.171767 trial_f 0.171767 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 0.532712 trial_f 0.532712 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 45: f 0.225113 trial_f 0.225113 accepted 1  lowest_f 0.00715521
# basinhopping step 46: f 0.225113 trial_f 0.388756 accepted 0  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 0.225113 trial_f 0.949207 accepted 0  lowest_f 0.00715521
# basinhopping step 48: f 0.288045 trial_f 0.288045 accepted 1  lowest_f 0.00715521
# basinhopping step 49: f 0.0456141 trial_f 0.0456141 accepted 1  lowest_f 0.00715521
# adaptive stepsize: acceptance rate 0.760000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# warning: basinhopping: local minimization failure
# basinhopping step 50: f 0.0456141 trial_f 5.74163 accepted 0  lowest_f 0.00715521
# basinhopping step 51: f 0.0456141 trial_f 0.786131 accepted 0  lowest_f 0.00715521
# basinhopping step 52: f 0.0487218 trial_f 0.0487218 accepted 1  lowest_f 0.00715521
# basinhopping step 53: f 0.0487218 trial_f 0.0915139 accepted 0  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 54: f 0.21023 trial_f 0.21023 accepted 1  lowest_f 0.00715521
# basinhopping step 55: f 0.21023 trial_f 1.1359 accepted 0  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 0.162308 trial_f 0.162308 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 57: f 0.573665 trial_f 0.573665 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 58: f 0.595563 trial_f 0.595563 accepted 1  lowest_f 0.00715521
# basinhopping step 59: f 0.478505 trial_f 0.478505 accepted 1  lowest_f 0.00715521
# adaptive stepsize: acceptance rate 0.733333 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 0.493899 trial_f 0.493899 accepted 1  lowest_f 0.00715521
# basinhopping step 61: f 0.504156 trial_f 0.504156 accepted 1  lowest_f 0.00715521
# basinhopping step 62: f 0.286128 trial_f 0.286128 accepted 1  lowest_f 0.00715521
# basinhopping step 63: f 0.286128 trial_f 0.626307 accepted 0  lowest_f 0.00715521
# basinhopping step 64: f 0.0174053 trial_f 0.0174053 accepted 1  lowest_f 0.00715521
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 0.0174053 trial_f 0.448975 accepted 0  lowest_f 0.00715521
# basinhopping step 66: f 0.0174053 trial_f 1.02645 accepted 0  lowest_f 0.00715521
# basinhopping step 0: f 2.9314
# basinhopping step 1: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 2: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 3: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 4: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 5: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 6: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 7: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 8: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 9: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 11: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 12: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 13: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 14: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 15: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 16: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 17: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 18: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 19: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 21: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# basinhopping step 22: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 2.9314
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 1.61403 trial_f 1.61403 accepted 1  lowest_f 1.61403
# found new global minimum on step 23 with function value 1.61403
# warning: basinhopping: local minimization failure
# basinhopping step 24: f 1.61298 trial_f 1.61298 accepted 1  lowest_f 1.61298
# found new global minimum on step 24 with function value 1.61298
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 1.36438 trial_f 1.36438 accepted 1  lowest_f 1.36438
# found new global minimum on step 25 with function value 1.36438
# basinhopping step 26: f 0.59686 trial_f 0.59686 accepted 1  lowest_f 0.59686
# found new global minimum on step 26 with function value 0.59686
# basinhopping step 27: f 0.59686 trial_f 2.65794 accepted 0  lowest_f 0.59686
# basinhopping step 28: f 0.641745 trial_f 0.641745 accepted 1  lowest_f 0.59686
# warning: basinhopping: local minimization failure
# basinhopping step 29: f 0.641745 trial_f 1.76395 accepted 0  lowest_f 0.59686
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 0.894579 trial_f 0.894579 accepted 1  lowest_f 0.59686
# basinhopping step 31: f 0.95722 trial_f 0.95722 accepted 1  lowest_f 0.59686
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 1.52177 trial_f 1.52177 accepted 1  lowest_f 0.59686
# basinhopping step 33: f 1.58996 trial_f 1.58996 accepted 1  lowest_f 0.59686
# basinhopping step 34: f 1.62318 trial_f 1.62318 accepted 1  lowest_f 0.59686
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 1.61402 trial_f 1.61402 accepted 1  lowest_f 0.59686
# basinhopping step 36: f 1.61978 trial_f 1.61978 accepted 1  lowest_f 0.59686
# basinhopping step 37: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# basinhopping step 38: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# basinhopping step 39: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# adaptive stepsize: acceptance rate 0.925000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# basinhopping step 41: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# basinhopping step 42: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# basinhopping step 43: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.59686
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 0.957286 trial_f 0.957286 accepted 1  lowest_f 0.59686
# basinhopping step 45: f 0.827488 trial_f 0.827488 accepted 1  lowest_f 0.59686
# warning: basinhopping: local minimization failure
# basinhopping step 46: f 0.509367 trial_f 0.509367 accepted 1  lowest_f 0.509367
# found new global minimum on step 46 with function value 0.509367
# basinhopping step 47: f 0.509367 trial_f 2.1044 accepted 0  lowest_f 0.509367
# basinhopping step 48: f 0.509367 trial_f 1.55395 accepted 0  lowest_f 0.509367
# basinhopping step 49: f 0.509367 trial_f 5.06743 accepted 0  lowest_f 0.509367
# adaptive stepsize: acceptance rate 0.880000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# warning: basinhopping: local minimization failure
# basinhopping step 50: f 0.509367 trial_f 1.41073 accepted 0  lowest_f 0.509367
# basinhopping step 51: f 1.59336 trial_f 1.59336 accepted 1  lowest_f 0.509367
# basinhopping step 52: f 1.5632 trial_f 1.5632 accepted 1  lowest_f 0.509367
# basinhopping step 53: f 0.665723 trial_f 0.665723 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 54: f 1.61752 trial_f 1.61752 accepted 1  lowest_f 0.509367
# basinhopping step 55: f 1.59192 trial_f 1.59192 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 0.890644 trial_f 0.890644 accepted 1  lowest_f 0.509367
# basinhopping step 57: f 1.33357 trial_f 1.33357 accepted 1  lowest_f 0.509367
# basinhopping step 58: f 0.671638 trial_f 0.671638 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 59: f 0.991982 trial_f 0.991982 accepted 1  lowest_f 0.509367
# adaptive stepsize: acceptance rate 0.883333 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# warning: basinhopping: local minimization failure
# basinhopping step 60: f 0.991982 trial_f 1.41464 accepted 0  lowest_f 0.509367
# basinhopping step 61: f 1.96647 trial_f 1.96647 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 62: f 0.845757 trial_f 0.845757 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 63: f 0.851962 trial_f 0.851962 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 64: f 0.99276 trial_f 0.99276 accepted 1  lowest_f 0.509367
# basinhopping step 65: f 0.99276 trial_f 2.9314 accepted 0  lowest_f 0.509367
# basinhopping step 66: f 1.33941 trial_f 1.33941 accepted 1  lowest_f 0.509367
# basinhopping step 67: f 1.3707 trial_f 1.3707 accepted 1  lowest_f 0.509367
# basinhopping step 68: f 1.30592 trial_f 1.30592 accepted 1  lowest_f 0.509367
# basinhopping step 69: f 1.17995 trial_f 1.17995 accepted 1  lowest_f 0.509367
# adaptive stepsize: acceptance rate 0.871429 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# warning: basinhopping: local minimization failure
# basinhopping step 70: f 1.17995 trial_f 2.27696 accepted 0  lowest_f 0.509367
# basinhopping step 71: f 1.46872 trial_f 1.46872 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 72: f 0.914695 trial_f 0.914695 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 73: f 0.914695 trial_f 1.68184 accepted 0  lowest_f 0.509367
# basinhopping step 74: f 0.974607 trial_f 0.974607 accepted 1  lowest_f 0.509367
# basinhopping step 75: f 0.974607 trial_f 2.40861 accepted 0  lowest_f 0.509367
# basinhopping step 76: f 0.812881 trial_f 0.812881 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 77: f 0.812881 trial_f 5.16061 accepted 0  lowest_f 0.509367
# basinhopping step 78: f 0.796698 trial_f 0.796698 accepted 1  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 79: f 0.777875 trial_f 0.777875 accepted 1  lowest_f 0.509367
# adaptive stepsize: acceptance rate 0.837500 target 0.500000 new stepsize 0.116153 old stepsize 0.104538
# basinhopping step 80: f 0.739742 trial_f 0.739742 accepted 1  lowest_f 0.509367
# basinhopping step 81: f 1.00902 trial_f 1.00902 accepted 1  lowest_f 0.509367
# basinhopping step 82: f 1.00902 trial_f 1.18498 accepted 0  lowest_f 0.509367
# basinhopping step 83: f 1.00902 trial_f 1.1008 accepted 0  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 84: f 1.00902 trial_f 2.93144 accepted 0  lowest_f 0.509367
# warning: basinhopping: local minimization failure
# basinhopping step 85: f 0.72402 trial_f 0.72402 accepted 1  lowest_f 0.509367
# basinhopping step 86: f 0.8075 trial_f 0.8075 accepted 1  lowest_f 0.509367
# basinhopping step 87: f 0.669744 trial_f 0.669744 accepted 1  lowest_f 0.509367
# basinhopping step 0: f 0.11076
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 0.0150756 trial_f 0.0150756 accepted 1  lowest_f 0.0150756
# found new global minimum on step 1 with function value 0.0150756
# basinhopping step 2: f 0.0150756 trial_f 0.149585 accepted 0  lowest_f 0.0150756
# basinhopping step 3: f 0.0590031 trial_f 0.0590031 accepted 1  lowest_f 0.0150756
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 0.0300125 trial_f 0.0300125 accepted 1  lowest_f 0.0150756
# basinhopping step 5: f 0.0491287 trial_f 0.0491287 accepted 1  lowest_f 0.0150756
# basinhopping step 6: f 0.250775 trial_f 0.250775 accepted 1  lowest_f 0.0150756
# basinhopping step 7: f 0.0156134 trial_f 0.0156134 accepted 1  lowest_f 0.0150756
# basinhopping step 8: f 0.215577 trial_f 0.215577 accepted 1  lowest_f 0.0150756
# basinhopping step 9: f 0.215577 trial_f 2.4679 accepted 0  lowest_f 0.0150756
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.0816339 trial_f 0.0816339 accepted 1  lowest_f 0.0150756
# basinhopping step 11: f 0.277375 trial_f 0.277375 accepted 1  lowest_f 0.0150756
# basinhopping step 12: f 0.245178 trial_f 0.245178 accepted 1  lowest_f 0.0150756
# basinhopping step 13: f 0.126193 trial_f 0.126193 accepted 1  lowest_f 0.0150756
# warning: basinhopping: local minimization failure
# basinhopping step 14: f 0.744137 trial_f 0.744137 accepted 1  lowest_f 0.0150756
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 1.81954 trial_f 1.81954 accepted 1  lowest_f 0.0150756
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 1.23147 trial_f 1.23147 accepted 1  lowest_f 0.0150756
# basinhopping step 17: f 1.23147 trial_f 4.38779 accepted 0  lowest_f 0.0150756
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 1.01811 trial_f 1.01811 accepted 1  lowest_f 0.0150756
# basinhopping step 19: f 1.20559 trial_f 1.20559 accepted 1  lowest_f 0.0150756
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# warning: basinhopping: local minimization failure
# basinhopping step 20: f 0.495013 trial_f 0.495013 accepted 1  lowest_f 0.0150756
# basinhopping step 21: f 0.552687 trial_f 0.552687 accepted 1  lowest_f 0.0150756
# basinhopping step 22: f 0.24405 trial_f 0.24405 accepted 1  lowest_f 0.0150756
# basinhopping step 23: f 0.063138 trial_f 0.063138 accepted 1  lowest_f 0.0150756
# basinhopping step 24: f 0.209834 trial_f 0.209834 accepted 1  lowest_f 0.0150756
# basinhopping step 25: f 0.543421 trial_f 0.543421 accepted 1  lowest_f 0.0150756
# basinhopping step 26: f 0.00481452 trial_f 0.00481452 accepted 1  lowest_f 0.00481452
# found new global minimum on step 26 with function value 0.00481452
# basinhopping step 27: f 0.450947 trial_f 0.450947 accepted 1  lowest_f 0.00481452
# basinhopping step 28: f 0.343379 trial_f 0.343379 accepted 1  lowest_f 0.00481452
# basinhopping step 29: f 0.0511677 trial_f 0.0511677 accepted 1  lowest_f 0.00481452
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 0.190579 trial_f 0.190579 accepted 1  lowest_f 0.00481452
# basinhopping step 31: f 0.286764 trial_f 0.286764 accepted 1  lowest_f 0.00481452
# basinhopping step 32: f 0.00876662 trial_f 0.00876662 accepted 1  lowest_f 0.00481452
# basinhopping step 33: f 0.0605225 trial_f 0.0605225 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 1.54292 trial_f 1.54292 accepted 1  lowest_f 0.00481452
# basinhopping step 35: f 1.46597 trial_f 1.46597 accepted 1  lowest_f 0.00481452
# basinhopping step 36: f 1.46597 trial_f 2.9314 accepted 0  lowest_f 0.00481452
# basinhopping step 37: f 1.58597 trial_f 1.58597 accepted 1  lowest_f 0.00481452
# basinhopping step 38: f 1.90243 trial_f 1.90243 accepted 1  lowest_f 0.00481452
# basinhopping step 39: f 1.90243 trial_f 2.9314 accepted 0  lowest_f 0.00481452
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 1.90243 trial_f 2.9314 accepted 0  lowest_f 0.00481452
# basinhopping step 41: f 1.604 trial_f 1.604 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 42: f 1.08214 trial_f 1.08214 accepted 1  lowest_f 0.00481452
# basinhopping step 43: f 0.0846014 trial_f 0.0846014 accepted 1  lowest_f 0.00481452
# basinhopping step 44: f 0.0846014 trial_f 0.922402 accepted 0  lowest_f 0.00481452
# basinhopping step 45: f 0.00997151 trial_f 0.00997151 accepted 1  lowest_f 0.00481452
# basinhopping step 46: f 0.0158393 trial_f 0.0158393 accepted 1  lowest_f 0.00481452
# basinhopping step 47: f 0.637433 trial_f 0.637433 accepted 1  lowest_f 0.00481452
# basinhopping step 48: f 0.588944 trial_f 0.588944 accepted 1  lowest_f 0.00481452
# basinhopping step 49: f 1.41261 trial_f 1.41261 accepted 1  lowest_f 0.00481452
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 1.45311 trial_f 1.45311 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 51: f 1.59157 trial_f 1.59157 accepted 1  lowest_f 0.00481452
# basinhopping step 52: f 1.59157 trial_f 2.9314 accepted 0  lowest_f 0.00481452
# basinhopping step 53: f 1.53571 trial_f 1.53571 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 54: f 1.60248 trial_f 1.60248 accepted 1  lowest_f 0.00481452
# basinhopping step 55: f 1.60248 trial_f 2.9314 accepted 0  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 0.676506 trial_f 0.676506 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 57: f 0.133141 trial_f 0.133141 accepted 1  lowest_f 0.00481452
# basinhopping step 58: f 0.0830173 trial_f 0.0830173 accepted 1  lowest_f 0.00481452
# basinhopping step 59: f 0.0830173 trial_f 1.24741 accepted 0  lowest_f 0.00481452
# adaptive stepsize: acceptance rate 0.816667 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# warning: basinhopping: local minimization failure
# basinhopping step 60: f 0.531531 trial_f 0.531531 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 61: f 0.129385 trial_f 0.129385 accepted 1  lowest_f 0.00481452
# basinhopping step 62: f 0.0332794 trial_f 0.0332794 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 63: f 0.0332794 trial_f 0.379482 accepted 0  lowest_f 0.00481452
# basinhopping step 64: f 0.0288027 trial_f 0.0288027 accepted 1  lowest_f 0.00481452
# basinhopping step 65: f 0.0288027 trial_f 1.22477 accepted 0  lowest_f 0.00481452
# basinhopping step 66: f 0.0288027 trial_f 0.322094 accepted 0  lowest_f 0.00481452
# basinhopping step 67: f 0.0081011 trial_f 0.0081011 accepted 1  lowest_f 0.00481452
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 0.88962
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 0.981397 trial_f 0.981397 accepted 1  lowest_f 0.88962
# basinhopping step 2: f 1.17784 trial_f 1.17784 accepted 1  lowest_f 0.88962
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 1.17784 trial_f 1.6022 accepted 0  lowest_f 0.88962
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 1.20526 trial_f 1.20526 accepted 1  lowest_f 0.88962
# warning: basinhopping: local minimization failure
# basinhopping step 5: f 0.750665 trial_f 0.750665 accepted 1  lowest_f 0.750665
# found new global minimum on step 5 with function value 0.750665
# basinhopping step 6: f 1.09133 trial_f 1.09133 accepted 1  lowest_f 0.750665
# basinhopping step 7: f 1.00777 trial_f 1.00777 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 8: f 1.31064 trial_f 1.31064 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 1.38831 trial_f 1.38831 accepted 1  lowest_f 0.750665
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 1.59189 trial_f 1.59189 accepted 1  lowest_f 0.750665
# basinhopping step 11: f 1.5159 trial_f 1.5159 accepted 1  lowest_f 0.750665
# basinhopping step 12: f 1.56291 trial_f 1.56291 accepted 1  lowest_f 0.750665
# basinhopping step 13: f 1.58254 trial_f 1.58254 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 14: f 1.4307 trial_f 1.4307 accepted 1  lowest_f 0.750665
# basinhopping step 15: f 1.27423 trial_f 1.27423 accepted 1  lowest_f 0.750665
# basinhopping step 16: f 1.18357 trial_f 1.18357 accepted 1  lowest_f 0.750665
# basinhopping step 17: f 1.39433 trial_f 1.39433 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 1.08434 trial_f 1.08434 accepted 1  lowest_f 0.750665
# basinhopping step 19: f 1.09963 trial_f 1.09963 accepted 1  lowest_f 0.750665
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# warning: basinhopping: local minimization failure
# basinhopping step 20: f 1.01253 trial_f 1.01253 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 21: f 0.895155 trial_f 0.895155 accepted 1  lowest_f 0.750665
# basinhopping step 22: f 1.27345 trial_f 1.27345 accepted 1  lowest_f 0.750665
# basinhopping step 23: f 1.27345 trial_f 1.59859 accepted 0  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 24: f 1.24064 trial_f 1.24064 accepted 1  lowest_f 0.750665
# basinhopping step 25: f 1.22118 trial_f 1.22118 accepted 1  lowest_f 0.750665
# warning: basinhopping: local minimization failure
# basinhopping step 26: f 1.43517 trial_f 1.43517 accepted 1  lowest_f 0.750665
# basinhopping step 27: f 0.741776 trial_f 0.741776 accepted 1  lowest_f 0.741776
# found new global minimum on step 27 with function value 0.741776
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 0.773041 trial_f 0.773041 accepted 1  lowest_f 0.741776
# basinhopping step 29: f 0.773041 trial_f 1.33394 accepted 0  lowest_f 0.741776
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 30: f 0.456943 trial_f 0.456943 accepted 1  lowest_f 0.456943
# found new global minimum on step 30 with function value 0.456943
# basinhopping step 31: f 0.44808 trial_f 0.44808 accepted 1  lowest_f 0.44808
# found new global minimum on step 31 with function value 0.44808
# basinhopping step 32: f 0.934031 trial_f 0.934031 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 0.484558 trial_f 0.484558 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 0.833718 trial_f 0.833718 accepted 1  lowest_f 0.44808
# basinhopping step 35: f 0.548518 trial_f 0.548518 accepted 1  lowest_f 0.44808
# basinhopping step 36: f 0.548518 trial_f 0.966296 accepted 0  lowest_f 0.44808
# basinhopping step 37: f 1.206 trial_f 1.206 accepted 1  lowest_f 0.44808
# basinhopping step 38: f 1.02816 trial_f 1.02816 accepted 1  lowest_f 0.44808
# basinhopping step 39: f 1.56352 trial_f 1.56352 accepted 1  lowest_f 0.44808
# adaptive stepsize: acceptance rate 0.875000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 1.61937 trial_f 1.61937 accepted 1  lowest_f 0.44808
# basinhopping step 41: f 1.57753 trial_f 1.57753 accepted 1  lowest_f 0.44808
# basinhopping step 42: f 1.29428 trial_f 1.29428 accepted 1  lowest_f 0.44808
# basinhopping step 43: f 1.61381 trial_f 1.61381 accepted 1  lowest_f 0.44808
# basinhopping step 44: f 1.89159 trial_f 1.89159 accepted 1  lowest_f 0.44808
# basinhopping step 45: f 1.89159 trial_f 2.9314 accepted 0  lowest_f 0.44808
# basinhopping step 46: f 1.58623 trial_f 1.58623 accepted 1  lowest_f 0.44808
# basinhopping step 47: f 1.62604 trial_f 1.62604 accepted 1  lowest_f 0.44808
# basinhopping step 48: f 1.62604 trial_f 2.9314 accepted 0  lowest_f 0.44808
# basinhopping step 49: f 1.62604 trial_f 2.9314 accepted 0  lowest_f 0.44808
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 1.62604 trial_f 2.9314 accepted 0  lowest_f 0.44808
# basinhopping step 51: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# basinhopping step 52: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# basinhopping step 53: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# basinhopping step 54: f 1.52198 trial_f 1.52198 accepted 1  lowest_f 0.44808
# basinhopping step 55: f 1.38614 trial_f 1.38614 accepted 1  lowest_f 0.44808
# basinhopping step 56: f 1.90255 trial_f 1.90255 accepted 1  lowest_f 0.44808
# basinhopping step 57: f 1.61285 trial_f 1.61285 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 58: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# basinhopping step 59: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0940838 old stepsize 0.0846754
# basinhopping step 60: f 2.9314 trial_f 2.9314 accepted 1  lowest_f 0.44808
# basinhopping step 61: f 1.90327 trial_f 1.90327 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 62: f 0.719352 trial_f 0.719352 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 63: f 1.11309 trial_f 1.11309 accepted 1  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 64: f 1.31763 trial_f 1.31763 accepted 1  lowest_f 0.44808
# basinhopping step 65: f 1.31763 trial_f 2.9314 accepted 0  lowest_f 0.44808
# basinhopping step 66: f 1.5396 trial_f 1.5396 accepted 1  lowest_f 0.44808
# basinhopping step 67: f 0.452316 trial_f 0.452316 accepted 1  lowest_f 0.44808
# basinhopping step 68: f 0.692657 trial_f 0.692657 accepted 1  lowest_f 0.44808
# basinhopping step 69: f 0.652064 trial_f 0.652064 accepted 1  lowest_f 0.44808
# adaptive stepsize: acceptance rate 0.857143 target 0.500000 new stepsize 0.104538 old stepsize 0.0940838
# basinhopping step 70: f 0.652064 trial_f 1.23063 accepted 0  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 0.843238 trial_f 0.843238 accepted 1  lowest_f 0.44808
# basinhopping step 72: f 0.843238 trial_f 3.68459 accepted 0  lowest_f 0.44808
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 3.11965
# basinhopping step 1: f 0.918014 trial_f 0.918014 accepted 1  lowest_f 0.918014
# found new global minimum on step 1 with function value 0.918014
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 0.819483 trial_f 0.819483 accepted 1  lowest_f 0.819483
# found new global minimum on step 2 with function value 0.819483
# basinhopping step 3: f 0.837952 trial_f 0.837952 accepted 1  lowest_f 0.819483
# basinhopping step 4: f 0.944219 trial_f 0.944219 accepted 1  lowest_f 0.819483
# warning: basinhopping: local minimization failure
# basinhopping step 5: f 0.482675 trial_f 0.482675 accepted 1  lowest_f 0.482675
# found new global minimum on step 5 with function value 0.482675
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 0.482675 trial_f 1.44064 accepted 0  lowest_f 0.482675
# basinhopping step 7: f 2.80614 trial_f 2.80614 accepted 1  lowest_f 0.482675
# basinhopping step 8: f 0.423151 trial_f 0.423151 accepted 1  lowest_f 0.423151
# found new global minimum on step 8 with function value 0.423151
# basinhopping step 9: f 0.0770399 trial_f 0.0770399 accepted 1  lowest_f 0.0770399
# found new global minimum on step 9 with function value 0.0770399
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.0459123 trial_f 0.0459123 accepted 1  lowest_f 0.0459123
# found new global minimum on step 10 with function value 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 0.0459123 trial_f 0.497776 accepted 0  lowest_f 0.0459123
# basinhopping step 12: f 0.167598 trial_f 0.167598 accepted 1  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 13: f 0.145912 trial_f 0.145912 accepted 1  lowest_f 0.0459123
# basinhopping step 14: f 0.171281 trial_f 0.171281 accepted 1  lowest_f 0.0459123
# basinhopping step 15: f 0.136453 trial_f 0.136453 accepted 1  lowest_f 0.0459123
# basinhopping step 16: f 0.111862 trial_f 0.111862 accepted 1  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 0.522056 trial_f 0.522056 accepted 1  lowest_f 0.0459123
# basinhopping step 18: f 0.137166 trial_f 0.137166 accepted 1  lowest_f 0.0459123
# basinhopping step 19: f 0.0949918 trial_f 0.0949918 accepted 1  lowest_f 0.0459123
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 20: f 0.128484 trial_f 0.128484 accepted 1  lowest_f 0.0459123
# basinhopping step 21: f 0.0741647 trial_f 0.0741647 accepted 1  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 0.123753 trial_f 0.123753 accepted 1  lowest_f 0.0459123
# basinhopping step 23: f 0.913484 trial_f 0.913484 accepted 1  lowest_f 0.0459123
# basinhopping step 24: f 1.14729 trial_f 1.14729 accepted 1  lowest_f 0.0459123
# basinhopping step 25: f 0.621151 trial_f 0.621151 accepted 1  lowest_f 0.0459123
# basinhopping step 26: f 0.193664 trial_f 0.193664 accepted 1  lowest_f 0.0459123
# basinhopping step 27: f 0.574379 trial_f 0.574379 accepted 1  lowest_f 0.0459123
# basinhopping step 28: f 1.00809 trial_f 1.00809 accepted 1  lowest_f 0.0459123
# basinhopping step 29: f 1.00809 trial_f 1.65416 accepted 0  lowest_f 0.0459123
# adaptive stepsize: acceptance rate 0.866667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# warning: basinhopping: local minimization failure
# basinhopping step 30: f 0.920454 trial_f 0.920454 accepted 1  lowest_f 0.0459123
# basinhopping step 31: f 0.616733 trial_f 0.616733 accepted 1  lowest_f 0.0459123
# basinhopping step 32: f 0.616733 trial_f 0.925985 accepted 0  lowest_f 0.0459123
# basinhopping step 33: f 0.616733 trial_f 0.91484 accepted 0  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 1.04666 trial_f 1.04666 accepted 1  lowest_f 0.0459123
# basinhopping step 35: f 1.42342 trial_f 1.42342 accepted 1  lowest_f 0.0459123
# basinhopping step 36: f 1.89016 trial_f 1.89016 accepted 1  lowest_f 0.0459123
# basinhopping step 37: f 0.928042 trial_f 0.928042 accepted 1  lowest_f 0.0459123
# basinhopping step 38: f 1.0094 trial_f 1.0094 accepted 1  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 0.922003 trial_f 0.922003 accepted 1  lowest_f 0.0459123
# adaptive stepsize: acceptance rate 0.850000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 40: f 0.932136 trial_f 0.932136 accepted 1  lowest_f 0.0459123
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 1.52572 trial_f 1.52572 accepted 1  lowest_f 0.0459123
# basinhopping step 42: f 1.5402 trial_f 1.5402 accepted 1  lowest_f 0.0459123
# basinhopping step 43: f 0.557557 trial_f 0.557557 accepted 1  lowest_f 0.0459123
# basinhopping step 44: f 0.620123 trial_f 0.620123 accepted 1  lowest_f 0.0459123
# basinhopping step 45: f 0.437489 trial_f 0.437489 accepted 1  lowest_f 0.0459123
# basinhopping step 46: f 0.106524 trial_f 0.106524 accepted 1  lowest_f 0.0459123
# basinhopping step 47: f 0.106524 trial_f 1.09615 accepted 0  lowest_f 0.0459123
# basinhopping step 48: f 0.0758989 trial_f 0.0758989 accepted 1  lowest_f 0.0459123
# basinhopping step 49: f 0.0758989 trial_f 6.11608 accepted 0  lowest_f 0.0459123
# adaptive stepsize: acceptance rate 0.840000 target 0.500000 new stepsize 0.0846754 old stepsize 0.0762079
# basinhopping step 50: f 0.623811 trial_f 0.623811 accepted 1  lowest_f 0.0459123
# basinhopping step 51: f 0.145032 trial_f 0.145032 accepted 1  lowest_f 0.0459123
# Optimization terminated successfully.
#          Current function value: 0.000003
#          Iterations: 63
#          Function evaluations: 171
# basinhopping step 0: f 2.85285
# basinhopping step 1: f 2.74371 trial_f 2.74371 accepted 1  lowest_f 2.74371
# found new global minimum on step 1 with function value 2.74371
# basinhopping step 2: f 2.97346 trial_f 2.97346 accepted 1  lowest_f 2.74371
# basinhopping step 3: f 3.495 trial_f 3.495 accepted 1  lowest_f 2.74371
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 3.44521 trial_f 3.44521 accepted 1  lowest_f 2.74371
# basinhopping step 5: f 2.7753 trial_f 2.7753 accepted 1  lowest_f 2.74371
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 2.35065 trial_f 2.35065 accepted 1  lowest_f 2.35065
# found new global minimum on step 6 with function value 2.35065
# warning: basinhopping: local minimization failure
# basinhopping step 7: f 2.3526 trial_f 2.3526 accepted 1  lowest_f 2.35065
# basinhopping step 8: f 2.12829 trial_f 2.12829 accepted 1  lowest_f 2.12829
# found new global minimum on step 8 with function value 2.12829
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 1.80627 trial_f 1.80627 accepted 1  lowest_f 1.80627
# found new global minimum on step 9 with function value 1.80627
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 1.77152 trial_f 1.77152 accepted 1  lowest_f 1.77152
# found new global minimum on step 10 with function value 1.77152
# basinhopping step 11: f 1.75864 trial_f 1.75864 accepted 1  lowest_f 1.75864
# found new global minimum on step 11 with function value 1.75864
# basinhopping step 12: f 1.87446 trial_f 1.87446 accepted 1  lowest_f 1.75864
# basinhopping step 13: f 1.81424 trial_f 1.81424 accepted 1  lowest_f 1.75864
# basinhopping step 14: f 1.84884 trial_f 1.84884 accepted 1  lowest_f 1.75864
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 1.75238 trial_f 1.75238 accepted 1  lowest_f 1.75238
# found new global minimum on step 15 with function value 1.75238
# basinhopping step 16: f 1.75358 trial_f 1.75358 accepted 1  lowest_f 1.75238
# basinhopping step 17: f 1.77441 trial_f 1.77441 accepted 1  lowest_f 1.75238
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 1.78053 trial_f 1.78053 accepted 1  lowest_f 1.75238
# basinhopping step 19: f 1.74831 trial_f 1.74831 accepted 1  lowest_f 1.74831
# found new global minimum on step 19 with function value 1.74831
# adaptive stepsize: acceptance rate 0.950000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 20: f 1.92385 trial_f 1.92385 accepted 1  lowest_f 1.74831
# basinhopping step 21: f 1.771 trial_f 1.771 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 1.91372 trial_f 1.91372 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 1.91372 trial_f 2.41214 accepted 0  lowest_f 1.74831
# basinhopping step 24: f 2.05634 trial_f 2.05634 accepted 1  lowest_f 1.74831
# basinhopping step 25: f 1.83816 trial_f 1.83816 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 26: f 1.75365 trial_f 1.75365 accepted 1  lowest_f 1.74831
# basinhopping step 27: f 1.74886 trial_f 1.74886 accepted 1  lowest_f 1.74831
# basinhopping step 28: f 1.77423 trial_f 1.77423 accepted 1  lowest_f 1.74831
# basinhopping step 29: f 1.77423 trial_f 1.95738 accepted 0  lowest_f 1.74831
# basinhopping step 30: f 1.81879 trial_f 1.81879 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 1.91407 trial_f 1.91407 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 2.08672 trial_f 2.08672 accepted 1  lowest_f 1.74831
# basinhopping step 33: f 1.83985 trial_f 1.83985 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 1.77417 trial_f 1.77417 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 1.81211 trial_f 1.81211 accepted 1  lowest_f 1.74831
# basinhopping step 36: f 1.99283 trial_f 1.99283 accepted 1  lowest_f 1.74831
# basinhopping step 37: f 2.16146 trial_f 2.16146 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 2.17973 trial_f 2.17973 accepted 1  lowest_f 1.74831
# basinhopping step 39: f 2.15844 trial_f 2.15844 accepted 1  lowest_f 1.74831
# adaptive stepsize: acceptance rate 0.925000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 40: f 2.18716 trial_f 2.18716 accepted 1  lowest_f 1.74831
# basinhopping step 41: f 2.18982 trial_f 2.18982 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 42: f 2.17518 trial_f 2.17518 accepted 1  lowest_f 1.74831
# basinhopping step 43: f 2.19014 trial_f 2.19014 accepted 1  lowest_f 1.74831
# basinhopping step 44: f 2.21793 trial_f 2.21793 accepted 1  lowest_f 1.74831
# basinhopping step 45: f 2.21793 trial_f 9.69491 accepted 0  lowest_f 1.74831
# basinhopping step 46: f 2.32355 trial_f 2.32355 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 2.24929 trial_f 2.24929 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 48: f 2.20517 trial_f 2.20517 accepted 1  lowest_f 1.74831
# basinhopping step 49: f 2.22447 trial_f 2.22447 accepted 1  lowest_f 1.74831
# basinhopping step 50: f 2.18062 trial_f 2.18062 accepted 1  lowest_f 1.74831
# basinhopping step 51: f 2.16606 trial_f 2.16606 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 52: f 2.1278 trial_f 2.1278 accepted 1  lowest_f 1.74831
# basinhopping step 53: f 1.89072 trial_f 1.89072 accepted 1  lowest_f 1.74831
# basinhopping step 54: f 1.83388 trial_f 1.83388 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 55: f 1.75665 trial_f 1.75665 accepted 1  lowest_f 1.74831
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 1.74861 trial_f 1.74861 accepted 1  lowest_f 1.74831
# basinhopping step 57: f 1.78717 trial_f 1.78717 accepted 1  lowest_f 1.74831
# basinhopping step 58: f 1.89199 trial_f 1.89199 accepted 1  lowest_f 1.74831
# basinhopping step 59: f 1.76391 trial_f 1.76391 accepted 1  lowest_f 1.74831
# adaptive stepsize: acceptance rate 0.933333 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# warning: basinhopping: local minimization failure
# basinhopping step 60: f 2.08752 trial_f 2.08752 accepted 1  lowest_f 1.74831
# basinhopping step 0: f 14.1468
# basinhopping step 1: f 14.1468 trial_f 17.2787 accepted 0  lowest_f 14.1468
# basinhopping step 2: f 14.0055 trial_f 14.0055 accepted 1  lowest_f 14.0055
# found new global minimum on step 2 with function value 14.0055
# basinhopping step 3: f 14.0055 trial_f 16.5692 accepted 0  lowest_f 14.0055
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 11.32 trial_f 11.32 accepted 1  lowest_f 11.32
# found new global minimum on step 4 with function value 11.32
# basinhopping step 5: f 11.3803 trial_f 11.3803 accepted 1  lowest_f 11.32
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 10.5334 trial_f 10.5334 accepted 1  lowest_f 10.5334
# found new global minimum on step 6 with function value 10.5334
# basinhopping step 7: f 10.5334 trial_f 12.2959 accepted 0  lowest_f 10.5334
# basinhopping step 8: f 10.6067 trial_f 10.6067 accepted 1  lowest_f 10.5334
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 10.6067 trial_f 12.0668 accepted 0  lowest_f 10.5334
# basinhopping step 10: f 10.6067 trial_f 11.1567 accepted 0  lowest_f 10.5334
# warning: basinhopping: local minimization failure
# basinhopping step 11: f 10.1085 trial_f 10.1085 accepted 1  lowest_f 10.1085
# found new global minimum on step 11 with function value 10.1085
# basinhopping step 12: f 10.1254 trial_f 10.1254 accepted 1  lowest_f 10.1085
# basinhopping step 13: f 10.1418 trial_f 10.1418 accepted 1  lowest_f 10.1085
# basinhopping step 14: f 10.1418 trial_f 10.6579 accepted 0  lowest_f 10.1085
# basinhopping step 15: f 10.147 trial_f 10.147 accepted 1  lowest_f 10.1085
# warning: basinhopping: local minimization failure
# basinhopping step 16: f 10.0971 trial_f 10.0971 accepted 1  lowest_f 10.0971
# found new global minimum on step 16 with function value 10.0971
# basinhopping step 17: f 10.1763 trial_f 10.1763 accepted 1  lowest_f 10.0971
# warning: basinhopping: local minimization failure
# basinhopping step 18: f 10.1447 trial_f 10.1447 accepted 1  lowest_f 10.0971
# basinhopping step 19: f 10.3984 trial_f 10.3984 accepted 1  lowest_f 10.0971
# adaptive stepsize: acceptance rate 0.650000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# warning: basinhopping: local minimization failure
# basinhopping step 20: f 10.1866 trial_f 10.1866 accepted 1  lowest_f 10.0971
# basinhopping step 21: f 10.3372 trial_f 10.3372 accepted 1  lowest_f 10.0971
# basinhopping step 22: f 10.395 trial_f 10.395 accepted 1  lowest_f 10.0971
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 10.395 trial_f 12.1089 accepted 0  lowest_f 10.0971
# warning: basinhopping: local minimization failure
# basinhopping step 24: f 10.2532 trial_f 10.2532 accepted 1  lowest_f 10.0971
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 11.0199 trial_f 11.0199 accepted 1  lowest_f 10.0971
# basinhopping step 26: f 10.1862 trial_f 10.1862 accepted 1  lowest_f 10.0971
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 10.0945 trial_f 10.0945 accepted 1  lowest_f 10.0945
# found new global minimum on step 27 with function value 10.0945
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 10.118 trial_f 10.118 accepted 1  lowest_f 10.0945
# basinhopping step 29: f 10.0795 trial_f 10.0795 accepted 1  lowest_f 10.0795
# found new global minimum on step 29 with function value 10.0795
# basinhopping step 30: f 10.0789 trial_f 10.0789 accepted 1  lowest_f 10.0789
# found new global minimum on step 30 with function value 10.0789
# warning: basinhopping: local minimization failure
# basinhopping step 31: f 10.485 trial_f 10.485 accepted 1  lowest_f 10.0789
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 10.9367 trial_f 10.9367 accepted 1  lowest_f 10.0789
# warning: basinhopping: local minimization failure
# basinhopping step 33: f 11.1328 trial_f 11.1328 accepted 1  lowest_f 10.0789
# basinhopping step 34: f 10.6166 trial_f 10.6166 accepted 1  lowest_f 10.0789
# warning: basinhopping: local minimization failure
# basinhopping step 35: f 10.0611 trial_f 10.0611 accepted 1  lowest_f 10.0611
# found new global minimum on step 35 with function value 10.0611
# basinhopping step 36: f 10.6607 trial_f 10.6607 accepted 1  lowest_f 10.0611
# warning: basinhopping: local minimization failure
# basinhopping step 37: f 10.181 trial_f 10.181 accepted 1  lowest_f 10.0611
# basinhopping step 38: f 10.8853 trial_f 10.8853 accepted 1  lowest_f 10.0611
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 10.2204 trial_f 10.2204 accepted 1  lowest_f 10.0611
# adaptive stepsize: acceptance rate 0.800000 target 0.500000 new stepsize 0.0617284 old stepsize 0.0555556
# basinhopping step 40: f 10.0172 trial_f 10.0172 accepted 1  lowest_f 10.0172
# found new global minimum on step 40 with function value 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 41: f 10.0989 trial_f 10.0989 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 42: f 10.0989 trial_f 11.5653 accepted 0  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 43: f 10.0989 trial_f 10.9923 accepted 0  lowest_f 10.0172
# basinhopping step 44: f 10.1227 trial_f 10.1227 accepted 1  lowest_f 10.0172
# basinhopping step 45: f 10.1227 trial_f 10.496 accepted 0  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 46: f 10.6503 trial_f 10.6503 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 10.2181 trial_f 10.2181 accepted 1  lowest_f 10.0172
# basinhopping step 48: f 10.2181 trial_f 11.173 accepted 0  lowest_f 10.0172
# basinhopping step 49: f 10.6013 trial_f 10.6013 accepted 1  lowest_f 10.0172
# basinhopping step 50: f 10.2936 trial_f 10.2936 accepted 1  lowest_f 10.0172
# basinhopping step 51: f 10.3352 trial_f 10.3352 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 52: f 10.1499 trial_f 10.1499 accepted 1  lowest_f 10.0172
# basinhopping step 53: f 11.2035 trial_f 11.2035 accepted 1  lowest_f 10.0172
# basinhopping step 54: f 11.1281 trial_f 11.1281 accepted 1  lowest_f 10.0172
# basinhopping step 55: f 11.24 trial_f 11.24 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 56: f 11.1289 trial_f 11.1289 accepted 1  lowest_f 10.0172
# basinhopping step 57: f 11.516 trial_f 11.516 accepted 1  lowest_f 10.0172
# basinhopping step 58: f 11.516 trial_f 11.9104 accepted 0  lowest_f 10.0172
# basinhopping step 59: f 11.516 trial_f 11.8257 accepted 0  lowest_f 10.0172
# adaptive stepsize: acceptance rate 0.766667 target 0.500000 new stepsize 0.0685871 old stepsize 0.0617284
# basinhopping step 60: f 11.155 trial_f 11.155 accepted 1  lowest_f 10.0172
# basinhopping step 61: f 10.8391 trial_f 10.8391 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 62: f 10.8391 trial_f 11.6711 accepted 0  lowest_f 10.0172
# basinhopping step 63: f 10.1047 trial_f 10.1047 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 64: f 10.1047 trial_f 10.6028 accepted 0  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 65: f 10.1047 trial_f 10.5203 accepted 0  lowest_f 10.0172
# basinhopping step 66: f 10.0482 trial_f 10.0482 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 67: f 10.3578 trial_f 10.3578 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 68: f 11.8733 trial_f 11.8733 accepted 1  lowest_f 10.0172
# basinhopping step 69: f 11.8627 trial_f 11.8627 accepted 1  lowest_f 10.0172
# basinhopping step 70: f 11.9256 trial_f 11.9256 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 71: f 11.9256 trial_f 16.0215 accepted 0  lowest_f 10.0172
# basinhopping step 72: f 11.7315 trial_f 11.7315 accepted 1  lowest_f 10.0172
# basinhopping step 73: f 11.7315 trial_f 12.1951 accepted 0  lowest_f 10.0172
# basinhopping step 74: f 11.7315 trial_f 14.4141 accepted 0  lowest_f 10.0172
# basinhopping step 75: f 10.566 trial_f 10.566 accepted 1  lowest_f 10.0172
# basinhopping step 76: f 10.2605 trial_f 10.2605 accepted 1  lowest_f 10.0172
# basinhopping step 77: f 10.2761 trial_f 10.2761 accepted 1  lowest_f 10.0172
# warning: basinhopping: local minimization failure
# basinhopping step 78: f 10.2696 trial_f 10.2696 accepted 1  lowest_f 10.0172
# basinhopping step 79: f 10.2068 trial_f 10.2068 accepted 1  lowest_f 10.0172
# adaptive stepsize: acceptance rate 0.750000 target 0.500000 new stepsize 0.0762079 old stepsize 0.0685871
# basinhopping step 80: f 10.1562 trial_f 10.1562 accepted 1  lowest_f 10.0172
# basinhopping step 81: f 10.1562 trial_f 10.6216 accepted 0  lowest_f 10.0172
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 39
#          Function evaluations: 85

# %%
f, axes = plt.subplots(2,3,figsize=(12, 7))
sns.set_context('notebook', font_scale=1.6)
fits=m.fits.reshape(2,16)
y=m.avg_y
labels=['Baseline', 'Caution']
datas=[redata.query('Cond=="bsl"'), redata.query('Cond=="pnl"')]
colors=["#e74c3c"]*2
for i in range(m.ncond):
      vis.plot_fits(y[i], fits[i], kind='radd', colors=["#e74c3c"]*2, data=datas[i], axes=axes[i])

plt.savefig('re_boundary_fits.png', dpi=500)
plt.savefig('re_boundary_fits.svg', rasterized=True)
for ax in axes:
      if ax.is_last_col():
            continue
      ax.set_ylim(0,11)
#vis.plot_fits(m.avg_y[1], m.fits[16:], kind='radd', colors=["#e74c3c"]*2, data=redata.query('Cond=="pnl"'))
#plt.savefig('repnl_boundary_fits.png', dpi=500)
#plt.savefig('repnl_boundary_fits.svg', rasterized=True)
