# %%
from radd import build, models, fit, vis
from radd.toolbox import theta
mx = build.Model(data=redf_store.redata, kind='xradd', dynamic='hyp', depends_on={'a':'Cond'})
mx.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True)

# %%
mx.optimize()

# %%
f, (ax1, ax2,ax3) = plt.subplots(1,3,figsize=(14, 6))

for i in range(20):
      #yh = mx.simulate(mx.popt)
      vis.plot_reactive_fits(mx, axes=[ax1, ax2, ax3], plot_sims=True)

# %%
pd.DataFrame(boot_y).std()

# %%
pd.DataFrame(boot_y).std()
# Out:
# 0     0.0246
# 1     0.0042
# 2     0.0095
# 3     0.0270
# 4     0.0556
# 5     0.0246
# 6     0.0089
# 7     0.0066
# 8     0.0070
# 9     0.0078
# 10    0.0092
# 11    0.0063
# 12    0.0064
# 13    0.0033
# 14    0.0065
# 15    0.0067
# dtype: float64

# %%
df, rtcix = analyze.make_proRT_conds(prodf_store.prodata, 50)

# %%
np.asarray(idx_res
# Out:
# (61,)

# %%
from radd.toolbox import analyze

# %%
x = mx.data.groupby(['Cond']).apply(analyze.resample_data, data_style='re')
#for indx in mx.indx:
dat = np.asarray([np.vstack(mx.data.groupby(['Cond']).apply(mx.resample_data)) for indx in mx.indx])

# %%
# Out:
# array([[ 0.91   ,  1.     ,  1.     ,  0.93   ,  0.54   ,  0.12   ,
#          0.49872,  0.53176,  0.5585 ,  0.58505,  0.62505,  0.50495,
#          0.52834,  0.54505,  0.55899,  0.59805],
#        [ 0.89   ,  1.     ,  1.     ,  0.93   ,  0.59   ,  0.17   ,
#          0.50514,  0.54507,  0.57143,  0.58504,  0.6119 ,  0.50518,
#          0.53187,  0.54524,  0.57175,  0.61175]])

# %%
x = np.asarray(dat)
# Out:
# (61, 2, 16)

# %%
np.vstack(dat).shape
# Out:
# (2, 16)

# %%
np.vstack(dat.unstack().unstack().values)
# Out:
# array([[ 0.99   ,  1.     ,  1.     , ...,  0.53187,  0.54517,  0.55855],
#        [ 0.97   ,  1.     ,  1.     , ...,  0.55848,  0.5717 ,  0.58509],
#        [ 0.92   ,  1.     ,  1.     , ...,  0.58535,  0.59971,  0.62495],
#        ...,
#        [ 0.91   ,  1.     ,  1.     , ...,  0.58682,  0.61164,  0.62506],
#        [ 0.99   ,  1.     ,  0.93   , ...,  0.53175,  0.54523,  0.59846],
#        [ 0.92   ,  1.     ,  1.     , ...,  0.53162,  0.54496,  0.55844]])

# %%
np.vstack(x.values)
# Out:
# array([[ 0.95   ,  1.     ,  1.     ,  0.925  ,  0.46667,  0.1    ,
#          0.50505,  0.53182,  0.5583 ,  0.58508,  0.61193,  0.50508,
#          0.52529,  0.54504,  0.55851,  0.59891],
#        [ 0.96667,  1.     ,  1.     ,  0.94167,  0.61667,  0.13333,
#          0.51837,  0.54518,  0.57164,  0.59834,  0.62502,  0.51831,
#          0.54495,  0.55823,  0.57183,  0.61154]])

# %%
#idx_res = df.apply(analyze.resample_data, data_style='pro')
dat = np.vstack([mx.resample_data(mx.data) for i in mx.indx])

# %%
dat.shape
# Out:
# (61, 16)

# %%
from radd.toolbox import theta
from radd import CORE
build=reload(build)
mx = build.Model(data=prodf_store.prodata, kind='xpro', dynamic='hyp')
mx.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True, fit_on='bootstrap')
# Out:
# /home/kyle/Dropbox/Git/radd/toolbox/analyze.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   godf['response']=np.where(godf.rt<tb, 1, 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-09c78d8af8d9> in <module>()
#       3 build=reload(build)
#       4 mx = build.Model(data=prodf_store.prodata, kind='xpro', dynamic='hyp')
# ----> 5 mx.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True, fit_on='bootstrap')
#
# /home/kyle/Dropbox/Git/radd/build.pyc in make_optimizer(self, ntrials, tol, maxfev, niter, disp, prob, fit_on, multiopt)
#      61             self.__check_inits__()
# ...

# %%
mx.tb

# %%
mx.optimize()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-241-42044604d262> in <module>()
# ----> 1 mx.optimize()
#
# /home/kyle/Dropbox/Git/radd/build.pyc in optimize(self, save, savepth, ntrials, tol, maxfev, niter, disp, prob, fit_on, multiopt)
#      72                   self.make_optimizer(ntrials=ntrials, tol=tol, maxfev=maxfev, niter=niter, disp=disp, prob=prob, fit_on=fit_on)
#      73
# ---> 74             self.fits, self.fitinfo, self.popt = self.opt.optimize_model(save=save, savepth=savepth)
#      75             # get residuals
#      76             self.residual = self.opt.residual
#
# /home/kyle/Dropbox/Git/radd/fit.py in optimize_model(self, save, savepth)
#      84                   self.yhat, self.fitinfo, self.popt = self.__opt_routine__()
#      85             elif self.fit_on in ['subjects', 'bootstrap']:
# ...

# %%
res.mean()
# Out:
# 0     0.9325
# 1     0.7551
# 2     0.4844
# 3     0.2373
# 4     0.0357
# 5     0.0042
# 6     0.5102
# 7     0.5341
# 8     0.5412
# 9     0.5445
# 10    0.5511
# 11    0.5351
# 12    0.5442
# 13    0.5447
# 14    0.5456
# 15    0.5530
# dtype: float64

# %%
res = pd.DataFrame(np.vstack(idx_res))

# %%
res
# Out:
#         0       1       2       3       4       5       6       7       8   \
# 0   0.9667  0.6750  0.5583  0.3083  0.0250  0.0000  0.4786  0.5065  0.5318
# 1   1.0000  0.8667  0.5750  0.4083  0.0000  0.0000  0.4859  0.5051  0.5185
# 2   1.0000  0.8750  0.6583  0.3583  0.0417  0.0000  0.5451  0.5451  0.5452
# 3   0.9333  0.8750  0.5500  0.1750  0.0750  0.0000  0.5048  0.5450  0.5451
# 4   0.9333  0.5917  0.4583  0.3333  0.0000  0.0000  0.5450  0.5452  0.5453
# 5   0.9500  0.7667  0.4167  0.0500  0.0000  0.0000  0.4919  0.5317  0.5451
# 6   1.0000  0.6833  0.4917  0.3833  0.0417  0.0000  0.5050  0.5316  0.5451
# 7   0.8333  0.6750  0.5083  0.1583  0.0083  0.0000  0.4918  0.5052  0.5317
# 8   1.0000  0.8083  0.6500  0.1500  0.0333  0.0000  0.5193  0.5451  0.5451
# 9   0.9750  0.7083  0.6500  0.2500  0.0917  0.0000  0.5318  0.5451  0.5451
# 10  0.9500  0.6167  0.3333  0.2333  0.0000  0.0167  0.5316  0.5451  0.5451
# ...

# %%
analyze.resample_data(df, data_style='pro', n=80)
# Out:
# array([ 0.8875 ,  0.6875 ,  0.5625 ,  0.275  ,  0.     ,  0.     ,
#         0.49182,  0.53186,  0.54511,  0.54519,  0.54686,  0.54502,
#         0.54509,  0.54514,  0.54521,  0.55811])

# %%
boot_y=[]
for i in range(50):
      boot_y.append(analyze.resample_data(mx.data, n=100))

# %%
from radd.toolbox import analyze
df = analyze.resample_data(mx.data)

# %%
yhat = array([0.9578, 0.9978, 0.987, 0.9376, 0.4868, 0.1274, 0.5138, 0.5428, 0.5648, 0.5878, 0.6178, 0.5108, 0.5338, 0.5508, 0.5718, 0.6008, 0.9159, 0.998, 0.9894, 0.9524, 0.5848, 0.1926, 0.5258, 0.5528, 0.5758, 0.5968, 0.6278, 0.5138, 0.5428, 0.5628, 0.5838, 0.6118])
for i in range(2):
      vis.plot_fits(mx.avg_y[i], yhat.reshape(2,16)[i])
