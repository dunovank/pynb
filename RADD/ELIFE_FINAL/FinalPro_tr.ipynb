# %% [markdown]
# #  Proactive TR

# %%
from radd import build, vis

# %%
d = 'FinalPro/tr'
if not os.path.isdir(pth+d):
      os.mkdir(pth+d)
os.chdir(pth+d)

# %%
m = build.Model(data=prodata, kind='xpro', dynamic='hyp', tb=.555, depends_on={'tr':'pGo'}, wt_prob=True)
m.optimize(tol=1.e-5, multiopt=True, maxfev=5000, ntrials=10000)
# Out:
# basinhopping step 0: f 0.0338756
# basinhopping step 1: f 0.111526 trial_f 0.111526 accepted 1  lowest_f 0.0338756
# basinhopping step 2: f 0.0975882 trial_f 0.0975882 accepted 1  lowest_f 0.0338756
# ...
# basinhopping step 3: f 0.0975882 trial_f 0.235684 accepted 0  lowest_f 0.0338756
# basinhopping step 4: f 0.287419 trial_f 0.287419 accepted 1  lowest_f 0.0338756
# basinhopping step 5: f 0.00608723 trial_f 0.00608723 accepted 1  lowest_f 0.00608723
# found new global minimum on step 5 with function value 0.00608723
# basinhopping step 6: f 0.00273629 trial_f 0.00273629 accepted 1  lowest_f 0.00273629
# found new global minimum on step 6 with function value 0.00273629
# basinhopping step 7: f 0.160285 trial_f 0.160285 accepted 1  lowest_f 0.00273629
# basinhopping step 8: f 0.258338 trial_f 0.258338 accepted 1  lowest_f 0.00273629
# ...
# basinhopping step 9: f 0.161504 trial_f 0.161504 accepted 1  lowest_f 0.00273629
# ...

# %%
vis.plot_fits(m.avg_y, m.fits, kind='pro', data=prodata)
plt.savefig('tr_profits.png')
# Out:
# /home/kyle/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
d = 'FinalPro/tr_no_dynamics'
if not os.path.isdir(pth+d):
      os.mkdir(pth+d)
os.chdir(pth+d)
m = build.Model(data=prodata, kind='pro', tb=.555, depends_on={'tr':'pGo'}, wt_prob=True)
m.optimize(tol=1.e-5, multiopt=True, maxfev=5000, ntrials=10000)
# Out:
# basinhopping step 0: f 0.000439078
# ...
# basinhopping step 1: f 0.187716 trial_f 0.187716 accepted 1  lowest_f 0.000439078
# basinhopping step 2: f 0.183611 trial_f 0.183611 accepted 1  lowest_f 0.000439078
# basinhopping step 3: f 0.0621033 trial_f 0.0621033 accepted 1  lowest_f 0.000439078
# ...
# basinhopping step 4: f 0.0824093 trial_f 0.0824093 accepted 1  lowest_f 0.000439078
# basinhopping step 5: f 0.310673 trial_f 0.310673 accepted 1  lowest_f 0.000439078
# basinhopping step 6: f 0.239468 trial_f 0.239468 accepted 1  lowest_f 0.000439078
# basinhopping step 7: f 0.100739 trial_f 0.100739 accepted 1  lowest_f 0.000439078
# basinhopping step 8: f 0.0196921 trial_f 0.0196921 accepted 1  lowest_f 0.000439078
# basinhopping step 9: f 0.00165128 trial_f 0.00165128 accepted 1  lowest_f 0.000439078
# adaptive stepsize: acceptance rate 0.900000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# basinhopping step 10: f 0.283934 trial_f 0.283934 accepted 1  lowest_f 0.000439078
# ...

# %%
vis.plot_fits(m.avg_y, m.fits,kind='pro', data=prodata)

# %%
m.residual
# Out:
# array([ 0.00953], dtype=float32)

# %%
m.fitinfo
# Out:
# {'AIC': nan,
#  'BIC': nan,
#  'CNVRG': False,
#  'a': 0.3241591266945336,
#  'chi': 9.090871e-05,
#  'nfev': 3300,
#  'rchi': -1.8181742052547634e-05,
#  'tr_0': 0.36461228199213791,
#  'tr_100': 0.27668469302300397,
#  'tr_20': 0.34395352442654509,
#  'tr_40': 0.32150306384276961,
#  'tr_60': 0.31063347462675678,
#  'tr_80': 0.28484007545292894,
#  'v': 1.3776720099182176,
#  'xb': 1.0}
