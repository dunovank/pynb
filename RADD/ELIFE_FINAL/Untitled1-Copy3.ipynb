# %%
from radd import build, models, fit, vis
from radd.toolbox import theta

# %%
m = build.Model(data=redf_store.redata, kind='xradd', dynamic='hyp', depends_on={'v':'Cond'})
m.make_optimizer(tol=1.e-5)

# %%
m.optimize()

# %%
yhat = array([0.9505, 1.0162, 1.0232, 0.9353, 0.5101, 0.1132, 0.5353, 0.5587, 0.5754, 0.5963, 0.6259, 0.5157, 0.5388, 0.5542, 0.5713, 0.5953, 0.9163, 1.0, 1.0240, 0.9486, 0.5865, 0.1763, 0.5391, 0.5647, 0.5835, 0.6023, 0.6318, 0.5213, 0.5446, 0.5596, 0.5769, 0.6022])

m

m.fits=yhat

# %%
m.fits
# Out:
# array([ 0.9765 ,  0.9988 ,  0.995  ,  0.9582 ,  0.536  ,  0.109  ,
#         0.51904,  0.54404,  0.56304,  0.58204,  0.61204,  0.51304,
#         0.53404,  0.55104,  0.57104,  0.59904,  0.9398 ,  0.9992 ,
#         0.995  ,  0.9766 ,  0.6404 ,  0.1812 ,  0.53004,  0.55504,
#         0.57604,  0.59504,  0.62604,  0.52148,  0.54404,  0.56304,
#         0.58204,  0.61104])

# %%
vis.plot_reactive_fits(m)

# %%
m.fits=simfx(p)

# %%
m.fits
# Out:
# array([ 0.9864 ,  0.9994 ,  0.9946 ,  0.9664 ,  0.523  ,  0.0954 ,
#         0.51281,  0.53781,  0.55481,  0.57581,  0.60581,  0.50681,
#         0.52781,  0.54581,  0.56481,  0.58881,  0.9764 ,  0.9996 ,
#         0.9972 ,  0.971  ,  0.5778 ,  0.1202 ,  0.51881,  0.54181,
#         0.56081,  0.58181,  0.61181,  0.51081,  0.53381,  0.54881,
#         0.56781,  0.59681])
