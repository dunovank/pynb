# %%
from radd import build, models, fit, vis
from radd.toolbox import theta

# %%
mx = build.Model(data=prodf_store.prodata, kind='xpro', dynamic='hyp')
mx.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True)

# %%
mx.optimize()
# Out:
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.

# %%
c = 0.00001531

# %%
p=m.popt
f=m.fitinfo

# %%
mx.simulate()
# Out:
# array([ 0.86255,  0.45918,  0.82953,  0.46819,  0.27911,  0.05822,
#         0.51337,  0.52537,  0.53237,  0.54037,  0.54637,  0.52537,
#         0.53437,  0.54037,  0.54637,  0.54937])

# %%
y=mx.avg_y
yh=mx.sim

# %%
np.sum(mx.)

# %%
mx.avg_wts
# Out:
# array([ 1.5    ,  1.25   ,  1.     ,  1.     ,  1.25   ,  1.5    ,
#         0.23737,  0.91449,  1.8348 ,  2.29188,  0.39819,  0.23504,
#         0.27596,  0.30927,  0.34629,  0.0374 ])

# %%
g = mx.observed.std()[:6]
#np.median(g)/g

# %%
vis.plot_fits(mx.avg_y, ys[0], kind='pro')

# %%
fit=reload(fit)

# %%
m = build.Model(data=prodf_store.prodata, kind='xpro', dynamic='hyp', depends_on={'v':'pGo', 'tr':'pGo'})
m.make_optimizer(tol=1.e-20, ntrials=10000, maxfev=5000, multiopt=True)
m.opt.make_simulator()
px = dict(deepcopy(m.inits))

# %% [markdown]
# # FINDING BASIN

# %%
m.opt.bwts
#m.opt.bwts = np.tile(np.array([1,2,2,2,2,1]), 6).reshape(6,6)
# Out:
# array([[1, 2, 2, 2, 2, 1],
#        [1, 2, 2, 2, 2, 1],
#        [1, 2, 2, 2, 2, 1],
#        [1, 2, 2, 2, 2, 1],
#        [1, 2, 2, 2, 2, 1],
#        [1, 2, 2, 2, 2, 1]])

# %%
pxx = m.opt.find_basin(px, disp=False, interval=10, nsuccess=100)

# %%
m.opt.simulator.ncond=6

# %%
pxx
# Out:
# {'a': 0.39000000000000007,
#  'tr': array([ 0.29824,  0.29245,  0.28193,  0.31717,  0.24461,  0.23347]),
#  'v': array([ 1.14431,  1.25434,  1.29044,  1.62186,  1.33032,  1.23846]),
#  'xb': 1.5}

# %%
y = m.avg_y

# %%
yx
# Out:
# {'a': 0.39,
#  'tr': array([ 0.29978,  0.29743,  0.29508,  0.29272,  0.29037,  0.28802]),
#  'v': array([ 1.07006,  1.0788 ,  1.08753,  1.09627,  1.105  ,  1.11374]),
#  'xb': 1.5}

# %%
pxx
# Out:
# {'a': array([ 0.39,  0.39,  0.39,  0.39,  0.39,  0.39]),
#  'tr': array([ 0.29824,  0.29245,  0.28193,  0.31717,  0.24461,  0.23347]),
#  'v': array([ 1.14431,  1.25434,  1.29044,  1.62186,  1.33032,  1.23846]),
#  'xb': array([ 1.5,  1.5,  1.5,  1.5,  1.5,  1.5])}

# %%
yx = m.opt.simulator.sim_fx(yx)

# %%
yh
# Out:
# array([ 0.94238,  0.77611,  0.58764,  0.37995,  0.12305,  0.16267,
#         0.48047,  0.50247,  0.51617,  0.53017,  0.54247,  0.51193,
#         0.5263 ,  0.53393,  0.54193,  0.54791])

# %%
m.opt.bwts
# Out:
# array([[ 1.5    ,  0.23737,  0.91449,  1.8348 ,  2.29188,  0.39819],
#        [ 1.25   ,  0.23737,  0.91449,  1.8348 ,  2.29188,  0.39819],
#        [ 1.     ,  0.23737,  0.91449,  1.8348 ,  2.29188,  0.39819],
#        [ 1.     ,  0.23504,  0.27596,  0.30927,  0.34629,  0.0374 ],
#        [ 1.25   ,  0.23504,  0.27596,  0.30927,  0.34629,  0.0374 ],
#        [ 1.5    ,  0.23504,  0.27596,  0.30927,  0.34629,  0.0374 ]])

# %%
x = m.__nudge_params__(m.inits)

# %%
vis.plot_fits(y, yx, kind='pro')

# %%
np.isnan(m.flat_wts)
# Out:
# array([False, False, False, False, False, False], dtype=bool)

# %%
np.median(m.observed.std()[:6])/m.observed.std()[:6]
# Out:
# 0      1.5530
# 20     0.9242
# 40     0.8522
# 60     0.8276
# 80     1.0893
# 100    1.4309
# dtype: float64

# %%
vis.plot_fits(y, yh, kind='pro')

# %%
ii=0
ys=[]
fs=[]
while not f['CNVRG'] and ii<=25:
      y,f,p = mx.opt.gradient_descent(y=mx.avg_y, wts=mx.avg_wts, is_flat=False, inits=p)
      ys.append(y)
      fs.append(f)
      ii+=1
# Out:
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# Warning: Maximum number of iterations has been exceeded.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-422-375113f7919f> in <module>()
#       3 fs=[]
#       4 while not f['CNVRG'] and ii<=25:
# ----> 5       y,f,p = mx.opt.gradient_descent(y=mx.avg_y, wts=mx.avg_wts, is_flat=False, inits=p)
#       6       ys.append(y)
#       7       fs.append(f)
#
# /home/kyle/Dropbox/Git/radd/fit.pyc in gradient_descent(self, y, wts, inits, is_flat)
#     226             # GEN PARAMS OBJ & OPTIMIZE THETA
#     227             lmParams=theta.loadParameters(inits=inits, pc_map=self.pc_map, is_flat=is_flat, kind=self.kind)
# --> 228             optmod = minimize(self.simulator.__cost_fx__, lmParams, method='nelder', options=opt_kws)
#     229
#     230             # gen dict of opt. params
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in minimize(fcn, params, method, args, kws, scale_covar, iter_cb, **fit_kws)
#     758     fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#     759                        iter_cb=iter_cb, scale_covar=scale_covar, **fit_kws)
# --> 760     return fitter.minimize(method=method)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in minimize(self, method, params, **kws)
#     690         elif user_method.startswith('lbfgsb'):
#     691             function = self.lbfgsb
# --> 692         return function(**kwargs)
#     693
#     694 def minimize(fcn, params, method='leastsq', args=None, kws=None,
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in scalar_minimize(self, method, params, **kws)
#     471             ret = _differential_evolution(self.penalty, vars, **fmin_kws)
#     472         else:
# --> 473             ret = scipy_minimize(self.penalty, vars, **fmin_kws)
#     474
#     475         for attr in dir(ret):
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     430                       callback=callback, **options)
#     431     elif meth == 'nelder-mead':
# --> 432         return _minimize_neldermead(fun, x0, args, callback, **options)
#     433     elif meth == 'powell':
#     434         return _minimize_powell(fun, x0, args, callback, **options)
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     461         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     462         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 463         fxr = func(xr)
#     464         doshrink = 0
#     465
#
# /home/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     283     def function_wrapper(*wrapper_args):
#     284         ncalls[0] += 1
# --> 285         return function(*(wrapper_args + args))
#     286
#     287     return ncalls, function_wrapper
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in penalty(self, fvars)
#     298             objective function is an array, return the array sum-of-squares
#     299         """
# --> 300         r = self.__residual(fvars)
#     301         if isinstance(r, ndarray):
#     302             r = (r*r).sum()
#
# /home/kyle/anaconda/lib/python2.7/site-packages/lmfit-0.8.3_115_gb405f5b-py2.7.egg/lmfit/minimizer.pyc in __residual(self, fvars)
#     252         self.result.nfev = self.result.nfev + 1
#     253
# --> 254         out = self.userfcn(params, *self.userargs, **self.userkws)
#     255         if callable(self.iter_cb):
#     256             self.iter_cb(params, self.result.nfev, out,
#
# /home/kyle/Dropbox/Git/radd/models.pyc in __cost_fx__(self, theta)
#     233
#     234       def simulate_radd(self, p, analyze=True):
# --> 235             """ Simulate the dependent process model (RADD)
#     236             ::Arguments::
#     237                   p (dict):
#
# /home/kyle/Dropbox/Git/radd/models.pyc in simulate_pro(self, p, analyze)
#     282             (see selfulate_radd() for I/O details)
#     283             """
# --> 284             p = self.vectorize_params(p)
#     285             Pg, Tg = self.__update_go_process__(p)
#     286             Ps, Ts = self.__update_stop_process__(p)
#
# /home/kyle/Dropbox/Git/radd/models.pyc in analyze_proactive(self, DVg, p)
#     375                   qrt = hs(self.RTQ(zpd))
#     376             # Get response and stop accuracy information
# --> 377             gacc = 1-np.mean(np.where(rt<tb, 1, 0), axis=1)
#     378             return hs([gacc, qrt])
#     379
#
# /home/kyle/Dropbox/Git/radd/models.pyc in <lambda>(trace, a)
#     154
#     155       def vectorize_params(self, p):
# --> 156             """ ensures that all parameters are converted to arrays before simulation. see
#     157             doc strings for prepare_fit() method of Model class (in build.py) for details
#     158             regarding pc_map and logic for fitting models with parameters that depend on
#
# KeyboardInterrupt:

# %%
popt={'a': array([ 0.44462,  0.44462]), 'v_pnl': 0.9689235891638055, 'z': 0.15225778581757374, 'v': array([ 1.04458,  0.96892], dtype=np.float32), 'xb': array([ 1.3909,  1.3909]), 'ssv': -0.92778056287176547, 'tr': array([ 0.30429,  0.30429]), 'v_bsl': 1.0445817952733745}

# %%
y = array([0.9412, 0.9966, 0.9865, 0.9038, 0.5087, 0.1036, 0.5146, 0.5437, 0.5634, 0.5826, 0.6104, 0.5034, 0.5318, 0.5493, 0.5677, 0.5946])

# %%
popt={'a': array([ 0.48758,  0.48758,  0.48758,  0.48758,  0.48758,  0.48758]), 'v_0': 1.3879819140690559, 'xb': array([ 1.84081,  1.84081,  1.84081,  1.84081,  1.84081,  1.84081]), 'v': array([ 1.38798,  1.55163,  1.66807,  1.75663,  1.89004,  1.91912], dtype=np.float32), 'tr': array([ 0.29224,  0.29224,  0.29224,  0.29224,  0.29224,  0.29224]), 'v_100': 1.919117679475622, 'v_60': 1.7566317451075852, 'v_80': 1.8900394160303426, 'v_20': 1.5516263043914149, 'v_40': 1.6680683637739491}
yh = mx.opt.simulator.sim_fx(popt)
yh = array([0.9531, 0.7923, 0.5834, 0.3703, 0.1158, 0.0738, 0.5062, 0.5172, 0.5262, 0.5342, 0.5432, 0.5232, 0.5342, 0.5392, 0.5432, 0.5462])

vis.plot_fits(mx.avg_y, yh, kind='pro')

# %%
yiact = array([0.9848, 1.0, 0.999, 0.931, 0.505, 0.108, 0.5077, 0.5337, 0.5537, 0.5757, 0.6057, 0.4937, 0.5197, 0.5357, 0.5497, 0.5777])
#yiact = y-((y-yiact)*m.flat_wts)

# %%
yradd = array([0.9781, 0.998, 0.9884, 0.9474, 0.4764, 0.0962, 0.5138, 0.5408, 0.5608, 0.5818, 0.6118, 0.5068, 0.5318, 0.5488, 0.5678, 0.5948])
#yradd= y-((y-yradd)*m.flat_wts)

# %%
yirace = array([0.9741, 0.998, 0.974, 0.8478, 0.5336, 0.196, 0.5169, 0.5399, 0.5589, 0.5809, 0.6129, 0.5069, 0.5259, 0.5439, 0.5589, 0.5859])
#yirace = y-((y-yirace)*m.flat_wts)

# %%
vis.plot_fits(bsly, yh[:len(bsly)], kind='radd')

# %%
sns.palplot(sns.color_palette(n_colors=10))

# %%
c
# Out:
# ['#444444', '#d9544d', '#3b5b92', '#39ad48']

# %%
vis.scurves(sc, kind='radd', linestyles=['-', '-', '-','-'], colors=sns.color_palette(n_colors=4), labels=['y', 'radd',  'irace', 'iact'])
# Out:
# [0.35078007800780076,
#  0.35078007800780076,
#  0.34836483648364835,
#  0.34836483648364835,
#  0.35424542454245428,
#  0.35424542454245428,
#  0.35039503950395046,
#  0.35039503950395046]

# %%
xd = sns.xkcd_rgb
c = ['#444444']+[xd[cc] for cc in ['pale red', 'denim blue', 'medium green']]

# %%
n=10
xcols = sns.xkcd_rgb.values()
clist = [xcols[i] for i in np.random.randint(low=0, high=len(xcols), size=n)]
sns.palplot(clist)

# %%
import brewer2mpl

c = brewer2mpl.get_map('Set1', 'qualitative', 4).mpl_colors

# %%
c = ['#333333', greens[3], reds[0], blues[0]]

# %%
from radd.toolbox import colors
cmaps = colors.get_cmaps()

# %%
cmaps['qual']
c=['k', "#2ecc71", "#e74c3c", '#3778bf', "#2980b9", "#009B76", "#8E44AD",  "#e67e22", '#36bcbc', '#32adad', '#3679bc', "#16a085", "#009B76", '#3778bf']

# %%
yhats = [yradd, yirace, yiact]
sns.set(style='white')
#c=sns.color_palette('Dark2', n_colors=4)
scfits = [hat[1:6] for hat in yhats]
sc=[y[1:6]]
sc.extend(scfits)
labels=['y', 'radd',  'irace', 'iact']
vis.scurves(sc, kind='radd', colors=c, labels=labels, markers=True)
plt.savefig('radd_irace_interact_SC.png', dpi=300)

# %%
from radd.toolbox import analyze

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
xd[colors[0]]
# Out:
# '#3778bf'

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(13, 5), sharey=True)
sns.set(font='Helvetica', style='white', rc={'text.color': 'black', 'axes.labelcolor': 'black', 'figure.facecolor': 'white'})
sns.set_context('notebook', font_scale=1.6)
labels=['Baseline', 'Dep',  'Ind', 'Int']
xlim=(.48, .65)
#mx=['+', 'o', '*', '^']

gqfits = [hat[6:11] for hat in yhats]
eqfits = [hat[11:] for hat in yhats]

gq=[y[6:11]]
eq=[y[11:]]
gq.extend(gqfits)
eq.extend(eqfits)

cor_kde = [analyze.kde_fit_quantiles(q, bw=.0001) for q in gq]
err_kde = [analyze.kde_fit_quantiles(q, bw=.0001) for q in eq]
ls = ['-']+['--']*3
lw = [3.5] + [3.5]*3
for i, qq in enumerate(cor_kde):
      sns.kdeplot(qq, cumulative=True, label=labels[i], linestyle=ls[i], color=c[i], ax=ax1, linewidth=lw[i], alpha=1)
for i, qq in enumerate(err_kde):
      sns.kdeplot(qq, cumulative=True, linestyle=ls[i], color=c[i], ax=ax2, linewidth=lw[i], alpha=1)
ax1.set_ylabel('P(RT<t)')
xx = ax1.get_xticks()[::2]
for ax in [ax1, ax2]:
      ax.set_xlim(xlim[0], xlim[1])
      ax.set_xlabel('RT (s)')
      ax.set_ylim(-.05, 1.05)
      ax.set_xticks(xx)
      ax.set_xticklabels(xx)
plt.tight_layout()
sns.despine()
#if save:
vis.scurves(sc, kind='radd', colors=c, labels=labels, ax=ax3, linestyles=ls, markers=True)
#      plt.savefig('rtquantiles_comparison', format='svg', dpi=600, rasterized=True)
plt.savefig('/home/kyle/Dropbox/radd_irace_interact_alldash.svg', rasterized=True, format='svg')
plt.savefig('/home/kyle/Dropbox/radd_irace_interact_alldash.png', format='png', dpi=600)

# %%
# Fit RT quantiles to KDE function in radd.analyze
linestyles = ['-', '-']*3
cor_kde = [analyze.kde_fit_quantiles(q, bw=.01) for q in gq]
err_kde = [analyze.kde_fit_quantiles(q, bw=.01) for q in eq]

for i, q in enumerate(kdefits):
      sns.kdeplot(kdefits[i], cumulative=True, label=labels[i], linestyle='-', color=c[i], ax=ax1, linewidth=3.5, alpha=.7)

# %%
from radd import neuro
b=neuro.BOLD(m)
b.kind='pro'

# %%
b.simulate_bold(ntrials=10)
gt = b.go_traces
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-301-5d1a8a07c82e> in <module>()
# ----> 1 b.simulate_bold(ntrials=10)
#       2 gt = b.go_traces
#
# /home/kyle/Dropbox/Git/radd/neuro.pyc in simulate_bold(self, hemodynamic, ntrials, decay, get_dfs, shape, savestr, save)
#     182             if 'pro' in self.kind:
#     183                   # simulate decision traces
# --> 184                   self.generate_pro_traces(ntrials=ntrials)
#     185             else:
#     186                   # simulate decision traces
#
# /home/kyle/Dropbox/Git/radd/neuro.pyc in generate_pro_traces(self, ntrials)
#     153             self.ntot=ntrials#*self.ncond
#     154             #simulate decision traces
# --> 155             self.dvg = self.sim_fx(self.p, analyze=False)
#     156
#     157
#
# /home/kyle/Dropbox/Git/radd/models.pyc in simulate_radd(self, p, analyze)
#     257             # INITIALIZE DVs FROM DVg(t=SSD)
#     258             init_ss = array([[DVg[i,:nss,ix] for ix in np.where(Ts<Tg[i],Tg[i]-Ts,0)] for i in range(nc)])
# --> 259             DVs = init_ss[:,:,:,None]+np.cumsum(np.where(rs((nss, Ts.max()))<Ps,dx,-dx), axis=1)
#     260             if analyze:
#     261                   return self.analyze_reactive(DVg, DVs, p)
#
# ValueError: operands could not be broadcast together with shapes (2,5,10,1) (5000,4537)

# %%
sns.set(style="darkgrid", palette="Set2")

# Create a noisy periodic dataset
sines = []
rs = np.random.RandomState(8)
for _ in range(15):
    x = np.linspace(0, 30 / 2, 30)
    y = np.sin(x) + rs.normal(0, 1.5) + rs.normal(0, .3, 30)
    sines.append(y)

# Plot the average over replicates with bootstrap resamples
sns.tsplot(sines, err_style="boot_traces", n_boot=500)

# %%
gq=y[6:11]; eq=y[11:]
gacc=y[0]; sc=y[1:6]

scfits = [hat[1:6] for hat in yhats]
gqfits = [hat[6:11] for hat in yhats]
eqfits = [hat[11:] for hat in yhats]

sc=[y[1:6]]
sc.extend(scfits)


for yhat in hats:
      gqfits.append(fit_gq=yhat[6:11]); fit_eq=yhat[11:]
      fit_gacc=yhat[0]; 
      scfits.append(fit_sacc=yhat[1:6])
      quant_list = [gq, fit_gq, fit_eq]
