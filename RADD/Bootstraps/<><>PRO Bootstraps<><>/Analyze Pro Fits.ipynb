# %%
cd FinalPro/
# Out:
# /Users/kyle/Dropbox/FinalPro

# %%
a = pd.read_csv('a/xpro_a_bootinfo.csv')
tr = pd.read_csv('tr/xpro_tr_bootinfo.csv')
v = pd.read_csv('v/xpro_v_bootinfo.csv')

# %%
from radd.analyze import assess_fit

# %%
x = tr[tr.AIC==tr.AIC.min()].T

# %%
x.to_csv("/Users/kyle/Dropbox/tr_pro_fitinfo.csv")

# %%
tr[tr.cnvrg]#tail()#loc[:, 'a_0':'a_100']
# Out:
#    cnvrg      logp     chi    rchi       AIC       BIC       a       v  \
# 34  True -122.7490  0.0047  0.0005 -110.7490 -118.1846  0.0672  0.9598
# 39  True -124.2490  0.0042  0.0004 -112.2490 -119.6847  0.0672  0.9598
# 49  True -119.4324  0.0057  0.0006 -107.4324 -114.8680  0.0672  0.9598
# 59  True -125.3646  0.0040  0.0004 -113.3646 -120.8003  0.0672  0.9598
# 64  True -123.3097  0.0045  0.0004 -111.3097 -118.7453  0.0672  0.9598
# 79  True -122.5545  0.0047  0.0005 -110.5545 -117.9901  0.0672  0.9598
# 89  True -123.7332  0.0044  0.0004 -111.7332 -119.1688  0.0672  0.9598
# 99  True -120.0957  0.0055  0.0005 -108.0957 -115.5313  0.0672  0.9598
#
#       tr_0   tr_20   tr_40   tr_60   tr_80  tr_100      xb
# 34  0.5171  0.5059  0.4923  0.4785  0.4538  0.4466  1.4676
# 39  0.5150  0.5054  0.4903  0.4783  0.4516  0.4462  1.4676
# 49  0.5179  0.5074  0.4913  0.4792  0.4577  0.4463  1.4676
# 59  0.5177  0.5048  0.4917  0.4799  0.4533  0.4486  1.4676
# ...

# %%
v.AIC.min()
# Out:
# -126.9164827

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9825, 0.8343, 0.5654, 0.3091, 0.1554, 0.1080, 0.5111, 0.5241, 0.5311, 0.5411, 0.5481, 0.5249, 0.5351, 0.5421, 0.5481, 0.5531])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
yhat = array([0.9555, 0.8325, 0.5204, 0.3583, 0.1380, 0.1038, 0.4687, 0.4907, 0.5087, 0.5237, 0.5417, 0.5017, 0.5237, 0.5357, 0.5457, 0.5527])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])
wts = array([ 1.44875,  0.92543,  0.84907,  0.82282,  1.08764,  1.49848,
        0.32548,  1.22685,  5.27358,  3.70829,  0.90674,  0.09328,
        0.52865,  1.22075,  1.06581,  0.28346])

# %%
wts = array([1.2079, 5.2949, 2.4038, 0.8531, 0.3861, 0.8083, 0.6227, 1.0511, 1.2813, 1.1725, 0.8949, 0.2348, 0.3385, 0.3590, 0.3292, 0.2911])
yhat = array([0.9898, 1.0, 0.998, 0.947, 0.478, 0.107, 0.5055, 0.5295, 0.5485, 0.5685, 0.5995, 0.4925, 0.5185, 0.5315, 0.5446, 0.5745])
y = array([0.9420, 0.9942, 0.9827, 0.8967, 0.5049, 0.1032, 0.5126, 0.5425, 0.5629, 0.5821, 0.6103, 0.4979, 0.5291, 0.5481, 0.5675, 0.5942])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9327, 0.7971, 0.5174, 0.3787, 0.1326, 0.0942, 0.4617, 0.4887, 0.5059, 0.5249, 0.5427, 0.5045, 0.5235, 0.5343, 0.5435, 0.5505])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
cost = lambda y2, y1, w: np.sum((y1-y2)**2)

# %%
get_finfo = lambda y, yhat, wts, nvary: {'chi':cost(y, yhat, wts), 'ndata':16, 'nvary':nvary}

# %%
#tr
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9327, 0.7971, 0.5174, 0.3787, 0.1326, 0.0942, 0.4617, 0.4887, 0.5059, 0.5249, 0.5427, 0.5045, 0.5235, 0.5343, 0.5435, 0.5505])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9609, 0.7839, 0.5312, 0.3475, 0.1452, 0.0696, 0.5111, 0.5221, 0.5311, 0.5391, 0.5501, 0.5241, 0.5351, 0.5421, 0.5481, 0.5521])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9555, 0.8325, 0.5204, 0.3583, 0.1380, 0.1038, 0.4687, 0.4907, 0.5087, 0.5237, 0.5417, 0.5017, 0.5237, 0.5357, 0.5457, 0.5527])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9543, 0.8265, 0.5678, 0.3313, 0.1278, 0.1020, 0.5004, 0.5128, 0.5244, 0.5346, 0.5468, 0.5314, 0.5394, 0.5434, 0.5489, 0.5531])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9609, 0.7839, 0.5312, 0.3475, 0.1452, 0.0696, 0.5111, 0.5221, 0.5311, 0.5391, 0.5501, 0.5241, 0.5351, 0.5421, 0.5481, 0.5521])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
finfo = get_finfo(y,yhat,wts,6)
#finfo['nvary']=12

# %%
#a
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9555, 0.8325, 0.5204, 0.3583, 0.1380, 0.1038, 0.4687, 0.4907, 0.5087, 0.5237, 0.5417, 0.5017, 0.5237, 0.5357, 0.5457, 0.5527])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
#v
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9609, 0.7839, 0.5312, 0.3475, 0.1452, 0.0696, 0.5111, 0.5221, 0.5311, 0.5391, 0.5501, 0.5241, 0.5351, 0.5421, 0.5481, 0.5521])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
#vtr
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9543, 0.8265, 0.5678, 0.3313, 0.1278, 0.1020, 0.5004, 0.5128, 0.5244, 0.5346, 0.5468, 0.5314, 0.5394, 0.5434, 0.5489, 0.5531])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
assess_fit(finfo)
# Out:
# chi        0.0022
# ndata     16.0000
# nvary      6.0000
# df        10.0000
# rchi       0.0002
# logp    -134.6522
# AIC     -122.6522
# BIC     -130.0879
# dtype: float64

# %%
#tr
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9327, 0.7971, 0.5174, 0.3787, 0.1326, 0.0942, 0.4617, 0.4887, 0.5059, 0.5249, 0.5427, 0.5045, 0.5235, 0.5343, 0.5435, 0.5505])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9441, 0.8139, 0.5450, 0.3205, 0.1164, 0.0828, 0.5180, 0.5290, 0.5350, 0.5410, 0.5490, 0.5300, 0.5390, 0.5450, 0.5490, 0.5530])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
wts = array([1.4487, 0.9254, 0.8490, 0.8228, 1.0876, 1.4984, 0.3254, 1.2268, 5.2735, 3.7082, 0.9067, 0.0932, 0.5286, 1.2207, 1.0658, 0.2834])
yhat = array([0.9543, 0.8265, 0.5678, 0.3313, 0.1278, 0.1020, 0.5004, 0.5128, 0.5244, 0.5346, 0.5468, 0.5314, 0.5394, 0.5434, 0.5489, 0.5531])
y = array([0.9399, 0.7903, 0.5477, 0.3399, 0.1180, 0.0813, 0.5034, 0.5315, 0.5409, 0.5442, 0.5452, 0.5337, 0.5439, 0.5446, 0.5451, 0.5453])

# %%
def assess_fit(finfo):
      """ calculate fit statistics
      """
      finfo = pd.Series(finfo)
      chisqr = finfo.chi
      finfo.ndata=16
      finfo['df'] = 16 - 6
      finfo['rchi'] = chisqr / finfo.df

      finfo['logp'] = finfo.ndata * np.log(finfo.rchi)
      finfo['AIC'] = finfo.logp + 2 * finfo.nvary
      finfo['BIC'] = finfo.logp + np.log(finfo.ndata * finfo.nvary)

      return finfo

# %%
cost(y, yhat, wts)
# Out:
# 0.0075834200000000126

# %%
a.AIC.min()
# Out:
# -120.033154594

# %%
tr.AIC.min()
# Out:
# -113.364638931

# %%
v.AIC.min()
# Out:
# -126.9164827

# %%
x = a[a.AIC==a.AIC.min()].T

# %%
x.to_csv("a/amin.csv")

# %%
tr.AIC.min()
# Out:
# -113.364638931

# %%
a.AIC.min()
# Out:
# -120.033154594

# %%
a[a.cnvrg==True].AIC.mean()
# Out:
# -114.9974787631579

# %%
tr.mean()
# Out:
# cnvrg      0.0800
# logp     -66.1087
# chi        0.6279
# rchi       0.0628
# AIC      -54.1087
# BIC      -61.5443
# a          0.3926
# v          1.3514
# tr_0       0.3181
# tr_20      0.3065
# tr_40      0.2986
# tr_60      0.2919
# tr_80      0.2817
# tr_100     0.2785
# xb         1.0406
# dtype: float64

# %%
tr[tr.cnvrg==True].AIC.mean()
# Out:
# -110.68600001125002

# %%
a.AIC.mean()
# Out:
# -69.76100283297842

# %%
sns.set(font_scale=1.3, context='notebook')
muv=v.mean().AIC
mutr=tr.mean().AIC
mua=a.mean().AIC


sns.distplot(tr.AIC, label=' '.join(['Onset', str(mutr)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)

sns.distplot(v.AIC, label=' '.join(['Drift', str(muv)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)

sns.distplot(a.AIC, label=' '.join(['Boundary', str(mua)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)


plt.legend()
plt.savefig('proAIC.png', dpi=300)
# Out:
# <img src='...

# %%
sns.set(font_scale=1.3, context='notebook')
muv=v[v.cnvrg==True].mean().AIC
mutr=tr[tr.cnvrg==True].mean().AIC
mua=a[a.cnvrg==True].mean().AIC


sns.distplot(tr[tr.cnvrg==True].AIC, label=' '.join(['Onset', str(mutr)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)

sns.distplot(v[v.cnvrg==True].AIC, label=' '.join(['Drift', str(muv)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)

sns.distplot(a[a.cnvrg==True].AIC, label=' '.join(['Boundary', str(mua)[:7]]), kde_kws={'shade':True}, hist=False, rug=True)


plt.legend()
plt.savefig('proAIC_cnvrg.png', dpi=300)
# Out:
# <img src='...
