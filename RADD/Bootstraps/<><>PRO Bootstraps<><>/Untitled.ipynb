# %%
fpopt = {'a': array([ 0.48986]),
 'tr': array([ 0.29207]),
 'v': array([ 1.72645]),
 'xb': array([ 1.51129])}

# %%
from radd import build, vis

# %%
m = build.Model(kind='xpro', data=pro, depends_on={'v':'pGo', 'tr':'pGo'}, inits=fpopt)

# %%
m.opt.hop_around(m.flat_popt, is_flat=True, ninits=20, niter=30)
# Out:
# ...
# basinhopping step 0: f 0.000197438
# basinhopping step 1: f 0.0181583 trial_f 0.0181583 accepted 1  lowest_f 0.000197438
# basinhopping step 2: f 0.266274 trial_f 0.266274 accepted 1  lowest_f 0.000197438
# basinhopping step 3: f 0.311668 trial_f 0.311668 accepted 1  lowest_f 0.000197438
# basinhopping step 4: f 0.208523 trial_f 0.208523 accepted 1  lowest_f 0.000197438
# basinhopping step 5: f 0.0544583 trial_f 0.0544583 accepted 1  lowest_f 0.000197438
# basinhopping step 6: f 0.000115769 trial_f 0.000115769 accepted 1  lowest_f 0.000115769
# found new global minimum on step 6 with function value 0.000115769
# basinhopping step 7: f 0.000115769 trial_f 0.213234 accepted 0  lowest_f 0.000115769
# basinhopping step 8: f 0.000115769 trial_f 0.240767 accepted 0  lowest_f 0.000115769
# ...
# basinhopping step 9: f 0.144003 trial_f 0.144003 accepted 1  lowest_f 0.000115769
# adaptive stepsize: acceptance rate 0.700000 target 0.500000 new stepsize 0.0555556 old stepsize 0.05
# ...

# %%
m.opt.basin_decision
# Out:
# 'using default inits: fmin=0.000102898'

# %%
m.opt.basinp
# Out:
# [{'a': 0.42023950654970083,
#   'tr': 0.32590649261298082,
#   'v': 1.6953022216985982,
#   'xb': 1.6618184973238113},
#  {'a': 0.66146895365786529,
#   'tr': 0.34429763560515947,
#   'v': 1.606038544741883,
#   'xb': 4.229015600863482},
#  {'a': 0.3871459639895819,
#   'tr': 0.3370509095833355,
#   'v': 1.3729878985358204,
#   'xb': 4.6438279905223325},
#  {'a': 0.15818894824787577,
#   'tr': 0.46220307297118257,
#   'v': 1.5688022005545732,
#   'xb': 4.0112469561277475},
#  {'a': 0.33600398693023503,
#   'tr': 0.32233556889733928,
#   'v': 0.87124070468192572,
#   'xb': 4.474033739606762},
#  {'a': 0.35076711304636204,
#   'tr': 0.3065276244598672,
#   'v': 0.94417031378469329,
#   'xb': 4.0217869915146665},
#  {'a': 0.31551926779611211,
#   'tr': 0.39956186911327229,
#   'v': 1.8138393151321925,
#   'xb': 3.4301511352091727},
#  {'a': 0.52995123439806124,
#   'tr': 0.27655272112052559,
#   'v': 0.94579940164261078,
#   'xb': 3.9939456476590021},
#  {'a': 0.28156246345972147,
# ...
