# %%
from radd import pipeline
depends_keys = ['tr', 'a', 'xb', ['xb','tr'], ['xb', 'a'], ['xb', 'v']]
condition = 'pGo'
kinds = ['xpro', 'pro']
dynamics = ['hyp','exp']
data=prodf_store.prodata
deplist = pipeline.make_depends_on_list(depends_keys, condition)

# %%
mlist = pipeline.run_pipeline(data=data, kinds=kinds, depends_keys=depends_keys, dynamics=dynamics, condition=condition, ntrials=10000, tol=1.e-20, maxfev=5000)
# Out:
# ['xpro', 'pro']
# ...

# %%
m = mlist[0]

# %%
m = build.Model(data=data, kind='xpro', dynamic='exp', depends_on = {'v':'pGo'})
# Out:
#       Model is prepared to fit xpro model (w/ exp dynamic bias) to average data,
#       allowing Drift-Rate to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       Check your zoomfile before optimizing. It should be in your computer

# %%
bias = m.__get_default_inits__(get_bias_vectors=True)
for k in bias.keys():
      diff = bias[k] - np.mean(bias[k])
      m.inits[k] = m.inits[k] + diff
