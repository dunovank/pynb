# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %% [markdown]
# ## Prepare Data/Params

# %% [markdown]
# ##Proactive

# %%
dirpath = '/home/kyle/Dropbox/ELife/ProVTr_Avg/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = prodf_store['prodata']
inits = dict(deepcopy(vtheta))
inits['v'] = np.mean(vopt.values())

# %%
m = build.Model(data=data, inits=inits, kind='proactive', fit_on='average', depends_on={'v': 'pGo', 'tr':'pGo'}, weight_presp=0)
# Out:
#       Model is prepared to fit on average proactive data, allowing
#       Onset Time and Drift-Rate to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       It'll probably work this time

# %%
m.optimize()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.002907
#          Iterations: 121
#          Function evaluations: 317
# ...

# %% [markdown]
# ##visualize fits

# %%
yhat = m.simulate()
vis.plot_fits(m.avg_y, m.fits, plot_acc=True, kind='proactive', save=False) #savestr=m.labels[i])
