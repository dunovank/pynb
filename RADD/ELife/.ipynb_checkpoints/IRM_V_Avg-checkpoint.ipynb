# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %% [markdown]
# ## Prepare Data/Params

# %%
data = redf_store['redata']
binits = { k: v for k, v in redf_store['rebsl_boot_popt'].items() }
binits['ssv'] = -abs(binits['ssv'])
pinits = { k: v for k, v in redf_store['repnl_boot_popt'].items() }

avg_inits = { k: np.mean([binits[k], pinits[k]]) for k in binits.keys() }
if 'ssd' in avg_inits.keys(): del avg_inits['ssd']

# %% [markdown]
# ##Reactive

# %%
dirpath = '/home/kyle/Dropbox/ELife/ReV_Avg_New/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = redf_store['redata']
inits = dict(deepcopy(avg_inits))

# %%
m = build.Model(data=data, inits=inits, kind='reactive', fit_on='average', depends_on={'v': 'Cond', 'tr':'Cond', 'a':'Cond'}, prepare=1, style='RADD')
# Out:
#       Model is prepared to fit on average reactive data, allowing
#       Boundary Height and Onset Time and Drift-Rate to vary across levels of Cond (bsl, pnl)
#
#       See it's not that Simplex, hey that's an oxymoron...

# %%
m.optimize(ntrials=20000, ftol=1.e-3, xtol=1.e-3, maxfev=5000)
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.

# %%
yhat = m.simulate().reshape(2,16)

# %%
yhat = m.fits.reshape(2,16)
for i in range(m.ncond):
      vis.plot_fits(m.avg_y[i], yhat[i], plot_acc=True, save=True)
