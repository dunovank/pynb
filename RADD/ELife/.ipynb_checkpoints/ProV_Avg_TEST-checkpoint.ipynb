# %%
#!/usr/local/bin/env python
from __future__ import division
import time
from copy import deepcopy
import numpy as np
from numpy.random import random_sample as rs
from scipy.stats.mstats import mquantiles as mq
from radd import build, fit, vis

# %%
dirpath = '/home/kyle/Dropbox/ELife/ProV_TEST/'
if not os.path.isdir(dirpath):
      os.mkdir(dirpath)
os.chdir(dirpath)

data = prodf_store['prodata']
inits = dict(deepcopy(vtheta))
inits['v'] = np.mean(vopt.values())
#inits['tr'] = np.mean(topt.values())

# %% [markdown]
# ##Proactive

# %%
m = build.Model(data=data, inits=inits, kind='pro', fit_on='average', depends_on={'v': 'pGo'}, weight_presp=0, tb=.560)
# Out:
#       Model is prepared to fit on average pro data, allowing
#       Drift-Rate to vary across levels of pGo (0, 20, 40, 60, 80, 100)
#
#       I wish you a steep gradient, and a happy Nature paper

# %%
m.wts=np.ones_like(m.avg_y)

# %%
#m.optimize(ntrials=20000, ftol=1.e-4, xtol=1.e-4, maxfev=10000, tb=.550)
m.optimize(ntrials=20000, ftol=1.e-20, xtol=1.e-20, maxfev=10000)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.008109
#          Iterations: 171
#          Function evaluations: 438
# Optimization terminated successfully.
#          Current function value: 0.107105
#          Iterations: 697
#          Function evaluations: 1876

# %% [markdown]
# ##visualize fits

# %%
yhat = m.simulate()
vis.plot_fits(m.avg_y, m.fits, plot_acc=True, kind='proactive')#, save=True, savestr='simulated')
