# %%
import hddm

# %%
data=pd.read_csv("/home/kyle/Dropbox/CoAx/SS/DataFiles/Re_Data.csv", index_col=0)
cgo=data.query("choice=='go' & acc==1")

# %%
flat_cgo.head()
# Out:
#    idx  GoTrial  StopSignal Cond trial_type choice  response  acc       rt  \
# 0   28        1        1000  bsl         go     go         1    1  0.59853
# 1   28        1        1000  bsl         go     go         1    1  0.52017
# 2   28        1        1000  bsl         go     go         1    1  0.54513
# 3   28        1        1000  bsl         go     go         1    1  0.57159
# 4   28        1        1000  bsl         go     go         1    1  0.50522
#
#     ssd  subj_idx
# 0  1000      1000
# 1  1000      1000
# 2  1000      1000
# 3  1000      1000
# 4  1000      1000

# %%
flat_cgo = cgo.copy()
flat_cgo['subj_idx']=[1000]*len(flat_cgo)#flat_cgo['idx']#
flat_cgo_filt=flat_cgo.query('idx != [39,66,69]')
                             
mflat=hddm.HDDM(flat_cgo_filt, informative=True, bias=True, include= ['a', 't', 'v', 'z'])
mflat.sample(60000, burn=20000, thin=3)
mflat.print_stats(pth+"reflat_nodep_informed_params.txt")
# Out:
#  [                  0%                  ] 6 of 60000 complete in 0.6 sec
#  [                  0%                  ] 12 of 60000 complete in 1.1 sec
#  [                  0%                  ] 18 of 60000 complete in 1.6 sec
#  [                  0%                  ] 24 of 60000 complete in 2.2 sec
#  [                  0%                  ] 29 of 60000 complete in 2.7 sec
#  [                  0%                  ] 35 of 60000 complete in 3.2 sec
#  [                  0%                  ] 40 of 60000 complete in 3.8 sec
#  [                  0%                  ] 46 of 60000 complete in 4.3 sec
#  [                  0%                  ] 51 of 60000 complete in 4.9 sec
#  [                  0%                  ] 57 of 60000 complete in 5.5 sec
#  [                  0%                  ] 62 of 60000 complete in 6.0 sec
#  [                  0%                  ] 67 of 60000 complete in 6.6 sec
#  [                  0%                  ] 73 of 60000 complete in 7.2 sec
# ...

# %%
#statsdf=mflat.gen_stats()
#statsdf['idx']=[idx]*len(statsdf)
#mflat.plot_posteriors(save=True)

mflat.print_stats(pth+"reflat_nodep_params.txt")
