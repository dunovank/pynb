# %%
os.chdir("/home/kyle/Dropbox/CoAx/SS/ParamFiles/")
df=pd.read_csv("ReBSL_AllSxParams.csv", index_col=0)

# %%
from scipy.stats import pearsonr, spearmanr
spearmanr(df.ssv, df.v)
# Out:
# (-0.10375588298624995, 0.43829516343676855)

# %%
sns.jointplot("v", "ssv", df, kind="reg", color="seagreen");
