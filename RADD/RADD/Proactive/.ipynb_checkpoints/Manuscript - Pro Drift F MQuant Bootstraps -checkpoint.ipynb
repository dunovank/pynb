# %%
from radd import final, vis, fitpro, utils, npsim, proboot

# %%
pro=final.all_data('pro')
pstop, mquant = utils.pstop_mquant(pro, filt_rts=True)

# %%
os.chdir("/Users/kyle/Dropbox/SS_Backups/SS/Proactive/Boot/DriftF_MQuant/")
opt=pd.read_csv("flat_opt_theta.csv", header=None, names=['mean'], index_col=0)
opt.drop(['v(Hi)', 'v(Lo)', 'v'], inplace=True)
inits=opt.to_dict()['mean']

# %%
proboot.Proboot(pro, inits, rtfunc='mquant', depends_on={'v': 'pGo'}, filt_rts=True, niter=150, disp=False)
# Out:
# data pstop:  [ 0.92848361  0.75532787  0.47807377  0.24036885  0.0352459   0.00488927]
# data rt:  [array([ 4.53525   ,  5.05157808,  5.318502  ,  5.45045804,  5.45079488]), array([ 5.04998852,  5.45005444,  5.450415  ,  5.45066404,  5.45089208]), array([ 5.0503831 ,  5.45006202,  5.450439  ,  5.45071414,  5.450911  ]), array([ 5.04897104,  5.31843476,  5.4503145 ,  5.450654  ,  5.45088756]), array([ 4.78511682,  5.05232094,  5.317021  ,  5.450253  ,  5.450812  ]), array([ 4.78103576,  5.05058784,  5.185191  ,  5.44070998,  5.45073838])]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-aa0af63f636b> in <module>()
# ----> 1 proboot.Proboot(pro, inits, rtfunc='mquant', depends_on={'v': 'pGo'}, filt_rts=True, niter=150, disp=False)
#
# /Users/kyle/Dropbox/Git/radd/proboot.py in Proboot(data, inits, niter, depends_on, save_path, simfx, method, ntrials, maxfun, ftol, xtol, disp, filt_rts, rtfunc, **kwargs)
#      53 		fits_i, rts_i, ps_i = fitpro.run_proactive_model(pstop, rt, inits, filt_rts=filt_rts,
#      54                                         ntrials=ntrials, depends_on=depends_on, nx=i, simfx=simfx,
# ---> 55 					maxfun=maxfun, ftol=ftol, xtol=xtol, pgolist=pgolist, disp=disp)
#      56
#      57                 ps_pred.loc[i,:]=np.array(ps_i)
#
# /Users/kyle/Dropbox/Git/radd/fitpro.py in run_proactive_model(pstop, rt, inits, depends_on, ntrials, nx, simfx, maxfun, ftol, xtol, rtfunc, disp, filt_rts, **kwargs)
#      99
#     100                 popt = Minimizer(sspro_minfunc, p, fcn_args=(y, ntrials), fcn_kws={'simfx':simfx,'rtfunc':rtfunc, 'filt_rts':filt_rts}, method='Nelder-Mead')
# --> 101                 popt.fmin(maxfun=maxfun, ftol=ftol, xtol=xtol, full_output=True, disp=disp)
#     102
#     103                 if rtfunc=="quants":
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/numpy/lib/utils.pyc in newfunc(*args, **kwds)
#      94             """`arrayrange` is deprecated, use `arange` instead!"""
#      95             warnings.warn(depdoc, DeprecationWarning)
# ---> 96             return func(*args, **kwds)
#      97
#      98         newfunc = _set_function_name(newfunc, old_name)
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/lmfit/minimizer.pyc in fmin(self, **kws)
#     452         fmin_kws.update(kws)
#     453
# --> 454         ret = scipy_fmin(self.penalty, self.vars, **fmin_kws)
#     455         xout, fout, niter, funccalls, warnflag, allvecs = ret
#     456         self.nfev = funccalls
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback)
#     372             'return_all': retall}
#     373
# --> 374     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     375     if full_output:
#     376         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     459         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     460         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 461         fxr = func(xr)
#     462         doshrink = 0
#     463
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     280     def function_wrapper(*wrapper_args):
#     281         ncalls[0] += 1
# --> 282         return function(*(wrapper_args + args))
#     283
#     284     return ncalls, function_wrapper
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/lmfit/minimizer.pyc in penalty(self, params)
#     338             objective function is an array, return the array sum-of-squares
#     339         """
# --> 340         r = self.__residual(params)
#     341         if isinstance(r, ndarray):
#     342             r = (r*r).sum()
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/lmfit/minimizer.pyc in __residual(self, fvars)
#     286
#     287         self.update_constraints()
# --> 288         out = self.userfcn(self.params, *self.userargs, **self.userkws)
#     289         if callable(self.iter_cb):
#     290             self.iter_cb(self.params, self.nfev, out,
#
# /Users/kyle/Dropbox/Git/radd/fitpro.py in sspro_minfunc(p, ydata, ntrials, theta, filt_rts, rtfunc, simfx, model, tb)
#     131                 psim, rtsim = simulate_lc(theta, ntrials=ntrials, filt_rts=filt_rts, timebound=tb)
#     132         elif simfx=='vector':
# --> 133                 psim, rtsim = simulate_np(theta, ntrials=ntrials, filt_rts=filt_rts, rtfunc=rtfunc, timebound=tb)
#     134         else:
#     135                 print "simfx method not understood\n\n\tpass 'standard', 'lc', or 'vector'"
#
# /Users/kyle/Dropbox/Git/radd/fitpro.py in simulate_np(theta, ntrials, timebound, filt_rts, rtfunc, intervar, **kwargs)
#     170         dvg, dvs = npsim.radd(theta, ntrials=ntrials, no_ss=True)
#     171
# --> 172         responses, rt = npsim.analyze_proactive_trials(dvg, dvs, theta, filt_rts=filt_rts, timebound=timebound, return_all=True)
#     173
#     174         if rtfunc=='quants':
#
# /Users/kyle/Dropbox/Git/radd/npsim.py in analyze_proactive_trials(DVg, DVs, theta, filt_rts, timebound, rtfunc, return_all)
#      89
#      90         #get vector of response times
# ---> 91         go_traces = [trace for trace in DVg if np.any(trace>=a)]
#      92         rts = np.array([tr + np.argmax(trace>=a)*.0005 for trace in go_traces])
#      93
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in any(a, axis, out, keepdims)
#    1846
#    1847     try:
# -> 1848         return arr.any(axis=axis, out=out, keepdims=keepdims)
#    1849     except TypeError:
#    1850         return arr.any(axis=axis, out=out)
#
# /Users/kyle/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _any(a, axis, dtype, out, keepdims)
#      35     return umr_prod(a, axis, dtype, out, keepdims)
#      36
# ---> 37 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
#      38     return umr_any(a, axis, dtype, out, keepdims)
#      39
#
# KeyboardInterrupt:
