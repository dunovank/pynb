# %%
from __future__ import division
from radd import ss, ssex, ssex_onsets, psy
import pandas as pd
#globals
a=.37; z=.5*a; Ter=.347; eta=.14; st=.0001; sz=.0001; s2=.01; xpo=[12, 12.29]
mu_ss=-2.17; ssTer=.099; ssRe_TB=.653; ssPro_TB=.6; nt=3000; sTB=.00001; ssTer_var=.0001

#ssRe
ssdlist=[.4, .35, .3, .25, .20]
#ssPro
pGo_list=[0, .2, .4, .6, .8, 1]
pSSD=.450
vlist_bsl=[0.073, 0.26, 0.4385, 0.601, 0.93, 1.09]
vlist_pnl=[0.05, 0.23, 0.425, 0.601, 0.93, 1.09]

# %% [markdown]
# #ssRe BSL

# %%
ssex=reload(ssex); ss=reload(ss)
rbsl_rt=[]; rbsl_p=[]; rbsl_sacc=[]
gp={'a':a, 'z':z, 'v':0.611, 'Ter':Ter, 'eta':eta, 'st':st, 'sz':sz, 's2':s2}
for ssd in ssdlist:
    sp={'mu_ss':mu_ss, 'pGo':.5, 'ssd':ssd, 'ssTer':ssTer, 'ssTer_var':ssTer_var}
    out=ss.set_model(gParams=gp, sParams=sp, ntrials=nt, timebound=ssRe_TB, stb=sTB, 
                     t_exp=True, analyze=True, exp_scale=xpo, visual=False, true_onsets=True, task='ssRe')
    rbsl_rt.append(out[0]); rbsl_p.append(out[1]); rbsl_sacc.append(out[2])
    print "SSD=%s : Go RT = %s \n%sP(Stop) = %s\n%sStop Acc = %s\n" % (str(ssd*1000)[:3], str(out[0])[:7]," "*10, 
                                                                       str(out[1])[:7], " "*10, str(out[2])[:7])
rbsl_GoRT=np.mean(rbsl_rt)
# Out:
# SSD=400 : Go RT = 0.56383
#           P(Stop) = 0.0775
#           Stop Acc = 0.13715
#
# SSD=350 : Go RT = 0.56365
#           P(Stop) = 0.2665
#           Stop Acc = 0.50097
# SSD=300 : Go RT = 0.56179
#           P(Stop) = 0.4695
#           Stop Acc = 0.91188
# SSD=250 : Go RT = 0.56517
#           P(Stop) = 0.483
#           Stop Acc = 0.99895
# SSD=200 : Go RT = 0.56207
#           P(Stop) = 0.506
#           Stop Acc = 1.0

# %% [markdown]
# #ssRe PNL

# %%
ssex=reload(ssex); ss=reload(ss)
rpnl_rt=[]; rpnl_p=[]; rpnl_sacc=[]
gp={'a':a, 'z':z, 'v':0.548, 'Ter':Ter, 'eta':eta, 'st':st, 'sz':sz, 's2':s2}
for ssd in ssdlist:
    sp={'mu_ss':mu_ss, 'pGo':.5, 'ssd':ssd, 'ssTer':ssTer, 'ssTer_var':ssTer_var}
    out=ss.set_model(gParams=gp, sParams=sp, ntrials=nt, timebound=ssRe_TB, stb=sTB, 
                     t_exp=True, analyze=True, exp_scale=xpo, visual=False, true_onsets=True, task='ssRe')
    rpnl_rt.append(out[0]); rpnl_p.append(out[1]); rpnl_sacc.append(out[2])
    print "SSD=%s : Go RT = %s \n%sP(Stop) = %s\n%sStop Acc = %s\n" % (str(ssd*1000)[:3], str(out[0])[:7]," "*10, 
                                                                       str(out[1])[:7], " "*10, str(out[2])[:7])
rpnl_GoRT=np.mean(rpnl_rt)
# Out:
# SSD=400 : Go RT = 0.57256
#           P(Stop) = 0.121
#           Stop Acc = 0.21052
#
# SSD=350 : Go RT = 0.57422
#           P(Stop) = 0.3025
#           Stop Acc = 0.58662
# SSD=300 : Go RT = 0.57055
#           P(Stop) = 0.4915
#           Stop Acc = 0.92864
# SSD=250 : Go RT = 0.57307
#           P(Stop) = 0.513
#           Stop Acc = 1.0
# SSD=200 : Go RT = 0.57259
#           P(Stop) = 0.5165
#           Stop Acc = 1.0

# %% [markdown]
# ______
# #ssRe Summary Plots
# ______

# %%
psy=reload(psy)
rbsl=np.array(rbsl_sacc, dtype='float')[::-1]
rpnl=np.array(rpnl_sacc, dtype='float')[::-1]

psy.fit_scurves(ysim=[rbsl, rpnl], task='ssRe')
psy.plot_goRTs(sim_rt=np.array([rbsl_GoRT, rpnl_GoRT]), task='ssRe')
# Out:
# [ 20.  25.  30.  35.  40.]
# [ 0.994  0.982  0.896  0.504  0.103]
# EmpBSL PSE = 3503.
#
# [ 20.  25.  30.  35.  40.]
# [ 0.993  0.985  0.925  0.594  0.181]
# EmpPNL PSE = 3590.
#
# [ 20.  25.  30.  35.  40.]
# [ 1.          0.99895178  0.91188119  0.50097466  0.13715455]
# SimBSL PSE = 3500.
#
# [ 20.  25.  30.  35.  40.]
# [ 1.          1.          0.92864125  0.58662614  0.21052632]
# SimPNL PSE = 3586.

# %% [markdown]
# #ssPro BSL

# %%
ssex=reload(ssex); ss=reload(ss)
pbsl_rt=[]; pbsl_p=[]; pbsl_sacc=[]
for i,v in enumerate(vlist_bsl):
    gp={'a':a, 'z':z, 'v':v, 'Ter':Ter, 'eta':eta, 'st':st, 'sz':sz, 's2':s2}
    sp={'mu_ss':mu_ss, 'pGo':pGo_list[i], 'ssd':pSSD, 'ssTer':ssTer, 'ssTer_var':ssTer_var}
    out=ss.set_model(gParams=gp, sParams=sp, ntrials=nt, timebound=ssPro_TB, stb=sTB, 
        t_exp=True, analyze=True, exp_scale=xpo, visual=False, true_onsets=True, task='ssPro') 
    pbsl_rt.append(out[0]); pbsl_p.append(out[1]); pbsl_sacc.append(out[2])
    print "Vg=%s : Go RT = %s \n%sP(Stop) = %s\n%sStop Acc = %s\n" % (str(v), str(out[0])[:7]," "*10, 
                                                                       str(out[1])[:7], " "*10, str(out[2])[:7])
pbsl_GoRT=np.mean(pbsl_rt[1:])
# Out:
# Vg=0.073 : Go RT = nan
#           P(Stop) = 0.92366
#           Stop Acc = 0.92366
#
# Vg=0.26 : Go RT = 0.57081
#           P(Stop) = 0.733
#           Stop Acc = 0.72912
# Vg=0.4385 : Go RT = 0.56030
#           P(Stop) = 0.46966
#           Stop Acc = 0.46422
# Vg=0.601 : Go RT = 0.55065
#           P(Stop) = 0.23766
#           Stop Acc = 0.22975
# Vg=0.93 : Go RT = 0.51642
#           P(Stop) = 0.019
#           Stop Acc = 0.02211
# Vg=1.09 : Go RT = 0.49860
#           P(Stop) = 0.003
#           Stop Acc = nan

# %% [markdown]
# #ssPro PNL

# %%
ssex=reload(ssex); ss=reload(ss)
ppnl_rt=[]; ppnl_p=[]; ppnl_sacc=[]
for i,v in enumerate(vlist_pnl):
    gp={'a':a, 'z':z, 'v':v, 'Ter':Ter, 'eta':eta, 'st':st, 'sz':sz, 's2':s2}
    sp={'mu_ss':mu_ss, 'pGo':pGo_list[i], 'ssd':pSSD, 'ssTer':ssTer, 'ssTer_var':ssTer_var}
    out=ss.set_model(gParams=gp, sParams=sp, ntrials=nt, timebound=ssPro_TB, stb=sTB, 
        t_exp=True, analyze=True, exp_scale=xpo, visual=False, true_onsets=True, task='ssPro') 
    ppnl_rt.append(out[0]); ppnl_p.append(out[1]); ppnl_sacc.append(out[2])
    print "Vg=%s : Go RT = %s \n%sP(Stop) = %s\n%sStop Acc = %s\n" % (str(v), str(out[0])[:7]," "*10, 
                                                                       str(out[1])[:7], " "*10, str(out[2])[:7])
ppnl_GoRT=np.mean(ppnl_rt[1:])
# Out:
# Vg=0.05 : Go RT = nan
#           P(Stop) = 0.92833
#           Stop Acc = 0.92833
#
# Vg=0.23 : Go RT = 0.57174
#           P(Stop) = 0.76766
#           Stop Acc = 0.76567
# Vg=0.425 : Go RT = 0.56192
#           P(Stop) = 0.50066
#           Stop Acc = 0.49859
# Vg=0.601 : Go RT = 0.55049
#           P(Stop) = 0.221
#           Stop Acc = 0.21
# Vg=0.93 : Go RT = 0.51659
#           P(Stop) = 0.01233
#           Stop Acc = 0.00874
# Vg=1.09 : Go RT = 0.49903
#           P(Stop) = 0.00266
#           Stop Acc = nan

# %% [markdown]
# ______
# #ssPro Summary Plots
# ______

# %%
psy=reload(psy)
pbsl=np.array(pbsl_p, dtype='float')
ppnl=np.array(ppnl_p, dtype='float')

psy.fit_scurves(ysim=[pbsl, ppnl], task='ssPro')
psy.plot_goRTs(sim_rt=np.array([pbsl_GoRT, ppnl_GoRT]), task='ssPro')
# Out:
# [  0.   2.   4.   6.   8.  10.]
# [ 0.931  0.744  0.471  0.24   0.034  0.005]
# EmpBSL PSE = 38.31
#
# [  0.   2.   4.   6.   8.  10.]
# [ 0.926  0.767  0.485  0.241  0.036  0.006]
# EmpPNL PSE = 39.55
#
# [  0.   2.   4.   6.   8.  10.]
# [ 0.92366667  0.733       0.46966667  0.23766667  0.019       0.003     ]
# SimBSL PSE = 37.98
#
# [  0.   2.   4.   6.   8.  10.]
# [ 0.92833333  0.76766667  0.50066667  0.221       0.01233333  0.00266667]
# SimPNL PSE = 39.88
