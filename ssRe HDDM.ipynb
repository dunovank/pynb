# %%
from __future__ import division
import pandas as pd
import hddm
import seaborn as sns
import os
from radd import ss, psy, simfx, utils, ft, qsim
from radd.simfx import sim_radd, sim_ss, sustained_integrator, integrator, thal

# %%
utils=reload(utils); ft=reload(ft)
pth=utils.find_path()
data=pd.read_csv(pth+"CoAx/SS/Reactive/Re_AllSx_Data.csv")

# %% [markdown]
# # Individual sx fits to full vbias model, BSL vs. PNL

# %%
ft=reload(ft)
os.chdir(pth+"CoAx/SS/HDDM/Reactive/vbias_full/")
vbias_stats=ft.fit_sxhddm(data, depends_on={'v':'Cond'}, bias=True, informative=True, include=['a', 't', 'v', 'z', 'sv'], 
                   task='ssRe', save_str="vBP")
# Out:
#  [                  0%                  ] 138 of 50000 complete in 0.5 sec
#  [                  0%                  ] 256 of 50000 complete in 1.0 sec
#  [                  0%                  ] 413 of 50000 complete in 1.5 sec
#  [                  1%                  ] 572 of 50000 complete in 2.0 sec
#  [                  1%                  ] 725 of 50000 complete in 2.5 sec
#  [                  1%                  ] 881 of 50000 complete in 3.0 sec
#  [                  2%                  ] 1034 of 50000 complete in 3.5 sec
#  [                  2%                  ] 1191 of 50000 complete in 4.0 sec
#  [-                 2%                  ] 1345 of 50000 complete in 4.5 sec
#  [-                 3%                  ] 1500 of 50000 complete in 5.0 sec
#  [-                 3%                  ] 1656 of 50000 complete in 5.5 sec
#  [-                 3%                  ] 1807 of 50000 complete in 6.0 sec
# ...

# %%
vbias_summary=ft.stats_summary(vbias_stats)
vbias_summary
# Out:
#             2.5q        25q        50q        75q      97.5q       mean  \
# param
# a       3.083409   3.809130   4.273840   4.805617   6.047514   4.349144
# sv      0.008772   0.088732   0.187563   0.320739   0.631487   0.222900
# t       0.257802   0.292560   0.308465   0.322827   0.346204   0.306783
# v(bsl)  9.645876  10.614381  11.151165  11.703528  12.814163  11.170379
# v(pnl)  9.309085  10.275814  10.810322  11.361077  12.472189  10.830050
# z       0.194370   0.290400   0.348117   0.407724   0.519262   0.350330
#
#              std
# param
# a       0.759426
# sv      0.169622
# t       0.022639
# v(bsl)  0.807156
# v(pnl)  0.805870
# z       0.084019

# %% [markdown]
# # Individual Sx Parameter Simulations (vbias, BSL vs. PNL)

# %%
qsim=reload(qsim); ss=reload(ss)

sxdf=qsim.sim_sx(vbias_stats, mfx=simfx.thal, ntrials=1000, tb=.650, task='ssRe')

# %%
#EmpBSL_RT=data.query('Cond=="bsl"').describe().ix['mean', 'rt']
#EmpPNL_RT=data.query('Cond=="pnl"').describe().ix['mean', 'rt']
#estd1=data.query('Cond=="bsl"').describe().ix['std', 'rt']
#estd2=data.query('Cond=="pnl"').describe().ix['std', 'rt']

SimBSL_RT=sxdf.query('condition=="bsl"').describe().ix['mean', 'go_rt_all']
SimPNL_RT=sxdf.query('condition=="pnl"').describe().ix['mean', 'go_rt_all']
sstd1=sxdf.query('condition=="bsl"').describe().ix['std', 'go_rt_cor']
sstd2=sxdf.query('condition=="pnl"').describe().ix['std', 'go_rt_cor']

sim_rt=np.array([SimBSL_RT, SimPNL_RT]) 
emp_rt=np.array([.565625, .573415]) #np.array([EmpBSL_RT, EmpPNL_RT])
sim_err=np.array([sstd1, sstd2])/sqrt(len(sxdf)/2) 
emp_err=emp_err = np.array([.0029, .0024]) #np.array([estd1, estd2])/sqrt(60)

# %%
psy=reload(psy)
psy.go_rt_evs(sim_rt=sim_rt, emp_rt=emp_rt, sim_err=sim_err, emp_err=emp_err, task='ssRe')

# %%
print "P(vbsl > vpnl) = ", (bsl.trace() > pnl.trace()).mean()
#print "P(LL > WL) = ", (v_LL.trace() > v_WL.trace()).mean()
# Out:
# P(vbsl > vpnl) =  0.883866666667

# %% [markdown]
# # ssRe Data formatting for HDDM

# %%
re=pd.read_csv("/Users/kyle/Dropbox/CoAx/SS/Reactive/SS_v1p3_fullsummary.dat", sep="\t")

re['RT_sec']=re['RT'].copy()*.001
re=re.rename(columns={'RT':'RT_msec', 'RT_sec':'rt'}, axis=1)

re.ix[re['Cond']==1, 'Cond']='bsl'
re.ix[re['Cond']==2, 'Cond']='pnl'

re['response']=re['Keypress'].copy()#np.zeros(len(re))
re['corr']=np.zeros(len(re))
re.ix[(re['GoTrial']==1)&(re['Keypress']==1), 'corr']=1
re.ix[(re['GoTrial']==0)&(re['Keypress']==1), 'corr']=0

re_df=re.ix[re['corr']==1]

re_sx=re_df['SubID']
re_intsx=[int(subj[1:]) for subj in re_sx]
re_df['subj_idx']=re_intsx

re_df=re_df[['subj_idx', 'GoTrial', 'StopSignal', 'Cond', 'response', 'corr', 'rt']]

re_df.to_csv("/Users/kyle/Dropbox/CoAx/SS/Reactive/Re_AllSx_Data.csv", index=False)

# %% [markdown]
# # RT Distributions (BSL v. PNL)

# %%
ion()

sns.set_style(style='white')
sns.set_context('talk')

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(211, xlabel='RT', ylabel='count', title='Baseline Condition')
ax2 = fig.add_subplot(212, xlabel='RT', ylabel='count', title='Penalty Condition')

re_df[re['Cond']=='bsl'].rt.hist(bins=50, histtype='stepfilled', color='green', ax=ax, alpha=.6)
re_df[re['Cond']=='pnl'].rt.hist(bins=50, histtype='stepfilled',color='red', ax=ax2, alpha=.6)

ax.set_xlim(.4,.66)
ax2.set_xlim(.4,.66)
plt.tight_layout()
