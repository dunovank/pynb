# %% [raw]
#        SSD = 450ms
#         Target Onset = 500ms
#         Time Bound = 600ms
#
#         #__________________________________________PROACTIVE BSL_________________________________________#
#
#         ##______P(STOP)_________________________________GO RT__________________________PSE______________##
#
#         |###      |  Mean   |		                  Mean    std        sem      Mean     std    sem ###
#         |:-------:|:-------:|
#         |p(Go=100)|    0.005|          p(Go=100) =  530.01   13.90      1.78     0.380	   0.068  0.009
#         |p(Go=80) |    0.034|          p(Go=80)  =  533.59   12.58      1.61
# 	    |p(Go=60) |    0.240|          p(Go=60)  =  542.7    6.46       0.83
# 	    |p(Go=40) |    0.471|          p(Go=40)  =  544.15   7.23       0.93
# 	    |p(Go=20) |    0.744|          p(Go=20)  =  545.32   7.90       1.01
#         |p(Go=0)  |    0.931|		     p(Go=0)   = N/A      N/A        N/A
#
#
#         __________________________________________PROACTIVE PNL_________________________________________
#
#         _______P(STOP)__________________________________GO RT_________________________PSE_______________
#
#                       Mean		                   Mean    std    sem          Mean    std    sem
#         ________________________________________________________________________________________________
#         p(Go=100) =  0.006          p(Go=100) =  529.97	  13.77   1.76        0.387	  0.074	 0.009
#         p(Go=80)  =  0.036          p(Go=80)  =  534.08	  12.64	  1.64
#         p(Go=60)  =  0.241          p(Go=60)  =  542.92	  6.15	  0.75
# 	    p(Go=40)  =  0.485          p(Go=40)  =  544.32	  6.19	  0.64
# 	    p(Go=20)  =  0.767          p(Go=20)  =  545.43	  7.19	  0.83
# 	    p(Go=0)   =  0.926          p(Go=0)   =  N/A      N/A     N/A

# %% [markdown]
# #PROACTIVE BSL#
# |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
# |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
# |p(Go=100)| 0.005   | 530.01  |  13.90  | 1.78    |  0.380	 | 0.068 |  0.009|
# |p(Go=80) | 0.034   | 533.59  |  12.58	 | 1.61   |          |       |   --  |
# |p(Go=60) | 0.240   | 542.7   |  6.46   | 0.83    |          |       |   --  |
# |p(Go=40) | 0.471   | 544.15  |  7.23   | 0.93    |          |       |   --  |
# |p(Go=20) | 0.744   | 545.32  |  7.90   | 1.01    |          |       |   --  |
# |p(Go=0)  | 0.931   | N/A     |  N/A    | N/A     |          |       |   --  |
#
#
# #PROACTIVE PNL#
# |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
# |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
# |p(Go=100)| 0.006   | 529.97  |  13.77  |1.76     |  0.387	 |0.074  |  0.009|
# |p(Go=80) | 0.036   | 534.08  |  12.64	|1.64     |          |       |       |
# |p(Go=60) | 0.241   | 542.92  |  6.15	|0.75     |          |       |       |
# |p(Go=40) | 0.485   | 544.32  |  6.19	|0.64     |          |       |       |
# |p(Go=20) | 0.767   | 545.43  |  7.19	|0.83     |          |       |       |
# |p(Go=0)  | 0.926   | N/A     |   N/A   | N/A     |          |       |       |
#
# #PROACTIVE BSL#
# |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
# |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
# |p(Go=100)| 0.005   | 530.01  |  13.90  | 1.78    |  0.380	 | 0.068 |  0.009|
# |p(Go=80) | 0.034   | 533.59  |  12.58	 | 1.61   |    --    |   --  |   --  |
# |p(Go=60) | 0.240   | 542.7   |  6.46   | 0.83    |    --    |   --  |   --  |
# |p(Go=40) | 0.471   | 544.15  |  7.23   | 0.93    |    --    |   --  |   --  |
# |p(Go=20) | 0.744   | 545.32  |  7.90   | 1.01    |    --    |   --  |   --  |
# |p(Go=0)  | 0.931   | N/A     |  N/A    | N/A     |    --    |   --  |   --  |
#
#
# #PROACTIVE PNL#
# |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
# |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
# |p(Go=100)| 0.006   | 529.97  |  13.77  |1.76     |  0.387	 |0.074  |  0.009|
# |p(Go=80) | 0.036   | 534.08  |  12.64	|1.64     |    --    |  --   |   --  |
# |p(Go=60) | 0.241   | 542.92  |  6.15	|0.75     |    --    |  --   |   --  |
# |p(Go=40) | 0.485   | 544.32  |  6.19	|0.64     |    --    |  --   |   --  |
# |p(Go=20) | 0.767   | 545.43  |  7.19	|0.83     |    --    |  --   |   --  |
# |p(Go=0)  | 0.926   | N/A     |   N/A   | N/A     |    --    |  --   |   --  |

# %% [markdown]
#  #                         PROACTIVE BSL                             #
#
#  |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
#  |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
#  |p(Go=100)|    0.005| 530.01  | 13.90   |   1.78  |   0.380  | 0.068 | 0.009 |
#  |p(Go=80) |    0.034| 533.59  | 12.58   |   1.61  |          |       |       |
#  |p(Go=60) |    0.240| 542.7   | 6.46    |   0.83  |          |       |       |
#  |p(Go=40) |    0.471| 544.15  | 7.23    |   0.93  |          |       |       |
#  |p(Go=20) |    0.744| 545.32  | 7.90    |   1.01  |          |       |       |
#  |p(Go=0)  |    0.931| N/A     | N/A     |   N/A   |          |       |       |
#
#
#  #                         PROACTIVE PNL                             #
#
#  |Condition| P(Stop) | Go RT   | std     |  RT sem |   PSE    |PSE_std|PSE_sem|
#  |:-------:|:-------:|:-------:|:-------:|:-------:|:--------:|:------|:-----:|
#  |p(Go=100)| 0.006   | 529.97  |  13.77  |1.76     |  0.387	  |0.074  |  0.009|
#  |p(Go=80) | 0.036   | 534.08  |  12.64	 |1.64     |          |       |       |
#  |p(Go=60) | 0.241   | 542.92  |  6.15	 |0.75     |          |       |       |
#  |p(Go=40) | 0.485   | 544.32  |  6.19	 |0.64     |          |       |       |
#  |p(Go=20) | 0.767   | 545.43  |  7.19	 |0.83     |          |       |       |
#  |p(Go=0)  | 0.926   | N/A     |   N/A   | N/A     |          |       |       |
